# %% [markdown]
# David Liu
#
# BAN 693
#
#
# https://codehandbook.org/how-to-read-email-from-gmail-using-python/
#
# https://machinelearningmastery.com/text-generation-lstm-recurrent-neural-networks-python-keras/

# %% [markdown]
# ## Preliminary Steps

# %% [markdown]
# Setting the authentification info and packages, and checking for available email folders in my gmail

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Dropout
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime, os, glob
import email, imaplib
import re

# %%
import imaplib
mail = imaplib.IMAP4_SSL('imap.gmail.com')
mail.login('david92liu@gmail.com', '********')  # this is not my actual gmail pw. I took it out for security reasons
print(mail.list())
# Out:
# ('OK', [b'(\\HasNoChildren) "/" "Drafts"', b'(\\HasNoChildren) "/" "INBOX"', b'(\\HasNoChildren) "/" "Orders"', b'(\\HasNoChildren) "/" "Other"', b'(\\HasNoChildren) "/" "Outbox"', b'(\\HasNoChildren) "/" "Sent"', b'(\\HasNoChildren) "/" "Trash"', b'(\\HasChildren \\Noselect) "/" "[Gmail]"', b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"', b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"', b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"', b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"', b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"', b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"', b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %% [markdown]
# generates search criterias

# %%
cwd = os.getcwd()

EMAIL_UN = 'david92liu@gmail.com'
EMAIL_PW = '********'    # this is not my actual gmail pw. I took it out for security reasons

# %% [markdown]
# ## Email Extraction, Cleaning, and Transforming
# ### Data Extraction and First Cleaning

# %%
Ignore_email_list = ["Please join Zoom meeting in progress"]

# %% [markdown]
# Method for extracting the texts from emails. Only emails that are sent by me will be extracted. Codes below also does some preliminary cleaning:
# - Reply emails contains a copy of the parent email. Codes below will attempt to remove them, althought the process isn't perfect.
# - Forwarded emails will also be removed.

# %%
def email_extraction():
    body_text = []
    
    un = EMAIL_UN
    pw = EMAIL_PW
    url = 'imap.gmail.com'

    m = imaplib.IMAP4_SSL(url,993)
    m.login(un,pw)
    #m.select("Sent") 
    m.select('"[Gmail]/Sent Mail"')  
    data = m.search(None, 'ALL')
    mail_ids = data[1]

    id_list = mail_ids[0].split()   
    first_email_id = int(id_list[0])
    latest_email_id = int(id_list[-1])

    for i in range(latest_email_id,latest_email_id-500, -1):                
        
        data = m.fetch(str(i), '(RFC822)' )

        for response_part in data:
            arr = response_part[0]
            if isinstance(arr, tuple):
                msg = email.message_from_string(str(arr[1],'utf-8'))
                email_from = msg['from']
                email_subject = msg['subject']
                
                try:
                    if (email_from == "David Liu <david92liu@gmail.com>") and (email_subject not in Ignore_email_list) and (email_subject.startswith("Fwd:") == False):

                        email_content = None

                        if msg.is_multipart():
                            email_content = msg.get_payload()[0].get_payload()      
                        else:
                            email_content = msg.get_payload()

                        if email_subject.startswith("Re:"):
                            email_content = email_content.split("On")[0]
                            body_text.append(email_content)
                        else:
                            body_text.append(email_content)
                except:
                    print("\n\nThe email that had issues was the following: ")
                    print(email_content)
    m.close()
    m.logout()
    
    return body_text

# %%
extracted_emails = email_extraction()
# Out:
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B00CC978>, <email.message.Message object at 0x000001C7B01745F8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0367F98>, <email.message.Message object at 0x000001C7CF5B80B8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0174470>, <email.message.Message object at 0x000001C793F84828>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B2AEEC50>, <email.message.Message object at 0x000001C78F064978>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C795C65518>, <email.message.Message object at 0x000001C7838E7F60>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C795C657B8>, <email.message.Message object at 0x000001C7838E7F60>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7AD03F400>, <email.message.Message object at 0x000001C7AD03F5F8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0F32278>, <email.message.Message object at 0x000001C7B0F32240>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B20CD358>, <email.message.Message object at 0x000001C7AD03F978>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7AD03F208>, <email.message.Message object at 0x000001C7AD03FAC8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7AD03F4A8>, <email.message.Message object at 0x000001C7AD03FB00>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C789211E10>, <email.message.Message object at 0x000001C7BA5A74A8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0F32278>, <email.message.Message object at 0x000001C7BA5A7358>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7748>, <email.message.Message object at 0x000001C7BA5A7908>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7550>, <email.message.Message object at 0x000001C7BA5A7E80>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A79B0>, <email.message.Message object at 0x000001C7BA5A7E48>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7E80>, <email.message.Message object at 0x000001C7BA5A7EF0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7E48>, <email.message.Message object at 0x000001C7BA5A74E0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7E80>, <email.message.Message object at 0x000001C7BA5A7860>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A74E0>, <email.message.Message object at 0x000001C7BA5A7A20>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7E80>, <email.message.Message object at 0x000001C7BA5A7BA8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7BA5A7E80>, <email.message.Message object at 0x000001C7BA5A7400>]
#
#
# The email that had issues was the following:
# http://www.calacademy.org:8080/sites/default/files/assets/docs/pdf/occ_pap_161_2013_swa_bib_2nd_ed_web_version.pdf
#
#
#
# The email that had issues was the following:
# Happy birthday! Hope the doc and the call went well. As always, let me know w=
# henever you need my help.
#
# David
#
# Sent from my iPhone
#
# >
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D9908>, <email.message.Message object at 0x000001C7B90D91D0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D97B8>, <email.message.Message object at 0x000001C7B90D3B38>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D75C0>, <email.message.Message object at 0x000001C7B90D3CC0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3164198>, <email.message.Message object at 0x000001C7B90D7080>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B20B02E8>, <email.message.Message object at 0x000001C7B90D9518>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3309D68>, <email.message.Message object at 0x000001C7B33095F8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3309550>, <email.message.Message object at 0x000001C7B20B0390>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B20B03C8>, <email.message.Message object at 0x000001C7B20B0898>]
#
#
# The email that had issues was the following:
# Hi Larry,
#
# Here's the serial number for our PCA-96 flow cytometer as requested.
# GTI S/N: GTI-96-020200
#
# Again, we just need the software to connect our laptop to the PCA-96.
#
# If there's a direct link to the software, that would be great. If not, let
# me know, and I will see what I can do. Thanks again for your help.
#
# David
#
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3164B38>, <email.message.Message object at 0x000001C7B90D7EF0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3164B38>, <email.message.Message object at 0x000001C7B31642B0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B3164860>, <email.message.Message object at 0x000001C7B90D7CF8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D7CF8>, <email.message.Message object at 0x000001C7B90D7A58>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D7CF8>, <email.message.Message object at 0x000001C7B90D79B0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B26B7320>, <email.message.Message object at 0x000001C7B31642B0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D7B38>, <email.message.Message object at 0x000001C7B90D36A0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B90D30F0>, <email.message.Message object at 0x000001C7B26B74E0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7AC944E48>, <email.message.Message object at 0x000001C7B90D7630>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7C1690240>, <email.message.Message object at 0x000001C7B90D9A20>, <email.message.Message object at 0x000001C7B90D94E0>, <email.message.Message object at 0x000001C7B04834E0>, <email.message.Message object at 0x000001C7B90D9208>, <email.message.Message object at 0x000001C789211B00>, <email.message.Message object at 0x000001C789211BE0>, <email.message.Message object at 0x000001C789211080>]
#
#
# The email that had issues was the following:
# Hey Charles,
#
# Probably won't be in tomorrow given tomorrow's schedule. But besides lab
# cleaning, is there anything else we'll be doing on Tuesday?
#
# Cheers,
#
# David
#
#
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C789211A90>, <email.message.Message object at 0x000001C7B90D3E10>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0F1EEF0>, <email.message.Message object at 0x000001C7B2D12780>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B0F1EE48>, <email.message.Message object at 0x000001C7B00CC470>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7B01747B8>, <email.message.Message object at 0x000001C7AD104940>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F5450550>, <email.message.Message object at 0x000001C7AD1043C8>]
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F544B390>, <email.message.Message object at 0x000001C7AD1043C8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F5450EF0>, <email.message.Message object at 0x000001C7B261C7F0>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F54495F8>, <email.message.Message object at 0x000001C7F4FBA6D8>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F544B668>, <email.message.Message object at 0x000001C7AD0F9240>]
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001C7F5449908>, <email.message.Message object at 0x000001C789211550>]

# %%
print("Number of emails extracted: ")
print(len(extracted_emails))
# Out:
# Number of emails extracted:
# 396

# %% [markdown]
# Below shows how the extracted email data looks like

# %%
extracted_emails
# Out:
# ['this is a response\r\n\r\n',
#  'Hi David,\r\n\r\nThis is a sample email.\r\n',
#  'https://www.walmart.com/ip/Apple-iPad-mini-Wi-Fi-64GB/207104625\r\n\r\nhttps://www.bestbuy.com/site/apple-10-2-inch-ipad-latest-model-with-wi-fi-3=\r\n2gb-space-gray/5199701.p?skuId=3D5199701\r\n\r\nhttps://www.adorama.com/acmyla2lla.html?gclid=3DCj0KCQiAzZL-BRDnARIsAPCJs73=\r\nIvW8I6hSvm04SkA0uSh1H4tsa0sjbo7Q-uuhvrndPUyO2jg-Md6QaAt_5EALw_wcB&utm_sourc=\r\ne=3Dadl-gbase\r\n\r\nOlder Model:\r\nhttps://www.walmart.com/ip/Apple-iPad-4-with-Retina-Display-32GB-Wi-Fi-4th-=\r\nGeneration-in-Black/22288800?wmlspartner=3Dwlpa&selectedSellerId=3D9186&&ad=\r\nid=3D22222222227016434816&wl0=3D&wl1=3Dg&wl2=3Dc&wl3=3D343334214440&wl4=3Dp=\r\nla-486397163036&wl5=3D9032013&wl6=3D&wl7=3D&wl8=3D&wl9=3Dpla&wl10=3D1170193=\r\n45&wl11=3Donline&wl12=3D22288800&veh=3Dsem&gclid=3DCj0KCQiAzZL-BRDnARIsAPCJ=\r\ns71ZBDQi_Vj6RvtNPGp55mVHFKiQ3f0UXexwDyKS6BIc_-X3kOA0wusaAmQ5EALw_wcB\r\n',
#  'Hi Han,\r\n\r\n\r\n\r\nThis is just a quick follow-up from yesterday. I would like to thank you\r\nfor spending an extended period of time interviewing me, and allowing me\r\nto have a better understanding of what the contract position entails. I am\r\nexcited for the possibility of working with the health strategic initiative\r\nteam to build data pipelines and machine learning functions for health and\r\nwellness applications.\r\n\r\n\r\n\r\nLooking forward to hearing back about any updates on the position.\r\n\r\n\r\n\r\nBest Regards,\r\n\r\n\r\n\r\nDavid\r\n\r\n',
#  'Greetings Han,\r\n\r\nI am guaranteed to be free on Friday 10/9 at 4 PM. I look forward to\r\nspeaking with you soon!\r\n\r\nThanks,\r\nDavid\r\n\r\n',
#  'Hi Andy,\r\n\r\nThat is great! I look forward to speaking with your lead. Should I be\r\nexpecting an email some time later today?\r\n\r\nThanks,\r\nDavid\r\n\r\n',
#  "Hi Andy,\r\n\r\nThis is just a follow up on our previous conversation regarding the\r\ncontract positions. Since the positions are still in the works, would it be\r\nnecessary for me to check in again at a later date if I am still\r\ninterested? And if so, when do you think would be a good time for me to do\r\nso? I ask because it was unclear to me during our previous correspondence\r\nwhether we were planning to further discuss the topic, or whether I should\r\ncheck in later. If there isn't much information on the planned contract\r\npositions at the moment, that is fine too. In any case, thank you so much\r\nfor your time and patience regarding my inquiries about these\r\nopportunities, thus far.\r\n\r\nRegards,\r\nDavid\r\n\r\n",
#  'Hi Andy,\r\n\r\nI completely understand. The contractor position sounds great and I am\r\ncertainly open to further discuss this opportunity. What would be the next\r\nstep?\r\n\r\nRegards,\r\nDavid\r\n\r\n',
#  'Hi Andy,\r\n\r\nI would like to check in again on the status of the Health Strategic\r\nInitiatives data engineering position and whether it is still available. I\r\nam still very much interested in the position and I look forward to hearing\r\nback about any updates on the situation.\r\n\r\nThanks,\r\nDavid\r\n\r\n',
#  'Hi Xiaoyi,\r\n\r\nI checked in with Andy yesterday, and he responded earlier today. According\r\nto him, he does not know the headcount for FY2021 and told me to check in\r\nlater as he will find out some time between now and October 1. Would you\r\nhappen to know how long does this usually take?\r\n\r\nThanks,\r\nDavid\r\n\r\n',
#  "Hi Andy,\r\n\r\nThanks for the update about the situation. I will check back around 3 weeks\r\nfrom now, or some time during the week of September 21, if you don't mind.\r\n\r\nThanks,\r\nDavid\r\n\r\n",
#  'Greetings Andy,\r\n\r\nWe previously spoke over the phone on June 7 regarding the Health Strategic\r\nInitiatives data engineer position, and you suggested that I contact you\r\nagain about it during early September of this year for a possible formal\r\nscreening. Is the position still open at this time? If so, what would be\r\nthe next step? Thank you very much.\r\n\r\nDavid\r\n\r\n',
#  "Hi Xiaoyi,\r\n\r\nIt has certainly been a while since we last spoke, so thanks for reaching\r\nout to me and for the reminder and tips!\r\n\r\nMy apologies for the lack of news about my status recently, but I am\r\ncurrently finishing up the last week of my summer session so I have not\r\nbeen sending out many resumes for the last couple weeks. I plan on resuming\r\nmy job apps after this week once I have more time. Project is fine. I was\r\nsimply reworking one of my older data collection projects and applying\r\nmachine learning techniques to better fit the job description, but there is\r\nstill more I plan on doing with it.\r\n\r\nI will definitely be contacting you soon about apple positions, so we'll be\r\nin touch!\r\n\r\nThanks,\r\nDavid\r\n\r\n",
#  "Hi Xiaoyi,\r\n\r\nYes, that's basically what he suggested: to talk about the methods I used\r\nin my project and why, any possible issues there might be, and, most\r\nimportantly, to not take the efficiency and speed of data processing tools\r\nfor granted. And yes, I intend to build a project in the time remaining as\r\nyou suggested that it might be better if it is new and related to the\r\nposition, and I will also have a good amount of machine learning resources\r\nto work with as I am taking it as a course this summer.\r\n\r\nI will definitely be applying for more positions at Apple in the near\r\nfuture, so thanks, and, again, we will be in touch! I will take a pause for\r\nmaybe a month, or at least until I finish this summer, as it appears that a\r\nlot of data positions utilizes machine learning and I would really want to\r\nknow what the subject is all about.\r\n\r\nDavid\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n",
#  "Hi Xiaoyi,\r\n\r\nWe spoke for around 40 minutes, and he just wanted to look into my\r\nbackground while I had the chance to learn more about the position. There\r\nwas actually nothing technical about it. I told him that I will graduate\r\nthis coming December, so he told me to shoot him an email during early\r\nSeptember which is when he will set up a formal interview. Here's hoping\r\nthat the position does not fill by then.\r\n\r\nI also asked him about the interview, and he told me that it will be a 1\r\nhour presentation about one of my projects but gave no more details or\r\nwhether it will be technical or not. Said that if I were to be hired for\r\nthe position, I would be someone who would need to be mentored and grow in\r\nthe position, so I am guessing he is not hiring me for my expertise. I\r\nassume that this sort of interview is pretty unusual for Apple standards?\r\n\r\nRegards,\r\nDavid\r\n\r\n",
#  'Hi Xiaoyi,\r\n\r\nSomeone named Andy Pham contacted me for the Data Engineer, Health\r\nStrategic Initiatives position (Role Number:200172241,\r\nhttps://jobs.apple.com/en-us/details/200172241/data-engineer-health-strateg=\r\nic-initiatives?team=3DSFTWR\r\n).\r\n\r\nWe arranged to speak for a few minutes on a video chat for the coming\r\nTuesday at 2 PM. I am guessing this is just the initial screening to see\r\nwhether I would be a good fit before there would be an interview. Do you\r\nhave any idea about what they might ask or what Apple does differently with\r\nthese screenings?\r\n\r\nThanks,\r\nDavid\r\n\r\n\r\n\r\n',
#  'Hello Andy,\r\n\r\nMarked on calendar. Looking forward to speaking to you soon.\r\n\r\nDavid\r\n\r\n',
#  'Hi Andy,\r\n\r\nI will be available anytime today or at anytime for the rest of this week.\r\nNext week will work as well, but only after 12 PM on Tuesdays and\r\nThursdays. I look forward to speaking with you!\r\n\r\nDavid\r\n\r\n',
#  "Hi Xiaoyi,\r\n\r\nGood to know! I will keep that in mind when applying for Apple jobs in the\r\nfuture.\r\n\r\nSince there isn't many job postings left that match my current skill set, I\r\nwill probably take a hiatus on any new applications at Apple for now. Can't\r\nthank you enough for all your help and thank you for making yourself\r\navailable for sending out resumes for me in the future. If your schedule or\r\nsituation permits, I would like to do this again in the coming months,\r\nassuming that none of my current applications go through.\r\n\r\nCheers,\r\nDavid\r\n\r\n",
#  'Hi Carlos,\r\n\r\nIt has been a while since we took linear algebra together at BCC. I hope\r\nyou are doing well!\r\n\r\nI am not sure if your email was actually meant for me, but, unfortunately,\r\nI am in no position to hand out job opportunities as I am finishing up a\r\ngraduates program and am looking for work positions myself; so it looks\r\nlike we are pretty much in the same boat! Let me know if there is anything\r\nelse I can help you with.\r\n\r\nCheers,\r\n\r\nDavid Liu\r\n\r\n',
#  'Xiaoyi,\r\n\r\nGreat! Thanks again.\r\n\r\nDavid\r\n\r\n',
#  "Forgot to tell you. I did not find any letters for you. I am not sure if\r\nsomebody else is keeping them for you, but I don't think there are any\r\nletters that has your name on it.\r\n\r\nOn Mon, May 18, 2020 at 9:38 PM David Liu <david92liu@gmail.com> wrote:\r\n\r\n> Yes. Okay. I will look for your letters.\r\n>\r\n> On Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wro=\r\nte:\r\n>\r\n>> Hi=EF=BC=81 David=EF=BC=9A\r\n>> Can you put all my letters in the mailbox today?   I'll get it tomorrow\r\n>> morning!  Thank  you!\r\n>>\r\n>> Yours.\r\n>> Yufen Lin\r\n>>\r\n>> =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone\r\n>\r\n>\r\n",
#  [<email.message.Message at 0x1c7b2aeeb00>,
#   <email.message.Message at 0x1c7b0174a58>],
#  "Yes. Okay. I will look for your letters.\r\n\r\nOn Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wrote=\r\n:\r\n\r\n> Hi=EF=BC=81 David=EF=BC=9A\r\n> Can you put all my letters in the mailbox today?   I'll get it tomorrow\r\n> morning!  Thank  you!\r\n>\r\n> Yours.\r\n> Yufen Lin\r\n>\r\n> =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone\r\n",
#  'Okay. I will look out for it.\r\n\r\n',
#  [<email.message.Message at 0x1c7ad0367f0>,
#   <email.message.Message at 0x1c7853722b0>],
#  [<email.message.Message at 0x1c794457ef0>,
#   <email.message.Message at 0x1c7b2d12400>],
#  'Okay\r\n\r\n',
#  'It looks like i received the letters. How do you want me to send the\r\nletters back?\r\n\r\n',
#  'okay. I will look out for it\r\n\r\n',
#  "Hi Joe,\r\n\r\nIn that case, thank you very much for the information. I'll definitely see\r\nwhat I can find and get the resume updated and going.\r\n\r\nDavid\r\n\r\n",
#  'Hi Joe,\r\n\r\nI was recently told about openings at a company called Veeva, and I believe\r\nit was your wife, Mrs. Li, who shared this information, so please give her\r\nmy thanks. I had a chance to look through the company website and there\r\nwere definitely some positions and roles that I found interesting. However,\r\nI could not find anything other than full-time/long-term positions, which I\r\nam not available for at this time. May I ask that she clarify exactly what\r\nthe new positions are, or where on the website can I find them in case I am\r\nlooking at the wrong places? Thank you very much.\r\n\r\nDavid\r\n\r\n',
#  'Hi Joe,\r\n\r\nI figured that I should share this email with you so that you know which\r\nemail I may be contacting you with, and to make sure that I added your\r\nemail correctly.\r\n\r\nThanks again for the talk and for the tips you shared with me last Monday.\r\nI very much appreciate it.\r\n\r\nCheers,\r\n\r\nDavid\r\n',
#  'Join Zoom Meeting\r\nhttps://csueb.zoom.us/j/554033172\r\n\r\nMeeting ID: 554 033 172\r\n\r\nOne tap mobile\r\n+16699006833,,554033172# US (San Jose)\r\n+16465588656,,554033172# US (New York)\r\n\r\nDial by your location\r\n        +1 669 900 6833 US (San Jose)\r\n        +1 646 558 8656 US (New York)\r\nMeeting ID: 554 033 172\r\nFind your local number: https://csueb.zoom.us/u/acNwdbUoa0\r\n\r\nJoin by SIP\r\n554033172@zoomcrc.com\r\n\r\nJoin by H.323\r\n162.255.37.11 (US West)\r\n162.255.36.11 (US East)\r\n221.122.88.195 (China)\r\n115.114.131.7 (India Mumbai)\r\n115.114.115.7 (India Hyderabad)\r\n213.19.144.110 (EMEA)\r\n103.122.166.55 (Australia)\r\n209.9.211.110 (Hong Kong)\r\n64.211.144.160 (Brazil)\r\n69.174.57.160 (Canada)\r\n207.226.132.110 (Japan)\r\nMeeting ID: 554 033 172\r\n',
#  'User name: Yufenlin72\r\nPassword: Lyf586091\r\n',
#  'Hi Jamieelee,\r\n\r\nThank you for getting back to me. My netid is az7762.  I was initially\r\nhaving issues with enrolling in courses because my MyCSUEB site did not\r\ninclude a student tab or student center link. I contacted Gradadmissions\r\nand was told that I should be able to start enrolling tomorrow, so, unless\r\nif there is anything else I missed, I believe I should be fine for now.\r\nAgain, thanks for touching base with me regarding my enrollment issue, and\r\nI will be sure to direct any of my future correspondence with you via\r\nHorizon in the future. ',
#  'Greetings Again Jiming,\r\n\r\nIt appears that the orientation registration had already closed. Would it\r\nbe possible that I just show up and attend the orientation anyways?\r\nOtherwise, is there any other way I can register at this point?\r\n\r\nAlso, I cannot seem to find an option to add courses on the myCSUEB site\r\nusing the instructions provided in my admissions package. Do I need to\r\nfollow additional steps to register for classes during the open enrollment\r\nperiod from Aug 15 - 19, or am I doing something wrong here?\r\n\r\nThanks in advance, and my apologies for the last minute questions. It was a\r\nbit hectic waiting and gathering the information I needed to make a\r\ndecision.\r\n\r\nRegards,\r\n\r\nDavid\r\n\r\n',
#  'Greetings Dr. Jiming Wu,\r\n\r\nI received an offer for admission to the CSUEB MS Business Analytics\r\nprogram in mid July and I was told by the Graduate Admission office that\r\nthere is no deadline to accept the offer, so I want to confirm with you\r\nabout whether this information is accurate, and whether there are any\r\ninformation about any deadlines that I may had missed regarding the\r\nadmission offer. I also found this information slightly confusing because\r\nthere is an MSBA program orientation on 8/17, and I cannot register for it\r\nunless I accept my offer.\r\n\r\nI would like to note that the reason why I want to know about the offer\r\nacceptance deadline is because I am still trying to weigh my options and I\r\nprobably will not receive all the information I can get to make my decision\r\nfor grad school until during or after the week of August 12. Hence, it\r\nwould be extremely helpful for me to know whether this may pose any issues\r\nin regards to my offer acceptance. Thank you for your time and thank you in\r\nadvance for any information that you may provide me.\r\n\r\nRegards,\r\nDavid\r\n',
#  "Hi Chris,\r\n\r\nYou mentioned that August 9 will be the end of the priority registration\r\nperiod. Does this mean that I can still register even after that date, but\r\nminus a few priority perks, or is it absolutely the last day that I can\r\nstill accept an offer of admission? Also, if August 9 really is the last\r\ndate, would it still be viable for me to register this week since I\r\nunderstand that there will probably be some prerequisites or processes that\r\nI'll need to finish that may take some time, such as mailing in\r\ntranscripts, registering for classes, submitting proof of immunization,\r\netc...\r\n\r\nThanks in advance,\r\nDavid\r\n\r\n",
#  'Greetings Sophie,\r\n\r\nIt has recently been brought to my attention that the time window for\r\naccepting my admission to the SFSU MSBA program is still open. I am\r\nwondering when is the actual deadline for me to make a decision. I am\r\ncurrently still weighing my options and it would be extremely helpful for\r\nme to know when action is needed on my part. For instance, would I still be\r\nallowed to make a decision by the week of August 12. Thanks.\r\n\r\nRegards,\r\nDavid Liu\r\n',
#  'Greetings,\r\n\r\nIt has recently been brought to my attention that the time window for\r\naccepting my admission to the CSUEB MSBS program is coming to a close but\r\nis still open. I am wondering when is the actual deadline for me to make a\r\ndecision. I am currently still weighing my options and it would be\r\nextremely helpful for me to know when action is needed on my part. Thanks.\r\n\r\nRegards,\r\nDavid Liu\r\n',
#  'Pretty cool you get entire books.\r\n\r\nThanks!\r\n\r\n',
#  'Hi Ben,\r\n\r\nyes I will be available\r\n\r\n',
#  [<email.message.Message at 0x1c7b0453400>,
#   <email.message.Message at 0x1c7b04530b8>],
#  'https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---256GB-SSD---Radeon-Pro-555X---Silver.product.100472319.html\r\n- ive confirmed that the one above is the one i want\r\n\r\nhttps://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---512GB-SSD---Radeon-Pro-560X---Space-Gray.product.100472395.html\r\n- this one here is good too, but the other one is cheaper.\r\n',
#  [<email.message.Message at 0x1c7addd30b8>,
#   <email.message.Message at 0x1c78f064978>],
#  [<email.message.Message at 0x1c7838e3c18>,
#   <email.message.Message at 0x1c7c169f0f0>],
#  'https://slickdeals.net/f/13011733-apple-macbook-pro-with-touch-bar-fptr2ll-a-15-4-laptop-computer-apple-certified-refurbished-space-gray-1599-98?attrsrc=Test%3AHideExpiredSearch%3AControl&src=SiteSearchV2Algo1\r\n\r\n',
#  'https://www.microcenter.com/product/600944/macbook-pro-with-touch-bar-fptr2ll-a-154-laptop-computer-apple-certified-refurbished---space-gray\r\n',
#  'https://www.apple.com/shop/product/G0SF2LL/A/Refurbished-133-inch-Macbook-P=\r\nro-33GHz-Dual-core-Intel-Core-i7-with-Retina-Display-Space-Gray?fnode=3Ddb7=\r\nb1e36e34e927189e9c4c5df91d78aa961b6be9d954739f3b99b5715dafbd0c9cb1f51fb42ff=\r\nc44e36bafc49750a454ba7f560fb3b22d6a6e1ac7cf8ba316b41cb60ac071128a83cb14916c=\r\nbafb7be\r\n',
#  'https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=\r\n07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=\r\nINT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=\r\namp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4\r\n\r\nthis one.. not the one above\r\n\r\n',
#  'https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=\r\n07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=\r\nINT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=\r\namp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4\r\n',
#  'https://www.apple.com/shop/product/G0T21LL/A/Refurbished-133-inch-Macbook-P=\r\nro-31GHz-Dual-core-Intel-Core-i5-with-Retina-Display-Silver?fnode=3D98769c7=\r\n052da9a6fb988727b003fb8b2e388032d5d0fde5e4890cdc5029b8d92cd91dc6b9bc8445f66=\r\n40e3f6fac54f2bc8fd0645a63fd5b983a4d4867c6e686fb089e6859185d916ac96d70b8253f=\r\n311\r\n',
#  [<email.message.Message at 0x1c795c65518>,
#   <email.message.Message at 0x1c793f84b00>],
#  [<email.message.Message at 0x1c7b0174470>,
#   <email.message.Message at 0x1c7838f2550>],
#  [<email.message.Message at 0x1c7b0453080>,
#   <email.message.Message at 0x1c7b0453550>],
#  [<email.message.Message at 0x1c7b0f1ec18>,
#   <email.message.Message at 0x1c7b0f1e748>],
#  [<email.message.Message at 0x1c7b20e5b00>,
#   <email.message.Message at 0x1c7b0f17898>],
#  [<email.message.Message at 0x1c7b0174b00>,
#   <email.message.Message at 0x1c789211828>],
#  [<email.message.Message at 0x1c7b0f1e518>,
#   <email.message.Message at 0x1c7892115c0>],
#  [<email.message.Message at 0x1c7afe24ac8>,
#   <email.message.Message at 0x1c7892110b8>],
#  [<email.message.Message at 0x1c789211fd0>,
#   <email.message.Message at 0x1c7892116a0>],
#  [<email.message.Message at 0x1c7892112e8>,
#   <email.message.Message at 0x1c789211cf8>],
#  [<email.message.Message at 0x1c789211da0>,
#   <email.message.Message at 0x1c789211208>],
#  [<email.message.Message at 0x1c789211198>,
#   <email.message.Message at 0x1c789211780>],
#  [<email.message.Message at 0x1c789211ba8>,
#   <email.message.Message at 0x1c789211630>],
#  [<email.message.Message at 0x1c7892117b8>,
#   <email.message.Message at 0x1c789211ac8>],
#  [<email.message.Message at 0x1c789211d68>,
#   <email.message.Message at 0x1c789211860>],
#  [<email.message.Message at 0x1c7939ef048>,
#   <email.message.Message at 0x1c7ad03f7b8>],
#  [<email.message.Message at 0x1c7ad03f828>,
#   <email.message.Message at 0x1c7ad03f588>],
#  'Hi Bill,\r\n\r\nThank you for checking in with me and my apologies for the late reply. I\r\nhave very recently been admitted to my top choice graduate program in Data\r\nScience and will no longer be continuing with my application. Thank you for\r\nspending your time to answer the questions I had early in the application\r\nand staying in touch with me throughout the process thus far.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n\r\n\r\n',
#  'Scincus - get rid of 3 and dot.\r\n- increase size if dots slightly\r\n- fix border and river gaps\r\n\r\nKeyserlingii - slightly darken the yellow region.\r\n- do not italicize the parenthesis parts in legend\r\n- fix border and river gaps\r\n- increase size of dots slightly\r\n- check whether the unknown region is correct\r\n- fix legend font\r\n',
#  [<email.message.Message at 0x1c7ad03f2b0>,
#   <email.message.Message at 0x1c7ad03f240>],
#  "Greetings,\r\n\r\nI was recently admitted to the MSDS program and my application checklist\r\nindicated that I must send in my official Bachelor's degree transcript. The\r\ntranscript was mistakenly sent electronically to the USF Office of Graduate\r\nAdmission located at 2130 Fulton Street, San Francisco. This was before I\r\nreceived a letter in my application status page instructing me to send any\r\nelectronic transcripts to the asgraduate@usfca.edu email address. Can my\r\nofficial transcript be received at its current destination or should I\r\nrequest to send a copy to asgraduate@usfca.edu as well?\r\n\r\nThanks,\r\nDavid Liu\r\n",
#  'un: david92liu@gmail.com\r\npw: Ilikebagel!1\r\n\r\nhttps://gradapply.usfca.edu/account/login?r=https%3a%2f%2fgradapply.usfca.edu%2fapply%2fstatus\r\n',
#  [<email.message.Message at 0x1c7ad03f780>,
#   <email.message.Message at 0x1c7ad03f358>],
#  [<email.message.Message at 0x1c7ad03fbe0>,
#   <email.message.Message at 0x1c7ad03f080>],
#  [<email.message.Message at 0x1c7ad03f908>,
#   <email.message.Message at 0x1c7ad03f630>],
#  'Hi Victoria,\r\n\r\nThank you for checking in with me and my apologies for the late reply. I\r\nhave very recently received admissions from a couple of my top choice\r\nuniversities and will no longer be continuing with my application. However,\r\nI want to thank you for striving to keep me in close communications\r\nthroughout the application and providing me with the information I need to\r\nweigh my options and to make an informed decision. Not many of the colleges\r\nI applied to actively initiated conversions with applicants.\r\n\r\nThanks again,\r\n\r\nDavid Liu\r\n\r\n\r\n',
#  "Was expecting something like CodeAcademy, but it looks like there's a lot\r\nmore useful resources here than just some practices. Thanks! Will look more\r\ninto it.\r\n\r\n",
#  'Hi Victoria,\r\n\r\nThank you for letting me know about the webinar. Unfortunately, I will not\r\nbe available at that time tomorrow. Will there be any followup webinars in\r\nthe near future?\r\n\r\nRegards,\r\n\r\nDavid\r\n\r\n',
#  'Hi Maggie,\r\n\r\nThank you for checking in with my application status. I have very recently\r\nreceived admissions from a couple of my top choice universities and will no\r\nlonger be continuing with my application.\r\n\r\nRegards,\r\n\r\nDavid\r\n\r\n',
#  'Hi Leyla,\r\n\r\nI am interested in attending the webinar. You mentioned that this will be\r\nthe first. What date will the other ones be held and will they be the same\r\nas this one? Thanks.\r\n\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7ad03f550>,
#   <email.message.Message at 0x1c7ad03f128>],
#  [<email.message.Message at 0x1c7ad03f940>,
#   <email.message.Message at 0x1c7ad03fcf8>],
#  'testing testing\r\n',
#  'Good to know! Will hear from you tomorrow.\r\n\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7ad03f9e8>,
#   <email.message.Message at 0x1c7ad03ff98>],
#  'Claremont Grad. Uni.\r\n<https://admissions.cgu.edu/account/login?r=https%3a%2f%2fadmissions.cgu.edu%2fapply%2fcertify>\r\n\r\nUN: david92liu@gmail.com\r\n\r\nPW: Ilikebagel!1\r\n',
#  'Hey Bob,\r\n\r\nGot your message. Call me back and let me know if you still need my help on\r\nthe map.\r\n\r\nDavid\r\n\r\n',
#  "Dear Professor Stephen Devlin,\r\n\r\n\r\n\r\nThank you for taking your time to interview me last Thursday and allowing\r\nme to have a better understanding of the USF Data Science Program's\r\ncurriculum roadmap, as well as the advantages that the program offers its\r\nstudents in terms of employment and learning outcome.\r\n\r\n\r\n\r\nI would like to reiterate my interest in the program's fast-paced, rigorous\r\nacademic environment and in the hands-on learning approach through\r\npracticum projects. I also believe that the program's focus in not only on\r\nthe computational aspects of data science, but also in experimental design\r\nand statistics, would be uniquely fitting for someone of my background.\r\nAlthough my primary programming language is Java, I realize from the\r\ninterview and data science programs that Python is the preferred\r\nprogramming language and I am currently taking a course, Python for Data\r\nScience, to improve my understanding.\r\n\r\n\r\n\r\nOnce again, thank you for speaking with me and I am enthusiastic about the\r\npossibility of enrolling in the program.\r\n\r\n\r\n\r\nBest Regards,\r\n\r\n\r\n\r\nDavid Liu\r\n",
#  "Dear Professor Stephen Devlin,\r\n\r\n\r\n\r\nThank you for taking your time to interview me last Thursday and allowing\r\nme to have a better understanding of the USF Data Science Program's\r\ncurriculum roadmap, as well as the advantages that the program offers its\r\nstudents in terms of employment and learning outcome.\r\n\r\n\r\nI would like to reiterate my interest in the program's fast-paced, rigorous\r\nacademic environment and in the hands-on learning approach through\r\npracticum projects. I also believe that the program's focus in not only on\r\nthe computational aspects of data science, but also in experimental design\r\nand statistics, would be uniquely fitting for someone of my background.\r\nAlthough my primary programming language is Java, I realize from the\r\ninterview and data science programs that Python is the preferred\r\nprogramming language and I am currently taking a course, Python for Data\r\nScience, to improve my understanding.\r\n\r\n\r\nOnce again, thank you for speaking with me about the program and I am\r\nenthusiastic about the possibility of enrolling in the program.\r\n\r\n\r\n\r\nBest Regards,\r\n\r\n\r\n\r\nDavid Liu\r\n",
#  "Dear Professor Stephen Devlin,\r\n\r\n\r\n\r\nThank you for taking your time to interview me last Thursday and allowing\r\nme to have a better understanding of the USF Data Science Program's\r\ncurriculum roadmap, as well as the advantages that the program offers its\r\nstudents in terms of employment and learning outcome.\r\n\r\nI would like to reiterate my interest in the program's fast-paced, rigorous\r\nacademic environment and in the hands-on learning approach through\r\npracticum projects. I also believe that the program's focus in not only on\r\nthe computational aspects of data science, but also in experimental design\r\nand statistics, would be uniquely fitting for someone of my background.\r\nAlthough my primary programming language is Java, I realize from the\r\ninterview and data science programs that Python is the preferred\r\nprogramming language and I am currently taking a course, Python for Data\r\nScience, to improve my understanding.\r\n\r\nOnce again, thank you for speaking with me about the program and I am\r\nenthusiastic about the possibility of enrolling in the program.\r\n\r\n\r\n\r\n\r\nBest Regards,\r\n\r\n\r\n\r\nDavid Liu\r\n",
#  "Dear Professor Stephen Devlin,\r\n\r\n\r\n\r\nThank you for taking your time to interview me last Thursday and allowing\r\nme to have a better understanding of the USF Data Science Program's\r\ncurriculum roadmap, as well as the advantages that the program offers its\r\nstudents in terms of employment and learning outcome.\r\n\r\n\r\nI would like to reiterate my interest in the program's fast-paced, rigorous\r\nacademic environment and in the hands-on learning approach through\r\npracticum projects. I also believe that the program's focus in not only on\r\nthe computational aspects of data science, but also in experimental design\r\nand statistics, would be uniquely fitting for someone of my background.\r\nAlthough my primary programming language is Java, I realize from the\r\ninterview and data science programs that Python is the preferred\r\nprogramming language and I am currently taking a course, Python for Data\r\nScience, to improve my understanding.\r\n\r\n\r\nOnce again, thank you for speaking with me about the program and I am\r\nenthusiastic about the possibility of enrolling in the program.\r\n\r\n\r\nBest Regards,\r\n\r\n\r\n\r\nDavid Liu\r\n",
#  'maybe i should also thank the admissions person who set up the interview as\r\nwell in this email.. what do you think about including it.\r\n\r\n',
#  "Dear Professor Stephen Devlin,\r\n\r\nThank you for taking your time to interview me last Thursday and allowing\r\nme to have a better understanding of the USF Data Science Program's\r\ncurriculum roadmap, as well as the advantages that the program offers its\r\nstudents in terms of employment and learning outcome.\r\n\r\nI would like to reiterate my interest in the program's fast-paced, rigorous\r\nacademic environment and in the hands-on learning approach through\r\npracticum projects. I also believe that the program's focus in not only on\r\nthe computational aspects of data science, but also in experimental design\r\nand statistics, would be uniquely fitting for someone of my background.\r\nAlthough I lack a fluent understanding in certain preferred skills, such as\r\nin Python, I am currently actively taking online courses in order to\r\nimprove my understanding of the subject.\r\n\r\nOnce again, thanks for speaking with me about the program and I look\r\nforward to hearing about the final admissions decision.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n",
#  'http://www.academia.edu/20025172/Linear_Algebra_and_Its_Applications_5th_Edition_\r\n',
#  'Greetings,\r\n\r\nOn January 18, I received an invitation to schedule an online interview for\r\nmy MS Data Science program application. I set up the interview to be on\r\nJanuary 24 at 1 PM and received an email that confirmed my chosen date and\r\ntime for an online meeting with Prof. Stephen Devlin. According to the\r\nconfirmation email, I am suppose to receive a followup email invitation\r\nwith a calendar invite to join the meeting on Zoom on my scheduled date. I\r\nwould like to know the status of the email as I have not yet received it.\r\nThanks.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n',
#  "Hi Patrick,\r\n\r\nI am still interested in applying for the MS Business Analytics program at\r\nGGU, although it might take some time to get all my materials together.\r\nJust to clarify, the priority deadline for applying to the fall semester is\r\nin August correct?\r\n\r\nRegards,\r\nDavid\r\n\r\nOn Wed, Jan 16, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote=\r\n:\r\n\r\n>\r\n>\r\n>\r\n>\r\n> Hi David ,\r\n>\r\n>\r\n> We at Golden Gate University would like to remind you that we are\r\n> dedicated to your educational success and here to support you with many\r\n> options for accomplishing your academic goals.  As your Enrollment\r\n> Counselor, I am committed to helping you learn more about GGU and determi=\r\nne\r\n> if our programs are a good fit for you and your goals.\r\n>\r\n>\r\n>\r\n> *Please help me understand your current educational plans by replying to\r\n> this email with the following scenario that best represents your\r\n> situation: *\r\n>\r\n> 1.    I plan to apply for the next available semester\r\n>\r\n> 2.    I am interested, but not until a later start term\r\n>\r\n> 3.    I have postponed my search at this time\r\n>\r\n> 4.    I intend to enroll at another university\r\n>\r\n> If I don't hear back from you, I will assume you are still interested in\r\n> Golden Gate University but not at this time. We may send you emails from\r\n> time to time to check in. Please get back to me when you can. I look\r\n> forward to working with you!\r\n>\r\n>\r\n>\r\n> Sincerely,\r\n>\r\n> Patrick Gonzales\r\n>\r\n> Golden Gate University\r\n>\r\n> 415-442-7800 GGU Hub\r\n>\r\n> GGUAdmissions@ggu.edu\r\n>\r\n> www.ggu.edu\r\n>\r\n> www.ggu.edu=E2=80=9D>GGU.edu\r\n>\r\n>\r\n> *WARNING: *This E-mail, and any attachments, are covered by the\r\n> Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=\r\nail may\r\n> contain confidential and legally privileged information. The contents of\r\n> this e-mail, and any attachments, are intended solely for the use of the\r\n> person or entity to whom the e-mail was addressed. This email may also\r\n> contain information that may be protected by the attorney-client privileg=\r\ne,\r\n> work-product doctrine, or other privileges, and may be restricted from\r\n> disclosure by applicable Federal and State laws. If you are not the\r\n> intended recipient of this email *you are advised that any dissemination,\r\n> distribution, or use of the contents of this message is strictly prohibit=\r\ned*.\r\n> If you received this e-mail message in error, please contact the sender b=\r\ny\r\n> reply e-mail or phone. Please also permanently delete all copies of the\r\n> original e-mail and any attachments.\r\n>\r\n>\r\n",
#  'Dear CSUEB Graduate Admissions Office,\r\n\r\nI am applying for the MS Business Analytics program for the fall 2019\r\nsemester, and the application asks that I send official transcripts from\r\nall colleges and universities attended to the CSUEB Office of Admissions.\r\nDoes CSU East Bay accept E-transcripts, and if so, is there a specific\r\nemail address that I can send my official transcripts to? If not, I would\r\nlike to confirm whether the address listed as "Office of Admission, Cal\r\nState East Bay, 25800 Carlos Bee Blvd., Hayward, CA, 94542" is the correct\r\naddress to send my transcript. Thanks.\r\n\r\nRegards,\r\nDavid Liu\r\n',
#  "Dear Dr. Jiming Wu,\r\n\r\nIn regards to the Business Analytics program's requirements, does the\r\nprogram require official standardized test scores from applicants? I can\r\nsee that the application requires manually entering test scores but it does\r\nnot mention needing any official copies from the testing agencies, so I\r\nwould like to get that clarified. Thanks.\r\n\r\nRegards,\r\nDavid Liu\r\n",
#  'Dear CGU Admissions Office,\r\n\r\nI am applying for the MS in Information Systems & Technology - Data Science\r\n& Analytics program for the fall 2019 semester, and the program asks for\r\nofficial transcripts to be sent. Does CGU accept E-transcripts, and if so,\r\nis there a specific email address that I can send my official transcripts\r\nto? If not, I would like to confirm whether the address listed as "CGU\r\nOffice of Admissions, 150 E. 10th Street, Claremont, CA, 91711" is the\r\ncorrect address to send my official transcript to. Also, does CGU allow an\r\napplicant to submit transcripts and standardized test scores before\r\nsubmitting the application? Thanks.\r\n\r\nRegards,\r\nDavid Liu\r\n',
#  'Definitely, it has been a while. It is great to see all the data show up on\r\nthe map and to know that there is still development on the project in\r\nrecent years. Hope it continues to grow, and maybe even have the pneumatic\r\ntubes that were discussed about back then to be installed on streets.\r\n\r\nRegards,\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7b0f32828>,
#   <email.message.Message at 0x1c7b0f328d0>],
#  'Hi Jason,\r\n\r\nI would like to add that the date I listed on one of my applications is\r\ninconsistent with the one on the attachment. In my application to the\r\nUniversity of Southern California (USC), I listed it as June to September\r\nas oppose to July to September. If this school happens to contact you and\r\nthey mention June - September, let them know that I acknowledge the\r\ninconsistency and you can correct them. The application does not seem to\r\nprovide any followup methods to edit experiences after submission. Thanks.\r\n\r\nRegards,\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7b2aee8d0>,
#   <email.message.Message at 0x1c7ba5a7a90>],
#  [<email.message.Message at 0x1c7ba5a7208>,
#   <email.message.Message at 0x1c7ba5a7ac8>],
#  'Hi Jason,\r\n\r\nThank you so much for getting back to me and for making yourself available\r\nas a contact. Below is a brief summary of what I can recall.\r\n\r\nI was a volunteer intern for approximately two months to help build a\r\ntraffic count database for an interactive count map project. I believe I\r\nstarted on the day listed on the application, which is 7/30/2012, and\r\nworked until 9/28/2012 for about 10-15 hours a week. I looked through years\r\nand months of traffic documents and surveys, each of which contains\r\npedestrian, bicycle, and vehicle counts of a specific street intersection\r\nin Oakland, and I added those information onto an excel spreadsheet.\r\n\r\nLet me know if there are any more information that you might need that can\r\nhelp you in any way. Again, thank you so much for making yourself available\r\nfor my application.\r\n\r\nKind regards,\r\n\r\nDavid\r\n\r\n\r\n',
#  'Hello Jason,\r\n\r\nIt has been a while since we last touched base back in 2014. I hope you are\r\ndoing well and I hope this email reaches you.\r\n\r\nI am contacting you again today because I recently started applying for\r\nmaster programs in data science. There are areas in some of my applications\r\nin which they asks whether the supervisors in each of my past listed\r\npositions can be contacted. I am letting you know that I listed my\r\nexperience at the Bicycle and Pedestrian Program on the application, so let\r\nme know whether or not you are okay with me listing you as contactable. I\r\nbelieve that it is just for letting the admissions office confirm my past\r\nexperiences. Thanks!\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n\r\n',
#  'Hi Patina,\r\n\r\nIt has been a while since we last spoke back when I was still at Resh Lab\r\ndoing the URAP program with you from 2013 to 2014 and also when you\r\nintroduced me to work with your colleague, Erin, on the nematology project.\r\nI hope you are doing well! I hope this email reaches you.\r\n\r\nI am contacting you today because I recently started applying for master\r\nprograms in data science. There are areas in some of my applications in\r\nwhich they asks whether the supervisors in each of my past listed positions\r\ncan be contacted. I am letting you know that I listed my URAP experience on\r\nthe application, so let me know whether or not you are okay with me listing\r\nyou as contactable. I believe that it is just for letting the admissions\r\noffice confirm my past experiences. Thanks!\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n',
#  'Hi Patrick,\r\n\r\nI would be happy to learn more about Golden Gate University and plan my\r\nnext steps. I will be available right after 12 PM on Friday or Monday.\r\nOtherwise, if you are available on the weekend, anytime on Saturday or\r\nafter 2 PM on Sunday will work for me. You can contact me at (510)\r\n219-5580.\r\n\r\nRegards,\r\nDavid Liu\r\n\r\nOn Wed, Jan 9, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote:\r\n\r\n>\r\n>\r\n>\r\n> Hi David ,\r\n>\r\n>\r\n> We hope you are looking forward to accomplishing your educational goals\r\n> with us at Golden Gate University. As your enrollment counselor, I am\r\n> dedicated to helping you get started on your degree with us!\r\n>\r\n>\r\n>\r\n> Please let me know when you are available to chat for 5 minutes so we can\r\n> plan your next steps. Kindly call to get started today.\r\n>\r\n>\r\n>\r\n> I look forward to speaking with you!\r\n>\r\n>\r\n> Best,\r\n>\r\n> Patrick Gonzales\r\n>\r\n> Golden Gate University\r\n>\r\n> 415-442-7800 GGU Hub\r\n>\r\n> GGUAdmissions@ggu.edu\r\n>\r\n> www.ggu.edu\r\n>\r\n>\r\n>\r\n>\r\n>\r\n>\r\n>\r\n>\r\n>\r\n> *WARNING: *This E-mail, and any attachments, are covered by the\r\n> Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=\r\nail may\r\n> contain confidential and legally privileged information. The contents of\r\n> this e-mail, and any attachments, are intended solely for the use of the\r\n> person or entity to whom the e-mail was addressed. This email may also\r\n> contain information that may be protected by the attorney-client privileg=\r\ne,\r\n> work-product doctrine, or other privileges, and may be restricted from\r\n> disclosure by applicable Federal and State laws. If you are not the\r\n> intended recipient of this email *you are advised that any dissemination,\r\n> distribution, or use of the contents of this message is strictly prohibit=\r\ned*.\r\n> If you received this e-mail message in error, please contact the sender b=\r\ny\r\n> reply e-mail or phone. Please also permanently delete all copies of the\r\n> original e-mail and any attachments.\r\n>\r\n>\r\n',
#  'Dear Admissions Office,\r\n\r\nI am just in need of a clarification in regards to reporting my test scores\r\nfor the MS in Data Science application at USF. After entering my GRE scores\r\nin the "Test Scores" tab in the application and sending in my GRE scores to\r\nUSF from my testing agency, the application also asks for a test upload. I\r\nbelieve that on a previous email, I was told to upload an official student\r\ncopy of my test scores. Am I correct to assume that I can simply submit a\r\nprintout of my reported scores from my testing agency website, or are there\r\nother official methods required?\r\n\r\nDavid Liu\r\n',
#  'Got you down as contactable. Thanks Erin!\r\n\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7b0f329e8>,
#   <email.message.Message at 0x1c7b0f322b0>],
#  'Hi Erin,\r\n\r\nIt has been a while since we last spoke back when I was still at the USDA\r\nfacility in Albany with you and the others. I hope you are doing well! I am\r\nnot certain whether you still communicate with this email address, so I\r\nhope this email reaches you.\r\n\r\nI am contacting you today because I recently started applying for masters\r\nprograms in data science. There are areas in some of my applications in\r\nwhich they asks whether the supervisors in each of my past listed positions\r\ncan be contacted. I am letting you know that I listed my temporary position\r\nat Albany as one of my previous experiences, so let me know whether or not\r\nyou are okay with me listing you as contactable. Thanks.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n',
#  "USF\r\nhttps://gradapply.usfca.edu/account/login\r\nUN: david92liu@gmail.com PW: Ilikebagel!1\r\n\r\nUSC\r\nhttps://usc.liaisoncas.com/applicant-ux/#/login\r\nUN: dkwliu PW: Ilikebagel!1\r\n\r\nWell I keep forgetting. We can't submit anything because the scores haven't\r\ncome in yet. But at the very least, check to see if everything else is in\r\norder first so that when the score comes in, I can immediately submit it.\r\n",
#  'Hi Bill,\r\n\r\nI would be happy to learn more about the UC Berkeley MIDS program. I will\r\nbe available right after 12 PM on Friday or Monday. Otherwise, if you are\r\navailable on the weekend, anytime on Saturday or after 2 PM on Sunday will\r\nwork for me as well. You can contact me at (510) 219-5580.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n\r\n',
#  [<email.message.Message at 0x1c7b0f329b0>,
#   <email.message.Message at 0x1c7b0f325c0>],
#  [<email.message.Message at 0x1c7b0f32ac8>,
#   <email.message.Message at 0x1c7b0f32898>],
#  [<email.message.Message at 0x1c7b0f32b38>,
#   <email.message.Message at 0x1c7b0f320b8>],
#  'He has taken various classes in computational sciences from 2015-2018 that\r\ncovers multiple programming languages, and throughout he has consistently\r\nearned high marks\r\n\r\n',
#  [<email.message.Message at 0x1c7b0f32d30>,
#   <email.message.Message at 0x1c7b0f32080>],
#  'David has academic experience creating applications with Java, JavaScript,\r\nC++, and C#. He also has a keen interest in learning PERL scripting for\r\nmanipulating genomic data.\r\n',
#  'David has academic experience creating applications with Java, JavaScript,\r\nC++, and C#.\r\n',
#  'Hi Bob,\r\n\r\nHope you had a great holiday! I am contacting you again about a number of\r\nother graduate programs that I am applying for and I just want to check\r\nwhether you have time to send out a few more letters. Some program\r\ndeadlines are coming up but I am definitely not in an immediate rush this\r\nweekend, so just let me know whenever, or if, you will be free. Thanks!\r\n\r\nDavid\r\n',
#  [<email.message.Message at 0x1c7b0f32048>,
#   <email.message.Message at 0x1c7b0f32e48>],
#  'Yuri,\r\n\r\nThat is perfect! Thank you very much.\r\n\r\nDavid\r\n\r\n\r\n',
#  "Greetings. I am currently attending Isaac's GRE quant session at San\r\nFrancisco which started on 12/06 and will end on 1/10. I do not think that\r\nI will be able to attend class 4 (1/03) and 5 (1/10) for his session, so if\r\npossible, I would like to make up for those two classes at the Santa Clara\r\nquant session instead, which will be held on 12/11 and 12/18. Please let me\r\nknow whether those class dates are available for make-up. If requesting for\r\ntwo make-up dates is not possible, then I am fine with just one, but I\r\nwould prefer it to be for the fifth class on 12/18. Thanks.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n",
#  [<email.message.Message at 0x1c7b0f321d0>,
#   <email.message.Message at 0x1c7b0f32240>],
#  [<email.message.Message at 0x1c7b0f32ef0>,
#   <email.message.Message at 0x1c7b0f32c18>],
#  'Thanks for the responses. Yes, I took one introductory statistics and a few\r\nprogramming courses, so I believe that the financial accounting course\r\nshould be my only prerequisite left.\r\n\r\nAlso, am I correct to assume that as long as I apply by any of the first\r\ntwo application rounds that I will make it for priority consideration, or\r\nare there advantages to applying by either of the two dates? Thanks again.\r\n\r\nDavid\r\n\r\n\r\n',
#  'Dear SF State Admissions,\r\n\r\nI have questions regarding the deadline for the MS Business Analytics\r\nprogram at SF state. The College of Business website linked here at\r\nhttps://cob.sfsu.edu/admissions says that there are three application\r\ndeadlines for fall 2019. What are the differences between the three, and is\r\nthere a priority consideration deadline? Furthermore, the application on\r\nCal State Apply says that the deadline is 7/1/2019, so I am slightly\r\nconfused as to which is the correct date.\r\n\r\nSecondly, I am planning on taking a financial accounting course to satisfy\r\nthe MSBA program prerequisite, and I see that the MSBA website lists a few\r\nspecific college accounting courses that I can take. Is it okay to take the\r\nfinancial accounting course elsewhere, and if so, what are the requirements\r\nfor the course to be eligible? For instance, would the Business 1A course\r\nlisted here http://www.berkeleycitycollege.edu/wp/business/business-courses/ be\r\nfine to take? Also, if the course is still ongoing after the application\r\ndeadline, may I still list it on my application? Thank you for your time\r\nand thanks in advance.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n',
#  [<email.message.Message at 0x1c7ad03f898>,
#   <email.message.Message at 0x1c7ad03f6d8>],
# ...
#  [<email.message.Message at 0x1c7ba58c208>,
#   <email.message.Message at 0x1c7b31644a8>],
#  [<email.message.Message at 0x1c7b90d7630>,
#   <email.message.Message at 0x1c7ba5a7240>],
#  'Hey Bob\r\n\r\nGot your call. With how things are looking right now, I will be available to=\r\n help out on Thursday.=20\r\n\r\nDavid\r\n\r\nSent from my iPhone\r\n\r\n> ',
#  [<email.message.Message at 0x1c7ba5bf4a8>,
#   <email.message.Message at 0x1c7b05fbbe0>],
#  "Whooo. Well I can understand.. he's driven by passion. But sure.. if you\r\ncan live for 10 years purely off oxygen and nothing else, then working for\r\nCGI would be a pretty good deal.\r\n\r\nHad he bugged you recently about the website or anything?\r\n\r\n",
#  "Right?\r\n\r\nPretty swell. Nothing new. Enjoying a very short break before school/job\r\nsearch/bob's stuff.\r\n\r\nI'd assume everything 's well with you? Heard you'll be in Santa Cruz for a\r\nwhile since you found a job there?\r\n\r\n",
#  "Hey Clay,\r\n\r\nPretty sure it's because all the stuff that Ted will bring to the airport\r\nwill not fit in just Bob's car. Of course there's always the option of\r\nrenting a van, but Bob is thinking that it'll be more convenient for Ted if\r\na small group can help him bring the equipment to the airport instead.\r\n\r\n",
#  "Checking in. I'll be coming by today.\r\n\r\nSent from my iPhone\r\n\r\n> ",
#  [<email.message.Message at 0x1c7b32e1f28>,
#   <email.message.Message at 0x1c784108518>],
#  'Hi Shan,\r\n\r\nThank you very much for presenting me the trainee position yesterday. I\r\nwould like to check in with you again about it. I am still very interested\r\nin the opening and would like to know if it is still open. Thanks in\r\nadvance.\r\n\r\nSincerely,\r\n\r\nDavid\r\n\r\n',
#  'Hey Charles,\r\n\r\nAre there still anymore cleaning work to be done at the moment?\r\n\r\n',
#  'Hi Shan,\r\n\r\nThank you very much for your quick response!\r\n\r\nI just have a couple questions regarding the trainee opening:\r\n\r\n- Will an employee in this position be doing work that will directly\r\ncontribute to the company, or at least assist with or build on the work of\r\nwhoever is training the trainee?\r\n\r\n- Is this a paid position, and if not, can it eventually become one?\r\n\r\nIf yes to all, I am definitely interested in this opening.\r\n\r\nSincerely,\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7ad038f28>,
#   <email.message.Message at 0x1c7b2aeec50>],
#  'Got it. I can help out a bit with cleaning on Tuesday since I will be\r\naround the area. Will see you then.\r\n\r\n',
#  "Hey Charles,\r\n\r\nProbably won't be in tomorrow given tomorrow's schedule. But besides lab\r\ncleaning, is there anything else we'll be doing on Tuesday?\r\n\r\nCheers,\r\n\r\nDavid\r\n\r\n",
#  [<email.message.Message at 0x1c7c168dc50>,
#   <email.message.Message at 0x1c7b26b7160>],
#  [<email.message.Message at 0x1c7b90d30f0>,
#   <email.message.Message at 0x1c7b90d36a0>],
#  'Perfect! see you then.\r\n\r\n',
#  'Hey Savannah,\r\n\r\nWe can get the plausible out of the way first. If you are going to be\r\naround Berkeley tomorrow at around 12 pm - 1 pm, or Monday or Wednesday at\r\naround 5 - 6 pm, I can pick it up from you there. Otherwise, coordinating\r\nwith Charles will be your best bet.\r\n\r\nCheers,\r\n\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7b32e7940>,
#   <email.message.Message at 0x1c7b32e7978>],
#  [<email.message.Message at 0x1c7b3309390>,
#   <email.message.Message at 0x1c7838e7f60>],
#  [<email.message.Message at 0x1c789211a90>,
#   <email.message.Message at 0x1c78f064898>],
#  [<email.message.Message at 0x1c7bddf3da0>,
#   <email.message.Message at 0x1c7b20b0390>],
#  'still at alameda.\r\n\r\n',
#  'i need that too. forgot. I figured out the wifi here.\r\n\r\n',
#  'may need acct # and acct holder phone # again. left info at home.\r\n\r\n',
#  'are you there?\r\n',
#  'are you at home\r\n',
#  "Hey everybody,\r\n\r\nI will be down at the lab tomorrow. If you're all still meeting, let me\r\nknow the time.\r\n\r\n",
#  'Cool. Thanks!\r\n\r\n',
#  "Awesome that you got access to the Nature articles!\r\n\r\nIt'll be better all around if I get your login info so that I'll have\r\naccess to the articles also. It'll definitely be better than just having\r\nyou download everything... or at least until we find a more efficient way\r\nto quicken this article searching process. Send me your login info however\r\nyou want. I will be free around Berkeley tonight at about 6:30 - 6:50 PM.\r\nIf that time isn't convenient for you, you may send it via email.... or\r\ncall/send text to my number: (510) 219 - 5580.\r\n\r\n",
#  'Hi Ryan,\r\n\r\nSorry about the spam. Please send the one sent at 8:49 instead.\r\n\r\nThanks,\r\n\r\nDavid\r\n\r\n',
#  "Hello Mike,\r\n\r\nThank you very much for yesterday's interview at 8:30 PM. It has given me\r\ngreater insight into Genentech's work culture and expectations, which has\r\nreinforced my interest in the position.\r\n\r\nI truly believe that working at Genentech will provide me with a great\r\nopportunity to gain valuable practical skills and knowledge in the\r\nbiotechnology industry through a fast-paced, engaging, and rewarding work\r\nexperience. I would also like to reiterate that I have worked in a number\r\nof collaborative laboratory environments in the past, as well as in a\r\ncustomer-oriented and physically demanding retail setting where I was a\r\nclerk assisting with cabinet sales. As such, I am confident that I will\r\nquickly adapt to the responsibilities of this position.\r\n\r\n\r\n\r\nOnce again, thank you for the interview. I'm sorry that I was a bit nervous\r\nyesterday as I was calculating the answer for a 5% detergent solution and I\r\nrealized immediately afterwards that my solution was grossly incorrect (A\r\nquick recalculation yielded an addition of ~19,700 mL detergents to the 374\r\nL of water, and an overall volume of ~394,000 mL in total, which is\r\nhopefully the correct solution). In any case, I look forward to hearing\r\nback about the final hiring decision.\r\n\r\n\r\nSincerely,\r\n\r\nDavid\r\n",
#  "Hello Mike,\r\n\r\nThank you very much for yesterday's interview at 8:30 PM. It has given me\r\ngreater insight into Genentech's work culture and expectations, which has\r\nreinforced my interest in the position,\r\n\r\nI truly believe that working at Genentech will provide me with a great\r\nopportunity to gain valuable practical skills and knowledge in the\r\nbiotechnology industry through a fast-paced, engaging, and rewarding work\r\nexperience. I would also like to reiterate that I have worked in a number\r\nof collaborative laboratory environments in the past, as well as in a\r\ncustomer-oriented and physically demanding retail setting where I was a\r\nclerk assisting with cabinet sales. As such, I am confident that I will\r\nquickly adapt to the responsibilities of this position.\r\n\r\n\r\n\r\nOnce again, thank you for the interview. I'm sorry that I was a bit nervous\r\nyesterday as I was calculating the answer for a 5% detergent solution and I\r\nrealized immediately afterwards that my solution was grossly incorrect (A\r\nquick recalculation yielded an addition of ~19,700 mL detergents to the 374\r\nL of water, and an overall volume of ~394,000 mL in total, which is\r\nhopefully the correct solution). In any case, I look forward to hearing\r\nback about the final hiring decision.\r\n\r\n\r\nSincerely,\r\n\r\nDavid\r\n",
#  [<email.message.Message at 0x1c7b31642b0>,
#   <email.message.Message at 0x1c7b0f37630>],
#  'Got it. See you all tomorrow.\r\n\r\n',
#  [<email.message.Message at 0x1c7b0453438>,
#   <email.message.Message at 0x1c7bddf33c8>],
#  "Hi Nate,\r\n\r\nNot sure if it's necessary... but the description on the lab3a + lab3b\r\nsubmission pages suggest that I should probably let you know directly if I\r\nturn in the labs after the due date(?). This email is just to let you know\r\nthat they're in. I can remind you again the next time we meet in class if\r\nneeded.\r\n\r\nCheers,\r\n\r\nDavid Liu\r\n",
#  [<email.message.Message at 0x1c7c169fa90>,
#   <email.message.Message at 0x1c7c169fa20>],
#  "again?? man he said he was going to sleep yesterday.\r\n\r\nyea I just might return his call later today. Didn't even really noticed it\r\nuntil now.\r\n\r\n",
#  [<email.message.Message at 0x1c7cf5b8b70>,
#   <email.message.Message at 0x1c793f84160>],
#  [<email.message.Message at 0x1c7b0f1eef0>,
#   <email.message.Message at 0x1c7b04535f8>],
#  [<email.message.Message at 0x1c7816c33c8>,
#   <email.message.Message at 0x1c7b00cc3c8>],
#  [<email.message.Message at 0x1c7ba5bff60>,
#   <email.message.Message at 0x1c7c169fba8>],
#  [<email.message.Message at 0x1c7b90d7b38>,
#   <email.message.Message at 0x1c7b00cc9b0>],
#  [<email.message.Message at 0x1c7ad0f90f0>,
#   <email.message.Message at 0x1c7b2d12630>],
#  [<email.message.Message at 0x1c7b0f1e860>,
#   <email.message.Message at 0x1c7b0f1ee48>],
#  [<email.message.Message at 0x1c7ad0f9470>,
#   <email.message.Message at 0x1c7ad0f9668>],
#  [<email.message.Message at 0x1c7b0174b70>,
#   <email.message.Message at 0x1c7b0174c88>],
#  "Gotcha. I'm already at alameda so you'll find me there.\r\n\r\n",
#  'Hi Melinda,\r\n\r\nJust to add on to my last email, if the position is still open, I am\r\nwilling to further discuss about it over the phone or on-site if emailing\r\nis getting too troublesome. Let me know what you think. I would love to\r\nlearn more about the position even if the pay is not quite up to where I am\r\ntargeting.\r\n\r\nThanks,\r\n\r\nDavid\r\n\r\n',
#  [<email.message.Message at 0x1c7ad104240>,
#   <email.message.Message at 0x1c7ad104940>],
#  "Would love to drop by to learn how to work the machines although I can only\r\nstick around until ~12:20 tomorrow. Let me know when you'll be down at the\r\nlab. Thanks!\r\n\r\n",
#  [<email.message.Message at 0x1c7ad104550>,
#   <email.message.Message at 0x1c7ad104be0>],
#  "Hi Melinda,\r\n\r\nI will still consider it, but I do have a few questions. Will there be any\r\nchance for an employee in this position to move upwards, and, if so, will\r\nthere be a pay raise and typically how much? Also, I realize that there are\r\nunmentioned responsibilities for this position along with the primary ones,\r\nso I would like to ask what these other responsibilities might be. Will\r\nthey involve more technical work related to the company's main product\r\nline?\r\n\r\nThanks,\r\n\r\nDavid\r\n\r\n",
#  "Hey Bob,\r\n\r\nSo I've been looking into temp agencies and jobs that require\r\nsupervisor/reference information from some of my past places of employment.\r\nI understand that I am simply volunteering as a lab assistant at Profile\r\nGenomics, but would you like to be listed as one of my contactable\r\nsupervisors/references?\r\n\r\nDavid\r\n",
#  "Hi Melinda,\r\n\r\nThank you for getting back to me about my application. I want to build my\r\ncareer in the biotechnology industry and so I am looking for new\r\nopportunities to gain general exposure and experience that is relevant for\r\nmeeting this goal. I see this position at CardioDx as an excellent\r\nopportunity for me to gain experience with the general day-to-day work\r\nprocesses of a biotechnology company, as well as a great chance for me to\r\nconnect and to learn from senior employees in the company. Also, I have\r\nalways been greatly interested in seeing an industry product come to life,\r\nso having the chance to work within CardioDx's product development line was\r\ndefinitely a factor in my consideration for this position.\r\n\r\nAs of this moment, I am currently engaged in other interviews, but they\r\nhave not yet progressed beyond a phone interview.\r\n\r\nI am currently in an on-call position with an hourly pay of $12/hr. I would\r\nlike to aim for a target of at least $17/hr for this position.\r\n\r\nIf I am allowed to move forward with this process, I will be available for\r\nan onsite interview on any Wednesday up until 5 PM or at any time during a\r\nThursday or Friday.\r\n\r\nAgain, thank you for your consideration of my application.\r\n\r\nRegards,\r\n\r\nDavid Liu\r\n\r\n",
#  [<email.message.Message at 0x1c7f544be10>,
#   <email.message.Message at 0x1c7f544b4e0>],
#  'Hi Kevin,\r\n\r\nI just realized that it was you who have just recently called me. I changed\r\nmy phone a while back so I lost most of my past contact information. In any\r\ncase, I would like to express my DEEPEST APOLOGIES for not recognizing you.\r\nI tried redialing your number but you did not pick up. Please let me know\r\nif you were trying to directly contact me or if the call was meant for\r\nsomeone else. I do remember there being another David Liu that provided you\r\nIT support.\r\n\r\nDavid\r\n',
#  "Hey Pete,\r\n\r\nWow. You must do a lot of risky activities.\r\n\r\nHere's the website. https://www.codecademy.com/\r\n\r\nJust a few things to keep in mind:\r\n> You need to register for an account first. It's very fast and easy.\r\n> Again, the website is great at teaching you the basics of programming and\r\nhow to think like a programmer.\r\n> It does not teach you Java, but it teaches you a few other programming\r\nlanguages that are widely used in the industry.\r\n> I highly suggest that you do the projects that the website tells you to\r\ndo. If you can do them successfully, you can add them onto your resume.\r\n\r\nProgramming can be difficult at first, but it will get easier once you\r\nlearn how to think about your codes. Good luck and take care.\r\n\r\nDavid\r\n\r\n\r\n",
#  'Wow lots of info. Thanks. Keep me updated on the web development thing.\r\n\r\n',
#  'Hi Charles,\r\n\r\nWill be dropping by tomorrow instead. Same time as always ~ 9:30 - 10:00.\r\n\r\nDavid\r\n\r\n',
#  'Ah yes. Pretty sure this is the exact guy that my friends recommended for\r\nme to learn java from. Never got to seeing his videos until now, so thanks\r\nfor reminding me. So much more useful than the Java platform SE site.\r\n\r\n',
#  'correction: Both labs are due Monday 19.\r\n\r\n',
#  'Hey Pete,\r\n\r\nGood to hear from you. I figured out Zip. I am currently trying to figure\r\nout Dots and Lines. Let me know which part of Zip do you not get, or if you\r\njust need some general pointers as to how to get started with your codes.\r\n\r\nBoth labs are due on Monday the 17.\r\n\r\nDavid\r\n\r\n',
#  "Hi Andy,\r\n\r\nIt was great meeting up with you today. Thanks for the chat. Learning some\r\nof your tips and perspectives was certainly helpful. Also, if it's\r\nconvenient, I would love to know about any internships or volunteer\r\npositions in web development or software engineering that may come your way\r\nsince you seem to know a good number of people in the industry.\r\n\r\nCheers,\r\n\r\nDavid\r\n",
#  'In checking Zillow, all areas of the island of Alameda are estimated for\r\ncost value, except for areas on the former Alameda Naval Base. Therefore,\r\nit was not possible to arrive at a cost value of the property with this\r\ntool.\r\n\r\n\r\nLink below have the land value info\r\nhttp://www.zillow.com/homes/for_sale/Alameda-CA/land_type/122160513_zpid/16697_rid/37.789851,-122.28044,37.788068,-122.283403_rect/18_zm/1_fr/\r\n\r\n410 Itliong Ln, Alameda, CA 94501\r\nLot Price $19.9 million\r\nLot size: 10.53 acres\r\n\r\nEstimated payment\r\n$3,396/month\r\n\r\nSold at $936,500\r\n',
#  [<email.message.Message at 0x1c7b00cc128>,
#   <email.message.Message at 0x1c7b00cc710>],
#  'http://www.zillow.com/homes/for_sale/Alameda-CA/land_type/16697_rid/37.79018,-122.279492,37.787009,-122.284835_rect/17_zm/1_fr/\r\n',
#  [<email.message.Message at 0x1c7b2d12e48>,
#   <email.message.Message at 0x1c7b261c6d8>],
#  [<email.message.Message at 0x1c7b261c278>,
#   <email.message.Message at 0x1c7b261c2b0>],
#  "There is a possibility that I might also be out during those Sundays. If\r\nChristian haven't already agreed to both Sundays yet, then I may need more\r\ntime to know how my schedule will turn out.\r\n\r\nDavid\r\n\r\n",
#  [<email.message.Message at 0x1c7f4fba438>,
#   <email.message.Message at 0x1c7f4fba0b8>]]

# %% [markdown]
# Checking the length of words in all extracted emails

# %%
word_dic = {}

for email in extracted_emails:
    try:
        split_email = email.split()
        for word in split_email:
            word_length = len(word)
            
            if word_length not in word_dic:
                word_dic[word_length] = 1
            else:
                word_dic[word_length] += 1
    except:
        print("Cannot split email")
# Out:
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email
# Cannot split email

# %% [markdown]
# ### Second Cleaning
# Below codes check for how many words of certain lengths are in the extracted emails.

# %%
for key in sorted(word_dic):
    print(key, word_dic[key])
# Out:
# 1 896
# 2 2374
# 3 2402
# 4 2245
# 5 1367
# 6 855
# 7 884
# 8 721
# 9 526
# 10 309
# 11 216
# 12 133
# 13 78
# 14 45
# 15 7
# 16 7
# 17 6
# 18 6
# 19 4
# 20 8
# 21 5
# 22 1
# 23 2
# 24 2
# 27 3
# 28 2
# 29 1
# 31 1
# 33 1
# 34 1
# 40 1
# 41 1
# 42 2
# 47 1
# 51 1
# 54 2
# 55 1
# 57 1
# 63 1
# 64 1
# 65 1
# 66 1
# 68 1
# 69 1
# 76 29
# 81 1
# 93 1
# 94 1
# 95 1
# 114 1
# 127 1
# 140 1
# 142 1
# 155 1
# 159 1
# 191 2
# 209 1

# %% [markdown]
# Going through the email to remove as many non-words as possible, such as web links and formattings. These non-words are usually long, so the codes below will simply remove strings that are greater than a certain length. Shown above, it would appear that the large majority of words are below 15 characters in length. As such, codes below will remove all words in all emails with lengths of 15 and over. Sequences of words after the removed long word will not be treated as contiguous from the sequence of words before the long word. These sequences of words will be removed from the original email and be treated as a new sequence of words.

# %%
def clean_word_sequences(list_of_emails, word_length_cutoff):
    cleaned_emails = []

    for email_texts in list_of_emails:
        try:
            sequence = []
            
            raw_email = email_texts.split()
            
            # removes the copy of the parent email from a reply email.
            # all parent copies starts with ">"
            for word in raw_email:
                if word == ">":
                    if len(sequence) > 0:
                        cleaned_emails.append(sequence)
                        sequence = [] 
                    break
                
                
                if len(word) < word_length_cutoff:
                    if word[len(word)-1:] in ["!","?",".",",",")"]:
                        sequence.append(word[:len(word)-1].lower())
                        sequence.append(word[len(word)-1:])
                    elif word[:1] in ["!","?",".",",","("]:
                        sequence.append(word[1:len(word)].lower())
                        sequence.append(word[:1])
                    else:
                        sequence.append(word.lower())
                else:
                    if len(sequence) > 0:
                        cleaned_emails.append(sequence)
                        sequence = []         
            
            if len(sequence) > 0:
                cleaned_emails.append(sequence)
        except:
            print("Could not be split")   
            
    return cleaned_emails

# %%
word_length_cutoff = 15

cleaned_data = clean_word_sequences(extracted_emails, word_length_cutoff)
cleaned_data
# Out:
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# [['this', 'is', 'a', 'response'],
#  ['hi', 'david', ',', 'this', 'is', 'a', 'sample', 'email', '.'],
#  ['e=3dadl-gbase', 'older', 'model:'],
#  ['hi',
#   'han',
#   ',',
#   'this',
#   'is',
#   'just',
#   'a',
#   'quick',
#   'follow-up',
#   'from',
#   'yesterday',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'spending',
#   'an',
#   'extended',
#   'period',
#   'of',
#   'time',
#   'interviewing',
#   'me',
#   ',',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'what',
#   'the',
#   'contract',
#   'position',
#   'entails',
#   '.',
#   'i',
#   'am',
#   'excited',
#   'for',
#   'the',
#   'possibility',
#   'of',
#   'working',
#   'with',
#   'the',
#   'health',
#   'strategic',
#   'initiative',
#   'team',
#   'to',
#   'build',
#   'data',
#   'pipelines',
#   'and',
#   'machine',
#   'learning',
#   'functions',
#   'for',
#   'health',
#   'and',
#   'wellness',
#   'applications',
#   '.',
#   'looking',
#   'forward',
#   'to',
#   'hearing',
#   'back',
#   'about',
#   'any',
#   'updates',
#   'on',
#   'the',
#   'position',
#   '.',
#   'best',
#   'regards',
#   ',',
#   'david'],
#  ['greetings',
#   'han',
#   ',',
#   'i',
#   'am',
#   'guaranteed',
#   'to',
#   'be',
#   'free',
#   'on',
#   'friday',
#   '10/9',
#   'at',
#   '4',
#   'pm',
#   '.',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'speaking',
#   'with',
#   'you',
#   'soon',
#   '!',
#   'thanks',
#   ',',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'that',
#   'is',
#   'great',
#   '!',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'speaking',
#   'with',
#   'your',
#   'lead',
#   '.',
#   'should',
#   'i',
#   'be',
#   'expecting',
#   'an',
#   'email',
#   'some',
#   'time',
#   'later',
#   'today',
#   '?',
#   'thanks',
#   ',',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'this',
#   'is',
#   'just',
#   'a',
#   'follow',
#   'up',
#   'on',
#   'our',
#   'previous',
#   'conversation',
#   'regarding',
#   'the',
#   'contract',
#   'positions',
#   '.',
#   'since',
#   'the',
#   'positions',
#   'are',
#   'still',
#   'in',
#   'the',
#   'works',
#   ',',
#   'would',
#   'it',
#   'be',
#   'necessary',
#   'for',
#   'me',
#   'to',
#   'check',
#   'in',
#   'again',
#   'at',
#   'a',
#   'later',
#   'date',
#   'if',
#   'i',
#   'am',
#   'still',
#   'interested',
#   '?',
#   'and',
#   'if',
#   'so',
#   ',',
#   'when',
#   'do',
#   'you',
#   'think',
#   'would',
#   'be',
#   'a',
#   'good',
#   'time',
#   'for',
#   'me',
#   'to',
#   'do',
#   'so',
#   '?',
#   'i',
#   'ask',
#   'because',
#   'it',
#   'was',
#   'unclear',
#   'to',
#   'me',
#   'during',
#   'our',
#   'previous',
#   'correspondence',
#   'whether',
#   'we',
#   'were',
#   'planning',
#   'to',
#   'further',
#   'discuss',
#   'the',
#   'topic',
#   ',',
#   'or',
#   'whether',
#   'i',
#   'should',
#   'check',
#   'in',
#   'later',
#   '.',
#   'if',
#   'there',
#   "isn't",
#   'much',
#   'information',
#   'on',
#   'the',
#   'planned',
#   'contract',
#   'positions',
#   'at',
#   'the',
#   'moment',
#   ',',
#   'that',
#   'is',
#   'fine',
#   'too',
#   '.',
#   'in',
#   'any',
#   'case',
#   ',',
#   'thank',
#   'you',
#   'so',
#   'much',
#   'for',
#   'your',
#   'time',
#   'and',
#   'patience',
#   'regarding',
#   'my',
#   'inquiries',
#   'about',
#   'these',
#   'opportunities',
#   ',',
#   'thus',
#   'far',
#   '.',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'i',
#   'completely',
#   'understand',
#   '.',
#   'the',
#   'contractor',
#   'position',
#   'sounds',
#   'great',
#   'and',
#   'i',
#   'am',
#   'certainly',
#   'open',
#   'to',
#   'further',
#   'discuss',
#   'this',
#   'opportunity',
#   '.',
#   'what',
#   'would',
#   'be',
#   'the',
#   'next',
#   'step',
#   '?',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'i',
#   'would',
#   'like',
#   'to',
#   'check',
#   'in',
#   'again',
#   'on',
#   'the',
#   'status',
#   'of',
#   'the',
#   'health',
#   'strategic',
#   'initiatives',
#   'data',
#   'engineering',
#   'position',
#   'and',
#   'whether',
#   'it',
#   'is',
#   'still',
#   'available',
#   '.',
#   'i',
#   'am',
#   'still',
#   'very',
#   'much',
#   'interested',
#   'in',
#   'the',
#   'position',
#   'and',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'hearing',
#   'back',
#   'about',
#   'any',
#   'updates',
#   'on',
#   'the',
#   'situation',
#   '.',
#   'thanks',
#   ',',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'i',
#   'checked',
#   'in',
#   'with',
#   'andy',
#   'yesterday',
#   ',',
#   'and',
#   'he',
#   'responded',
#   'earlier',
#   'today',
#   '.',
#   'according',
#   'to',
#   'him',
#   ',',
#   'he',
#   'does',
#   'not',
#   'know',
#   'the',
#   'headcount',
#   'for',
#   'fy2021',
#   'and',
#   'told',
#   'me',
#   'to',
#   'check',
#   'in',
#   'later',
#   'as',
#   'he',
#   'will',
#   'find',
#   'out',
#   'some',
#   'time',
#   'between',
#   'now',
#   'and',
#   'october',
#   '1',
#   '.',
#   'would',
#   'you',
#   'happen',
#   'to',
#   'know',
#   'how',
#   'long',
#   'does',
#   'this',
#   'usually',
#   'take',
#   '?',
#   'thanks',
#   ',',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'thanks',
#   'for',
#   'the',
#   'update',
#   'about',
#   'the',
#   'situation',
#   '.',
#   'i',
#   'will',
#   'check',
#   'back',
#   'around',
#   '3',
#   'weeks',
#   'from',
#   'now',
#   ',',
#   'or',
#   'some',
#   'time',
#   'during',
#   'the',
#   'week',
#   'of',
#   'september',
#   '21',
#   ',',
#   'if',
#   'you',
#   "don't",
#   'mind',
#   '.',
#   'thanks',
#   ',',
#   'david'],
#  ['greetings',
#   'andy',
#   ',',
#   'we',
#   'previously',
#   'spoke',
#   'over',
#   'the',
#   'phone',
#   'on',
#   'june',
#   '7',
#   'regarding',
#   'the',
#   'health',
#   'strategic',
#   'initiatives',
#   'data',
#   'engineer',
#   'position',
#   ',',
#   'and',
#   'you',
#   'suggested',
#   'that',
#   'i',
#   'contact',
#   'you',
#   'again',
#   'about',
#   'it',
#   'during',
#   'early',
#   'september',
#   'of',
#   'this',
#   'year',
#   'for',
#   'a',
#   'possible',
#   'formal',
#   'screening',
#   '.',
#   'is',
#   'the',
#   'position',
#   'still',
#   'open',
#   'at',
#   'this',
#   'time',
#   '?',
#   'if',
#   'so',
#   ',',
#   'what',
#   'would',
#   'be',
#   'the',
#   'next',
#   'step',
#   '?',
#   'thank',
#   'you',
#   'very',
#   'much',
#   '.',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'it',
#   'has',
#   'certainly',
#   'been',
#   'a',
#   'while',
#   'since',
#   'we',
#   'last',
#   'spoke',
#   ',',
#   'so',
#   'thanks',
#   'for',
#   'reaching',
#   'out',
#   'to',
#   'me',
#   'and',
#   'for',
#   'the',
#   'reminder',
#   'and',
#   'tips',
#   '!',
#   'my',
#   'apologies',
#   'for',
#   'the',
#   'lack',
#   'of',
#   'news',
#   'about',
#   'my',
#   'status',
#   'recently',
#   ',',
#   'but',
#   'i',
#   'am',
#   'currently',
#   'finishing',
#   'up',
#   'the',
#   'last',
#   'week',
#   'of',
#   'my',
#   'summer',
#   'session',
#   'so',
#   'i',
#   'have',
#   'not',
#   'been',
#   'sending',
#   'out',
#   'many',
#   'resumes',
#   'for',
#   'the',
#   'last',
#   'couple',
#   'weeks',
#   '.',
#   'i',
#   'plan',
#   'on',
#   'resuming',
#   'my',
#   'job',
#   'apps',
#   'after',
#   'this',
#   'week',
#   'once',
#   'i',
#   'have',
#   'more',
#   'time',
#   '.',
#   'project',
#   'is',
#   'fine',
#   '.',
#   'i',
#   'was',
#   'simply',
#   'reworking',
#   'one',
#   'of',
#   'my',
#   'older',
#   'data',
#   'collection',
#   'projects',
#   'and',
#   'applying',
#   'machine',
#   'learning',
#   'techniques',
#   'to',
#   'better',
#   'fit',
#   'the',
#   'job',
#   'description',
#   ',',
#   'but',
#   'there',
#   'is',
#   'still',
#   'more',
#   'i',
#   'plan',
#   'on',
#   'doing',
#   'with',
#   'it',
#   '.',
#   'i',
#   'will',
#   'definitely',
#   'be',
#   'contacting',
#   'you',
#   'soon',
#   'about',
#   'apple',
#   'positions',
#   ',',
#   'so',
#   "we'll",
#   'be',
#   'in',
#   'touch',
#   '!',
#   'thanks',
#   ',',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'yes',
#   ',',
#   "that's",
#   'basically',
#   'what',
#   'he',
#   'suggested:',
#   'to',
#   'talk',
#   'about',
#   'the',
#   'methods',
#   'i',
#   'used',
#   'in',
#   'my',
#   'project',
#   'and',
#   'why',
#   ',',
#   'any',
#   'possible',
#   'issues',
#   'there',
#   'might',
#   'be',
#   ',',
#   'and',
#   ',',
#   'most',
#   'importantly',
#   ',',
#   'to',
#   'not',
#   'take',
#   'the',
#   'efficiency',
#   'and',
#   'speed',
#   'of',
#   'data',
#   'processing',
#   'tools',
#   'for',
#   'granted',
#   '.',
#   'and',
#   'yes',
#   ',',
#   'i',
#   'intend',
#   'to',
#   'build',
#   'a',
#   'project',
#   'in',
#   'the',
#   'time',
#   'remaining',
#   'as',
#   'you',
#   'suggested',
#   'that',
#   'it',
#   'might',
#   'be',
#   'better',
#   'if',
#   'it',
#   'is',
#   'new',
#   'and',
#   'related',
#   'to',
#   'the',
#   'position',
#   ',',
#   'and',
#   'i',
#   'will',
#   'also',
#   'have',
#   'a',
#   'good',
#   'amount',
#   'of',
#   'machine',
#   'learning',
#   'resources',
#   'to',
#   'work',
#   'with',
#   'as',
#   'i',
#   'am',
#   'taking',
#   'it',
#   'as',
#   'a',
#   'course',
#   'this',
#   'summer',
#   '.',
#   'i',
#   'will',
#   'definitely',
#   'be',
#   'applying',
#   'for',
#   'more',
#   'positions',
#   'at',
#   'apple',
#   'in',
#   'the',
#   'near',
#   'future',
#   ',',
#   'so',
#   'thanks',
#   ',',
#   'and',
#   ',',
#   'again',
#   ',',
#   'we',
#   'will',
#   'be',
#   'in',
#   'touch',
#   '!',
#   'i',
#   'will',
#   'take',
#   'a',
#   'pause',
#   'for',
#   'maybe',
#   'a',
#   'month',
#   ',',
#   'or',
#   'at',
#   'least',
#   'until',
#   'i',
#   'finish',
#   'this',
#   'summer',
#   ',',
#   'as',
#   'it',
#   'appears',
#   'that',
#   'a',
#   'lot',
#   'of',
#   'data',
#   'positions',
#   'utilizes',
#   'machine',
#   'learning',
#   'and',
#   'i',
#   'would',
#   'really',
#   'want',
#   'to',
#   'know',
#   'what',
#   'the',
#   'subject',
#   'is',
#   'all',
#   'about',
#   '.',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'we',
#   'spoke',
#   'for',
#   'around',
#   '40',
#   'minutes',
#   ',',
#   'and',
#   'he',
#   'just',
#   'wanted',
#   'to',
#   'look',
#   'into',
#   'my',
#   'background',
#   'while',
#   'i',
#   'had',
#   'the',
#   'chance',
#   'to',
#   'learn',
#   'more',
#   'about',
#   'the',
#   'position',
#   '.',
#   'there',
#   'was',
#   'actually',
#   'nothing',
#   'technical',
#   'about',
#   'it',
#   '.',
#   'i',
#   'told',
#   'him',
#   'that',
#   'i',
#   'will',
#   'graduate',
#   'this',
#   'coming',
#   'december',
#   ',',
#   'so',
#   'he',
#   'told',
#   'me',
#   'to',
#   'shoot',
#   'him',
#   'an',
#   'email',
#   'during',
#   'early',
#   'september',
#   'which',
#   'is',
#   'when',
#   'he',
#   'will',
#   'set',
#   'up',
#   'a',
#   'formal',
#   'interview',
#   '.',
#   "here's",
#   'hoping',
#   'that',
#   'the',
#   'position',
#   'does',
#   'not',
#   'fill',
#   'by',
#   'then',
#   '.',
#   'i',
#   'also',
#   'asked',
#   'him',
#   'about',
#   'the',
#   'interview',
#   ',',
#   'and',
#   'he',
#   'told',
#   'me',
#   'that',
#   'it',
#   'will',
#   'be',
#   'a',
#   '1',
#   'hour',
#   'presentation',
#   'about',
#   'one',
#   'of',
#   'my',
#   'projects',
#   'but',
#   'gave',
#   'no',
#   'more',
#   'details',
#   'or',
#   'whether',
#   'it',
#   'will',
#   'be',
#   'technical',
#   'or',
#   'not',
#   '.',
#   'said',
#   'that',
#   'if',
#   'i',
#   'were',
#   'to',
#   'be',
#   'hired',
#   'for',
#   'the',
#   'position',
#   ',',
#   'i',
#   'would',
#   'be',
#   'someone',
#   'who',
#   'would',
#   'need',
#   'to',
#   'be',
#   'mentored',
#   'and',
#   'grow',
#   'in',
#   'the',
#   'position',
#   ',',
#   'so',
#   'i',
#   'am',
#   'guessing',
#   'he',
#   'is',
#   'not',
#   'hiring',
#   'me',
#   'for',
#   'my',
#   'expertise',
#   '.',
#   'i',
#   'assume',
#   'that',
#   'this',
#   'sort',
#   'of',
#   'interview',
#   'is',
#   'pretty',
#   'unusual',
#   'for',
#   'apple',
#   'standards',
#   '?',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'someone',
#   'named',
#   'andy',
#   'pham',
#   'contacted',
#   'me',
#   'for',
#   'the',
#   'data',
#   'engineer',
#   ',',
#   'health',
#   'strategic',
#   'initiatives',
#   'position',
#   'role',
#   '('],
#  [')',
#   '.',
#   'we',
#   'arranged',
#   'to',
#   'speak',
#   'for',
#   'a',
#   'few',
#   'minutes',
#   'on',
#   'a',
#   'video',
#   'chat',
#   'for',
#   'the',
#   'coming',
#   'tuesday',
#   'at',
#   '2',
#   'pm',
#   '.',
#   'i',
#   'am',
#   'guessing',
#   'this',
#   'is',
#   'just',
#   'the',
#   'initial',
#   'screening',
#   'to',
#   'see',
#   'whether',
#   'i',
#   'would',
#   'be',
#   'a',
#   'good',
#   'fit',
#   'before',
#   'there',
#   'would',
#   'be',
#   'an',
#   'interview',
#   '.',
#   'do',
#   'you',
#   'have',
#   'any',
#   'idea',
#   'about',
#   'what',
#   'they',
#   'might',
#   'ask',
#   'or',
#   'what',
#   'apple',
#   'does',
#   'differently',
#   'with',
#   'these',
#   'screenings',
#   '?',
#   'thanks',
#   ',',
#   'david'],
#  ['hello',
#   'andy',
#   ',',
#   'marked',
#   'on',
#   'calendar',
#   '.',
#   'looking',
#   'forward',
#   'to',
#   'speaking',
#   'to',
#   'you',
#   'soon',
#   '.',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'i',
#   'will',
#   'be',
#   'available',
#   'anytime',
#   'today',
#   'or',
#   'at',
#   'anytime',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'this',
#   'week',
#   '.',
#   'next',
#   'week',
#   'will',
#   'work',
#   'as',
#   'well',
#   ',',
#   'but',
#   'only',
#   'after',
#   '12',
#   'pm',
#   'on',
#   'tuesdays',
#   'and',
#   'thursdays',
#   '.',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'speaking',
#   'with',
#   'you',
#   '!',
#   'david'],
#  ['hi',
#   'xiaoyi',
#   ',',
#   'good',
#   'to',
#   'know',
#   '!',
#   'i',
#   'will',
#   'keep',
#   'that',
#   'in',
#   'mind',
#   'when',
#   'applying',
#   'for',
#   'apple',
#   'jobs',
#   'in',
#   'the',
#   'future',
#   '.',
#   'since',
#   'there',
#   "isn't",
#   'many',
#   'job',
#   'postings',
#   'left',
#   'that',
#   'match',
#   'my',
#   'current',
#   'skill',
#   'set',
#   ',',
#   'i',
#   'will',
#   'probably',
#   'take',
#   'a',
#   'hiatus',
#   'on',
#   'any',
#   'new',
#   'applications',
#   'at',
#   'apple',
#   'for',
#   'now',
#   '.',
#   "can't",
#   'thank',
#   'you',
#   'enough',
#   'for',
#   'all',
#   'your',
#   'help',
#   'and',
#   'thank',
#   'you',
#   'for',
#   'making',
#   'yourself',
#   'available',
#   'for',
#   'sending',
#   'out',
#   'resumes',
#   'for',
#   'me',
#   'in',
#   'the',
#   'future',
#   '.',
#   'if',
#   'your',
#   'schedule',
#   'or',
#   'situation',
#   'permits',
#   ',',
#   'i',
#   'would',
#   'like',
#   'to',
#   'do',
#   'this',
#   'again',
#   'in',
#   'the',
#   'coming',
#   'months',
#   ',',
#   'assuming',
#   'that',
#   'none',
#   'of',
#   'my',
#   'current',
#   'applications',
#   'go',
#   'through',
#   '.',
#   'cheers',
#   ',',
#   'david'],
#  ['hi',
#   'carlos',
#   ',',
#   'it',
#   'has',
#   'been',
#   'a',
#   'while',
#   'since',
#   'we',
#   'took',
#   'linear',
#   'algebra',
#   'together',
#   'at',
#   'bcc',
#   '.',
#   'i',
#   'hope',
#   'you',
#   'are',
#   'doing',
#   'well',
#   '!',
#   'i',
#   'am',
#   'not',
#   'sure',
#   'if',
#   'your',
#   'email',
#   'was',
#   'actually',
#   'meant',
#   'for',
#   'me',
#   ',',
#   'but',
#   ',',
#   'unfortunately',
#   ',',
#   'i',
#   'am',
#   'in',
#   'no',
#   'position',
#   'to',
#   'hand',
#   'out',
#   'job',
#   'opportunities',
#   'as',
#   'i',
#   'am',
#   'finishing',
#   'up',
#   'a',
#   'graduates',
#   'program',
#   'and',
#   'am',
#   'looking',
#   'for',
#   'work',
#   'positions',
#   'myself;',
#   'so',
#   'it',
#   'looks',
#   'like',
#   'we',
#   'are',
#   'pretty',
#   'much',
#   'in',
#   'the',
#   'same',
#   'boat',
#   '!',
#   'let',
#   'me',
#   'know',
#   'if',
#   'there',
#   'is',
#   'anything',
#   'else',
#   'i',
#   'can',
#   'help',
#   'you',
#   'with',
#   '.',
#   'cheers',
#   ',',
#   'david',
#   'liu'],
#  ['xiaoyi', ',', 'great', '!', 'thanks', 'again', '.', 'david'],
#  ['forgot',
#   'to',
#   'tell',
#   'you',
#   '.',
#   'i',
#   'did',
#   'not',
#   'find',
#   'any',
#   'letters',
#   'for',
#   'you',
#   '.',
#   'i',
#   'am',
#   'not',
#   'sure',
#   'if',
#   'somebody',
#   'else',
#   'is',
#   'keeping',
#   'them',
#   'for',
#   'you',
#   ',',
#   'but',
#   'i',
#   "don't",
#   'think',
#   'there',
#   'are',
#   'any',
#   'letters',
#   'that',
#   'has',
#   'your',
#   'name',
#   'on',
#   'it',
#   '.',
#   'on',
#   'mon',
#   ',',
#   'may',
#   '18',
#   ',',
#   '2020',
#   'at',
#   '9:38',
#   'pm',
#   'david',
#   'liu'],
#  ['wrote:'],
#  ['yes',
#   '.',
#   'okay',
#   '.',
#   'i',
#   'will',
#   'look',
#   'for',
#   'your',
#   'letters',
#   '.',
#   'on',
#   'mon',
#   ',',
#   'may',
#   '18',
#   ',',
#   '2020',
#   'at',
#   '7:27',
#   'pm',
#   '=e6=9e=97',
#   'fanny'],
#  ['wrote=', ':'],
#  ['okay', '.', 'i', 'will', 'look', 'out', 'for', 'it', '.'],
#  ['okay'],
#  ['it',
#   'looks',
#   'like',
#   'i',
#   'received',
#   'the',
#   'letters',
#   '.',
#   'how',
#   'do',
#   'you',
#   'want',
#   'me',
#   'to',
#   'send',
#   'the',
#   'letters',
#   'back',
#   '?'],
#  ['okay', '.', 'i', 'will', 'look', 'out', 'for', 'it'],
#  ['hi',
#   'joe',
#   ',',
#   'in',
#   'that',
#   'case',
#   ',',
#   'thank',
#   'you',
#   'very',
#   'much',
#   'for',
#   'the',
#   'information',
#   '.',
#   "i'll",
#   'definitely',
#   'see',
#   'what',
#   'i',
#   'can',
#   'find',
#   'and',
#   'get',
#   'the',
#   'resume',
#   'updated',
#   'and',
#   'going',
#   '.',
#   'david'],
#  ['hi',
#   'joe',
#   ',',
#   'i',
#   'was',
#   'recently',
#   'told',
#   'about',
#   'openings',
#   'at',
#   'a',
#   'company',
#   'called',
#   'veeva',
#   ',',
#   'and',
#   'i',
#   'believe',
#   'it',
#   'was',
#   'your',
#   'wife',
#   ',',
#   'mrs',
#   '.',
#   'li',
#   ',',
#   'who',
#   'shared',
#   'this',
#   'information',
#   ',',
#   'so',
#   'please',
#   'give',
#   'her',
#   'my',
#   'thanks',
#   '.',
#   'i',
#   'had',
#   'a',
#   'chance',
#   'to',
#   'look',
#   'through',
#   'the',
#   'company',
#   'website',
#   'and',
#   'there',
#   'were',
#   'definitely',
#   'some',
#   'positions',
#   'and',
#   'roles',
#   'that',
#   'i',
#   'found',
#   'interesting',
#   '.',
#   'however',
#   ',',
#   'i',
#   'could',
#   'not',
#   'find',
#   'anything',
#   'other',
#   'than'],
#  ['positions',
#   ',',
#   'which',
#   'i',
#   'am',
#   'not',
#   'available',
#   'for',
#   'at',
#   'this',
#   'time',
#   '.',
#   'may',
#   'i',
#   'ask',
#   'that',
#   'she',
#   'clarify',
#   'exactly',
#   'what',
#   'the',
#   'new',
#   'positions',
#   'are',
#   ',',
#   'or',
#   'where',
#   'on',
#   'the',
#   'website',
#   'can',
#   'i',
#   'find',
#   'them',
#   'in',
#   'case',
#   'i',
#   'am',
#   'looking',
#   'at',
#   'the',
#   'wrong',
#   'places',
#   '?',
#   'thank',
#   'you',
#   'very',
#   'much',
#   '.',
#   'david'],
#  ['hi',
#   'joe',
#   ',',
#   'i',
#   'figured',
#   'that',
#   'i',
#   'should',
#   'share',
#   'this',
#   'email',
#   'with',
#   'you',
#   'so',
#   'that',
#   'you',
#   'know',
#   'which',
#   'email',
#   'i',
#   'may',
#   'be',
#   'contacting',
#   'you',
#   'with',
#   ',',
#   'and',
#   'to',
#   'make',
#   'sure',
#   'that',
#   'i',
#   'added',
#   'your',
#   'email',
#   'correctly',
#   '.',
#   'thanks',
#   'again',
#   'for',
#   'the',
#   'talk',
#   'and',
#   'for',
#   'the',
#   'tips',
#   'you',
#   'shared',
#   'with',
#   'me',
#   'last',
#   'monday',
#   '.',
#   'i',
#   'very',
#   'much',
#   'appreciate',
#   'it',
#   '.',
#   'cheers',
#   ',',
#   'david'],
#  ['join', 'zoom', 'meeting'],
#  ['meeting', 'id:', '554', '033', '172', 'one', 'tap', 'mobile'],
#  ['us', 'san', '(', 'jose', ')'],
#  ['us',
#   'new',
#   '(',
#   'york',
#   ')',
#   'dial',
#   'by',
#   'your',
#   'location',
#   '+1',
#   '669',
#   '900',
#   '6833',
#   'us',
#   'san',
#   '(',
#   'jose',
#   ')',
#   '+1',
#   '646',
#   '558',
#   '8656',
#   'us',
#   'new',
#   '(',
#   'york',
#   ')',
#   'meeting',
#   'id:',
#   '554',
#   '033',
#   '172',
#   'find',
#   'your',
#   'local',
#   'number:'],
#  ['join', 'by', 'sip'],
#  ['join',
#   'by',
#   'h.323',
#   '162.255.37.11',
#   'us',
#   '(',
#   'west',
#   ')',
#   '162.255.36.11',
#   'us',
#   '(',
#   'east',
#   ')',
#   '221.122.88.195',
#   '(china',
#   ')',
#   '115.114.131.7',
#   'india',
#   '(',
#   'mumbai',
#   ')',
#   '115.114.115.7',
#   'india',
#   '(',
#   'hyderabad',
#   ')',
#   '213.19.144.110',
#   '(emea',
#   ')',
#   '103.122.166.55',
#   '(australia',
#   ')',
#   '209.9.211.110',
#   'hong',
#   '(',
#   'kong',
#   ')',
#   '64.211.144.160',
#   '(brazil',
#   ')',
#   '69.174.57.160',
#   '(canada',
#   ')'],
#  ['(japan', ')', 'meeting', 'id:', '554', '033', '172'],
#  ['user', 'name:', 'yufenlin72', 'password:', 'lyf586091'],
#  ['hi',
#   'jamieelee',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'getting',
#   'back',
#   'to',
#   'me',
#   '.',
#   'my',
#   'netid',
#   'is',
#   'az7762',
#   '.',
#   'i',
#   'was',
#   'initially',
#   'having',
#   'issues',
#   'with',
#   'enrolling',
#   'in',
#   'courses',
#   'because',
#   'my',
#   'mycsueb',
#   'site',
#   'did',
#   'not',
#   'include',
#   'a',
#   'student',
#   'tab',
#   'or',
#   'student',
#   'center',
#   'link',
#   '.',
#   'i',
#   'contacted',
#   'gradadmissions',
#   'and',
#   'was',
#   'told',
#   'that',
#   'i',
#   'should',
#   'be',
#   'able',
#   'to',
#   'start',
#   'enrolling',
#   'tomorrow',
#   ',',
#   'so',
#   ',',
#   'unless',
#   'if',
#   'there',
#   'is',
#   'anything',
#   'else',
#   'i',
#   'missed',
#   ',',
#   'i',
#   'believe',
#   'i',
#   'should',
#   'be',
#   'fine',
#   'for',
#   'now',
#   '.',
#   'again',
#   ',',
#   'thanks',
#   'for',
#   'touching',
#   'base',
#   'with',
#   'me',
#   'regarding',
#   'my',
#   'enrollment',
#   'issue',
#   ',',
#   'and',
#   'i',
#   'will',
#   'be',
#   'sure',
#   'to',
#   'direct',
#   'any',
#   'of',
#   'my',
#   'future',
#   'correspondence',
#   'with',
#   'you',
#   'via',
#   'horizon',
#   'in',
#   'the',
#   'future',
#   '.'],
#  ['greetings',
#   'again',
#   'jiming',
#   ',',
#   'it',
#   'appears',
#   'that',
#   'the',
#   'orientation',
#   'registration',
#   'had',
#   'already',
#   'closed',
#   '.',
#   'would',
#   'it',
#   'be',
#   'possible',
#   'that',
#   'i',
#   'just',
#   'show',
#   'up',
#   'and',
#   'attend',
#   'the',
#   'orientation',
#   'anyways',
#   '?',
#   'otherwise',
#   ',',
#   'is',
#   'there',
#   'any',
#   'other',
#   'way',
#   'i',
#   'can',
#   'register',
#   'at',
#   'this',
#   'point',
#   '?',
#   'also',
#   ',',
#   'i',
#   'cannot',
#   'seem',
#   'to',
#   'find',
#   'an',
#   'option',
#   'to',
#   'add',
#   'courses',
#   'on',
#   'the',
#   'mycsueb',
#   'site',
#   'using',
#   'the',
#   'instructions',
#   'provided',
#   'in',
#   'my',
#   'admissions',
#   'package',
#   '.',
#   'do',
#   'i',
#   'need',
#   'to',
#   'follow',
#   'additional',
#   'steps',
#   'to',
#   'register',
#   'for',
#   'classes',
#   'during',
#   'the',
#   'open',
#   'enrollment',
#   'period',
#   'from',
#   'aug',
#   '15',
#   '-',
#   '19',
#   ',',
#   'or',
#   'am',
#   'i',
#   'doing',
#   'something',
#   'wrong',
#   'here',
#   '?',
#   'thanks',
#   'in',
#   'advance',
#   ',',
#   'and',
#   'my',
#   'apologies',
#   'for',
#   'the',
#   'last',
#   'minute',
#   'questions',
#   '.',
#   'it',
#   'was',
#   'a',
#   'bit',
#   'hectic',
#   'waiting',
#   'and',
#   'gathering',
#   'the',
#   'information',
#   'i',
#   'needed',
#   'to',
#   'make',
#   'a',
#   'decision',
#   '.',
#   'regards',
#   ',',
#   'david'],
#  ['greetings',
#   'dr',
#   '.',
#   'jiming',
#   'wu',
#   ',',
#   'i',
#   'received',
#   'an',
#   'offer',
#   'for',
#   'admission',
#   'to',
#   'the',
#   'csueb',
#   'ms',
#   'business',
#   'analytics',
#   'program',
#   'in',
#   'mid',
#   'july',
#   'and',
#   'i',
#   'was',
#   'told',
#   'by',
#   'the',
#   'graduate',
#   'admission',
#   'office',
#   'that',
#   'there',
#   'is',
#   'no',
#   'deadline',
#   'to',
#   'accept',
#   'the',
#   'offer',
#   ',',
#   'so',
#   'i',
#   'want',
#   'to',
#   'confirm',
#   'with',
#   'you',
#   'about',
#   'whether',
#   'this',
#   'information',
#   'is',
#   'accurate',
#   ',',
#   'and',
#   'whether',
#   'there',
#   'are',
#   'any',
#   'information',
#   'about',
#   'any',
#   'deadlines',
#   'that',
#   'i',
#   'may',
#   'had',
#   'missed',
#   'regarding',
#   'the',
#   'admission',
#   'offer',
#   '.',
#   'i',
#   'also',
#   'found',
#   'this',
#   'information',
#   'slightly',
#   'confusing',
#   'because',
#   'there',
#   'is',
#   'an',
#   'msba',
#   'program',
#   'orientation',
#   'on',
#   '8/17',
#   ',',
#   'and',
#   'i',
#   'cannot',
#   'register',
#   'for',
#   'it',
#   'unless',
#   'i',
#   'accept',
#   'my',
#   'offer',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'note',
#   'that',
#   'the',
#   'reason',
#   'why',
#   'i',
#   'want',
#   'to',
#   'know',
#   'about',
#   'the',
#   'offer',
#   'acceptance',
#   'deadline',
#   'is',
#   'because',
#   'i',
#   'am',
#   'still',
#   'trying',
#   'to',
#   'weigh',
#   'my',
#   'options',
#   'and',
#   'i',
#   'probably',
#   'will',
#   'not',
#   'receive',
#   'all',
#   'the',
#   'information',
#   'i',
#   'can',
#   'get',
#   'to',
#   'make',
#   'my',
#   'decision',
#   'for',
#   'grad',
#   'school',
#   'until',
#   'during',
#   'or',
#   'after',
#   'the',
#   'week',
#   'of',
#   'august',
#   '12',
#   '.',
#   'hence',
#   ',',
#   'it',
#   'would',
#   'be',
#   'extremely',
#   'helpful',
#   'for',
#   'me',
#   'to',
#   'know',
#   'whether',
#   'this',
#   'may',
#   'pose',
#   'any',
#   'issues',
#   'in',
#   'regards',
#   'to',
#   'my',
#   'offer',
#   'acceptance',
#   '.',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'time',
#   'and',
#   'thank',
#   'you',
#   'in',
#   'advance',
#   'for',
#   'any',
#   'information',
#   'that',
#   'you',
#   'may',
#   'provide',
#   'me',
#   '.',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'chris',
#   ',',
#   'you',
#   'mentioned',
#   'that',
#   'august',
#   '9',
#   'will',
#   'be',
#   'the',
#   'end',
#   'of',
#   'the',
#   'priority',
#   'registration',
#   'period',
#   '.',
#   'does',
#   'this',
#   'mean',
#   'that',
#   'i',
#   'can',
#   'still',
#   'register',
#   'even',
#   'after',
#   'that',
#   'date',
#   ',',
#   'but',
#   'minus',
#   'a',
#   'few',
#   'priority',
#   'perks',
#   ',',
#   'or',
#   'is',
#   'it',
#   'absolutely',
#   'the',
#   'last',
#   'day',
#   'that',
#   'i',
#   'can',
#   'still',
#   'accept',
#   'an',
#   'offer',
#   'of',
#   'admission',
#   '?',
#   'also',
#   ',',
#   'if',
#   'august',
#   '9',
#   'really',
#   'is',
#   'the',
#   'last',
#   'date',
#   ',',
#   'would',
#   'it',
#   'still',
#   'be',
#   'viable',
#   'for',
#   'me',
#   'to',
#   'register',
#   'this',
#   'week',
#   'since',
#   'i',
#   'understand',
#   'that',
#   'there',
#   'will',
#   'probably',
#   'be',
#   'some',
#   'prerequisites',
#   'or',
#   'processes',
#   'that',
#   "i'll",
#   'need',
#   'to',
#   'finish',
#   'that',
#   'may',
#   'take',
#   'some',
#   'time',
#   ',',
#   'such',
#   'as',
#   'mailing',
#   'in',
#   'transcripts',
#   ',',
#   'registering',
#   'for',
#   'classes',
#   ',',
#   'submitting',
#   'proof',
#   'of',
#   'immunization',
#   ',',
#   'etc..',
#   '.',
#   'thanks',
#   'in',
#   'advance',
#   ',',
#   'david'],
#  ['greetings',
#   'sophie',
#   ',',
#   'it',
#   'has',
#   'recently',
#   'been',
#   'brought',
#   'to',
#   'my',
#   'attention',
#   'that',
#   'the',
#   'time',
#   'window',
#   'for',
#   'accepting',
#   'my',
#   'admission',
#   'to',
#   'the',
#   'sfsu',
#   'msba',
#   'program',
#   'is',
#   'still',
#   'open',
#   '.',
#   'i',
#   'am',
#   'wondering',
#   'when',
#   'is',
#   'the',
#   'actual',
#   'deadline',
#   'for',
#   'me',
#   'to',
#   'make',
#   'a',
#   'decision',
#   '.',
#   'i',
#   'am',
#   'currently',
#   'still',
#   'weighing',
#   'my',
#   'options',
#   'and',
#   'it',
#   'would',
#   'be',
#   'extremely',
#   'helpful',
#   'for',
#   'me',
#   'to',
#   'know',
#   'when',
#   'action',
#   'is',
#   'needed',
#   'on',
#   'my',
#   'part',
#   '.',
#   'for',
#   'instance',
#   ',',
#   'would',
#   'i',
#   'still',
#   'be',
#   'allowed',
#   'to',
#   'make',
#   'a',
#   'decision',
#   'by',
#   'the',
#   'week',
#   'of',
#   'august',
#   '12',
#   '.',
#   'thanks',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['greetings',
#   ',',
#   'it',
#   'has',
#   'recently',
#   'been',
#   'brought',
#   'to',
#   'my',
#   'attention',
#   'that',
#   'the',
#   'time',
#   'window',
#   'for',
#   'accepting',
#   'my',
#   'admission',
#   'to',
#   'the',
#   'csueb',
#   'msbs',
#   'program',
#   'is',
#   'coming',
#   'to',
#   'a',
#   'close',
#   'but',
#   'is',
#   'still',
#   'open',
#   '.',
#   'i',
#   'am',
#   'wondering',
#   'when',
#   'is',
#   'the',
#   'actual',
#   'deadline',
#   'for',
#   'me',
#   'to',
#   'make',
#   'a',
#   'decision',
#   '.',
#   'i',
#   'am',
#   'currently',
#   'still',
#   'weighing',
#   'my',
#   'options',
#   'and',
#   'it',
#   'would',
#   'be',
#   'extremely',
#   'helpful',
#   'for',
#   'me',
#   'to',
#   'know',
#   'when',
#   'action',
#   'is',
#   'needed',
#   'on',
#   'my',
#   'part',
#   '.',
#   'thanks',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['pretty', 'cool', 'you', 'get', 'entire', 'books', '.', 'thanks', '!'],
#  ['hi', 'ben', ',', 'yes', 'i', 'will', 'be', 'available'],
#  ['-',
#   'ive',
#   'confirmed',
#   'that',
#   'the',
#   'one',
#   'above',
#   'is',
#   'the',
#   'one',
#   'i',
#   'want'],
#  ['-',
#   'this',
#   'one',
#   'here',
#   'is',
#   'good',
#   'too',
#   ',',
#   'but',
#   'the',
#   'other',
#   'one',
#   'is',
#   'cheaper',
#   '.'],
#  ['bafb7be'],
#  ['this', 'one.', '.', 'not', 'the', 'one', 'above'],
#  ['311'],
#  ['hi',
#   'bill',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'checking',
#   'in',
#   'with',
#   'me',
#   'and',
#   'my',
#   'apologies',
#   'for',
#   'the',
#   'late',
#   'reply',
#   '.',
#   'i',
#   'have',
#   'very',
#   'recently',
#   'been',
#   'admitted',
#   'to',
#   'my',
#   'top',
#   'choice',
#   'graduate',
#   'program',
#   'in',
#   'data',
#   'science',
#   'and',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'continuing',
#   'with',
#   'my',
#   'application',
#   '.',
#   'thank',
#   'you',
#   'for',
#   'spending',
#   'your',
#   'time',
#   'to',
#   'answer',
#   'the',
#   'questions',
#   'i',
#   'had',
#   'early',
#   'in',
#   'the',
#   'application',
#   'and',
#   'staying',
#   'in',
#   'touch',
#   'with',
#   'me',
#   'throughout',
#   'the',
#   'process',
#   'thus',
#   'far',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['scincus',
#   '-',
#   'get',
#   'rid',
#   'of',
#   '3',
#   'and',
#   'dot',
#   '.',
#   '-',
#   'increase',
#   'size',
#   'if',
#   'dots',
#   'slightly',
#   '-',
#   'fix',
#   'border',
#   'and',
#   'river',
#   'gaps',
#   'keyserlingii',
#   '-',
#   'slightly',
#   'darken',
#   'the',
#   'yellow',
#   'region',
#   '.',
#   '-',
#   'do',
#   'not',
#   'italicize',
#   'the',
#   'parenthesis',
#   'parts',
#   'in',
#   'legend',
#   '-',
#   'fix',
#   'border',
#   'and',
#   'river',
#   'gaps',
#   '-',
#   'increase',
#   'size',
#   'of',
#   'dots',
#   'slightly',
#   '-',
#   'check',
#   'whether',
#   'the',
#   'unknown',
#   'region',
#   'is',
#   'correct',
#   '-',
#   'fix',
#   'legend',
#   'font'],
#  ['greetings',
#   ',',
#   'i',
#   'was',
#   'recently',
#   'admitted',
#   'to',
#   'the',
#   'msds',
#   'program',
#   'and',
#   'my',
#   'application',
#   'checklist',
#   'indicated',
#   'that',
#   'i',
#   'must',
#   'send',
#   'in',
#   'my',
#   'official',
#   "bachelor's",
#   'degree',
#   'transcript',
#   '.',
#   'the',
#   'transcript',
#   'was',
#   'mistakenly',
#   'sent',
#   'electronically',
#   'to',
#   'the',
#   'usf',
#   'office',
#   'of',
#   'graduate',
#   'admission',
#   'located',
#   'at',
#   '2130',
#   'fulton',
#   'street',
#   ',',
#   'san',
#   'francisco',
#   '.',
#   'this',
#   'was',
#   'before',
#   'i',
#   'received',
#   'a',
#   'letter',
#   'in',
#   'my',
#   'application',
#   'status',
#   'page',
#   'instructing',
#   'me',
#   'to',
#   'send',
#   'any',
#   'electronic',
#   'transcripts',
#   'to',
#   'the'],
#  ['email',
#   'address',
#   '.',
#   'can',
#   'my',
#   'official',
#   'transcript',
#   'be',
#   'received',
#   'at',
#   'its',
#   'current',
#   'destination',
#   'or',
#   'should',
#   'i',
#   'request',
#   'to',
#   'send',
#   'a',
#   'copy',
#   'to'],
#  ['as', 'well', '?', 'thanks', ',', 'david', 'liu'],
#  ['un:'],
#  ['pw:', 'ilikebagel!1'],
#  ['hi',
#   'victoria',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'checking',
#   'in',
#   'with',
#   'me',
#   'and',
#   'my',
#   'apologies',
#   'for',
#   'the',
#   'late',
#   'reply',
#   '.',
#   'i',
#   'have',
#   'very',
#   'recently',
#   'received',
#   'admissions',
#   'from',
#   'a',
#   'couple',
#   'of',
#   'my',
#   'top',
#   'choice',
#   'universities',
#   'and',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'continuing',
#   'with',
#   'my',
#   'application',
#   '.',
#   'however',
#   ',',
#   'i',
#   'want',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'striving',
#   'to',
#   'keep',
#   'me',
#   'in',
#   'close',
#   'communications',
#   'throughout',
#   'the',
#   'application',
#   'and',
#   'providing',
#   'me',
#   'with',
#   'the',
#   'information',
#   'i',
#   'need',
#   'to',
#   'weigh',
#   'my',
#   'options',
#   'and',
#   'to',
#   'make',
#   'an',
#   'informed',
#   'decision',
#   '.',
#   'not',
#   'many',
#   'of',
#   'the',
#   'colleges',
#   'i',
#   'applied',
#   'to',
#   'actively',
#   'initiated',
#   'conversions',
#   'with',
#   'applicants',
#   '.',
#   'thanks',
#   'again',
#   ',',
#   'david',
#   'liu'],
#  ['was',
#   'expecting',
#   'something',
#   'like',
#   'codeacademy',
#   ',',
#   'but',
#   'it',
#   'looks',
#   'like',
#   "there's",
#   'a',
#   'lot',
#   'more',
#   'useful',
#   'resources',
#   'here',
#   'than',
#   'just',
#   'some',
#   'practices',
#   '.',
#   'thanks',
#   '!',
#   'will',
#   'look',
#   'more',
#   'into',
#   'it',
#   '.'],
#  ['hi',
#   'victoria',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'letting',
#   'me',
#   'know',
#   'about',
#   'the',
#   'webinar',
#   '.',
#   'unfortunately',
#   ',',
#   'i',
#   'will',
#   'not',
#   'be',
#   'available',
#   'at',
#   'that',
#   'time',
#   'tomorrow',
#   '.',
#   'will',
#   'there',
#   'be',
#   'any',
#   'followup',
#   'webinars',
#   'in',
#   'the',
#   'near',
#   'future',
#   '?',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'maggie',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'checking',
#   'in',
#   'with',
#   'my',
#   'application',
#   'status',
#   '.',
#   'i',
#   'have',
#   'very',
#   'recently',
#   'received',
#   'admissions',
#   'from',
#   'a',
#   'couple',
#   'of',
#   'my',
#   'top',
#   'choice',
#   'universities',
#   'and',
#   'will',
#   'no',
#   'longer',
#   'be',
#   'continuing',
#   'with',
#   'my',
#   'application',
#   '.',
#   'regards',
#   ',',
#   'david'],
#  ['hi',
#   'leyla',
#   ',',
#   'i',
#   'am',
#   'interested',
#   'in',
#   'attending',
#   'the',
#   'webinar',
#   '.',
#   'you',
#   'mentioned',
#   'that',
#   'this',
#   'will',
#   'be',
#   'the',
#   'first',
#   '.',
#   'what',
#   'date',
#   'will',
#   'the',
#   'other',
#   'ones',
#   'be',
#   'held',
#   'and',
#   'will',
#   'they',
#   'be',
#   'the',
#   'same',
#   'as',
#   'this',
#   'one',
#   '?',
#   'thanks',
#   '.',
#   'david'],
#  ['testing', 'testing'],
#  ['good',
#   'to',
#   'know',
#   '!',
#   'will',
#   'hear',
#   'from',
#   'you',
#   'tomorrow',
#   '.',
#   'david'],
#  ['claremont', 'grad', '.', 'uni', '.'],
#  ['un:'],
#  ['pw:', 'ilikebagel!1'],
#  ['hey',
#   'bob',
#   ',',
#   'got',
#   'your',
#   'message',
#   '.',
#   'call',
#   'me',
#   'back',
#   'and',
#   'let',
#   'me',
#   'know',
#   'if',
#   'you',
#   'still',
#   'need',
#   'my',
#   'help',
#   'on',
#   'the',
#   'map',
#   '.',
#   'david'],
#  ['dear',
#   'professor',
#   'stephen',
#   'devlin',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'taking',
#   'your',
#   'time',
#   'to',
#   'interview',
#   'me',
#   'last',
#   'thursday',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'usf',
#   'data',
#   'science',
#   "program's",
#   'curriculum',
#   'roadmap',
#   ',',
#   'as',
#   'well',
#   'as',
#   'the',
#   'advantages',
#   'that',
#   'the',
#   'program',
#   'offers',
#   'its',
#   'students',
#   'in',
#   'terms',
#   'of',
#   'employment',
#   'and',
#   'learning',
#   'outcome',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'reiterate',
#   'my',
#   'interest',
#   'in',
#   'the',
#   "program's",
#   'fast-paced',
#   ',',
#   'rigorous',
#   'academic',
#   'environment',
#   'and',
#   'in',
#   'the',
#   'hands-on',
#   'learning',
#   'approach',
#   'through',
#   'practicum',
#   'projects',
#   '.',
#   'i',
#   'also',
#   'believe',
#   'that',
#   'the',
#   "program's",
#   'focus',
#   'in',
#   'not',
#   'only',
#   'on',
#   'the',
#   'computational',
#   'aspects',
#   'of',
#   'data',
#   'science',
#   ',',
#   'but',
#   'also',
#   'in',
#   'experimental',
#   'design',
#   'and',
#   'statistics',
#   ',',
#   'would',
#   'be',
#   'uniquely',
#   'fitting',
#   'for',
#   'someone',
#   'of',
#   'my',
#   'background',
#   '.',
#   'although',
#   'my',
#   'primary',
#   'programming',
#   'language',
#   'is',
#   'java',
#   ',',
#   'i',
#   'realize',
#   'from',
#   'the',
#   'interview',
#   'and',
#   'data',
#   'science',
#   'programs',
#   'that',
#   'python',
#   'is',
#   'the',
#   'preferred',
#   'programming',
#   'language',
#   'and',
#   'i',
#   'am',
#   'currently',
#   'taking',
#   'a',
#   'course',
#   ',',
#   'python',
#   'for',
#   'data',
#   'science',
#   ',',
#   'to',
#   'improve',
#   'my',
#   'understanding',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'speaking',
#   'with',
#   'me',
#   'and',
#   'i',
#   'am',
#   'enthusiastic',
#   'about',
#   'the',
#   'possibility',
#   'of',
#   'enrolling',
#   'in',
#   'the',
#   'program',
#   '.',
#   'best',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['dear',
#   'professor',
#   'stephen',
#   'devlin',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'taking',
#   'your',
#   'time',
#   'to',
#   'interview',
#   'me',
#   'last',
#   'thursday',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'usf',
#   'data',
#   'science',
#   "program's",
#   'curriculum',
#   'roadmap',
#   ',',
#   'as',
#   'well',
#   'as',
#   'the',
#   'advantages',
#   'that',
#   'the',
#   'program',
#   'offers',
#   'its',
#   'students',
#   'in',
#   'terms',
#   'of',
#   'employment',
#   'and',
#   'learning',
#   'outcome',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'reiterate',
#   'my',
#   'interest',
#   'in',
#   'the',
#   "program's",
#   'fast-paced',
#   ',',
#   'rigorous',
#   'academic',
#   'environment',
#   'and',
#   'in',
#   'the',
#   'hands-on',
#   'learning',
#   'approach',
#   'through',
#   'practicum',
#   'projects',
#   '.',
#   'i',
#   'also',
#   'believe',
#   'that',
#   'the',
#   "program's",
#   'focus',
#   'in',
#   'not',
#   'only',
#   'on',
#   'the',
#   'computational',
#   'aspects',
#   'of',
#   'data',
#   'science',
#   ',',
#   'but',
#   'also',
#   'in',
#   'experimental',
#   'design',
#   'and',
#   'statistics',
#   ',',
#   'would',
#   'be',
#   'uniquely',
#   'fitting',
#   'for',
#   'someone',
#   'of',
#   'my',
#   'background',
#   '.',
#   'although',
#   'my',
#   'primary',
#   'programming',
#   'language',
#   'is',
#   'java',
#   ',',
#   'i',
#   'realize',
#   'from',
#   'the',
#   'interview',
#   'and',
#   'data',
#   'science',
#   'programs',
#   'that',
#   'python',
#   'is',
#   'the',
#   'preferred',
#   'programming',
#   'language',
#   'and',
#   'i',
#   'am',
#   'currently',
#   'taking',
#   'a',
#   'course',
#   ',',
#   'python',
#   'for',
#   'data',
#   'science',
#   ',',
#   'to',
#   'improve',
#   'my',
#   'understanding',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'speaking',
#   'with',
#   'me',
#   'about',
#   'the',
#   'program',
#   'and',
#   'i',
#   'am',
#   'enthusiastic',
#   'about',
#   'the',
#   'possibility',
#   'of',
#   'enrolling',
#   'in',
#   'the',
#   'program',
#   '.',
#   'best',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['dear',
#   'professor',
#   'stephen',
#   'devlin',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'taking',
#   'your',
#   'time',
#   'to',
#   'interview',
#   'me',
#   'last',
#   'thursday',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'usf',
#   'data',
#   'science',
#   "program's",
#   'curriculum',
#   'roadmap',
#   ',',
#   'as',
#   'well',
#   'as',
#   'the',
#   'advantages',
#   'that',
#   'the',
#   'program',
#   'offers',
#   'its',
#   'students',
#   'in',
#   'terms',
#   'of',
#   'employment',
#   'and',
#   'learning',
#   'outcome',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'reiterate',
#   'my',
#   'interest',
#   'in',
#   'the',
#   "program's",
#   'fast-paced',
#   ',',
#   'rigorous',
#   'academic',
#   'environment',
#   'and',
#   'in',
#   'the',
#   'hands-on',
#   'learning',
#   'approach',
#   'through',
#   'practicum',
#   'projects',
#   '.',
#   'i',
#   'also',
#   'believe',
#   'that',
#   'the',
#   "program's",
#   'focus',
#   'in',
#   'not',
#   'only',
#   'on',
#   'the',
#   'computational',
#   'aspects',
#   'of',
#   'data',
#   'science',
#   ',',
#   'but',
#   'also',
#   'in',
#   'experimental',
#   'design',
#   'and',
#   'statistics',
#   ',',
#   'would',
#   'be',
#   'uniquely',
#   'fitting',
#   'for',
#   'someone',
#   'of',
#   'my',
#   'background',
#   '.',
#   'although',
#   'my',
#   'primary',
#   'programming',
#   'language',
#   'is',
#   'java',
#   ',',
#   'i',
#   'realize',
#   'from',
#   'the',
#   'interview',
#   'and',
#   'data',
#   'science',
#   'programs',
#   'that',
#   'python',
#   'is',
#   'the',
#   'preferred',
#   'programming',
#   'language',
#   'and',
#   'i',
#   'am',
#   'currently',
#   'taking',
#   'a',
#   'course',
#   ',',
#   'python',
#   'for',
#   'data',
#   'science',
#   ',',
#   'to',
#   'improve',
#   'my',
#   'understanding',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'speaking',
#   'with',
#   'me',
#   'about',
#   'the',
#   'program',
#   'and',
#   'i',
#   'am',
#   'enthusiastic',
#   'about',
#   'the',
#   'possibility',
#   'of',
#   'enrolling',
#   'in',
#   'the',
#   'program',
#   '.',
#   'best',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['dear',
#   'professor',
#   'stephen',
#   'devlin',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'taking',
#   'your',
#   'time',
#   'to',
#   'interview',
#   'me',
#   'last',
#   'thursday',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'usf',
#   'data',
#   'science',
#   "program's",
#   'curriculum',
#   'roadmap',
#   ',',
#   'as',
#   'well',
#   'as',
#   'the',
#   'advantages',
#   'that',
#   'the',
#   'program',
#   'offers',
#   'its',
#   'students',
#   'in',
#   'terms',
#   'of',
#   'employment',
#   'and',
#   'learning',
#   'outcome',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'reiterate',
#   'my',
#   'interest',
#   'in',
#   'the',
#   "program's",
#   'fast-paced',
#   ',',
#   'rigorous',
#   'academic',
#   'environment',
#   'and',
#   'in',
#   'the',
#   'hands-on',
#   'learning',
#   'approach',
#   'through',
#   'practicum',
#   'projects',
#   '.',
#   'i',
#   'also',
#   'believe',
#   'that',
#   'the',
#   "program's",
#   'focus',
#   'in',
#   'not',
#   'only',
#   'on',
#   'the',
#   'computational',
#   'aspects',
#   'of',
#   'data',
#   'science',
#   ',',
#   'but',
#   'also',
#   'in',
#   'experimental',
#   'design',
#   'and',
#   'statistics',
#   ',',
#   'would',
#   'be',
#   'uniquely',
#   'fitting',
#   'for',
#   'someone',
#   'of',
#   'my',
#   'background',
#   '.',
#   'although',
#   'my',
#   'primary',
#   'programming',
#   'language',
#   'is',
#   'java',
#   ',',
#   'i',
#   'realize',
#   'from',
#   'the',
#   'interview',
#   'and',
#   'data',
#   'science',
#   'programs',
#   'that',
#   'python',
#   'is',
#   'the',
#   'preferred',
#   'programming',
#   'language',
#   'and',
#   'i',
#   'am',
#   'currently',
#   'taking',
#   'a',
#   'course',
#   ',',
#   'python',
#   'for',
#   'data',
#   'science',
#   ',',
#   'to',
#   'improve',
#   'my',
#   'understanding',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'speaking',
#   'with',
#   'me',
#   'about',
#   'the',
#   'program',
#   'and',
#   'i',
#   'am',
#   'enthusiastic',
#   'about',
#   'the',
#   'possibility',
#   'of',
#   'enrolling',
#   'in',
#   'the',
#   'program',
#   '.',
#   'best',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['maybe',
#   'i',
#   'should',
#   'also',
#   'thank',
#   'the',
#   'admissions',
#   'person',
#   'who',
#   'set',
#   'up',
#   'the',
#   'interview',
#   'as',
#   'well',
#   'in',
#   'this',
#   'email.',
#   '.',
#   'what',
#   'do',
#   'you',
#   'think',
#   'about',
#   'including',
#   'it',
#   '.'],
#  ['dear',
#   'professor',
#   'stephen',
#   'devlin',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'taking',
#   'your',
#   'time',
#   'to',
#   'interview',
#   'me',
#   'last',
#   'thursday',
#   'and',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'a',
#   'better',
#   'understanding',
#   'of',
#   'the',
#   'usf',
#   'data',
#   'science',
#   "program's",
#   'curriculum',
#   'roadmap',
#   ',',
#   'as',
#   'well',
#   'as',
#   'the',
#   'advantages',
#   'that',
#   'the',
#   'program',
#   'offers',
#   'its',
#   'students',
#   'in',
#   'terms',
#   'of',
#   'employment',
#   'and',
#   'learning',
#   'outcome',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'reiterate',
#   'my',
#   'interest',
#   'in',
#   'the',
#   "program's",
#   'fast-paced',
#   ',',
#   'rigorous',
#   'academic',
#   'environment',
#   'and',
#   'in',
#   'the',
#   'hands-on',
#   'learning',
#   'approach',
#   'through',
#   'practicum',
#   'projects',
#   '.',
#   'i',
#   'also',
#   'believe',
#   'that',
#   'the',
#   "program's",
#   'focus',
#   'in',
#   'not',
#   'only',
#   'on',
#   'the',
#   'computational',
#   'aspects',
#   'of',
#   'data',
#   'science',
#   ',',
#   'but',
#   'also',
#   'in',
#   'experimental',
#   'design',
#   'and',
#   'statistics',
#   ',',
#   'would',
#   'be',
#   'uniquely',
#   'fitting',
#   'for',
#   'someone',
#   'of',
#   'my',
#   'background',
#   '.',
#   'although',
#   'i',
#   'lack',
#   'a',
#   'fluent',
#   'understanding',
#   'in',
#   'certain',
#   'preferred',
#   'skills',
#   ',',
#   'such',
#   'as',
#   'in',
#   'python',
#   ',',
#   'i',
#   'am',
#   'currently',
#   'actively',
#   'taking',
#   'online',
#   'courses',
#   'in',
#   'order',
#   'to',
#   'improve',
#   'my',
#   'understanding',
#   'of',
#   'the',
#   'subject',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thanks',
#   'for',
#   'speaking',
#   'with',
#   'me',
#   'about',
#   'the',
#   'program',
#   'and',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'hearing',
#   'about',
#   'the',
#   'final',
#   'admissions',
#   'decision',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['greetings',
#   ',',
#   'on',
#   'january',
#   '18',
#   ',',
#   'i',
#   'received',
#   'an',
#   'invitation',
#   'to',
#   'schedule',
#   'an',
#   'online',
#   'interview',
#   'for',
#   'my',
#   'ms',
#   'data',
#   'science',
#   'program',
#   'application',
#   '.',
#   'i',
#   'set',
#   'up',
#   'the',
#   'interview',
#   'to',
#   'be',
#   'on',
#   'january',
#   '24',
#   'at',
#   '1',
#   'pm',
#   'and',
#   'received',
#   'an',
#   'email',
#   'that',
#   'confirmed',
#   'my',
#   'chosen',
#   'date',
#   'and',
#   'time',
#   'for',
#   'an',
#   'online',
#   'meeting',
#   'with',
#   'prof',
#   '.',
#   'stephen',
#   'devlin',
#   '.',
#   'according',
#   'to',
#   'the',
#   'confirmation',
#   'email',
#   ',',
#   'i',
#   'am',
#   'suppose',
#   'to',
#   'receive',
#   'a',
#   'followup',
#   'email',
#   'invitation',
#   'with',
#   'a',
#   'calendar',
#   'invite',
#   'to',
#   'join',
#   'the',
#   'meeting',
#   'on',
#   'zoom',
#   'on',
#   'my',
#   'scheduled',
#   'date',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'know',
#   'the',
#   'status',
#   'of',
#   'the',
#   'email',
#   'as',
#   'i',
#   'have',
#   'not',
#   'yet',
#   'received',
#   'it',
#   '.',
#   'thanks',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['hi',
#   'patrick',
#   ',',
#   'i',
#   'am',
#   'still',
#   'interested',
#   'in',
#   'applying',
#   'for',
#   'the',
#   'ms',
#   'business',
#   'analytics',
#   'program',
#   'at',
#   'ggu',
#   ',',
#   'although',
#   'it',
#   'might',
#   'take',
#   'some',
#   'time',
#   'to',
#   'get',
#   'all',
#   'my',
#   'materials',
#   'together',
#   '.',
#   'just',
#   'to',
#   'clarify',
#   ',',
#   'the',
#   'priority',
#   'deadline',
#   'for',
#   'applying',
#   'to',
#   'the',
#   'fall',
#   'semester',
#   'is',
#   'in',
#   'august',
#   'correct',
#   '?',
#   'regards',
#   ',',
#   'david',
#   'on',
#   'wed',
#   ',',
#   'jan',
#   '16',
#   ',',
#   '2019',
#   'at',
#   '10:09',
#   'am',
#   'patrick',
#   'gonzales'],
#  ['wrote=', ':'],
#  ['dear',
#   'csueb',
#   'graduate',
#   'admissions',
#   'office',
#   ',',
#   'i',
#   'am',
#   'applying',
#   'for',
#   'the',
#   'ms',
#   'business',
#   'analytics',
#   'program',
#   'for',
#   'the',
#   'fall',
#   '2019',
#   'semester',
#   ',',
#   'and',
#   'the',
#   'application',
#   'asks',
#   'that',
#   'i',
#   'send',
#   'official',
#   'transcripts',
#   'from',
#   'all',
#   'colleges',
#   'and',
#   'universities',
#   'attended',
#   'to',
#   'the',
#   'csueb',
#   'office',
#   'of',
#   'admissions',
#   '.',
#   'does',
#   'csu',
#   'east',
#   'bay',
#   'accept',
#   'e-transcripts',
#   ',',
#   'and',
#   'if',
#   'so',
#   ',',
#   'is',
#   'there',
#   'a',
#   'specific',
#   'email',
#   'address',
#   'that',
#   'i',
#   'can',
#   'send',
#   'my',
#   'official',
#   'transcripts',
#   'to',
#   '?',
#   'if',
#   'not',
#   ',',
#   'i',
#   'would',
#   'like',
#   'to',
#   'confirm',
#   'whether',
#   'the',
#   'address',
#   'listed',
#   'as',
#   '"office',
#   'of',
#   'admission',
#   ',',
#   'cal',
#   'state',
#   'east',
#   'bay',
#   ',',
#   '25800',
#   'carlos',
#   'bee',
#   'blvd.',
#   ',',
#   'hayward',
#   ',',
#   'ca',
#   ',',
#   '94542"',
#   'is',
# ...
#   'around',
#   'berkeley',
#   'tonight',
#   'at',
#   'about',
#   '6:30',
#   '-',
#   '6:50',
#   'pm',
#   '.',
#   'if',
#   'that',
#   'time',
#   "isn't",
#   'convenient',
#   'for',
#   'you',
#   ',',
#   'you',
#   'may',
#   'send',
#   'it',
#   'via',
#   'email...',
#   '.',
#   'or',
#   'call/send',
#   'text',
#   'to',
#   'my',
#   'number:',
#   '(510',
#   ')',
#   '219',
#   '-',
#   '5580',
#   '.'],
#  ['hi',
#   'ryan',
#   ',',
#   'sorry',
#   'about',
#   'the',
#   'spam',
#   '.',
#   'please',
#   'send',
#   'the',
#   'one',
#   'sent',
#   'at',
#   '8:49',
#   'instead',
#   '.',
#   'thanks',
#   ',',
#   'david'],
#  ['hello',
#   'mike',
#   ',',
#   'thank',
#   'you',
#   'very',
#   'much',
#   'for',
#   "yesterday's",
#   'interview',
#   'at',
#   '8:30',
#   'pm',
#   '.',
#   'it',
#   'has',
#   'given',
#   'me',
#   'greater',
#   'insight',
#   'into',
#   "genentech's",
#   'work',
#   'culture',
#   'and',
#   'expectations',
#   ',',
#   'which',
#   'has',
#   'reinforced',
#   'my',
#   'interest',
#   'in',
#   'the',
#   'position',
#   '.',
#   'i',
#   'truly',
#   'believe',
#   'that',
#   'working',
#   'at',
#   'genentech',
#   'will',
#   'provide',
#   'me',
#   'with',
#   'a',
#   'great',
#   'opportunity',
#   'to',
#   'gain',
#   'valuable',
#   'practical',
#   'skills',
#   'and',
#   'knowledge',
#   'in',
#   'the',
#   'biotechnology',
#   'industry',
#   'through',
#   'a',
#   'fast-paced',
#   ',',
#   'engaging',
#   ',',
#   'and',
#   'rewarding',
#   'work',
#   'experience',
#   '.',
#   'i',
#   'would',
#   'also',
#   'like',
#   'to',
#   'reiterate',
#   'that',
#   'i',
#   'have',
#   'worked',
#   'in',
#   'a',
#   'number',
#   'of',
#   'collaborative',
#   'laboratory',
#   'environments',
#   'in',
#   'the',
#   'past',
#   ',',
#   'as',
#   'well',
#   'as',
#   'in',
#   'a'],
#  ['and',
#   'physically',
#   'demanding',
#   'retail',
#   'setting',
#   'where',
#   'i',
#   'was',
#   'a',
#   'clerk',
#   'assisting',
#   'with',
#   'cabinet',
#   'sales',
#   '.',
#   'as',
#   'such',
#   ',',
#   'i',
#   'am',
#   'confident',
#   'that',
#   'i',
#   'will',
#   'quickly',
#   'adapt',
#   'to',
#   'the'],
#  ['of',
#   'this',
#   'position',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'interview',
#   '.',
#   "i'm",
#   'sorry',
#   'that',
#   'i',
#   'was',
#   'a',
#   'bit',
#   'nervous',
#   'yesterday',
#   'as',
#   'i',
#   'was',
#   'calculating',
#   'the',
#   'answer',
#   'for',
#   'a',
#   '5%',
#   'detergent',
#   'solution',
#   'and',
#   'i',
#   'realized',
#   'immediately',
#   'afterwards',
#   'that',
#   'my',
#   'solution',
#   'was',
#   'grossly',
#   'incorrect',
#   'a',
#   '(',
#   'quick',
#   'recalculation',
#   'yielded',
#   'an',
#   'addition',
#   'of',
#   '~19,700',
#   'ml',
#   'detergents',
#   'to',
#   'the',
#   '374',
#   'l',
#   'of',
#   'water',
#   ',',
#   'and',
#   'an',
#   'overall',
#   'volume',
#   'of',
#   '~394,000',
#   'ml',
#   'in',
#   'total',
#   ',',
#   'which',
#   'is',
#   'hopefully',
#   'the',
#   'correct',
#   'solution)',
#   '.',
#   'in',
#   'any',
#   'case',
#   ',',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'hearing',
#   'back',
#   'about',
#   'the',
#   'final',
#   'hiring',
#   'decision',
#   '.',
#   'sincerely',
#   ',',
#   'david'],
#  ['hello',
#   'mike',
#   ',',
#   'thank',
#   'you',
#   'very',
#   'much',
#   'for',
#   "yesterday's",
#   'interview',
#   'at',
#   '8:30',
#   'pm',
#   '.',
#   'it',
#   'has',
#   'given',
#   'me',
#   'greater',
#   'insight',
#   'into',
#   "genentech's",
#   'work',
#   'culture',
#   'and',
#   'expectations',
#   ',',
#   'which',
#   'has',
#   'reinforced',
#   'my',
#   'interest',
#   'in',
#   'the',
#   'position',
#   ',',
#   'i',
#   'truly',
#   'believe',
#   'that',
#   'working',
#   'at',
#   'genentech',
#   'will',
#   'provide',
#   'me',
#   'with',
#   'a',
#   'great',
#   'opportunity',
#   'to',
#   'gain',
#   'valuable',
#   'practical',
#   'skills',
#   'and',
#   'knowledge',
#   'in',
#   'the',
#   'biotechnology',
#   'industry',
#   'through',
#   'a',
#   'fast-paced',
#   ',',
#   'engaging',
#   ',',
#   'and',
#   'rewarding',
#   'work',
#   'experience',
#   '.',
#   'i',
#   'would',
#   'also',
#   'like',
#   'to',
#   'reiterate',
#   'that',
#   'i',
#   'have',
#   'worked',
#   'in',
#   'a',
#   'number',
#   'of',
#   'collaborative',
#   'laboratory',
#   'environments',
#   'in',
#   'the',
#   'past',
#   ',',
#   'as',
#   'well',
#   'as',
#   'in',
#   'a'],
#  ['and',
#   'physically',
#   'demanding',
#   'retail',
#   'setting',
#   'where',
#   'i',
#   'was',
#   'a',
#   'clerk',
#   'assisting',
#   'with',
#   'cabinet',
#   'sales',
#   '.',
#   'as',
#   'such',
#   ',',
#   'i',
#   'am',
#   'confident',
#   'that',
#   'i',
#   'will',
#   'quickly',
#   'adapt',
#   'to',
#   'the'],
#  ['of',
#   'this',
#   'position',
#   '.',
#   'once',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'the',
#   'interview',
#   '.',
#   "i'm",
#   'sorry',
#   'that',
#   'i',
#   'was',
#   'a',
#   'bit',
#   'nervous',
#   'yesterday',
#   'as',
#   'i',
#   'was',
#   'calculating',
#   'the',
#   'answer',
#   'for',
#   'a',
#   '5%',
#   'detergent',
#   'solution',
#   'and',
#   'i',
#   'realized',
#   'immediately',
#   'afterwards',
#   'that',
#   'my',
#   'solution',
#   'was',
#   'grossly',
#   'incorrect',
#   'a',
#   '(',
#   'quick',
#   'recalculation',
#   'yielded',
#   'an',
#   'addition',
#   'of',
#   '~19,700',
#   'ml',
#   'detergents',
#   'to',
#   'the',
#   '374',
#   'l',
#   'of',
#   'water',
#   ',',
#   'and',
#   'an',
#   'overall',
#   'volume',
#   'of',
#   '~394,000',
#   'ml',
#   'in',
#   'total',
#   ',',
#   'which',
#   'is',
#   'hopefully',
#   'the',
#   'correct',
#   'solution)',
#   '.',
#   'in',
#   'any',
#   'case',
#   ',',
#   'i',
#   'look',
#   'forward',
#   'to',
#   'hearing',
#   'back',
#   'about',
#   'the',
#   'final',
#   'hiring',
#   'decision',
#   '.',
#   'sincerely',
#   ',',
#   'david'],
#  ['got', 'it', '.', 'see', 'you', 'all', 'tomorrow', '.'],
#  ['hi',
#   'nate',
#   ',',
#   'not',
#   'sure',
#   'if',
#   "it's",
#   'necessary..',
#   '.',
#   'but',
#   'the',
#   'description',
#   'on',
#   'the',
#   'lab3a',
#   '+',
#   'lab3b',
#   'submission',
#   'pages',
#   'suggest',
#   'that',
#   'i',
#   'should',
#   'probably',
#   'let',
#   'you',
#   'know',
#   'directly',
#   'if',
#   'i',
#   'turn',
#   'in',
#   'the',
#   'labs',
#   'after',
#   'the',
#   'due',
#   'date(?)',
#   '.',
#   'this',
#   'email',
#   'is',
#   'just',
#   'to',
#   'let',
#   'you',
#   'know',
#   'that',
#   "they're",
#   'in',
#   '.',
#   'i',
#   'can',
#   'remind',
#   'you',
#   'again',
#   'the',
#   'next',
#   'time',
#   'we',
#   'meet',
#   'in',
#   'class',
#   'if',
#   'needed',
#   '.',
#   'cheers',
#   ',',
#   'david',
#   'liu'],
#  ['again?',
#   '?',
#   'man',
#   'he',
#   'said',
#   'he',
#   'was',
#   'going',
#   'to',
#   'sleep',
#   'yesterday',
#   '.',
#   'yea',
#   'i',
#   'just',
#   'might',
#   'return',
#   'his',
#   'call',
#   'later',
#   'today',
#   '.',
#   "didn't",
#   'even',
#   'really',
#   'noticed',
#   'it',
#   'until',
#   'now',
#   '.'],
#  ['gotcha',
#   '.',
#   "i'm",
#   'already',
#   'at',
#   'alameda',
#   'so',
#   "you'll",
#   'find',
#   'me',
#   'there',
#   '.'],
#  ['hi',
#   'melinda',
#   ',',
#   'just',
#   'to',
#   'add',
#   'on',
#   'to',
#   'my',
#   'last',
#   'email',
#   ',',
#   'if',
#   'the',
#   'position',
#   'is',
#   'still',
#   'open',
#   ',',
#   'i',
#   'am',
#   'willing',
#   'to',
#   'further',
#   'discuss',
#   'about',
#   'it',
#   'over',
#   'the',
#   'phone',
#   'or',
#   'on-site',
#   'if',
#   'emailing',
#   'is',
#   'getting',
#   'too',
#   'troublesome',
#   '.',
#   'let',
#   'me',
#   'know',
#   'what',
#   'you',
#   'think',
#   '.',
#   'i',
#   'would',
#   'love',
#   'to',
#   'learn',
#   'more',
#   'about',
#   'the',
#   'position',
#   'even',
#   'if',
#   'the',
#   'pay',
#   'is',
#   'not',
#   'quite',
#   'up',
#   'to',
#   'where',
#   'i',
#   'am',
#   'targeting',
#   '.',
#   'thanks',
#   ',',
#   'david'],
#  ['would',
#   'love',
#   'to',
#   'drop',
#   'by',
#   'to',
#   'learn',
#   'how',
#   'to',
#   'work',
#   'the',
#   'machines',
#   'although',
#   'i',
#   'can',
#   'only',
#   'stick',
#   'around',
#   'until',
#   '~12:20',
#   'tomorrow',
#   '.',
#   'let',
#   'me',
#   'know',
#   'when',
#   "you'll",
#   'be',
#   'down',
#   'at',
#   'the',
#   'lab',
#   '.',
#   'thanks',
#   '!'],
#  ['hi',
#   'melinda',
#   ',',
#   'i',
#   'will',
#   'still',
#   'consider',
#   'it',
#   ',',
#   'but',
#   'i',
#   'do',
#   'have',
#   'a',
#   'few',
#   'questions',
#   '.',
#   'will',
#   'there',
#   'be',
#   'any',
#   'chance',
#   'for',
#   'an',
#   'employee',
#   'in',
#   'this',
#   'position',
#   'to',
#   'move',
#   'upwards',
#   ',',
#   'and',
#   ',',
#   'if',
#   'so',
#   ',',
#   'will',
#   'there',
#   'be',
#   'a',
#   'pay',
#   'raise',
#   'and',
#   'typically',
#   'how',
#   'much',
#   '?',
#   'also',
#   ',',
#   'i',
#   'realize',
#   'that',
#   'there',
#   'are',
#   'unmentioned'],
#  ['for',
#   'this',
#   'position',
#   'along',
#   'with',
#   'the',
#   'primary',
#   'ones',
#   ',',
#   'so',
#   'i',
#   'would',
#   'like',
#   'to',
#   'ask',
#   'what',
#   'these',
#   'other'],
#  ['might',
#   'be',
#   '.',
#   'will',
#   'they',
#   'involve',
#   'more',
#   'technical',
#   'work',
#   'related',
#   'to',
#   'the',
#   "company's",
#   'main',
#   'product',
#   'line',
#   '?',
#   'thanks',
#   ',',
#   'david'],
#  ['hey',
#   'bob',
#   ',',
#   'so',
#   "i've",
#   'been',
#   'looking',
#   'into',
#   'temp',
#   'agencies',
#   'and',
#   'jobs',
#   'that',
#   'require'],
#  ['information',
#   'from',
#   'some',
#   'of',
#   'my',
#   'past',
#   'places',
#   'of',
#   'employment',
#   '.',
#   'i',
#   'understand',
#   'that',
#   'i',
#   'am',
#   'simply',
#   'volunteering',
#   'as',
#   'a',
#   'lab',
#   'assistant',
#   'at',
#   'profile',
#   'genomics',
#   ',',
#   'but',
#   'would',
#   'you',
#   'like',
#   'to',
#   'be',
#   'listed',
#   'as',
#   'one',
#   'of',
#   'my',
#   'contactable'],
#  ['david'],
#  ['hi',
#   'melinda',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'getting',
#   'back',
#   'to',
#   'me',
#   'about',
#   'my',
#   'application',
#   '.',
#   'i',
#   'want',
#   'to',
#   'build',
#   'my',
#   'career',
#   'in',
#   'the',
#   'biotechnology',
#   'industry',
#   'and',
#   'so',
#   'i',
#   'am',
#   'looking',
#   'for',
#   'new',
#   'opportunities',
#   'to',
#   'gain',
#   'general',
#   'exposure',
#   'and',
#   'experience',
#   'that',
#   'is',
#   'relevant',
#   'for',
#   'meeting',
#   'this',
#   'goal',
#   '.',
#   'i',
#   'see',
#   'this',
#   'position',
#   'at',
#   'cardiodx',
#   'as',
#   'an',
#   'excellent',
#   'opportunity',
#   'for',
#   'me',
#   'to',
#   'gain',
#   'experience',
#   'with',
#   'the',
#   'general',
#   'day-to-day',
#   'work',
#   'processes',
#   'of',
#   'a',
#   'biotechnology',
#   'company',
#   ',',
#   'as',
#   'well',
#   'as',
#   'a',
#   'great',
#   'chance',
#   'for',
#   'me',
#   'to',
#   'connect',
#   'and',
#   'to',
#   'learn',
#   'from',
#   'senior',
#   'employees',
#   'in',
#   'the',
#   'company',
#   '.',
#   'also',
#   ',',
#   'i',
#   'have',
#   'always',
#   'been',
#   'greatly',
#   'interested',
#   'in',
#   'seeing',
#   'an',
#   'industry',
#   'product',
#   'come',
#   'to',
#   'life',
#   ',',
#   'so',
#   'having',
#   'the',
#   'chance',
#   'to',
#   'work',
#   'within',
#   "cardiodx's",
#   'product',
#   'development',
#   'line',
#   'was',
#   'definitely',
#   'a',
#   'factor',
#   'in',
#   'my',
#   'consideration',
#   'for',
#   'this',
#   'position',
#   '.',
#   'as',
#   'of',
#   'this',
#   'moment',
#   ',',
#   'i',
#   'am',
#   'currently',
#   'engaged',
#   'in',
#   'other',
#   'interviews',
#   ',',
#   'but',
#   'they',
#   'have',
#   'not',
#   'yet',
#   'progressed',
#   'beyond',
#   'a',
#   'phone',
#   'interview',
#   '.',
#   'i',
#   'am',
#   'currently',
#   'in',
#   'an',
#   'on-call',
#   'position',
#   'with',
#   'an',
#   'hourly',
#   'pay',
#   'of',
#   '$12/hr',
#   '.',
#   'i',
#   'would',
#   'like',
#   'to',
#   'aim',
#   'for',
#   'a',
#   'target',
#   'of',
#   'at',
#   'least',
#   '$17/hr',
#   'for',
#   'this',
#   'position',
#   '.',
#   'if',
#   'i',
#   'am',
#   'allowed',
#   'to',
#   'move',
#   'forward',
#   'with',
#   'this',
#   'process',
#   ',',
#   'i',
#   'will',
#   'be',
#   'available',
#   'for',
#   'an',
#   'onsite',
#   'interview',
#   'on',
#   'any',
#   'wednesday',
#   'up',
#   'until',
#   '5',
#   'pm',
#   'or',
#   'at',
#   'any',
#   'time',
#   'during',
#   'a',
#   'thursday',
#   'or',
#   'friday',
#   '.',
#   'again',
#   ',',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'consideration',
#   'of',
#   'my',
#   'application',
#   '.',
#   'regards',
#   ',',
#   'david',
#   'liu'],
#  ['hi',
#   'kevin',
#   ',',
#   'i',
#   'just',
#   'realized',
#   'that',
#   'it',
#   'was',
#   'you',
#   'who',
#   'have',
#   'just',
#   'recently',
#   'called',
#   'me',
#   '.',
#   'i',
#   'changed',
#   'my',
#   'phone',
#   'a',
#   'while',
#   'back',
#   'so',
#   'i',
#   'lost',
#   'most',
#   'of',
#   'my',
#   'past',
#   'contact',
#   'information',
#   '.',
#   'in',
#   'any',
#   'case',
#   ',',
#   'i',
#   'would',
#   'like',
#   'to',
#   'express',
#   'my',
#   'deepest',
#   'apologies',
#   'for',
#   'not',
#   'recognizing',
#   'you',
#   '.',
#   'i',
#   'tried',
#   'redialing',
#   'your',
#   'number',
#   'but',
#   'you',
#   'did',
#   'not',
#   'pick',
#   'up',
#   '.',
#   'please',
#   'let',
#   'me',
#   'know',
#   'if',
#   'you',
#   'were',
#   'trying',
#   'to',
#   'directly',
#   'contact',
#   'me',
#   'or',
#   'if',
#   'the',
#   'call',
#   'was',
#   'meant',
#   'for',
#   'someone',
#   'else',
#   '.',
#   'i',
#   'do',
#   'remember',
#   'there',
#   'being',
#   'another',
#   'david',
#   'liu',
#   'that',
#   'provided',
#   'you',
#   'it',
#   'support',
#   '.',
#   'david'],
#  ['hey',
#   'pete',
#   ',',
#   'wow',
#   '.',
#   'you',
#   'must',
#   'do',
#   'a',
#   'lot',
#   'of',
#   'risky',
#   'activities',
#   '.',
#   "here's",
#   'the',
#   'website',
#   '.'],
#  ['just', 'a', 'few', 'things', 'to', 'keep', 'in', 'mind:'],
#  ['wow',
#   'lots',
#   'of',
#   'info',
#   '.',
#   'thanks',
#   '.',
#   'keep',
#   'me',
#   'updated',
#   'on',
#   'the',
#   'web',
#   'development',
#   'thing',
#   '.'],
#  ['hi',
#   'charles',
#   ',',
#   'will',
#   'be',
#   'dropping',
#   'by',
#   'tomorrow',
#   'instead',
#   '.',
#   'same',
#   'time',
#   'as',
#   'always',
#   '~',
#   '9:30',
#   '-',
#   '10:00',
#   '.',
#   'david'],
#  ['ah',
#   'yes',
#   '.',
#   'pretty',
#   'sure',
#   'this',
#   'is',
#   'the',
#   'exact',
#   'guy',
#   'that',
#   'my',
#   'friends',
#   'recommended',
#   'for',
#   'me',
#   'to',
#   'learn',
#   'java',
#   'from',
#   '.',
#   'never',
#   'got',
#   'to',
#   'seeing',
#   'his',
#   'videos',
#   'until',
#   'now',
#   ',',
#   'so',
#   'thanks',
#   'for',
#   'reminding',
#   'me',
#   '.',
#   'so',
#   'much',
#   'more',
#   'useful',
#   'than',
#   'the',
#   'java',
#   'platform',
#   'se',
#   'site',
#   '.'],
#  ['correction:', 'both', 'labs', 'are', 'due', 'monday', '19', '.'],
#  ['hey',
#   'pete',
#   ',',
#   'good',
#   'to',
#   'hear',
#   'from',
#   'you',
#   '.',
#   'i',
#   'figured',
#   'out',
#   'zip',
#   '.',
#   'i',
#   'am',
#   'currently',
#   'trying',
#   'to',
#   'figure',
#   'out',
#   'dots',
#   'and',
#   'lines',
#   '.',
#   'let',
#   'me',
#   'know',
#   'which',
#   'part',
#   'of',
#   'zip',
#   'do',
#   'you',
#   'not',
#   'get',
#   ',',
#   'or',
#   'if',
#   'you',
#   'just',
#   'need',
#   'some',
#   'general',
#   'pointers',
#   'as',
#   'to',
#   'how',
#   'to',
#   'get',
#   'started',
#   'with',
#   'your',
#   'codes',
#   '.',
#   'both',
#   'labs',
#   'are',
#   'due',
#   'on',
#   'monday',
#   'the',
#   '17',
#   '.',
#   'david'],
#  ['hi',
#   'andy',
#   ',',
#   'it',
#   'was',
#   'great',
#   'meeting',
#   'up',
#   'with',
#   'you',
#   'today',
#   '.',
#   'thanks',
#   'for',
#   'the',
#   'chat',
#   '.',
#   'learning',
#   'some',
#   'of',
#   'your',
#   'tips',
#   'and',
#   'perspectives',
#   'was',
#   'certainly',
#   'helpful',
#   '.',
#   'also',
#   ',',
#   'if',
#   "it's",
#   'convenient',
#   ',',
#   'i',
#   'would',
#   'love',
#   'to',
#   'know',
#   'about',
#   'any',
#   'internships',
#   'or',
#   'volunteer',
#   'positions',
#   'in',
#   'web',
#   'development',
#   'or',
#   'software',
#   'engineering',
#   'that',
#   'may',
#   'come',
#   'your',
#   'way',
#   'since',
#   'you',
#   'seem',
#   'to',
#   'know',
#   'a',
#   'good',
#   'number',
#   'of',
#   'people',
#   'in',
#   'the',
#   'industry',
#   '.',
#   'cheers',
#   ',',
#   'david'],
#  ['in',
#   'checking',
#   'zillow',
#   ',',
#   'all',
#   'areas',
#   'of',
#   'the',
#   'island',
#   'of',
#   'alameda',
#   'are',
#   'estimated',
#   'for',
#   'cost',
#   'value',
#   ',',
#   'except',
#   'for',
#   'areas',
#   'on',
#   'the',
#   'former',
#   'alameda',
#   'naval',
#   'base',
#   '.',
#   'therefore',
#   ',',
#   'it',
#   'was',
#   'not',
#   'possible',
#   'to',
#   'arrive',
#   'at',
#   'a',
#   'cost',
#   'value',
#   'of',
#   'the',
#   'property',
#   'with',
#   'this',
#   'tool',
#   '.',
#   'link',
#   'below',
#   'have',
#   'the',
#   'land',
#   'value',
#   'info'],
#  ['410',
#   'itliong',
#   'ln',
#   ',',
#   'alameda',
#   ',',
#   'ca',
#   '94501',
#   'lot',
#   'price',
#   '$19.9',
#   'million',
#   'lot',
#   'size:',
#   '10.53',
#   'acres',
#   'estimated',
#   'payment',
#   '$3,396/month',
#   'sold',
#   'at',
#   '$936,500'],
#  ['there',
#   'is',
#   'a',
#   'possibility',
#   'that',
#   'i',
#   'might',
#   'also',
#   'be',
#   'out',
#   'during',
#   'those',
#   'sundays',
#   '.',
#   'if',
#   'christian',
#   "haven't",
#   'already',
#   'agreed',
#   'to',
#   'both',
#   'sundays',
#   'yet',
#   ',',
#   'then',
#   'i',
#   'may',
#   'need',
#   'more',
#   'time',
#   'to',
#   'know',
#   'how',
#   'my',
#   'schedule',
#   'will',
#   'turn',
#   'out',
#   '.',
#   'david']]

# %% [markdown]
# ## Email Data Reformatting
# The data needs to be reformatted in such a way that it can become output for a deep learning model. Codes below will go through all the lists of email words. The algorithm will work in such a way that every sequence of, at most, 5 words will be mapped to the following word as the target. This algorithm will move through each list of words in the entire list of email data and continously form sets of 5 word sequences that maps to the next word as targets.
#
# Firstly, it would be necessary to tokenize the words (change to numbers), because that is the only way a deep learning model can handle the words as data.

# %% [markdown]
# Method reformat_data() formats the data into inputs and outputs

# %%
input_data = None
target_data = None
max_input_length = 5
max_target_length = 1

# %%
def reformat_data(data_list, max_input_len):
    inputs = []
    outputs = []
    
    for email in data_list:
        if len(email) >= 2:
            for i in range(1,len(email)):
                input_sequence = email[max(0,i-max_input_len):i]
                target_word = email[i:i+max_target_length]
                
                if len(input_sequence) < max_input_len:
                    for i in range(max_input_len - len(input_sequence)):
                        input_sequence.append(0)
                
                inputs.append(input_sequence)
                outputs.append(target_word)
                
    return inputs, outputs

# %% [markdown]
# enumerate_words() method finds all the unique words in the list of emails, and then assigns indexes to them. The method then returns a dictionary that contains the enumerated words.

# %%
def enumerate_words(dataset):
    unique_words = []
    word_dic = {}
    
    for word_set in dataset:
        for word in word_set:
            if word not in unique_words:
                unique_words.append(word)
    
    for i, word in enumerate(unique_words):
        word_dic[word] = i
    
    return word_dic, unique_words

# %%
unique_words_list, all_words = enumerate_words(cleaned_data)

# %% [markdown]
# Tokenizing the words, and converting each set of words into set of numbers.

# %%
def split_tokenize(input_len, data, word_list):
    tokenized_data = []
    inputs = []
    outputs = []
    
    for email_text in data:
        seq = []
        
        for word in email_text:
            seq.append(word_list[word])
        
        tokenized_data.append(seq)
    
    inputs, outputs = reformat_data(tokenized_data, input_len)
    
    return inputs, outputs

# %%
input_data, output_data = split_tokenize(max_input_length, cleaned_data, unique_words_list)

# %%
unique_words_list,
# Out:
# ({'this': 0,
#   'is': 1,
#   'a': 2,
#   'response': 3,
#   'hi': 4,
#   'david': 5,
#   ',': 6,
#   'sample': 7,
#   'email': 8,
#   '.': 9,
#   'e=3dadl-gbase': 10,
#   'older': 11,
#   'model:': 12,
#   'han': 13,
#   'just': 14,
#   'quick': 15,
#   'follow-up': 16,
#   'from': 17,
#   'yesterday': 18,
#   'i': 19,
#   'would': 20,
#   'like': 21,
#   'to': 22,
#   'thank': 23,
#   'you': 24,
#   'for': 25,
#   'spending': 26,
#   'an': 27,
#   'extended': 28,
#   'period': 29,
#   'of': 30,
#   'time': 31,
#   'interviewing': 32,
#   'me': 33,
#   'and': 34,
#   'allowing': 35,
#   'have': 36,
#   'better': 37,
#   'understanding': 38,
#   'what': 39,
#   'the': 40,
#   'contract': 41,
#   'position': 42,
#   'entails': 43,
#   'am': 44,
#   'excited': 45,
#   'possibility': 46,
#   'working': 47,
#   'with': 48,
#   'health': 49,
#   'strategic': 50,
#   'initiative': 51,
#   'team': 52,
#   'build': 53,
#   'data': 54,
#   'pipelines': 55,
#   'machine': 56,
#   'learning': 57,
#   'functions': 58,
#   'wellness': 59,
#   'applications': 60,
#   'looking': 61,
#   'forward': 62,
#   'hearing': 63,
#   'back': 64,
#   'about': 65,
#   'any': 66,
#   'updates': 67,
#   'on': 68,
#   'best': 69,
#   'regards': 70,
#   'greetings': 71,
#   'guaranteed': 72,
#   'be': 73,
#   'free': 74,
#   'friday': 75,
#   '10/9': 76,
#   'at': 77,
#   '4': 78,
#   'pm': 79,
#   'look': 80,
#   'speaking': 81,
#   'soon': 82,
#   '!': 83,
#   'thanks': 84,
#   'andy': 85,
#   'that': 86,
#   'great': 87,
#   'your': 88,
#   'lead': 89,
#   'should': 90,
#   'expecting': 91,
#   'some': 92,
#   'later': 93,
#   'today': 94,
#   '?': 95,
#   'follow': 96,
#   'up': 97,
#   'our': 98,
#   'previous': 99,
#   'conversation': 100,
#   'regarding': 101,
#   'positions': 102,
#   'since': 103,
#   'are': 104,
#   'still': 105,
#   'in': 106,
#   'works': 107,
#   'it': 108,
#   'necessary': 109,
#   'check': 110,
#   'again': 111,
#   'date': 112,
#   'if': 113,
#   'interested': 114,
#   'so': 115,
#   'when': 116,
#   'do': 117,
#   'think': 118,
#   'good': 119,
#   'ask': 120,
#   'because': 121,
#   'was': 122,
#   'unclear': 123,
#   'during': 124,
#   'correspondence': 125,
#   'whether': 126,
#   'we': 127,
#   'were': 128,
#   'planning': 129,
#   'further': 130,
#   'discuss': 131,
#   'topic': 132,
#   'or': 133,
#   'there': 134,
#   "isn't": 135,
#   'much': 136,
#   'information': 137,
#   'planned': 138,
#   'moment': 139,
#   'fine': 140,
#   'too': 141,
#   'case': 142,
#   'patience': 143,
#   'my': 144,
#   'inquiries': 145,
#   'these': 146,
#   'opportunities': 147,
#   'thus': 148,
#   'far': 149,
#   'completely': 150,
#   'understand': 151,
#   'contractor': 152,
#   'sounds': 153,
#   'certainly': 154,
#   'open': 155,
#   'opportunity': 156,
#   'next': 157,
#   'step': 158,
#   'status': 159,
#   'initiatives': 160,
#   'engineering': 161,
#   'available': 162,
#   'very': 163,
#   'situation': 164,
#   'xiaoyi': 165,
#   'checked': 166,
#   'he': 167,
#   'responded': 168,
#   'earlier': 169,
#   'according': 170,
#   'him': 171,
#   'does': 172,
#   'not': 173,
#   'know': 174,
#   'headcount': 175,
#   'fy2021': 176,
#   'told': 177,
#   'as': 178,
#   'will': 179,
#   'find': 180,
#   'out': 181,
#   'between': 182,
#   'now': 183,
#   'october': 184,
#   '1': 185,
#   'happen': 186,
#   'how': 187,
#   'long': 188,
#   'usually': 189,
#   'take': 190,
#   'update': 191,
#   'around': 192,
#   '3': 193,
#   'weeks': 194,
#   'week': 195,
#   'september': 196,
#   '21': 197,
#   "don't": 198,
#   'mind': 199,
#   'previously': 200,
#   'spoke': 201,
#   'over': 202,
#   'phone': 203,
#   'june': 204,
#   '7': 205,
#   'engineer': 206,
#   'suggested': 207,
#   'contact': 208,
#   'early': 209,
#   'year': 210,
#   'possible': 211,
#   'formal': 212,
#   'screening': 213,
#   'has': 214,
#   'been': 215,
#   'while': 216,
#   'last': 217,
#   'reaching': 218,
#   'reminder': 219,
#   'tips': 220,
#   'apologies': 221,
#   'lack': 222,
#   'news': 223,
#   'recently': 224,
#   'but': 225,
#   'currently': 226,
#   'finishing': 227,
#   'summer': 228,
#   'session': 229,
#   'sending': 230,
#   'many': 231,
#   'resumes': 232,
#   'couple': 233,
#   'plan': 234,
#   'resuming': 235,
#   'job': 236,
#   'apps': 237,
#   'after': 238,
#   'once': 239,
#   'more': 240,
#   'project': 241,
#   'simply': 242,
#   'reworking': 243,
#   'one': 244,
#   'collection': 245,
#   'projects': 246,
#   'applying': 247,
#   'techniques': 248,
#   'fit': 249,
#   'description': 250,
#   'doing': 251,
#   'definitely': 252,
#   'contacting': 253,
#   'apple': 254,
#   "we'll": 255,
#   'touch': 256,
#   'yes': 257,
#   "that's": 258,
#   'basically': 259,
#   'suggested:': 260,
#   'talk': 261,
#   'methods': 262,
#   'used': 263,
#   'why': 264,
#   'issues': 265,
#   'might': 266,
#   'most': 267,
#   'importantly': 268,
#   'efficiency': 269,
#   'speed': 270,
#   'processing': 271,
#   'tools': 272,
#   'granted': 273,
#   'intend': 274,
#   'remaining': 275,
#   'new': 276,
#   'related': 277,
#   'also': 278,
#   'amount': 279,
#   'resources': 280,
#   'work': 281,
#   'taking': 282,
#   'course': 283,
#   'near': 284,
#   'future': 285,
#   'pause': 286,
#   'maybe': 287,
#   'month': 288,
#   'least': 289,
#   'until': 290,
#   'finish': 291,
#   'appears': 292,
#   'lot': 293,
#   'utilizes': 294,
#   'really': 295,
#   'want': 296,
#   'subject': 297,
#   'all': 298,
#   '40': 299,
#   'minutes': 300,
#   'wanted': 301,
#   'into': 302,
#   'background': 303,
#   'had': 304,
#   'chance': 305,
#   'learn': 306,
#   'actually': 307,
#   'nothing': 308,
#   'technical': 309,
#   'graduate': 310,
#   'coming': 311,
#   'december': 312,
#   'shoot': 313,
#   'which': 314,
#   'set': 315,
#   'interview': 316,
#   "here's": 317,
#   'hoping': 318,
#   'fill': 319,
#   'by': 320,
#   'then': 321,
#   'asked': 322,
#   'hour': 323,
#   'presentation': 324,
#   'gave': 325,
#   'no': 326,
#   'details': 327,
#   'said': 328,
#   'hired': 329,
#   'someone': 330,
#   'who': 331,
#   'need': 332,
#   'mentored': 333,
#   'grow': 334,
#   'guessing': 335,
#   'hiring': 336,
#   'expertise': 337,
#   'assume': 338,
#   'sort': 339,
#   'pretty': 340,
#   'unusual': 341,
#   'standards': 342,
#   'named': 343,
#   'pham': 344,
#   'contacted': 345,
#   'role': 346,
#   '(': 347,
#   ')': 348,
#   'arranged': 349,
#   'speak': 350,
#   'few': 351,
#   'video': 352,
#   'chat': 353,
#   'tuesday': 354,
#   '2': 355,
#   'initial': 356,
#   'see': 357,
#   'before': 358,
#   'idea': 359,
#   'they': 360,
#   'differently': 361,
#   'screenings': 362,
#   'hello': 363,
#   'marked': 364,
#   'calendar': 365,
#   'anytime': 366,
#   'rest': 367,
#   'well': 368,
#   'only': 369,
#   '12': 370,
#   'tuesdays': 371,
#   'thursdays': 372,
#   'keep': 373,
#   'jobs': 374,
#   'postings': 375,
#   'left': 376,
#   'match': 377,
#   'current': 378,
#   'skill': 379,
#   'probably': 380,
#   'hiatus': 381,
#   "can't": 382,
#   'enough': 383,
#   'help': 384,
#   'making': 385,
#   'yourself': 386,
#   'schedule': 387,
#   'permits': 388,
#   'months': 389,
#   'assuming': 390,
#   'none': 391,
#   'go': 392,
#   'through': 393,
#   'cheers': 394,
#   'carlos': 395,
#   'took': 396,
#   'linear': 397,
#   'algebra': 398,
#   'together': 399,
#   'bcc': 400,
#   'hope': 401,
#   'sure': 402,
#   'meant': 403,
#   'unfortunately': 404,
#   'hand': 405,
#   'graduates': 406,
#   'program': 407,
#   'myself;': 408,
#   'looks': 409,
#   'same': 410,
#   'boat': 411,
#   'let': 412,
#   'anything': 413,
#   'else': 414,
#   'can': 415,
#   'liu': 416,
#   'forgot': 417,
#   'tell': 418,
#   'did': 419,
#   'letters': 420,
#   'somebody': 421,
#   'keeping': 422,
#   'them': 423,
#   'name': 424,
#   'mon': 425,
#   'may': 426,
#   '18': 427,
#   '2020': 428,
#   '9:38': 429,
#   'wrote:': 430,
#   'okay': 431,
#   '7:27': 432,
#   '=e6=9e=97': 433,
#   'fanny': 434,
#   'wrote=': 435,
#   ':': 436,
#   'received': 437,
#   'send': 438,
#   'joe': 439,
#   "i'll": 440,
#   'get': 441,
#   'resume': 442,
#   'updated': 443,
#   'going': 444,
#   'openings': 445,
#   'company': 446,
#   'called': 447,
#   'veeva': 448,
#   'believe': 449,
#   'wife': 450,
#   'mrs': 451,
#   'li': 452,
#   'shared': 453,
#   'please': 454,
#   'give': 455,
#   'her': 456,
#   'website': 457,
#   'roles': 458,
#   'found': 459,
#   'interesting': 460,
#   'however': 461,
#   'could': 462,
#   'other': 463,
#   'than': 464,
#   'she': 465,
#   'clarify': 466,
#   'exactly': 467,
#   'where': 468,
#   'wrong': 469,
#   'places': 470,
#   'figured': 471,
#   'share': 472,
#   'make': 473,
#   'added': 474,
#   'correctly': 475,
#   'monday': 476,
#   'appreciate': 477,
#   'join': 478,
#   'zoom': 479,
#   'meeting': 480,
#   'id:': 481,
#   '554': 482,
#   '033': 483,
#   '172': 484,
#   'tap': 485,
#   'mobile': 486,
#   'us': 487,
#   'san': 488,
#   'jose': 489,
#   'york': 490,
#   'dial': 491,
#   'location': 492,
#   '+1': 493,
#   '669': 494,
#   '900': 495,
#   '6833': 496,
#   '646': 497,
#   '558': 498,
#   '8656': 499,
#   'local': 500,
#   'number:': 501,
#   'sip': 502,
#   'h.323': 503,
#   '162.255.37.11': 504,
#   'west': 505,
#   '162.255.36.11': 506,
#   'east': 507,
#   '221.122.88.195': 508,
#   '(china': 509,
#   '115.114.131.7': 510,
#   'india': 511,
#   'mumbai': 512,
#   '115.114.115.7': 513,
#   'hyderabad': 514,
#   '213.19.144.110': 515,
#   '(emea': 516,
#   '103.122.166.55': 517,
#   '(australia': 518,
#   '209.9.211.110': 519,
#   'hong': 520,
#   'kong': 521,
#   '64.211.144.160': 522,
#   '(brazil': 523,
#   '69.174.57.160': 524,
#   '(canada': 525,
#   '(japan': 526,
#   'user': 527,
#   'name:': 528,
#   'yufenlin72': 529,
#   'password:': 530,
#   'lyf586091': 531,
#   'jamieelee': 532,
#   'getting': 533,
#   'netid': 534,
#   'az7762': 535,
#   'initially': 536,
#   'having': 537,
#   'enrolling': 538,
#   'courses': 539,
#   'mycsueb': 540,
#   'site': 541,
#   'include': 542,
#   'student': 543,
#   'tab': 544,
#   'center': 545,
#   'link': 546,
#   'gradadmissions': 547,
#   'able': 548,
#   'start': 549,
#   'tomorrow': 550,
#   'unless': 551,
#   'missed': 552,
#   'touching': 553,
#   'base': 554,
#   'enrollment': 555,
#   'issue': 556,
#   'direct': 557,
#   'via': 558,
#   'horizon': 559,
#   'jiming': 560,
#   'orientation': 561,
#   'registration': 562,
#   'already': 563,
#   'closed': 564,
#   'show': 565,
#   'attend': 566,
#   'anyways': 567,
#   'otherwise': 568,
#   'way': 569,
#   'register': 570,
#   'point': 571,
#   'cannot': 572,
#   'seem': 573,
#   'option': 574,
#   'add': 575,
#   'using': 576,
#   'instructions': 577,
#   'provided': 578,
#   'admissions': 579,
#   'package': 580,
#   'additional': 581,
#   'steps': 582,
#   'classes': 583,
#   'aug': 584,
#   '15': 585,
#   '-': 586,
#   '19': 587,
#   'something': 588,
#   'here': 589,
#   'advance': 590,
#   'minute': 591,
#   'questions': 592,
#   'bit': 593,
#   'hectic': 594,
#   'waiting': 595,
#   'gathering': 596,
#   'needed': 597,
#   'decision': 598,
#   'dr': 599,
#   'wu': 600,
#   'offer': 601,
#   'admission': 602,
#   'csueb': 603,
#   'ms': 604,
#   'business': 605,
#   'analytics': 606,
#   'mid': 607,
#   'july': 608,
#   'office': 609,
#   'deadline': 610,
#   'accept': 611,
#   'confirm': 612,
#   'accurate': 613,
#   'deadlines': 614,
#   'slightly': 615,
#   'confusing': 616,
#   'msba': 617,
#   '8/17': 618,
#   'note': 619,
#   'reason': 620,
#   'acceptance': 621,
#   'trying': 622,
#   'weigh': 623,
#   'options': 624,
#   'receive': 625,
#   'grad': 626,
#   'school': 627,
#   'august': 628,
#   'hence': 629,
#   'extremely': 630,
#   'helpful': 631,
#   'pose': 632,
#   'provide': 633,
#   'chris': 634,
#   'mentioned': 635,
#   '9': 636,
#   'end': 637,
#   'priority': 638,
#   'mean': 639,
#   'even': 640,
#   'minus': 641,
#   'perks': 642,
#   'absolutely': 643,
#   'day': 644,
#   'viable': 645,
#   'prerequisites': 646,
#   'processes': 647,
#   'such': 648,
#   'mailing': 649,
#   'transcripts': 650,
#   'registering': 651,
#   'submitting': 652,
#   'proof': 653,
#   'immunization': 654,
#   'etc..': 655,
#   'sophie': 656,
#   'brought': 657,
#   'attention': 658,
#   'window': 659,
#   'accepting': 660,
#   'sfsu': 661,
#   'wondering': 662,
#   'actual': 663,
#   'weighing': 664,
#   'action': 665,
#   'part': 666,
#   'instance': 667,
#   'allowed': 668,
#   'msbs': 669,
#   'close': 670,
#   'cool': 671,
#   'entire': 672,
#   'books': 673,
#   'ben': 674,
#   'ive': 675,
#   'confirmed': 676,
#   'above': 677,
#   'cheaper': 678,
#   'bafb7be': 679,
#   'one.': 680,
#   '311': 681,
#   'bill': 682,
#   'checking': 683,
#   'late': 684,
#   'reply': 685,
#   'admitted': 686,
#   'top': 687,
#   'choice': 688,
#   'science': 689,
#   'longer': 690,
#   'continuing': 691,
#   'application': 692,
#   'answer': 693,
#   'staying': 694,
#   'throughout': 695,
#   'process': 696,
#   'scincus': 697,
#   'rid': 698,
#   'dot': 699,
#   'increase': 700,
#   'size': 701,
#   'dots': 702,
#   'fix': 703,
#   'border': 704,
#   'river': 705,
#   'gaps': 706,
#   'keyserlingii': 707,
#   'darken': 708,
#   'yellow': 709,
#   'region': 710,
#   'italicize': 711,
#   'parenthesis': 712,
#   'parts': 713,
#   'legend': 714,
#   'unknown': 715,
#   'correct': 716,
#   'font': 717,
#   'msds': 718,
#   'checklist': 719,
#   'indicated': 720,
#   'must': 721,
#   'official': 722,
#   "bachelor's": 723,
#   'degree': 724,
#   'transcript': 725,
#   'mistakenly': 726,
#   'sent': 727,
#   'electronically': 728,
#   'usf': 729,
#   'located': 730,
#   '2130': 731,
#   'fulton': 732,
#   'street': 733,
#   'francisco': 734,
#   'letter': 735,
#   'page': 736,
#   'instructing': 737,
#   'electronic': 738,
#   'address': 739,
#   'its': 740,
#   'destination': 741,
#   'request': 742,
#   'copy': 743,
#   'un:': 744,
#   'pw:': 745,
#   'ilikebagel!1': 746,
#   'victoria': 747,
#   'universities': 748,
#   'striving': 749,
#   'communications': 750,
#   'providing': 751,
#   'informed': 752,
#   'colleges': 753,
#   'applied': 754,
#   'actively': 755,
#   'initiated': 756,
#   'conversions': 757,
#   'applicants': 758,
#   'codeacademy': 759,
#   "there's": 760,
#   'useful': 761,
#   'practices': 762,
#   'letting': 763,
#   'webinar': 764,
#   'followup': 765,
#   'webinars': 766,
#   'maggie': 767,
#   'leyla': 768,
#   'attending': 769,
#   'first': 770,
#   'ones': 771,
#   'held': 772,
#   'testing': 773,
#   'hear': 774,
#   'claremont': 775,
#   'uni': 776,
#   'hey': 777,
#   'bob': 778,
#   'got': 779,
#   'message': 780,
#   'call': 781,
#   'map': 782,
#   'dear': 783,
#   'professor': 784,
#   'stephen': 785,
#   'devlin': 786,
#   'thursday': 787,
#   "program's": 788,
#   'curriculum': 789,
#   'roadmap': 790,
#   'advantages': 791,
#   'offers': 792,
#   'students': 793,
#   'terms': 794,
#   'employment': 795,
#   'outcome': 796,
#   'reiterate': 797,
#   'interest': 798,
#   'fast-paced': 799,
#   'rigorous': 800,
#   'academic': 801,
#   'environment': 802,
#   'hands-on': 803,
#   'approach': 804,
#   'practicum': 805,
#   'focus': 806,
#   'computational': 807,
#   'aspects': 808,
#   'experimental': 809,
#   'design': 810,
#   'statistics': 811,
#   'uniquely': 812,
#   'fitting': 813,
#   'although': 814,
#   'primary': 815,
#   'programming': 816,
#   'language': 817,
#   'java': 818,
#   'realize': 819,
#   'programs': 820,
#   'python': 821,
#   'preferred': 822,
#   'improve': 823,
#   'enthusiastic': 824,
#   'person': 825,
#   'email.': 826,
#   'including': 827,
#   'fluent': 828,
#   'certain': 829,
#   'skills': 830,
#   'online': 831,
#   'order': 832,
#   'final': 833,
#   'january': 834,
#   'invitation': 835,
#   '24': 836,
#   'chosen': 837,
#   'prof': 838,
#   'confirmation': 839,
#   'suppose': 840,
#   'invite': 841,
#   'scheduled': 842,
#   'yet': 843,
#   'patrick': 844,
#   'ggu': 845,
#   'materials': 846,
#   'fall': 847,
#   'semester': 848,
#   'wed': 849,
#   'jan': 850,
#   '16': 851,
#   '2019': 852,
#   '10:09': 853,
#   'gonzales': 854,
#   'asks': 855,
#   'attended': 856,
#   'csu': 857,
#   'bay': 858,
#   'e-transcripts': 859,
#   'specific': 860,
#   'listed': 861,
#   '"office': 862,
#   'cal': 863,
#   'state': 864,
#   '25800': 865,
#   'bee': 866,
#   'blvd.': 867,
#   'hayward': 868,
#   'ca': 869,
#   '94542"': 870,
#   'requirements': 871,
#   'require': 872,
#   'standardized': 873,
#   'test': 874,
#   'scores': 875,
#   'requires': 876,
#   'manually': 877,
#   'entering': 878,
#   'mention': 879,
#   'needing': 880,
#   'copies': 881,
#   'agencies': 882,
#   'clarified': 883,
#   'cgu': 884,
#   'systems': 885,
#   '&': 886,
#   'technology': 887,
#   '"cgu': 888,
#   '150': 889,
#   'e': 890,
#   '10th': 891,
#   '91711"': 892,
#   'allow': 893,
#   'applicant': 894,
#   'submit': 895,
#   'development': 896,
#   'recent': 897,
#   'years': 898,
#   'continues': 899,
#   'pneumatic': 900,
#   'tubes': 901,
#   'discussed': 902,
#   'installed': 903,
#   'streets': 904,
#   'jason': 905,
#   'inconsistent': 906,
#   'attachment': 907,
#   'university': 908,
#   'southern': 909,
#   'california': 910,
#   '(usc)': 911,
#   'oppose': 912,
#   'happens': 913,
#   'acknowledge': 914,
#   'inconsistency': 915,
#   'edit': 916,
#   'experiences': 917,
#   'submission': 918,
#   'below': 919,
#   'brief': 920,
#   'summary': 921,
#   'recall': 922,
#   'volunteer': 923,
#   'intern': 924,
#   'approximately': 925,
#   'two': 926,
#   'traffic': 927,
#   'count': 928,
#   'database': 929,
#   'interactive': 930,
#   'started': 931,
#   '7/30/2012': 932,
#   'worked': 933,
#   '9/28/2012': 934,
#   '10-15': 935,
#   'hours': 936,
#   'looked': 937,
#   'documents': 938,
#   'surveys': 939,
#   'each': 940,
#   'contains': 941,
#   'pedestrian': 942,
#   'bicycle': 943,
#   'vehicle': 944,
#   'counts': 945,
#   'intersection': 946,
#   'oakland': 947,
#   'those': 948,
#   'onto': 949,
#   'excel': 950,
#   'spreadsheet': 951,
#   'kind': 952,
#   'touched': 953,
#   '2014': 954,
#   'reaches': 955,
#   'master': 956,
#   'areas': 957,
#   'supervisors': 958,
#   'past': 959,
#   'experience': 960,
#   'listing': 961,
#   'contactable': 962,
#   'patina': 963,
#   'resh': 964,
#   'lab': 965,
#   'urap': 966,
#   '2013': 967,
#   'introduced': 968,
#   'colleague': 969,
#   'erin': 970,
#   'nematology': 971,
#   'happy': 972,
#   'golden': 973,
#   'gate': 974,
#   'right': 975,
#   'weekend': 976,
#   'saturday': 977,
#   'sunday': 978,
#   '(510': 979,
#   '219-5580': 980,
#   'clarification': 981,
#   'reporting': 982,
#   'gre': 983,
#   '"test': 984,
#   'scores"': 985,
#   'agency': 986,
#   'upload': 987,
#   'printout': 988,
#   'reported': 989,
#   'required': 990,
#   'down': 991,
#   'usda': 992,
#   'facility': 993,
#   'albany': 994,
#   'others': 995,
#   'communicate': 996,
#   'masters': 997,
#   'temporary': 998,
#   'usc': 999,
#   ...},)

# %% [markdown]
# Reformatting the shape of the input data to (length of data inputs, max input length, 1), and then normalizing the integers to be between 0 and 1
#
# Reformatting the output data into dummy variables.

# %%
from tensorflow.keras.utils import to_categorical

reformatted_input_data = np.reshape(input_data, (len(input_data), max_input_length, 1))
reformatted_input_data = reformatted_input_data / float(len(unique_words_list))
print(reformatted_input_data.shape)

reformatted_output_data = to_categorical(output_data)
print(reformatted_output_data.shape)
# Out:
# (13297, 5, 1)
# (13297, 1986)

# %%
reformatted_input_data
# Out:
# array([[[0.00000000e+00],
#         [0.00000000e+00],
#         [0.00000000e+00],
#         [0.00000000e+00],
#         [0.00000000e+00]],
#
#        [[0.00000000e+00],
#         [5.03524673e-04],
#         [0.00000000e+00],
#         [0.00000000e+00],
#         [0.00000000e+00]],
#
#        [[0.00000000e+00],
#         [5.03524673e-04],
#         [1.00704935e-03],
#         [0.00000000e+00],
#         [0.00000000e+00]],
#
#        ...,
#
#        [[9.41591138e-02],
#         [7.25075529e-02],
#         [1.94864048e-01],
#         [9.01309164e-02],
#         [6.41993958e-01]],
#
#        [[7.25075529e-02],
#         [1.94864048e-01],
#         [9.01309164e-02],
#         [6.41993958e-01],
#         [9.11379658e-02]],
#
#        [[1.94864048e-01],
#         [9.01309164e-02],
#         [6.41993958e-01],
#         [9.11379658e-02],
#         [4.53172205e-03]]])

# %% [markdown]
# ## LSTM Models

# %% [markdown]
# Building the model. The LSTM_model() function runs an LSTM model.
# - batch size is 64
# - will be run with 100 and 200 epochs

# %%
def LSTM_model(batch_size, ep, model_name, history_name):
    dimension_size = 256
    
    model = Sequential()
    model.add(LSTM(dimension_size, input_shape=(reformatted_input_data.shape[1], reformatted_input_data.shape[2])))
    model.add(Dropout(0.2))
    model.add(Dense(reformatted_output_data.shape[1], activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    print(model.summary())
    
    gen_model_history = model.fit(reformatted_input_data, reformatted_output_data, epochs=ep, batch_size=batch_size)
    
    # saving the model
    model.save(model_name)
    # saving the loss history of the model
    pd.DataFrame(gen_model_history.history).to_csv(history_name)
    
    return model, gen_model_history

# %% [markdown]
# Building the second model. The LSTM_model_2() function runs an LSTM model. Unlike the first model, this model has two LSTM layers
# - batch size is 64
# - will be run with 100 and 200 epochs

# %%
def LSTM_model_2(batch_size, ep, model_name, history_name):
    dimension_size = 256
    
    model = Sequential()
    model.add(LSTM(dimension_size, return_sequences=True, input_shape=(reformatted_input_data.shape[1], reformatted_input_data.shape[2])))
    model.add(LSTM(dimension_size))
    model.add(Dropout(0.2))
    model.add(Dense(reformatted_output_data.shape[1], activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    print(model.summary())
    
    gen_model_history = model.fit(reformatted_input_data, reformatted_output_data, epochs=ep, batch_size=batch_size)
    
    # saving the model
    model.save(model_name)
    # saving the loss history of the model
    pd.DataFrame(gen_model_history.history).to_csv(history_name)
    
    return model, gen_model_history

# %% [markdown]
# ## Running LSTM_model()
# ### Batch Size 64, Epochs 100

# %%
# batch size and epochs. Adjust these numbers to fit the specifications for the model
# batch_size was 64 for all four models below
# epochs of 100 and 200 were used for LSTM_model
# epochs of 100 and 200 were used for LSTM_model_2
batch_size = 64
epochs = 200

# %%
def return_model(ep, bs):
    # specifying the name of the model and model history csv
    model_name = "text_gen_" + str(ep) +".h5"
    model_history_name = "text_gen_history_" + str(ep) +".csv"
    text_gen_model = None
    text_gen_model_history = pd.DataFrame()

    if os.path.exists(model_name):
        print("Model Found: Loading...")
        text_gen_model = load_model(model_name)
        text_gen_model_history = pd.read_csv(model_history_name)
        print(text_gen_model.summary())
        print("Model Loaded!")
    else:
        print("Model not Found. Fitting model...")
        text_gen_model, text_gen_model_history = LSTM_model(bs, ep, model_name, model_history_name)
        text_gen_model_history = text_gen_model_history.history
        
    return text_gen_model, text_gen_model_history

# %%
gen_model_1, gen_model_history_1 = return_model(epochs, batch_size)
# Out:
# Model Found: Loading...
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_20 (LSTM)               (None, 256)               264192
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1986)              510402
# =================================================================
# Total params: 774,594
# Trainable params: 774,594
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model Loaded!

# %%
plt.figure(figsize=(16,10))
plt.plot(np.arange(0,epochs,1), gen_model_history_1['loss'], color='blue', label='Baseline Train')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.xlim([0,max(np.arange(0,epochs,1))])
plt.ylim([0,10])
plt.legend()
plt.show()

# %% [markdown]
# ### Batch Size 64, Epochs 200

# %%
# batch size and epochs. Adjust these numbers to fit the specifications for the model
# batch_size was 64 for all four models below
# epochs of 100 and 200 were used for LSTM_model
# epochs of 100 and 200 were used for LSTM_model_2
batch_size = 64
epochs = 500

# %%
gen_model_2, gen_model_history_2 = return_model(epochs, batch_size)
# Out:
# Model not Found. Fitting model...
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_25 (LSTM)               (None, 256)               264192
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1986)              510402
# =================================================================
# Total params: 774,594
# Trainable params: 774,594
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 208/208 [==============================] - 3s 14ms/step - loss: 6.3045
# Epoch 2/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.9630
# Epoch 3/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.9464
# Epoch 4/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.9289
# Epoch 5/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.9021
# Epoch 6/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.8758
# Epoch 7/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.8503
# Epoch 8/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.8210
# Epoch 9/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.7851
# Epoch 10/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.7406
# Epoch 11/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.6927
# Epoch 12/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.6406
# Epoch 13/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.5899
# Epoch 14/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.5284
# Epoch 15/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.4739
# Epoch 16/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.4114
# Epoch 17/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.3490
# Epoch 18/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.2815
# Epoch 19/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.2194
# Epoch 20/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.1532
# Epoch 21/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.0888
# Epoch 22/500
# 208/208 [==============================] - 3s 14ms/step - loss: 5.0246
# Epoch 23/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.9605
# Epoch 24/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.8934
# Epoch 25/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.8322
# Epoch 26/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.7752
# Epoch 27/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.7081
# Epoch 28/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.6575
# Epoch 29/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.6057
# Epoch 30/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.5537
# Epoch 31/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.4938
# Epoch 32/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.4427
# Epoch 33/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.3935
# Epoch 34/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.3458
# Epoch 35/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.2954
# Epoch 36/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.2504
# Epoch 37/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.2013
# Epoch 38/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.1655
# Epoch 39/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.1129
# Epoch 40/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.0780
# Epoch 41/500
# 208/208 [==============================] - 3s 14ms/step - loss: 4.0369
# Epoch 42/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.9974
# Epoch 43/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.9555
# Epoch 44/500
# 208/208 [==============================] - 3s 15ms/step - loss: 3.9135
# Epoch 45/500
# 208/208 [==============================] - 3s 15ms/step - loss: 3.8757
# Epoch 46/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.8447
# Epoch 47/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.8113
# Epoch 48/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.7850
# Epoch 49/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.7429
# Epoch 50/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.7049
# Epoch 51/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.6770
# Epoch 52/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.6432
# Epoch 53/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.6161
# Epoch 54/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.5877
# Epoch 55/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.5583
# Epoch 56/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.5226
# Epoch 57/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.4993
# Epoch 58/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.4663
# Epoch 59/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.4328
# Epoch 60/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.4109
# Epoch 61/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.3904
# Epoch 62/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.3525
# Epoch 63/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.3328
# Epoch 64/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.3119
# Epoch 65/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.2881
# Epoch 66/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.2635
# Epoch 67/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.2377
# Epoch 68/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.2201
# Epoch 69/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.1923
# Epoch 70/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.1638
# Epoch 71/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.1599
# Epoch 72/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.1384
# Epoch 73/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.1168
# Epoch 74/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.0918
# Epoch 75/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.0628
# Epoch 76/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.0366
# Epoch 77/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.0147
# Epoch 78/500
# 208/208 [==============================] - 3s 14ms/step - loss: 3.0031
# Epoch 79/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.9829
# Epoch 80/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.9647
# Epoch 81/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.9407
# Epoch 82/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.9300
# Epoch 83/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.9125
# Epoch 84/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8999
# Epoch 85/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8880
# Epoch 86/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8636
# Epoch 87/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8398
# Epoch 88/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8220
# Epoch 89/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.8048
# Epoch 90/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.7816
# Epoch 91/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.7686
# Epoch 92/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.7650
# Epoch 93/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.7403
# Epoch 94/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.7330
# Epoch 95/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6935
# Epoch 96/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6946
# Epoch 97/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6889
# Epoch 98/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6548
# Epoch 99/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6489
# Epoch 100/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6410
# Epoch 101/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6257
# Epoch 102/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6087
# Epoch 103/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.6000
# Epoch 104/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5802
# Epoch 105/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5775
# Epoch 106/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5585
# Epoch 107/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5297
# Epoch 108/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5248
# Epoch 109/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.5095
# Epoch 110/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4996
# Epoch 111/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4882
# Epoch 112/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4842
# Epoch 113/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4634
# Epoch 114/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4592
# Epoch 115/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4512
# Epoch 116/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4331
# Epoch 117/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4096
# Epoch 118/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.4065
# Epoch 119/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3886
# Epoch 120/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3852
# Epoch 121/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3706
# Epoch 122/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3510
# Epoch 123/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3478
# Epoch 124/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3370
# Epoch 125/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3420
# Epoch 126/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.3077
# Epoch 127/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2906
# Epoch 128/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2859
# Epoch 129/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2778
# Epoch 130/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2613
# Epoch 131/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2618
# Epoch 132/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2532
# Epoch 133/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2468
# Epoch 134/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2293
# Epoch 135/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2311
# Epoch 136/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.2155
# Epoch 137/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1987
# Epoch 138/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1879
# Epoch 139/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1744
# Epoch 140/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1773
# Epoch 141/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1698
# Epoch 142/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1569
# Epoch 143/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1501
# Epoch 144/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1322
# Epoch 145/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1196
# Epoch 146/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1064
# Epoch 147/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1095
# Epoch 148/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.1075
# Epoch 149/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0943
# Epoch 150/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0806
# Epoch 151/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0726
# Epoch 152/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0731
# Epoch 153/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0511
# Epoch 154/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0632
# Epoch 155/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0588
# Epoch 156/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0318
# Epoch 157/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0144
# Epoch 158/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0203
# Epoch 159/500
# 208/208 [==============================] - 3s 14ms/step - loss: 2.0105
# Epoch 160/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9935
# Epoch 161/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9960
# Epoch 162/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9898
# Epoch 163/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9783
# Epoch 164/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9535
# Epoch 165/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9606
# Epoch 166/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9499
# Epoch 167/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9499
# Epoch 168/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9393
# Epoch 169/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9367
# Epoch 170/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9209
# Epoch 171/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9150
# Epoch 172/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.9133
# Epoch 173/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8988
# Epoch 174/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8985
# Epoch 175/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8894
# Epoch 176/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8760
# Epoch 177/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8821
# Epoch 178/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8589
# Epoch 179/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8674
# Epoch 180/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8465
# Epoch 181/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8459
# Epoch 182/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8317
# Epoch 183/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8427
# Epoch 184/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8279
# Epoch 185/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8055
# Epoch 186/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8023
# Epoch 187/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8239
# Epoch 188/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7976
# Epoch 189/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7959
# Epoch 190/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7894
# Epoch 191/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.8007
# Epoch 192/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7767
# Epoch 193/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7688
# Epoch 194/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7662
# Epoch 195/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7559
# Epoch 196/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7369
# Epoch 197/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7583
# Epoch 198/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7231
# Epoch 199/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7373
# Epoch 200/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7336
# Epoch 201/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7199
# Epoch 202/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7217
# Epoch 203/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7138
# Epoch 204/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.7094
# Epoch 205/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6812
# Epoch 206/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6750
# Epoch 207/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6730
# Epoch 208/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6825
# Epoch 209/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6600
# Epoch 210/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6656
# Epoch 211/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6625
# Epoch 212/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6540
# Epoch 213/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6503
# Epoch 214/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6625
# Epoch 215/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6485
# Epoch 216/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6324
# Epoch 217/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6256
# Epoch 218/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6267
# Epoch 219/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6170
# Epoch 220/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6117
# Epoch 221/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6006
# Epoch 222/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6229
# Epoch 223/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5928
# Epoch 224/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.6110
# Epoch 225/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5916
# Epoch 226/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5839
# Epoch 227/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5829
# Epoch 228/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5695
# Epoch 229/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5813
# Epoch 230/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5522
# Epoch 231/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5710
# Epoch 232/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5255
# Epoch 233/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5639
# Epoch 234/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5339
# Epoch 235/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5376
# Epoch 236/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5413
# Epoch 237/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5292
# Epoch 238/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5280
# Epoch 239/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5175
# Epoch 240/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5243
# Epoch 241/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.5119
# Epoch 242/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4911
# Epoch 243/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4900
# Epoch 244/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4903
# Epoch 245/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4908
# Epoch 246/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4787
# Epoch 247/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4788
# Epoch 248/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4712
# Epoch 249/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4646
# Epoch 250/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4730
# Epoch 251/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4550
# Epoch 252/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4683
# Epoch 253/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4577
# Epoch 254/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4592
# Epoch 255/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4490
# Epoch 256/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4323
# Epoch 257/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4400
# Epoch 258/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4292
# Epoch 259/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4380
# Epoch 260/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4235
# Epoch 261/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4169
# Epoch 262/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4014
# Epoch 263/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4014
# Epoch 264/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3987
# Epoch 265/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4142
# Epoch 266/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4207
# Epoch 267/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.4066
# Epoch 268/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3972
# Epoch 269/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3840
# Epoch 270/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3828
# Epoch 271/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3696
# Epoch 272/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3844
# Epoch 273/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3588
# Epoch 274/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3754
# Epoch 275/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3549
# Epoch 276/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3546
# Epoch 277/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3658
# Epoch 278/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3719
# Epoch 279/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3571
# Epoch 280/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3480
# Epoch 281/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3387
# Epoch 282/500
# 208/208 [==============================] - 3s 15ms/step - loss: 1.3367
# Epoch 283/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3328
# Epoch 284/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3371
# Epoch 285/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3103
# Epoch 286/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3247
# Epoch 287/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3385: 0s - loss: 1.323 - ETA: 0s -
# Epoch 288/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3103
# Epoch 289/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3162
# Epoch 290/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3152
# Epoch 291/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3206
# Epoch 292/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2932
# Epoch 293/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2931
# Epoch 294/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2966
# Epoch 295/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.3028
# Epoch 296/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2814
# Epoch 297/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2810
# Epoch 298/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2915
# Epoch 299/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2876
# Epoch 300/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2841
# Epoch 301/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2763
# Epoch 302/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2759
# Epoch 303/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2663
# Epoch 304/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2866
# Epoch 305/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2498
# Epoch 306/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2503
# Epoch 307/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2566
# Epoch 308/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2477
# Epoch 309/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2517
# Epoch 310/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2540
# Epoch 311/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2458
# Epoch 312/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2413
# Epoch 313/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2434
# Epoch 314/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2386
# Epoch 315/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2325
# Epoch 316/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2142
# Epoch 317/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2287
# Epoch 318/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2210
# Epoch 319/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2034
# Epoch 320/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2254
# Epoch 321/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2154
# Epoch 322/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2166
# Epoch 323/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2102
# Epoch 324/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2063
# Epoch 325/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.2062
# Epoch 326/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1865
# Epoch 327/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1851
# Epoch 328/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1996
# Epoch 329/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1833
# Epoch 330/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1808
# Epoch 331/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1774
# Epoch 332/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1835
# Epoch 333/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1931
# Epoch 334/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1742
# Epoch 335/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1625
# Epoch 336/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1661
# Epoch 337/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1689
# Epoch 338/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1537
# Epoch 339/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1631: 0s
# Epoch 340/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1670
# Epoch 341/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1648
# Epoch 342/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1584: 0s - loss
# Epoch 343/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1390
# Epoch 344/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1553
# Epoch 345/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1443
# Epoch 346/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1288
# Epoch 347/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1309
# Epoch 348/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1362:
# Epoch 349/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1261
# Epoch 350/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1450
# Epoch 351/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1235
# Epoch 352/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1363
# Epoch 353/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1195
# Epoch 354/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1231
# Epoch 355/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1256
# Epoch 356/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1226
# Epoch 357/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1198
# Epoch 358/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1171
# Epoch 359/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1087
# Epoch 360/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1139
# Epoch 361/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0964
# Epoch 362/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.1098
# Epoch 363/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0932
# Epoch 364/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0847
# Epoch 365/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0925
# Epoch 366/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0846
# Epoch 367/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0813
# Epoch 368/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0753
# Epoch 369/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0700
# Epoch 370/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0669
# Epoch 371/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0928
# Epoch 372/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0797
# Epoch 373/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0654
# Epoch 374/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0713
# Epoch 375/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0772
# Epoch 376/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0625
# Epoch 377/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0683
# Epoch 378/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0690
# Epoch 379/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0679
# Epoch 380/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0579
# Epoch 381/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0422
# Epoch 382/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0581
# Epoch 383/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0616
# Epoch 384/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0485
# Epoch 385/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0431
# Epoch 386/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0350
# Epoch 387/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0217
# Epoch 388/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0288
# Epoch 389/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0338
# Epoch 390/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0292
# Epoch 391/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0432
# Epoch 392/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0287
# Epoch 393/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0504:
# Epoch 394/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0303
# Epoch 395/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0182
# Epoch 396/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0203
# Epoch 397/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0301
# Epoch 398/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0290
# Epoch 399/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0136
# Epoch 400/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0038
# Epoch 401/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0032
# Epoch 402/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0140
# Epoch 403/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0115
# Epoch 404/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0072
# Epoch 405/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0118
# Epoch 406/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9805
# Epoch 407/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9993
# Epoch 408/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9924
# Epoch 409/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9954
# Epoch 410/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9871
# Epoch 411/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9770
# Epoch 412/500
# 208/208 [==============================] - 3s 14ms/step - loss: 1.0032
# Epoch 413/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9882
# Epoch 414/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9899
# Epoch 415/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9934
# Epoch 416/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9767
# Epoch 417/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9901
# Epoch 418/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9699
# Epoch 419/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9627
# Epoch 420/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9715
# Epoch 421/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9809
# Epoch 422/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9830
# Epoch 423/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9601
# Epoch 424/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9580
# Epoch 425/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9783
# Epoch 426/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9718
# Epoch 427/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9540
# Epoch 428/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9446
# Epoch 429/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9501
# Epoch 430/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9395
# Epoch 431/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9433
# Epoch 432/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9518
# Epoch 433/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9564
# Epoch 434/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9327
# Epoch 435/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9555
# Epoch 436/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9443
# Epoch 437/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9391
# Epoch 438/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9391
# Epoch 439/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9488
# Epoch 440/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9355
# Epoch 441/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9395
# Epoch 442/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9357
# Epoch 443/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9450
# Epoch 444/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9253
# Epoch 445/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9221
# Epoch 446/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9150
# Epoch 447/500
# 208/208 [==============================] - 3s 15ms/step - loss: 0.9173
# Epoch 448/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9276
# Epoch 449/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9219
# Epoch 450/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9260
# Epoch 451/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9239
# Epoch 452/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9232
# Epoch 453/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9181
# Epoch 454/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9008
# Epoch 455/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9163
# Epoch 456/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9145
# Epoch 457/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9141
# Epoch 458/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9086
# Epoch 459/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9093
# Epoch 460/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9092
# Epoch 461/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9026
# Epoch 462/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8938
# Epoch 463/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8984
# Epoch 464/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.9012
# Epoch 465/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8877
# Epoch 466/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8966
# Epoch 467/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8995
# Epoch 468/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8858
# Epoch 469/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8967
# Epoch 470/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8883
# Epoch 471/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8873
# Epoch 472/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8848
# Epoch 473/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8790
# Epoch 474/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8857
# Epoch 475/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8892
# Epoch 476/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8935
# Epoch 477/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8772
# Epoch 478/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8705
# Epoch 479/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8724
# Epoch 480/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8768
# Epoch 481/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8731
# Epoch 482/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8603
# Epoch 483/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8747
# Epoch 484/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8614
# Epoch 485/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8716
# Epoch 486/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8545
# Epoch 487/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8701
# Epoch 488/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8741
# Epoch 489/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8555
# Epoch 490/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8610
# Epoch 491/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8616
# Epoch 492/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8459
# Epoch 493/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8442
# Epoch 494/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8350
# Epoch 495/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8431
# Epoch 496/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8529
# Epoch 497/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8455
# Epoch 498/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8501
# Epoch 499/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8472
# Epoch 500/500
# 208/208 [==============================] - 3s 14ms/step - loss: 0.8430

# %%
plt.figure(figsize=(16,10))
plt.plot(np.arange(0,epochs,1), gen_model_history_2['loss'], color='blue', label='Baseline Train')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.xlim([0,max(np.arange(0,epochs,1))])
plt.ylim([0,10])
plt.legend()
plt.show()

# %% [markdown]
# ## Running LSTM_model_2()
# ### Batch Size 64, Epochs 100

# %%
# batch size and epochs. Adjust these numbers to fit the specifications for the model
# batch_size was 64 for all four models below
# epochs of 100 and 200 were used for LSTM_model
# epochs of 100 and 200 were used for LSTM_model_2
batch_size = 64
epochs = 200

# %%
def return_model_2(ep, bs):
    # specifying the name of the model and model history csv
    model_name = "text_gen_" + str(ep) +"_2.h5"
    model_history_name = "text_gen_history_" + str(ep) +"_2.csv"
    text_gen_model = None
    text_gen_model_history = pd.DataFrame()

    if os.path.exists(model_name):
        print("Model Found: Loading...")
        text_gen_model = load_model(model_name)
        text_gen_model_history = pd.read_csv(model_history_name)
        print(text_gen_model.summary())
        print("Model Loaded!")
    else:
        print("Model not Found. Fitting model...")
        text_gen_model, text_gen_model_history = LSTM_model_2(bs, ep, model_name, model_history_name)
        text_gen_model_history = text_gen_model_history.history
        
    return text_gen_model, text_gen_model_history

# %%
gen_model_3, gen_model_history_3 = return_model_2(epochs, batch_size)
# Out:
# Model Found: Loading...
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_23 (LSTM)               (None, 5, 256)            264192
# _________________________________________________________________
# lstm_24 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1986)              510402
# =================================================================
# Total params: 1,299,906
# Trainable params: 1,299,906
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model Loaded!

# %%
plt.figure(figsize=(16,10))
plt.plot(np.arange(0,epochs,1), gen_model_history_3['loss'], color='blue', label='Baseline Train')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.xlim([0,max(np.arange(0,epochs,1))])
plt.ylim([0,10])
plt.legend()
plt.show()

# %% [markdown]
# ### Batch Size 64, Epochs 200

# %%
# batch size and epochs. Adjust these numbers to fit the specifications for the model
# batch_size was 64 for all four models below
# epochs of 100 and 200 were used for LSTM_model
# epochs of 100 and 200 were used for LSTM_model_2
batch_size = 64
epochs = 500

# %%
gen_model_4, gen_model_history_4 = return_model_2(epochs, batch_size)
# Out:
# Model not Found. Fitting model...
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_26 (LSTM)               (None, 5, 256)            264192
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1986)              510402
# =================================================================
# Total params: 1,299,906
# Trainable params: 1,299,906
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 208/208 [==============================] - 6s 27ms/step - loss: 6.2591
# Epoch 2/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.9700
# Epoch 3/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.9460
# Epoch 4/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.9178
# Epoch 5/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.8789
# Epoch 6/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.8460
# Epoch 7/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.8120
# Epoch 8/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.7799
# Epoch 9/500
# 208/208 [==============================] - 6s 26ms/step - loss: 5.7380
# Epoch 10/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.6828
# Epoch 11/500
# 208/208 [==============================] - 6s 28ms/step - loss: 5.6101
# Epoch 12/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.5212
# Epoch 13/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.4122
# Epoch 14/500
# 208/208 [==============================] - 6s 27ms/step - loss: 5.3165
# Epoch 15/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.2087
# Epoch 16/500
# 208/208 [==============================] - 5s 26ms/step - loss: 5.1011
# Epoch 17/500
# 208/208 [==============================] - 6s 27ms/step - loss: 4.9860
# Epoch 18/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.8796
# Epoch 19/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.7755
# Epoch 20/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.6704
# Epoch 21/500
# 208/208 [==============================] - 6s 27ms/step - loss: 4.5647
# Epoch 22/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.4650
# Epoch 23/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.3615
# Epoch 24/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.2684
# Epoch 25/500
# 208/208 [==============================] - 6s 27ms/step - loss: 4.1724
# Epoch 26/500
# 208/208 [==============================] - 5s 26ms/step - loss: 4.0813
# Epoch 27/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.9993
# Epoch 28/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.9167
# Epoch 29/500
# 208/208 [==============================] - 6s 27ms/step - loss: 3.8411
# Epoch 30/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.7641
# Epoch 31/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.6959
# Epoch 32/500
# 208/208 [==============================] - 6s 27ms/step - loss: 3.6239
# Epoch 33/500
# 208/208 [==============================] - 6s 27ms/step - loss: 3.5582
# Epoch 34/500
# 208/208 [==============================] - 6s 26ms/step - loss: 3.4953
# Epoch 35/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.4287
# Epoch 36/500
# 208/208 [==============================] - 6s 26ms/step - loss: 3.3718
# Epoch 37/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.2987
# Epoch 38/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.2542
# Epoch 39/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.1910
# Epoch 40/500
# 208/208 [==============================] - 6s 26ms/step - loss: 3.1428
# Epoch 41/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.0949
# Epoch 42/500
# 208/208 [==============================] - 5s 26ms/step - loss: 3.0278
# Epoch 43/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.9849
# Epoch 44/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.9468
# Epoch 45/500
# 208/208 [==============================] - 6s 27ms/step - loss: 2.8918
# Epoch 46/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.8601
# Epoch 47/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.8054
# Epoch 48/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.7663
# Epoch 49/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.7342
# Epoch 50/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.7029
# Epoch 51/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.6259
# Epoch 52/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.6098
# Epoch 53/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.5708
# Epoch 54/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.5345
# Epoch 55/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.4965
# Epoch 56/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.4589
# Epoch 57/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.4240
# Epoch 58/500
# 208/208 [==============================] - 6s 27ms/step - loss: 2.4015
# Epoch 59/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.3655
# Epoch 60/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.3410
# Epoch 61/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.2969
# Epoch 62/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.2727
# Epoch 63/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.2411
# Epoch 64/500
# 208/208 [==============================] - 6s 27ms/step - loss: 2.2087
# Epoch 65/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.1899
# Epoch 66/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.1598
# Epoch 67/500
# 208/208 [==============================] - 6s 27ms/step - loss: 2.1248
# Epoch 68/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.1046
# Epoch 69/500
# 208/208 [==============================] - 6s 27ms/step - loss: 2.0755
# Epoch 70/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.0476
# Epoch 71/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.0274
# Epoch 72/500
# 208/208 [==============================] - 5s 26ms/step - loss: 2.0141
# Epoch 73/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.9784
# Epoch 74/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.9682
# Epoch 75/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.9227
# Epoch 76/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.8968
# Epoch 77/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.8841
# Epoch 78/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.8679
# Epoch 79/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.8276
# Epoch 80/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.8105
# Epoch 81/500
# 208/208 [==============================] - 6s 28ms/step - loss: 1.7999
# Epoch 82/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.7823
# Epoch 83/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.7500
# Epoch 84/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.7277
# Epoch 85/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.7144
# Epoch 86/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.6888
# Epoch 87/500
# 208/208 [==============================] - 6s 26ms/step - loss: 1.6800
# Epoch 88/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.6537
# Epoch 89/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.6329
# Epoch 90/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.6091
# Epoch 91/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.5999
# Epoch 92/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.5786
# Epoch 93/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.5475
# Epoch 94/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.5317
# Epoch 95/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.5177
# Epoch 96/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.4878
# Epoch 97/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.5023
# Epoch 98/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.4828
# Epoch 99/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.4775
# Epoch 100/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.4412
# Epoch 101/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.4157
# Epoch 102/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.4272
# Epoch 103/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3793
# Epoch 104/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3860
# Epoch 105/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.3475
# Epoch 106/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3699
# Epoch 107/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3515
# Epoch 108/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3167: 0s - loss: 1
# Epoch 109/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.3089
# Epoch 110/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2978
# Epoch 111/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2937
# Epoch 112/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2663
# Epoch 113/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.2532
# Epoch 114/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2299
# Epoch 115/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2382
# Epoch 116/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2161
# Epoch 117/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.2115
# Epoch 118/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.1896
# Epoch 119/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.2040
# Epoch 120/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.1635
# Epoch 121/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.1447
# Epoch 122/500
# 208/208 [==============================] - 6s 26ms/step - loss: 1.1676
# Epoch 123/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.1291
# Epoch 124/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.1117
# Epoch 125/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.1238
# Epoch 126/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0846
# Epoch 127/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0960
# Epoch 128/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0893
# Epoch 129/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.0736
# Epoch 130/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0552
# Epoch 131/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.0635
# Epoch 132/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0483
# Epoch 133/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0431
# Epoch 134/500
# 208/208 [==============================] - 6s 27ms/step - loss: 1.0647
# Epoch 135/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0257
# Epoch 136/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0030
# Epoch 137/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.9979
# Epoch 138/500
# 208/208 [==============================] - 5s 26ms/step - loss: 1.0022
# Epoch 139/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9744
# Epoch 140/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9781
# Epoch 141/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.9834
# Epoch 142/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9424
# Epoch 143/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9502
# Epoch 144/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.9653
# Epoch 145/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.9448
# Epoch 146/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9166
# Epoch 147/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9316
# Epoch 148/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.9107
# Epoch 149/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8925
# Epoch 150/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8953
# Epoch 151/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8874
# Epoch 152/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8968
# Epoch 153/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.8894
# Epoch 154/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8775
# Epoch 155/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8574
# Epoch 156/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8603
# Epoch 157/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8573
# Epoch 158/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8333
# Epoch 159/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8409
# Epoch 160/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.8306
# Epoch 161/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8231
# Epoch 162/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8148
# Epoch 163/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8345
# Epoch 164/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8277
# Epoch 165/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7884
# Epoch 166/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.8110
# Epoch 167/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7869
# Epoch 168/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7790
# Epoch 169/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7766
# Epoch 170/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7812
# Epoch 171/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7769
# Epoch 172/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7610
# Epoch 173/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7761
# Epoch 174/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7521
# Epoch 175/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7459
# Epoch 176/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7296
# Epoch 177/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7288
# Epoch 178/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7524
# Epoch 179/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7368
# Epoch 180/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.7267
# Epoch 181/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7408
# Epoch 182/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7196
# Epoch 183/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.7282
# Epoch 184/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6983
# Epoch 185/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6966
# Epoch 186/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.6914
# Epoch 187/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6869
# Epoch 188/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.6978: 0s
# Epoch 189/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.6946
# Epoch 190/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6719
# Epoch 191/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6662
# Epoch 192/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6686
# Epoch 193/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6935
# Epoch 194/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6936
# Epoch 195/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6626
# Epoch 196/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6679
# Epoch 197/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6649
# Epoch 198/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6457
# Epoch 199/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6504
# Epoch 200/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.6466
# Epoch 201/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6248
# Epoch 202/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6358
# Epoch 203/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6317
# Epoch 204/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6345
# Epoch 205/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6460
# Epoch 206/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6530
# Epoch 207/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6295
# Epoch 208/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6133
# Epoch 209/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6075
# Epoch 210/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.6120
# Epoch 211/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6223
# Epoch 212/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5927
# Epoch 213/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6059
# Epoch 214/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6136
# Epoch 215/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6222
# Epoch 216/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6203
# Epoch 217/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.6041
# Epoch 218/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5751
# Epoch 219/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5832
# Epoch 220/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5921
# Epoch 221/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5769
# Epoch 222/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5841
# Epoch 223/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5770
# Epoch 224/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5862
# Epoch 225/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5905
# Epoch 226/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5767
# Epoch 227/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5796
# Epoch 228/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5623
# Epoch 229/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5763
# Epoch 230/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5542
# Epoch 231/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5525
# Epoch 232/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5621
# Epoch 233/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5436
# Epoch 234/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5768
# Epoch 235/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5383
# Epoch 236/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5494
# Epoch 237/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5567
# Epoch 238/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5612
# Epoch 239/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5400
# Epoch 240/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5540
# Epoch 241/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5260
# Epoch 242/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5102
# Epoch 243/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5412
# Epoch 244/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5385
# Epoch 245/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5410
# Epoch 246/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.5400
# Epoch 247/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5276
# Epoch 248/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5177
# Epoch 249/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5460
# Epoch 250/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5262
# Epoch 251/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5168
# Epoch 252/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5274
# Epoch 253/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4984
# Epoch 254/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5109
# Epoch 255/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5152
# Epoch 256/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5261
# Epoch 257/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5086
# Epoch 258/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5215
# Epoch 259/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5213
# Epoch 260/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5044
# Epoch 261/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.5159
# Epoch 262/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5270
# Epoch 263/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5104
# Epoch 264/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5130
# Epoch 265/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.4933
# Epoch 266/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4866
# Epoch 267/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.4895
# Epoch 268/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4918
# Epoch 269/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4863
# Epoch 270/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4843
# Epoch 271/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4644
# Epoch 272/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4913
# Epoch 273/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5017
# Epoch 274/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5046
# Epoch 275/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.5005: 0s - loss: 0.5
# Epoch 276/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4841
# Epoch 277/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4817
# Epoch 278/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4775
# Epoch 279/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4701
# Epoch 280/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4822
# Epoch 281/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4698
# Epoch 282/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4706
# Epoch 283/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4873
# Epoch 284/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4582
# Epoch 285/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4677
# Epoch 286/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4741
# Epoch 287/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4787
# Epoch 288/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4609
# Epoch 289/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4761
# Epoch 290/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4620
# Epoch 291/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4482
# Epoch 292/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4595
# Epoch 293/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4515
# Epoch 294/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4770
# Epoch 295/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4498
# Epoch 296/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4517
# Epoch 297/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4498
# Epoch 298/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4525
# Epoch 299/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4732
# Epoch 300/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4704
# Epoch 301/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4465
# Epoch 302/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.4575
# Epoch 303/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4424
# Epoch 304/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4415
# Epoch 305/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4535
# Epoch 306/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4432
# Epoch 307/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4360
# Epoch 308/500
# 208/208 [==============================] - 6s 28ms/step - loss: 0.4350
# Epoch 309/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4440
# Epoch 310/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4370
# Epoch 311/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4423
# Epoch 312/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4403
# Epoch 313/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4348
# Epoch 314/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4244
# Epoch 315/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4366
# Epoch 316/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4404
# Epoch 317/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4298
# Epoch 318/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4287
# Epoch 319/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4371
# Epoch 320/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4391
# Epoch 321/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4500
# Epoch 322/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4273
# Epoch 323/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4155
# Epoch 324/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4275: 0s - loss: 0
# Epoch 325/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4337
# Epoch 326/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4301
# Epoch 327/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4365
# Epoch 328/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4236
# Epoch 329/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4074
# Epoch 330/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.4255
# Epoch 331/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4154
# Epoch 332/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4170
# Epoch 333/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4279
# Epoch 334/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3940
# Epoch 335/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4210
# Epoch 336/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3868
# Epoch 337/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4207
# Epoch 338/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4182
# Epoch 339/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4209
# Epoch 340/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4304
# Epoch 341/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4341
# Epoch 342/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4087
# Epoch 343/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4044
# Epoch 344/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4148
# Epoch 345/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4194
# Epoch 346/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4054
# Epoch 347/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3872
# Epoch 348/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4105
# Epoch 349/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4343
# Epoch 350/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4001
# Epoch 351/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3937
# Epoch 352/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3946
# Epoch 353/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3933
# Epoch 354/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3905
# Epoch 355/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3936
# Epoch 356/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4022
# Epoch 357/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3944
# Epoch 358/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4047
# Epoch 359/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4273
# Epoch 360/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3998
# Epoch 361/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3917
# Epoch 362/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3865
# Epoch 363/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.4380
# Epoch 364/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4023
# Epoch 365/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3942
# Epoch 366/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3973
# Epoch 367/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3967
# Epoch 368/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3981
# Epoch 369/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.4013
# Epoch 370/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3844
# Epoch 371/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3834
# Epoch 372/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3865
# Epoch 373/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3933
# Epoch 374/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3667
# Epoch 375/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3789
# Epoch 376/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3935
# Epoch 377/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3940
# Epoch 378/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3793
# Epoch 379/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3858
# Epoch 380/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3831
# Epoch 381/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3954
# Epoch 382/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3785
# Epoch 383/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3794
# Epoch 384/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3776
# Epoch 385/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3957
# Epoch 386/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3751
# Epoch 387/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3955
# Epoch 388/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3740
# Epoch 389/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3899
# Epoch 390/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3867
# Epoch 391/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3930
# Epoch 392/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3759
# Epoch 393/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3714
# Epoch 394/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3662
# Epoch 395/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3952
# Epoch 396/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3816
# Epoch 397/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3670: 0s - l
# Epoch 398/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3711
# Epoch 399/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3630
# Epoch 400/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3568
# Epoch 401/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3732
# Epoch 402/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3593
# Epoch 403/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3803
# Epoch 404/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3799
# Epoch 405/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3657
# Epoch 406/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3701
# Epoch 407/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3638
# Epoch 408/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3573
# Epoch 409/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3639
# Epoch 410/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3666
# Epoch 411/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3662
# Epoch 412/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3521
# Epoch 413/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3740
# Epoch 414/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3867
# Epoch 415/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3543
# Epoch 416/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3559
# Epoch 417/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3512
# Epoch 418/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3629
# Epoch 419/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3553
# Epoch 420/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3513
# Epoch 421/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3892
# Epoch 422/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3839
# Epoch 423/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3599
# Epoch 424/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3577
# Epoch 425/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3618
# Epoch 426/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3522
# Epoch 427/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3578
# Epoch 428/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3511
# Epoch 429/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3494
# Epoch 430/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3596
# Epoch 431/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3586
# Epoch 432/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3556
# Epoch 433/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3549
# Epoch 434/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3589
# Epoch 435/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3625
# Epoch 436/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3421
# Epoch 437/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3433
# Epoch 438/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3497
# Epoch 439/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3530
# Epoch 440/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3466
# Epoch 441/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3488
# Epoch 442/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3436
# Epoch 443/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3375
# Epoch 444/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3593
# Epoch 445/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3456
# Epoch 446/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3621
# Epoch 447/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3701
# Epoch 448/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3360
# Epoch 449/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3377
# Epoch 450/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3557
# Epoch 451/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3594
# Epoch 452/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3430
# Epoch 453/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3486
# Epoch 454/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3439
# Epoch 455/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3290
# Epoch 456/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3399
# Epoch 457/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3555
# Epoch 458/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3475
# Epoch 459/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3398
# Epoch 460/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3481
# Epoch 461/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3417
# Epoch 462/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3452
# Epoch 463/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3440
# Epoch 464/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3365
# Epoch 465/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3252
# Epoch 466/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3252
# Epoch 467/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3368
# Epoch 468/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3375
# Epoch 469/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3412
# Epoch 470/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3528
# Epoch 471/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3345
# Epoch 472/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3210
# Epoch 473/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3409
# Epoch 474/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3481: 0s - loss: 0.3
# Epoch 475/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3490
# Epoch 476/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3490
# Epoch 477/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3341
# Epoch 478/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3407
# Epoch 479/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3274
# Epoch 480/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3262
# Epoch 481/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3323
# Epoch 482/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3333
# Epoch 483/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3395
# Epoch 484/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3338
# Epoch 485/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3355
# Epoch 486/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3377
# Epoch 487/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3271
# Epoch 488/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3292
# Epoch 489/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3311
# Epoch 490/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3437
# Epoch 491/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3325
# Epoch 492/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3269
# Epoch 493/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3235
# Epoch 494/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3211
# Epoch 495/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3299
# Epoch 496/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3264
# Epoch 497/500
# 208/208 [==============================] - 5s 26ms/step - loss: 0.3283
# Epoch 498/500
# 208/208 [==============================] - 6s 26ms/step - loss: 0.3304
# Epoch 499/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3331
# Epoch 500/500
# 208/208 [==============================] - 6s 27ms/step - loss: 0.3224

# %%
plt.figure(figsize=(16,10))
plt.plot(np.arange(0,epochs,1), gen_model_history_4['loss'], color='blue', label='Baseline Train')
plt.ylabel("loss")
plt.xlabel("epoch")
plt.xlim([0,max(np.arange(0,epochs,1))])
plt.ylim([0,10])
plt.legend()
plt.show()

# %% [markdown]
# ## Inference
# ### Accuracy Test

# %% [markdown]
# Inserting all input data back into each model to see how well each model generate words.

# %%
model_1_pred = gen_model_1.predict(reformatted_input_data)
model_2_pred = gen_model_2.predict(reformatted_input_data)
model_3_pred = gen_model_3.predict(reformatted_input_data)
model_4_pred = gen_model_4.predict(reformatted_input_data)

# %%
def untokenize_output_data(output_data, all_words):
    untokenized_words = []
    
    for word_int in output_data:
        untokenized_words.append(all_words[word_int[0]])
        
    return untokenized_words

# %%
def predicted_word(predictions, all_words): 
    word_predictions = []
    
    for pred in predictions:
        max_value_index = np.argmax(pred)
        best_word = all_words[max_value_index]
        word_predictions.append(best_word)
    
    return word_predictions

# %%
def accuracy(list_1, list_2):
    matches = 0
    
    for i in range(len(list_1)):
        if list_1[i] == list_2[i]:
            matches += 1
    
    return matches/len(list_1)

# %% [markdown]
# Untokenizing all the predictions from each of the 4 models

# %%
untokenized_predictions_model_1 = predicted_word(model_1_pred, all_words)
untokenized_predictions_model_2 = predicted_word(model_2_pred, all_words)
untokenized_predictions_model_3 = predicted_word(model_3_pred, all_words)
untokenized_predictions_model_4 = predicted_word(model_4_pred, all_words)

# %%
untokened_outputs = untokenize_output_data(output_data, all_words)

# %% [markdown]
# Testing the accuracy of each model. Original inputs are reinserted into each model to predict words. These words are then compared with the original outputs to see how well they match

# %%
model_1_accuracy = accuracy(untokenized_predictions_model_1,untokened_outputs)
model_2_accuracy = accuracy(untokenized_predictions_model_2,untokened_outputs)
model_3_accuracy = accuracy(untokenized_predictions_model_3,untokened_outputs)
model_4_accuracy = accuracy(untokenized_predictions_model_4,untokened_outputs)

# %%
print("model 1 accuracy: ", model_1_accuracy)
print("model 2 accuracy: ", model_2_accuracy)
print("model 3 accuracy: ", model_3_accuracy)
print("model 4 accuracy: ", model_4_accuracy)
# Out:
# model 1 accuracy:  0.7041437918327442
# model 2 accuracy:  0.8877942393020982
# model 3 accuracy:  0.9134391216063774
# model 4 accuracy:  0.9414153568474092

# %% [markdown]
# ### Benchmark Model

# %%
output_word_dic = {}

for each in untokened_outputs:
    if each not in output_word_dic:
        output_word_dic[each] = 1
    else:
        output_word_dic[each] += 1

# %% [markdown]
# Finding the most commonly occuring word in the output dataset

# %%
max_key = 0
max_count = 0  

for i in output_word_dic: 
    key = i 
    count = output_word_dic[i]
    
    if count > max_count:
        max_count = count
        max_key = key

# %%
print("Most counted output is:", max_key, "with count of:" , max_count, " ||  total number of output values is:", len(untokened_outputs))
print("Naive chance of correct guesses: ", max_count/len(untokened_outputs))
# Out:
# Most counted output is: . with count of: 631  ||  total number of output values is: 13297
# Naive chance of correct guesses:  0.04745431300293299

# %% [markdown]
# ### Subjective Text Generation Test

# %%
def tokenize(list_of_words, unique_words_list):
    new_list = []
    
    try:
        for each in list_of_words:
            new_list.append(unique_words_list[each.lower()])
            
        return new_list
    except:
        return []

# %% [markdown]
# Below function word_generation_test() will continously generate new words corresponding to the number of iterations specified.

# %%
def word_generation_test(model, starting_words, iterations, input_length):
    list_of_words = starting_words.copy()    
    
    for it in range(iterations):
        
        if len(list_of_words) < input_length:    
            temp_list_of_words = list_of_words.copy()

            for i in range(input_length - len(list_of_words)):
                temp_list_of_words.append(0)
            
            reformat_input = np.reshape(temp_list_of_words, (1, input_length, 1))
            reformat_input = reformat_input / float(len(unique_words_list))
            
            prediction = model.predict(reformat_input)
            word_int = np.argmax(prediction[0])
            
            list_of_words.append(word_int)
        else:
            temp_list_of_words = list_of_words[len(list_of_words)-5:len(list_of_words)]
            
            reformat_input = np.reshape(temp_list_of_words, (1, input_length, 1))
            reformat_input = reformat_input / float(len(unique_words_list))
            
            prediction = model.predict(reformat_input)
            word_int = np.argmax(prediction[0])
            
            list_of_words.append(word_int)
            
    return list_of_words

# %%
def decipher_tokens(word_list, all_words):
    string = ""
    
    for index in word_list:
        string = string + all_words[index] + " "
        
    return string

# %%
iterations = 100
input_length = 5
starting_words = ["hello", "david"]
starting_words_token = tokenize(starting_words, unique_words_list)

word_list_1 = word_generation_test(gen_model_1, starting_words_token, iterations, input_length)
word_list_2 = word_generation_test(gen_model_2, starting_words_token, iterations, input_length)
word_list_3 = word_generation_test(gen_model_3, starting_words_token, iterations, input_length)
word_list_4 = word_generation_test(gen_model_4, starting_words_token, iterations, input_length)

# %%
print(decipher_tokens(word_list_1, all_words))
# Out:
# hello david mike week several our in left . i would snake guy of number , . former . of and realized that i . quickly adapt on and course , time am , following company whether , i . for to do to for thanks love . dr . madasamy . charles will be small pm . plaxgen fremont . typically sales found genentech's work culture and the would like i contract like , questions of know call . i me regards taking your a while we'll . here's hoping python . the i got asks of i csueb , data

# %%
print(decipher_tokens(word_list_2, all_words))
# Out:
# hello david we arranged speak speak a the . probably you ask . david am love to , sn rubbed or and i just be do if today opportunities far will the apply , either is news you had that i david interview me last , pretty 12 my my contacted , i lot that this a interview me chance a pretty unusual for apple standards ? regards , david liu wed 510-219-5580 . threads that recommended be #2 , five , the #5 . the sn with the sn rubbed , $12/hr . read to the already . as that i

# %%
print(decipher_tokens(word_list_3, all_words))
# Out:
# hello david mike see several and the so very case this the shoot up and would enthusiastic two on were only program on site , i page . and interview me the interview tools . granted that summer project . the am david to i be someone who would need to be mentored and grow in the position , so i am guessing he is not hiring me for my expertise . i assume that this sort of interview is pretty unusual for apple standards ? regards , david liu apologies wed statistics and the estimate , the only include the front

# %%
print(decipher_tokens(word_list_4, all_words))
# Out:
# hello david would it be possible if i get a reestimate for the project if we exclude scaffolding on the back side of the building , and only include the front and and the two adjacent sides ? also , would you happen to know how long does this usually take ? thanks , david liu got you the you david have a david along on making . goal for my short for this am planning i weekend a . . am birthday email i sn rubbed off , or bates immediately next in santa in on of for are apologies on

# %% [markdown]
# ## Demo

# %%
import tkinter as tk
from tkinter import *

iterations = 1
input_length = 5
gen_model = gen_model_4

root = tk.Tk()
# **********************************************************************
def generate_text():
    text = text1.get("1.0","end-1c")
    Text = text.split()
    
    sequence = []
    
    for word in Text:
        if word[len(word)-1:] in ["!","?",".",",",")"]:
            sequence.append(word[:len(word)-1].lower())
            sequence.append(word[len(word)-1:])
        elif word[:1] in ["!","?",".",",","("]:
            sequence.append(word[1:len(word)].lower())
            sequence.append(word[:1])
        else:
            sequence.append(word.lower())
    
    tokenized_sequence = tokenize(sequence, unique_words_list)
    
    gen_word = word_generation_test(gen_model, tokenized_sequence, iterations, input_length)
    
    deciphered_word = decipher_tokens(gen_word[len(gen_word) - 1:], all_words)
    
    text1.insert(tk.END, deciphered_word)

    
# **********************************************************************
text1 = tk.Text(root, height=20, width=50)
scroll = tk.Scrollbar(root, command=text2.yview)
text1.configure(yscrollcommand=scroll.set)
Take_text=Button(root, height=1, width=10, text="Generate", 
                    command=lambda: generate_text())
Take_text.pack()
text1.pack(side=tk.LEFT)
scroll.pack(side=tk.RIGHT, fill=tk.Y)

root.mainloop()
