# %% [markdown]
# https://towardsdatascience.com/how-to-evaluate-text-generation-models-metrics-for-automatic-evaluation-of-nlp-models-e1c251b04ec1
#
# https://towardsdatascience.com/evaluating-text-output-in-nlp-bleu-at-your-own-risk-e8609665a213
#
# https://www.datacourses.com/extracting-data-from-gmail-emails-with-python-470/
#
# https://codehandbook.org/how-to-read-email-from-gmail-api-using-python/
#
# https://codehandbook.org/how-to-read-email-from-gmail-using-python/

# %% [markdown]
# ## Preliminary Steps

# %% [markdown]
# Setting the authentification info and packages, and checking for available email folders in my gmail

# %%
import pandas as pd
import datetime, os, glob
import email, imaplib
import re

# %%
os.listdir("Emails")
# Out:
# ['file.txt']

# %%
import imaplib
mail = imaplib.IMAP4_SSL('imap.gmail.com')
mail.login('david92liu@gmail.com', 'andesmint')
print(mail.list())
# Out:
# ('OK', [b'(\\HasNoChildren) "/" "Drafts"', b'(\\HasNoChildren) "/" "INBOX"', b'(\\HasNoChildren) "/" "Orders"', b'(\\HasNoChildren) "/" "Other"', b'(\\HasNoChildren) "/" "Outbox"', b'(\\HasNoChildren) "/" "Sent"', b'(\\HasNoChildren) "/" "Trash"', b'(\\HasChildren \\Noselect) "/" "[Gmail]"', b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"', b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"', b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"', b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"', b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"', b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"', b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %% [markdown]
# generates search criterias

# %%
cwd = os.getcwd()

EMAIL_UN = 'david92liu@gmail.com'
EMAIL_PW = 'andesmint'

# %% [markdown]
# ## Email Extraction Method

# %%
Ignore_email_list = ["Please join Zoom meeting in progress"]

# %% [markdown]
# Method for extracting the texts from emails

# %%
def email_extraction():
    body_text = []
    
    un = EMAIL_UN
    pw = EMAIL_PW
    url = 'imap.gmail.com'

    m = imaplib.IMAP4_SSL(url,993)
    m.login(un,pw)
    #m.select("Sent") 
    m.select('"[Gmail]/Sent Mail"')  
    data = m.search(None, 'ALL')
    mail_ids = data[1]

    id_list = mail_ids[0].split()   
    first_email_id = int(id_list[0])
    latest_email_id = int(id_list[-1])

    for i in range(latest_email_id,latest_email_id-300, -1):                
        
        data = m.fetch(str(i), '(RFC822)' )

        for response_part in data:
            arr = response_part[0]
            if isinstance(arr, tuple):
                msg = email.message_from_string(str(arr[1],'utf-8'))
                email_from = msg['from']
                email_subject = msg['subject']
                
                try:
                    if (email_from == "David Liu <david92liu@gmail.com>") and (email_subject not in Ignore_email_list) and (email_subject.startswith("Fwd:") == False):

                        email_content = None

                        if msg.is_multipart():
                            email_content = msg.get_payload()[0].get_payload()      
                        else:
                            email_content = msg.get_payload()

                        if email_subject.startswith("Re:"):
                            email_content = email_content.split("On")[0]
                            body_text.append(email_content)
                        else:
                            body_text.append(email_content)
                except:
                    print("\n\nThe email that had issues was the following: ")
                    print(email_content)
    m.close()
    m.logout()
    
    return body_text

# %%
extracted_emails = email_extraction()
# Out:
# Re: Sample
# this is a response
#
#
# Sample
# Hi David,
#
# This is a sample email.
#
#
# https://www.walmart.com/ip/Apple-iPad-mini-Wi-Fi-64GB/207104625
#
# https://www.bestbuy.com/site/apple-10-2-inch-ipad-latest-model-with-wi-fi-3=
# 2gb-space-gray/5199701.p?skuId=3D5199701
#
# https://www.adorama.com/acmyla2lla.html?gclid=3DCj0KCQiAzZL-BRDnARIsAPCJs73=
# IvW8I6hSvm04SkA0uSh1H4tsa0sjbo7Q-uuhvrndPUyO2jg-Md6QaAt_5EALw_wcB&utm_sourc=
# e=3Dadl-gbase
#
# Older Model:
# https://www.walmart.com/ip/Apple-iPad-4-with-Retina-Display-32GB-Wi-Fi-4th-=
# Generation-in-Black/22288800?wmlspartner=3Dwlpa&selectedSellerId=3D9186&&ad=
# id=3D22222222227016434816&wl0=3D&wl1=3Dg&wl2=3Dc&wl3=3D343334214440&wl4=3Dp=
# la-486397163036&wl5=3D9032013&wl6=3D&wl7=3D&wl8=3D&wl9=3Dpla&wl10=3D1170193=
# 45&wl11=3Donline&wl12=3D22288800&veh=3Dsem&gclid=3DCj0KCQiAzZL-BRDnARIsAPCJ=
# s71ZBDQi_Vj6RvtNPGp55mVHFKiQ3f0UXexwDyKS6BIc_-X3kOA0wusaAmQ5EALw_wcB
#
# Re: Apple Health Strategic Initiative Opportunity
# Hi Han,
#
#
#
# This is just a quick follow-up from yesterday. I would like to thank you
# for spending an extended period of time interviewing me, and allowing me
# to have a better understanding of what the contract position entails. I am
# excited for the possibility of working with the health strategic initiative
# team to build data pipelines and machine learning functions for health and
# wellness applications.
#
#
#
# Looking forward to hearing back about any updates on the position.
#
#
#
# Best Regards,
#
#
#
# David
#
#
# Re: Apple Health Strategic Initiative Opportunity
# Greetings Han,
#
# I am guaranteed to be free on Friday 10/9 at 4 PM. I look forward to
# speaking with you soon!
#
# Thanks,
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# That is great! I look forward to speaking with your lead. Should I be
# expecting an email some time later today?
#
# Thanks,
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# This is just a follow up on our previous conversation regarding the
# contract positions. Since the positions are still in the works, would it be
# necessary for me to check in again at a later date if I am still
# interested? And if so, when do you think would be a good time for me to do
# so? I ask because it was unclear to me during our previous correspondence
# whether we were planning to further discuss the topic, or whether I should
# check in later. If there isn't much information on the planned contract
# positions at the moment, that is fine too. In any case, thank you so much
# for your time and patience regarding my inquiries about these
# opportunities, thus far.
#
# Regards,
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# I completely understand. The contractor position sounds great and I am
# certainly open to further discuss this opportunity. What would be the next
# step?
#
# Regards,
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# I would like to check in again on the status of the Health Strategic
# Initiatives data engineering position and whether it is still available. I
# am still very much interested in the position and I look forward to hearing
# back about any updates on the situation.
#
# Thanks,
# David
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# I checked in with Andy yesterday, and he responded earlier today. According
# to him, he does not know the headcount for FY2021 and told me to check in
# later as he will find out some time between now and October 1. Would you
# happen to know how long does this usually take?
#
# Thanks,
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# Thanks for the update about the situation. I will check back around 3 weeks
# from now, or some time during the week of September 21, if you don't mind.
#
# Thanks,
# David
#
#
# Re: Data Engineering role
# Greetings Andy,
#
# We previously spoke over the phone on June 7 regarding the Health Strategic
# Initiatives data engineer position, and you suggested that I contact you
# again about it during early September of this year for a possible formal
# screening. Is the position still open at this time? If so, what would be
# the next step? Thank you very much.
#
# David
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED588>, <email.message.Message object at 0x000001FFDBDC2DA0>]
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# It has certainly been a while since we last spoke, so thanks for reaching
# out to me and for the reminder and tips!
#
# My apologies for the lack of news about my status recently, but I am
# currently finishing up the last week of my summer session so I have not
# been sending out many resumes for the last couple weeks. I plan on resuming
# my job apps after this week once I have more time. Project is fine. I was
# simply reworking one of my older data collection projects and applying
# machine learning techniques to better fit the job description, but there is
# still more I plan on doing with it.
#
# I will definitely be contacting you soon about apple positions, so we'll be
# in touch!
#
# Thanks,
# David
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# Yes, that's basically what he suggested: to talk about the methods I used
# in my project and why, any possible issues there might be, and, most
# importantly, to not take the efficiency and speed of data processing tools
# for granted. And yes, I intend to build a project in the time remaining as
# you suggested that it might be better if it is new and related to the
# position, and I will also have a good amount of machine learning resources
# to work with as I am taking it as a course this summer.
#
# I will definitely be applying for more positions at Apple in the near
# future, so thanks, and, again, we will be in touch! I will take a pause for
# maybe a month, or at least until I finish this summer, as it appears that a
# lot of data positions utilizes machine learning and I would really want to
# know what the subject is all about.
#
# David
#
#
#
#
#
#
#
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# We spoke for around 40 minutes, and he just wanted to look into my
# background while I had the chance to learn more about the position. There
# was actually nothing technical about it. I told him that I will graduate
# this coming December, so he told me to shoot him an email during early
# September which is when he will set up a formal interview. Here's hoping
# that the position does not fill by then.
#
# I also asked him about the interview, and he told me that it will be a 1
# hour presentation about one of my projects but gave no more details or
# whether it will be technical or not. Said that if I were to be hired for
# the position, I would be someone who would need to be mentored and grow in
# the position, so I am guessing he is not hiring me for my expertise. I
# assume that this sort of interview is pretty unusual for Apple standards?
#
# Regards,
# David
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# Someone named Andy Pham contacted me for the Data Engineer, Health
# Strategic Initiatives position (Role Number:200172241,
# https://jobs.apple.com/en-us/details/200172241/data-engineer-health-strateg=
# ic-initiatives?team=3DSFTWR
# ).
#
# We arranged to speak for a few minutes on a video chat for the coming
# Tuesday at 2 PM. I am guessing this is just the initial screening to see
# whether I would be a good fit before there would be an interview. Do you
# have any idea about what they might ask or what Apple does differently with
# these screenings?
#
# Thanks,
# David
#
#
#
#
# Re: Data Engineering role
# Hello Andy,
#
# Marked on calendar. Looking forward to speaking to you soon.
#
# David
#
#
# Re: Data Engineering role
# Hi Andy,
#
# I will be available anytime today or at anytime for the rest of this week.
# Next week will work as well, but only after 12 PM on Tuesdays and
# Thursdays. I look forward to speaking with you!
#
# David
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Hi Xiaoyi,
#
# Good to know! I will keep that in mind when applying for Apple jobs in the
# future.
#
# Since there isn't many job postings left that match my current skill set, I
# will probably take a hiatus on any new applications at Apple for now. Can't
# thank you enough for all your help and thank you for making yourself
# available for sending out resumes for me in the future. If your schedule or
# situation permits, I would like to do this again in the coming months,
# assuming that none of my current applications go through.
#
# Cheers,
# David
# Re: Touching Base Regarding an Internship Opportunity at Apple
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDBDC2CC0>, <email.message.Message object at 0x000001FFDBDC2278>]
# Re: Touching Base Regarding an Internship Opportunity at Apple
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3EDA20>, <email.message.Message object at 0x000001FFDC3ED1D0>]
# Re: Touching Base Regarding an Internship Opportunity at Apple
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDBDC2CF8>, <email.message.Message object at 0x000001FFDBDC2DA0>]
# Re: Resume Carlos Ovalles
# Hi Carlos,
#
# It has been a while since we took linear algebra together at BCC. I hope
# you are doing well!
#
# I am not sure if your email was actually meant for me, but, unfortunately,
# I am in no position to hand out job opportunities as I am finishing up a
# graduates program and am looking for work positions myself; so it looks
# like we are pretty much in the same boat! Let me know if there is anything
# else I can help you with.
#
# Cheers,
#
# David Liu
#
#
# Re: Touching Base Regarding an Internship Opportunity at Apple
# Xiaoyi,
#
# Great! Thanks again.
#
# David
#
#
# =?UTF-8?Q?Re=3A_I=E2=80=99ll_get_my_letters_tomorrow_morning=21?=
# Forgot to tell you. I did not find any letters for you. I am not sure if
# somebody else is keeping them for you, but I don't think there are any
# letters that has your name on it.
#
# On Mon, May 18, 2020 at 9:38 PM David Liu <david92liu@gmail.com> wrote:
#
# > Yes. Okay. I will look for your letters.
# >
# > On Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wro=
# te:
# >
# >> Hi=EF=BC=81 David=EF=BC=9A
# >> Can you put all my letters in the mailbox today?   I'll get it tomorrow
# >> morning!  Thank  you!
# >>
# >> Yours.
# >> Yufen Lin
# >>
# >> =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone
# >
# >
#
# Touching Base Regarding an Internship Opportunity at Apple
# [<email.message.Message object at 0x000001FFDBDC2EB8>, <email.message.Message object at 0x000001FFDBDC2E10>]
# =?UTF-8?Q?Re=3A_I=E2=80=99ll_get_my_letters_tomorrow_morning=21?=
# Yes. Okay. I will look for your letters.
#
# On Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wrote=
# :
#
# > Hi=EF=BC=81 David=EF=BC=9A
# > Can you put all my letters in the mailbox today?   I'll get it tomorrow
# > morning!  Thank  you!
# >
# > Yours.
# > Yufen Lin
# >
# > =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone
#
# Re: Can you do me a favor?
# Okay. I will look out for it.
#
#
# Re: 1098t-david
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDBDC2710>, <email.message.Message object at 0x000001FFDC3EDA58>]
# 1098t-david
# [<email.message.Message object at 0x000001FFDC3EDC88>, <email.message.Message object at 0x000001FFDC3ED898>]
# Document from David L
# [<email.message.Message object at 0x000001FFDBDC2278>, <email.message.Message object at 0x000001FFDC3ED518>]
# Re: Please open this letter!
# Okay
#
#
# Re: Please open this letter!
# It looks like i received the letters. How do you want me to send the
# letters back?
#
#
# Re: Please open this letter!
# okay. I will look out for it
#
#
# Re: Please open this letter!
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED748>, <email.message.Message object at 0x000001FFDC3EDF60>]
# Re: Touching Base
# Hi Joe,
#
# In that case, thank you very much for the information. I'll definitely see
# what I can find and get the resume updated and going.
#
# David
#
#
# Re: Touching Base
# Hi Joe,
#
# I was recently told about openings at a company called Veeva, and I believe
# it was your wife, Mrs. Li, who shared this information, so please give her
# my thanks. I had a chance to look through the company website and there
# were definitely some positions and roles that I found interesting. However,
# I could not find anything other than full-time/long-term positions, which I
# am not available for at this time. May I ask that she clarify exactly what
# the new positions are, or where on the website can I find them in case I am
# looking at the wrong places? Thank you very much.
#
# David
#
#
# Touching Base
# Hi Joe,
#
# I figured that I should share this email with you so that you know which
# email I may be contacting you with, and to make sure that I added your
# email correctly.
#
# Thanks again for the talk and for the tips you shared with me last Monday.
# I very much appreciate it.
#
# Cheers,
#
# David
#
# Zoom Meeting Room BAN612
# Join Zoom Meeting
# https://csueb.zoom.us/j/554033172
#
# Meeting ID: 554 033 172
#
# One tap mobile
# +16699006833,,554033172# US (San Jose)
# +16465588656,,554033172# US (New York)
#
# Dial by your location
#         +1 669 900 6833 US (San Jose)
#         +1 646 558 8656 US (New York)
# Meeting ID: 554 033 172
# Find your local number: https://csueb.zoom.us/u/acNwdbUoa0
#
# Join by SIP
# 554033172@zoomcrc.com
#
# Join by H.323
# 162.255.37.11 (US West)
# 162.255.36.11 (US East)
# 221.122.88.195 (China)
# 115.114.131.7 (India Mumbai)
# 115.114.115.7 (India Hyderabad)
# 213.19.144.110 (EMEA)
# 103.122.166.55 (Australia)
# 209.9.211.110 (Hong Kong)
# 64.211.144.160 (Brazil)
# 69.174.57.160 (Canada)
# 207.226.132.110 (Japan)
# Meeting ID: 554 033 172
#
#
# User name: Yufenlin72
# Password: Lyf586091
#
# Re: Regarding the Deadline to Accept Admission to the CSUEB MS
#  Business Analytics Program
# Hi Jamieelee,
#
# Thank you for getting back to me. My netid is az7762.  I was initially
# having issues with enrolling in courses because my MyCSUEB site did not
# include a student tab or student center link. I contacted Gradadmissions
# and was told that I should be able to start enrolling tomorrow, so, unless
# if there is anything else I missed, I believe I should be fine for now.
# Again, thanks for touching base with me regarding my enrollment issue, and
# I will be sure to direct any of my future correspondence with you via
# Horizon in the future.
# Re: Regarding the Deadline to Accept Admission to the CSUEB MS
#  Business Analytics Program
# Greetings Again Jiming,
#
# It appears that the orientation registration had already closed. Would it
# be possible that I just show up and attend the orientation anyways?
# Otherwise, is there any other way I can register at this point?
#
# Also, I cannot seem to find an option to add courses on the myCSUEB site
# using the instructions provided in my admissions package. Do I need to
# follow additional steps to register for classes during the open enrollment
# period from Aug 15 - 19, or am I doing something wrong here?
#
# Thanks in advance, and my apologies for the last minute questions. It was a
# bit hectic waiting and gathering the information I needed to make a
# decision.
#
# Regards,
#
# David
#
#
# Regarding the Deadline to Accept Admission to the CSUEB MS Business
#  Analytics Program
# Greetings Dr. Jiming Wu,
#
# I received an offer for admission to the CSUEB MS Business Analytics
# program in mid July and I was told by the Graduate Admission office that
# there is no deadline to accept the offer, so I want to confirm with you
# about whether this information is accurate, and whether there are any
# information about any deadlines that I may had missed regarding the
# admission offer. I also found this information slightly confusing because
# there is an MSBA program orientation on 8/17, and I cannot register for it
# unless I accept my offer.
#
# I would like to note that the reason why I want to know about the offer
# acceptance deadline is because I am still trying to weigh my options and I
# probably will not receive all the information I can get to make my decision
# for grad school until during or after the week of August 12. Hence, it
# would be extremely helpful for me to know whether this may pose any issues
# in regards to my offer acceptance. Thank you for your time and thank you in
# advance for any information that you may provide me.
#
# Regards,
# David
#
# Re: Deadline to Accept Admission to the SFSU MS Business Analytics Program
# Hi Chris,
#
# You mentioned that August 9 will be the end of the priority registration
# period. Does this mean that I can still register even after that date, but
# minus a few priority perks, or is it absolutely the last day that I can
# still accept an offer of admission? Also, if August 9 really is the last
# date, would it still be viable for me to register this week since I
# understand that there will probably be some prerequisites or processes that
# I'll need to finish that may take some time, such as mailing in
# transcripts, registering for classes, submitting proof of immunization,
# etc...
#
# Thanks in advance,
# David
#
#
# Deadline to Accept Admission to the SFSU MS Business Analytics Program
# Greetings Sophie,
#
# It has recently been brought to my attention that the time window for
# accepting my admission to the SFSU MSBA program is still open. I am
# wondering when is the actual deadline for me to make a decision. I am
# currently still weighing my options and it would be extremely helpful for
# me to know when action is needed on my part. For instance, would I still be
# allowed to make a decision by the week of August 12. Thanks.
#
# Regards,
# David Liu
#
# Deadline to Accept Admission to the CSUEB MS Business Analytics Program
# Greetings,
#
# It has recently been brought to my attention that the time window for
# accepting my admission to the CSUEB MSBS program is coming to a close but
# is still open. I am wondering when is the actual deadline for me to make a
# decision. I am currently still weighing my options and it would be
# extremely helpful for me to know when action is needed on my part. Thanks.
#
# Regards,
# David Liu
# Re: Python Books
# Pretty cool you get entire books.
#
# Thanks!
#
#
# Re: AV this Sunday
# Hi Ben,
#
# yes I will be available
#
#
#
# [<email.message.Message object at 0x000001FFDC3ED438>, <email.message.Message object at 0x000001FFDC3ED390>]
# costco laptop
# https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---256GB-SSD---Radeon-Pro-555X---Silver.product.100472319.html
# - ive confirmed that the one above is the one i want
#
# https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---512GB-SSD---Radeon-Pro-560X---Space-Gray.product.100472395.html
# - this one here is good too, but the other one is cheaper.
#
#
# [<email.message.Message object at 0x000001FFDC3ED4A8>, <email.message.Message object at 0x000001FFDC3ED320>]
# picture layout
# [<email.message.Message object at 0x000001FFDC3ED550>, <email.message.Message object at 0x000001FFDC3EDB00>]
# Re:
# https://slickdeals.net/f/13011733-apple-macbook-pro-with-touch-bar-fptr2ll-a-15-4-laptop-computer-apple-certified-refurbished-space-gray-1599-98?attrsrc=Test%3AHideExpiredSearch%3AControl&src=SiteSearchV2Algo1
#
#
#
# https://www.microcenter.com/product/600944/macbook-pro-with-touch-bar-fptr2ll-a-154-laptop-computer-apple-certified-refurbished---space-gray
#
# another refurbished one
# https://www.apple.com/shop/product/G0SF2LL/A/Refurbished-133-inch-Macbook-P=
# ro-33GHz-Dual-core-Intel-Core-i7-with-Retina-Display-Space-Gray?fnode=3Ddb7=
# b1e36e34e927189e9c4c5df91d78aa961b6be9d954739f3b99b5715dafbd0c9cb1f51fb42ff=
# c44e36bafc49750a454ba7f560fb3b22d6a6e1ac7cf8ba316b41cb60ac071128a83cb14916c=
# bafb7be
#
# Re:
# https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=
# 07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=
# INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=
# amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4
#
# this one.. not the one above
#
#
#
# https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=
# 07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=
# INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=
# amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4
#
#
# https://www.apple.com/shop/product/G0T21LL/A/Refurbished-133-inch-Macbook-P=
# ro-31GHz-Dual-core-Intel-Core-i5-with-Retina-Display-Silver?fnode=3D98769c7=
# 052da9a6fb988727b003fb8b2e388032d5d0fde5e4890cdc5029b8d92cd91dc6b9bc8445f66=
# 40e3f6fac54f2bc8fd0645a63fd5b983a4d4867c6e686fb089e6859185d916ac96d70b8253f=
# 311
#
#
# [<email.message.Message object at 0x000001FFDC3CC668>, <email.message.Message object at 0x000001FFDC3CC860>]
#
# [<email.message.Message object at 0x000001FFDC3CCB70>, <email.message.Message object at 0x000001FFDC3CC048>]
#
# [<email.message.Message object at 0x000001FFDC3CC9E8>, <email.message.Message object at 0x000001FFDC3CC978>]
#
# [<email.message.Message object at 0x000001FFDC3CC0B8>, <email.message.Message object at 0x000001FFDC3CCCC0>]
#
# [<email.message.Message object at 0x000001FFDC3CC748>, <email.message.Message object at 0x000001FFDC3CC710>]
#
# [<email.message.Message object at 0x000001FFDC3CC828>, <email.message.Message object at 0x000001FFDC3CCAC8>]
#
# [<email.message.Message object at 0x000001FFDC3CCC88>, <email.message.Message object at 0x000001FFDC3CC470>]
#
# [<email.message.Message object at 0x000001FFDC3CC278>, <email.message.Message object at 0x000001FFDC3CC630>]
#
# [<email.message.Message object at 0x000001FFDC3CC5F8>, <email.message.Message object at 0x000001FFDC3CC7F0>]
#
# [<email.message.Message object at 0x000001FFDC3CC160>, <email.message.Message object at 0x000001FFDC3CC3C8>]
#
# [<email.message.Message object at 0x000001FFDC3CC390>, <email.message.Message object at 0x000001FFDC3CC4E0>]
#
# [<email.message.Message object at 0x000001FFDC3CC2B0>, <email.message.Message object at 0x000001FFDC3CC4A8>]
# scincus rustamowi map
# [<email.message.Message object at 0x000001FFDC3CC128>, <email.message.Message object at 0x000001FFDC3CC080>]
# even more maps 2
# [<email.message.Message object at 0x000001FFDC3CC208>, <email.message.Message object at 0x000001FFDC3CC8D0>]
# even more maps
# [<email.message.Message object at 0x000001FFDC3CC400>, <email.message.Message object at 0x000001FFDC3CCA20>]
# przewalskii & roborowskii + scincus & rustamowi
# [<email.message.Message object at 0x000001FFDC3CC898>, <email.message.Message object at 0x000001FFDC3CC358>]
# bedriagai + keyserlingii & mesriensis + microlepis maps
# [<email.message.Message object at 0x000001FFDC3CC780>, <email.message.Message object at 0x000001FFDC3CC438>]
# Re: Point of Contact | UC Berkeley MIDS
# Hi Bill,
#
# Thank you for checking in with me and my apologies for the late reply. I
# have very recently been admitted to my top choice graduate program in Data
# Science and will no longer be continuing with my application. Thank you for
# spending your time to answer the questions I had early in the application
# and staying in touch with me throughout the process thus far.
#
# Regards,
#
# David Liu
#
#
#
#
# Scincus - get rid of 3 and dot.
# - increase size if dots slightly
# - fix border and river gaps
#
# Keyserlingii - slightly darken the yellow region.
# - do not italicize the parenthesis parts in legend
# - fix border and river gaps
# - increase size of dots slightly
# - check whether the unknown region is correct
# - fix legend font
#
# Two more maps
# [<email.message.Message object at 0x000001FFDC3CCDA0>, <email.message.Message object at 0x000001FFDC3CCF60>]
# Sending Official Transcript
# Greetings,
#
# I was recently admitted to the MSDS program and my application checklist
# indicated that I must send in my official Bachelor's degree transcript. The
# transcript was mistakenly sent electronically to the USF Office of Graduate
# Admission located at 2130 Fulton Street, San Francisco. This was before I
# received a letter in my application status page instructing me to send any
# electronic transcripts to the asgraduate@usfca.edu email address. Can my
# official transcript be received at its current destination or should I
# request to send a copy to asgraduate@usfca.edu as well?
#
# Thanks,
# David Liu
#
#
# un: david92liu@gmail.com
# pw: Ilikebagel!1
#
# https://gradapply.usfca.edu/account/login?r=https%3a%2f%2fgradapply.usfca.edu%2fapply%2fstatus
#
# Teratoscinus scincus re-edited
# [<email.message.Message object at 0x000001FFDC3CCA58>, <email.message.Message object at 0x000001FFDC3CC320>]
#
# [<email.message.Message object at 0x000001FFDC3CC9B0>, <email.message.Message object at 0x000001FFDC3CCD68>]
#
# [<email.message.Message object at 0x000001FFDC3CC588>, <email.message.Message object at 0x000001FFDC3CCA90>]
# Re: DataScience@Syracuse I Careers in Data Science Webinar
# Hi Victoria,
#
# Thank you for checking in with me and my apologies for the late reply. I
# have very recently received admissions from a couple of my top choice
# universities and will no longer be continuing with my application. However,
# I want to thank you for striving to keep me in close communications
# throughout the application and providing me with the information I need to
# weigh my options and to make an informed decision. Not many of the colleges
# I applied to actively initiated conversions with applicants.
#
# Thanks again,
#
# David Liu
#
#
#
# Re: Coding Practice
# Was expecting something like CodeAcademy, but it looks like there's a lot
# more useful resources here than just some practices. Thanks! Will look more
# into it.
#
#
# Re: Syracuse Student Panel Webinar and Application Fee Waiver Opportunity
# Hi Victoria,
#
# Thank you for letting me know about the webinar. Unfortunately, I will not
# be available at that time tomorrow. Will there be any followup webinars in
# the near future?
#
# Regards,
#
# David
#
#
# Re: Your DataScience@SMU Application
# Hi Maggie,
#
# Thank you for checking in with my application status. I have very recently
# received admissions from a couple of my top choice universities and will no
# longer be continuing with my application.
#
# Regards,
#
# David
#
#
# Re: SFSU MSBA information
# Hi Leyla,
#
# I am interested in attending the webinar. You mentioned that this will be
# the first. What date will the other ones be held and will they be the same
# as this one? Thanks.
#
# David
#
#
# Craigslist Ad Screenshot 2
# [<email.message.Message object at 0x000001FFDC3CCE48>, <email.message.Message object at 0x000001FFDC3CCBA8>]
# Ad Screenshot
# [<email.message.Message object at 0x000001FFDC3CCE80>, <email.message.Message object at 0x000001FFDC3CC908>]
#
# testing testing
#
# Re: Fantastic
# Good to know! Will hear from you tomorrow.
#
# David
#
#
# Re:
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3CCF98>, <email.message.Message object at 0x000001FFDC3CCF28>]
# Trogonophidae Map Editted
# [<email.message.Message object at 0x000001FFDC3CCEF0>, <email.message.Message object at 0x000001FFDC3CCDD8>]
#
# Claremont Grad. Uni.
# <https://admissions.cgu.edu/account/login?r=https%3a%2f%2fadmissions.cgu.edu%2fapply%2fcertify>
#
# UN: david92liu@gmail.com
#
# PW: Ilikebagel!1
#
# Re: Map
# Hey Bob,
#
# Got your message. Call me back and let me know if you still need my help on
# the map.
#
# David
#
#
# Thank you for interviewing me
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
#
# Once again, thank you for speaking with me and I am enthusiastic about the
# possibility of enrolling in the program.
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Thank you for interviewing me
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Thank You for Interviewing Me
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Thank You for Interviewing Me on Thursday
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
# Best Regards,
#
#
#
# David Liu
#
# Re:
# maybe i should also thank the admissions person who set up the interview as
# well in this email.. what do you think about including it.
#
#
#
# Dear Professor Stephen Devlin,
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although I lack a fluent understanding in certain preferred skills, such as
# in Python, I am currently actively taking online courses in order to
# improve my understanding of the subject.
#
# Once again, thanks for speaking with me about the program and I look
# forward to hearing about the final admissions decision.
#
# Regards,
#
# David Liu
#
#
# http://www.academia.edu/20025172/Linear_Algebra_and_Its_Applications_5th_Edition_
#
# Link to Zoom Online Interview
# Greetings,
#
# On January 18, I received an invitation to schedule an online interview for
# my MS Data Science program application. I set up the interview to be on
# January 24 at 1 PM and received an email that confirmed my chosen date and
# time for an online meeting with Prof. Stephen Devlin. According to the
# confirmation email, I am suppose to receive a followup email invitation
# with a calendar invite to join the meeting on Zoom on my scheduled date. I
# would like to know the status of the email as I have not yet received it.
# Thanks.
#
# Regards,
#
# David Liu
#
# =?UTF-8?Q?Re=3A_David=C2=A0=E2=80=93Action_Required_CRM=3A000100012771?=
# Hi Patrick,
#
# I am still interested in applying for the MS Business Analytics program at
# GGU, although it might take some time to get all my materials together.
# Just to clarify, the priority deadline for applying to the fall semester is
# in August correct?
#
# Regards,
# David
#
# On Wed, Jan 16, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote=
# :
#
# >
# >
# >
# >
# > Hi David ,
# >
# >
# > We at Golden Gate University would like to remind you that we are
# > dedicated to your educational success and here to support you with many
# > options for accomplishing your academic goals.  As your Enrollment
# > Counselor, I am committed to helping you learn more about GGU and determi=
# ne
# > if our programs are a good fit for you and your goals.
# >
# >
# >
# > *Please help me understand your current educational plans by replying to
# > this email with the following scenario that best represents your
# > situation: *
# >
# > 1.    I plan to apply for the next available semester
# >
# > 2.    I am interested, but not until a later start term
# >
# > 3.    I have postponed my search at this time
# >
# > 4.    I intend to enroll at another university
# >
# > If I don't hear back from you, I will assume you are still interested in
# > Golden Gate University but not at this time. We may send you emails from
# > time to time to check in. Please get back to me when you can. I look
# > forward to working with you!
# >
# >
# >
# > Sincerely,
# >
# > Patrick Gonzales
# >
# > Golden Gate University
# >
# > 415-442-7800 GGU Hub
# >
# > GGUAdmissions@ggu.edu
# >
# > www.ggu.edu
# >
# > www.ggu.edu=E2=80=9D>GGU.edu
# >
# >
# > *WARNING: *This E-mail, and any attachments, are covered by the
# > Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=
# ail may
# > contain confidential and legally privileged information. The contents of
# > this e-mail, and any attachments, are intended solely for the use of the
# > person or entity to whom the e-mail was addressed. This email may also
# > contain information that may be protected by the attorney-client privileg=
# e,
# > work-product doctrine, or other privileges, and may be restricted from
# > disclosure by applicable Federal and State laws. If you are not the
# > intended recipient of this email *you are advised that any dissemination,
# > distribution, or use of the contents of this message is strictly prohibit=
# ed*.
# > If you received this e-mail message in error, please contact the sender b=
# y
# > reply e-mail or phone. Please also permanently delete all copies of the
# > original e-mail and any attachments.
# >
# >
#
# Sending Official Transcripts
# Dear CSUEB Graduate Admissions Office,
#
# I am applying for the MS Business Analytics program for the fall 2019
# semester, and the application asks that I send official transcripts from
# all colleges and universities attended to the CSUEB Office of Admissions.
# Does CSU East Bay accept E-transcripts, and if so, is there a specific
# email address that I can send my official transcripts to? If not, I would
# like to confirm whether the address listed as "Office of Admission, Cal
# State East Bay, 25800 Carlos Bee Blvd., Hayward, CA, 94542" is the correct
# address to send my transcript. Thanks.
#
# Regards,
# David Liu
# Business Analytics Program - Test Scores
# Dear Dr. Jiming Wu,
#
# In regards to the Business Analytics program's requirements, does the
# program require official standardized test scores from applicants? I can
# see that the application requires manually entering test scores but it does
# not mention needing any official copies from the testing agencies, so I
# would like to get that clarified. Thanks.
#
# Regards,
# David Liu
#
# Regarding Official Transcripts and Test Scores
# Dear CGU Admissions Office,
#
# I am applying for the MS in Information Systems & Technology - Data Science
# & Analytics program for the fall 2019 semester, and the program asks for
# official transcripts to be sent. Does CGU accept E-transcripts, and if so,
# is there a specific email address that I can send my official transcripts
# to? If not, I would like to confirm whether the address listed as "CGU
# Office of Admissions, 150 E. 10th Street, Claremont, CA, 91711" is the
# correct address to send my official transcript to. Also, does CGU allow an
# applicant to submit transcripts and standardized test scores before
# submitting the application? Thanks.
#
# Regards,
# David Liu
#
# Re: Oakland volunteer intern application/MOU
# Definitely, it has been a while. It is great to see all the data show up on
# the map and to know that there is still development on the project in
# recent years. Hope it continues to grow, and maybe even have the pneumatic
# tubes that were discussed about back then to be installed on streets.
#
# Regards,
# David
#
#
#
# [<email.message.Message object at 0x000001FFDC3EDEB8>, <email.message.Message object at 0x000001FFDC3ED7B8>]
# Re: Oakland volunteer intern application/MOU
# Hi Jason,
#
# I would like to add that the date I listed on one of my applications is
# inconsistent with the one on the attachment. In my application to the
# University of Southern California (USC), I listed it as June to September
# as oppose to July to September. If this school happens to contact you and
# they mention June - September, let them know that I acknowledge the
# inconsistency and you can correct them. The application does not seem to
# provide any followup methods to edit experiences after submission. Thanks.
#
# Regards,
# David
#
#
# PS
# [<email.message.Message object at 0x000001FFDBDC2CF8>, <email.message.Message object at 0x000001FFDBDC2DA0>]
# textbooks
# [<email.message.Message object at 0x000001FFDBDC2F98>, <email.message.Message object at 0x000001FFDC3EDF98>]
# Re: Oakland volunteer intern application/MOU
# Hi Jason,
#
# Thank you so much for getting back to me and for making yourself available
# as a contact. Below is a brief summary of what I can recall.
#
# I was a volunteer intern for approximately two months to help build a
# traffic count database for an interactive count map project. I believe I
# started on the day listed on the application, which is 7/30/2012, and
# worked until 9/28/2012 for about 10-15 hours a week. I looked through years
# and months of traffic documents and surveys, each of which contains
# pedestrian, bicycle, and vehicle counts of a specific street intersection
# in Oakland, and I added those information onto an excel spreadsheet.
#
# Let me know if there are any more information that you might need that can
# help you in any way. Again, thank you so much for making yourself available
# for my application.
#
# Kind regards,
#
# David
#
#
#
# Re: Oakland volunteer intern application/MOU
# Hello Jason,
#
# It has been a while since we last touched base back in 2014. I hope you are
# doing well and I hope this email reaches you.
#
# I am contacting you again today because I recently started applying for
# master programs in data science. There are areas in some of my applications
# in which they asks whether the supervisors in each of my past listed
# positions can be contacted. I am letting you know that I listed my
# experience at the Bicycle and Pedestrian Program on the application, so let
# me know whether or not you are okay with me listing you as contactable. I
# believe that it is just for letting the admissions office confirm my past
# experiences. Thanks!
#
# Regards,
#
# David Liu
#
#
# Masters Application Contact
# Hi Patina,
#
# It has been a while since we last spoke back when I was still at Resh Lab
# doing the URAP program with you from 2013 to 2014 and also when you
# introduced me to work with your colleague, Erin, on the nematology project.
# I hope you are doing well! I hope this email reaches you.
#
# I am contacting you today because I recently started applying for master
# programs in data science. There are areas in some of my applications in
# which they asks whether the supervisors in each of my past listed positions
# can be contacted. I am letting you know that I listed my URAP experience on
# the application, so let me know whether or not you are okay with me listing
# you as contactable. I believe that it is just for letting the admissions
# office confirm my past experiences. Thanks!
#
# Regards,
#
# David Liu
#
# =?UTF-8?Q?Re=3A_David=E2=80=89_Let=27s_Talk_Soon=21_CRM=3A000100011928?=
# Hi Patrick,
#
# I would be happy to learn more about Golden Gate University and plan my
# next steps. I will be available right after 12 PM on Friday or Monday.
# Otherwise, if you are available on the weekend, anytime on Saturday or
# after 2 PM on Sunday will work for me. You can contact me at (510)
# 219-5580.
#
# Regards,
# David Liu
#
# On Wed, Jan 9, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote:
#
# >
# >
# >
# > Hi David ,
# >
# >
# > We hope you are looking forward to accomplishing your educational goals
# > with us at Golden Gate University. As your enrollment counselor, I am
# > dedicated to helping you get started on your degree with us!
# >
# >
# >
# > Please let me know when you are available to chat for 5 minutes so we can
# > plan your next steps. Kindly call to get started today.
# >
# >
# >
# > I look forward to speaking with you!
# >
# >
# > Best,
# >
# > Patrick Gonzales
# >
# > Golden Gate University
# >
# > 415-442-7800 GGU Hub
# >
# > GGUAdmissions@ggu.edu
# >
# > www.ggu.edu
# >
# >
# >
# >
# >
# >
# >
# >
# >
# > *WARNING: *This E-mail, and any attachments, are covered by the
# > Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=
# ail may
# > contain confidential and legally privileged information. The contents of
# > this e-mail, and any attachments, are intended solely for the use of the
# > person or entity to whom the e-mail was addressed. This email may also
# > contain information that may be protected by the attorney-client privileg=
# e,
# > work-product doctrine, or other privileges, and may be restricted from
# > disclosure by applicable Federal and State laws. If you are not the
# > intended recipient of this email *you are advised that any dissemination,
# > distribution, or use of the contents of this message is strictly prohibit=
# ed*.
# > If you received this e-mail message in error, please contact the sender b=
# y
# > reply e-mail or phone. Please also permanently delete all copies of the
# > original e-mail and any attachments.
# >
# >
#
# Re: MS in Data Science at USF Application - Question about Test Upload
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDBDC2BE0>, <email.message.Message object at 0x000001FFDC3C2EF0>]
# MS in Data Science at USF Application - Question about Test Upload
# Dear Admissions Office,
#
# I am just in need of a clarification in regards to reporting my test scores
# for the MS in Data Science application at USF. After entering my GRE scores
# in the "Test Scores" tab in the application and sending in my GRE scores to
# USF from my testing agency, the application also asks for a test upload. I
# believe that on a previous email, I was told to upload an official student
# copy of my test scores. Am I correct to assume that I can simply submit a
# printout of my reported scores from my testing agency website, or are there
# other official methods required?
#
# David Liu
#
# Re: Masters Reference
# Got you down as contactable. Thanks Erin!
#
# David
#
#
#
# [<email.message.Message object at 0x000001FFDC3C2D30>, <email.message.Message object at 0x000001FFDC3C2DD8>]
# Masters Reference
# Hi Erin,
#
# It has been a while since we last spoke back when I was still at the USDA
# facility in Albany with you and the others. I hope you are doing well! I am
# not certain whether you still communicate with this email address, so I
# hope this email reaches you.
#
# I am contacting you today because I recently started applying for masters
# programs in data science. There are areas in some of my applications in
# which they asks whether the supervisors in each of my past listed positions
# can be contacted. I am letting you know that I listed my temporary position
# at Albany as one of my previous experiences, so let me know whether or not
# you are okay with me listing you as contactable. Thanks.
#
# Regards,
#
# David Liu
# USF
# https://gradapply.usfca.edu/account/login
# UN: david92liu@gmail.com PW: Ilikebagel!1
#
# USC
# https://usc.liaisoncas.com/applicant-ux/#/login
# UN: dkwliu PW: Ilikebagel!1
#
# Well I keep forgetting. We can't submit anything because the scores haven't
# come in yet. But at the very least, check to see if everything else is in
# order first so that when the score comes in, I can immediately submit it.
#
# Re: Your UC Berkeley MIDS Application
# Hi Bill,
#
# I would be happy to learn more about the UC Berkeley MIDS program. I will
# be available right after 12 PM on Friday or Monday. Otherwise, if you are
# available on the weekend, anytime on Saturday or after 2 PM on Sunday will
# work for me as well. You can contact me at (510) 219-5580.
#
# Regards,
#
# David Liu
#
#
#
# [<email.message.Message object at 0x000001FFDC3C2B38>, <email.message.Message object at 0x000001FFDC3C2B00>]
# Outline for the Prompt
# [<email.message.Message object at 0x000001FFDC3C27B8>, <email.message.Message object at 0x000001FFDC3C2C18>]
# Draft 2
# [<email.message.Message object at 0x000001FFDBDC2B38>, <email.message.Message object at 0x000001FFDC3C2390>]
# Re: Added a Sentence
# He has taken various classes in computational sciences from 2015-2018 that
# covers multiple programming languages, and throughout he has consistently
# earned high marks
#
#
# Added a Sentence
# [<email.message.Message object at 0x000001FFDC3C2048>, <email.message.Message object at 0x000001FFDC3C2F98>]
# New Assessment
# David has academic experience creating applications with Java, JavaScript,
# C++, and C#. He also has a keen interest in learning PERL scripting for
# manipulating genomic data.
#
# Programming Skills Assessment
# David has academic experience creating applications with Java, JavaScript,
# C++, and C#.
#
# Looking for More Letter of Recommendations/References
# Hi Bob,
#
# Hope you had a great holiday! I am contacting you again about a number of
# other graduate programs that I am applying for and I just want to check
# whether you have time to send out a few more letters. Some program
# deadlines are coming up but I am definitely not in an immediate rush this
# weekend, so just let me know whenever, or if, you will be free. Thanks!
#
# David
#
# List of MS Programs
# [<email.message.Message object at 0x000001FFDC3C2940>, <email.message.Message object at 0x000001FFDC3C2240>]
# Re: Class Make-up Request
# Yuri,
#
# That is perfect! Thank you very much.
#
# David
#
#
#
# Class Make-up Request
# Greetings. I am currently attending Isaac's GRE quant session at San
# Francisco which started on 12/06 and will end on 1/10. I do not think that
# I will be able to attend class 4 (1/03) and 5 (1/10) for his session, so if
# possible, I would like to make up for those two classes at the Santa Clara
# quant session instead, which will be held on 12/11 and 12/18. Please let me
# know whether those class dates are available for make-up. If requesting for
# two make-up dates is not possible, then I am fine with just one, but I
# would prefer it to be for the fifth class on 12/18. Thanks.
#
# Regards,
#
# David Liu
#
# ...
#  Draft - David Liu
# Hi Shawn,
#
# I would like to do 6.4.31 for my solution share next Wednesday. Let me know
# whether it's still available.
#
# ---------------------------------------------------------
#
# Also, the following are the questions that my team will be using for the
# extra credit survey. The subject will be on "Opinions about Protest".
#
# 1) Do you have a positive or negative perception about the way you think
# protests are conducted nowadays, and why?
#
# 2a) (*If survey taker has a negative perception) *Do you know who is Colin
# Kaepernick? (Describe to survey taker if not). Does this form of protest
# fit in your negative perception?
#
# 2b) *(If survey taker has a positive perception) *Do you know about the
# recent Berkeley protests? (Describe to survey taker if not). Does this form
# of protest fit in your positive perception?
#
# 3) As far as you know, what do you think needs to be changed about how
# protests are conducted nowadays?
#
# Let me hear your objections.
#
#
# Thanks,
# David Liu
#
# Schedule Update Plaxgen - David Liu
# Hi Shan,
#
# As I had mentioned a couple months prior, as a part of my plan to make time
# to pursue my educational and career goals, I need to make revisions to my
# weekly working schedule. So from this point forth, I will be available to
# work each week on-call on the following days: Tuesday, Thursday, Friday,
# and conditionally on Saturday.
#
# Regards,
#
# David Liu
#
# Re: Agenda: CONN/HOUSE Svc 10/15 (CCS Sunday)
# Looks like everything=E2=80=99s covered. I will also be free if I=E2=80=99m n=
# eeded for any reason.=20
#
# David
#
# Sent from my iPhone
#
# >
#
# keyboard and mouse
#
# https://www.amazon.com/dp/B00NLZUM36/?tag=pcpapi-20
#
#
# motherboard
# https://www.newegg.com/Product/Product.aspx?Item=N82E16813130935&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=
#
#
# RAM
# https://www.newegg.com/Product/Product.aspx?Item=N82E16820232419&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=
#
# Re: Connection #4
# Submitted.
#
#
# Re: Connection #4
# Hey Ratthanan,
#
# The writeup looks good! I will go ahead and send it in in maybe about half
# an hour. But until then, let me know if you still want anything changed.
#
# David
#
#
# Connection #4
# Hey Ratthanan,
#
# Just shared a doc with you. You can ignore this email if you got it. If
# not, let me know.
#
# David
#
# Re: Call me
# Woops. Didn't check my email yesterday. Also got home a bit late. Let me kno=
# w if you still need me, in which case I'll just call you later today.
#
# Sent from my iPhone
#
# >
# Connection #3
# Hey Jihyun,
#
# Finally got to write up a response. Go ahead and look it over and see if
# you'd like to add anymore comments for your part, and I'll probably do the
# same. Otherwise, I think we got a pretty good piece for submission.
#
# David
#
# READ THIS EMAIL IF YOU'RE CONFUSED
# Hey Bob,
#
# Just a bit of clarification for the last 6 emails I sent you in the last 20
# minutes or so.
#
# The emails that says "PDF versions" and "TIF versions" on the subject line
# are probably the ones you want to look at.
#
# The ones that says "Word versions" are the original files in which I used
# to create the PDFs and TIFs. You may look at those only if you're planning
# on making some adjustments or corrections.
#
# cheers,
#
# David
#
# 8 Plates - Word versions one more
# [<email.message.Message object at 0x000001FFDC3CCF28>, <email.message.Message object at 0x000001FFDC3ED6A0>]
# 8 Plates - Word versions one more
# [<email.message.Message object at 0x000001FFDC3ED2E8>, <email.message.Message object at 0x000001FFDC3EDEF0>]
# 8 Plates - Word versions part 3
# [<email.message.Message object at 0x000001FFDC3ED358>, <email.message.Message object at 0x000001FFDC3ED0F0>]
# 8 Plates - Word versions part 2
# [<email.message.Message object at 0x000001FFDC3ED828>, <email.message.Message object at 0x000001FFDC3EDE48>]
# 8 Plates - Word versions
# [<email.message.Message object at 0x000001FFDC3ED780>, <email.message.Message object at 0x000001FFDC3ED048>]
# 8 Plates - PDF versions
# [<email.message.Message object at 0x000001FFDC3ED128>, <email.message.Message object at 0x000001FFDC3ED908>]
# 8 Plates - TIF versions
# [<email.message.Message object at 0x000001FFDC3ED278>, <email.message.Message object at 0x000001FFDC3ED9B0>]
# Re: Connection Assignment #2
# Also, let me know whether you agree that this article is considered a math
# article.
#
#
# Connection Assignment #2
# Hey Alex,
#
# Lets get the ball rolling. I've decided to go with a question involving
# "news story with (interesting, confusing, problematic) use of math". If you
# have another question in mind, feel free to share it. We can later decide
# which question would be the easiest to work off of. Otherwise, feel free to
# reply to my email with your response to my prompt.
#
#
# Initiator: David Liu
# Responder: Alex Alba
# Date: 9/6/2017
# Topic: News story with (interesting, confusing, problematic) use of math:
# plastic-contaminated water
# Source: Magness, Josh. Billions are drinking water contaminated with
# plastic - and US has it the worst, study finds. September 6, 2017
# http://www.sacbee.com/latest-news/article171475582.html
#
# So I found this article about plastic contamination in the world's water
# supply. In the study in which the article is based on, 159 tap water
# samples in total were tested from five different continents. The overall
# result is that 83% of the samples were contaminated with plastic. The water
# with the lowest contamination rate was collected from Europe, which had a
# 72% contamination, whereas the United States had the highest contamination
# at 94%. I did not read the original manuscript, but, without knowing the
# methods used in the experiment, I would take the results from this study
# with a grain of salt. The overall contamination rate is way too high to be
# believable and to have not done something to us already.
# Re: Plates
# Hi Bob,
#
# All is well. So I will refer to this doc instead of the old one then. I
# will look through it as soon as I can.
#
# Thanks,
#
# David
#
#
# Re: Help - can we talk
# Hey bob,
#
# Great to hear from you. Can't help at the moment. Will be home at probably a=
# round 6-7. Will call you. Otherwise you can call me if you still need help w=
# ith the scans.
#
# David=20
#
# Sent from my iPhone
#
# >
# Re: Connection Project
# Almost forgot. Checking in to let you know the assignment was submitted.
#
#
# Re: Connection Project
# Also. Let me know if/when you decide to submit it.
#
#
# Re: Connection Project
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED208>, <email.message.Message object at 0x000001FFDC3ED978>]
# Re: Connection Project
# Hey Sam,
#
# Lets put the connection document together. I was thinking that you can put
# all the parts you want to include in a word doc first since you initiated
# the question on Monday. Then you can send the word doc to me and I'll add
# my parts to it.
#
# Content-wise, I think the short exchange we had over emails on Monday would
# do just fine as our connection. At least I know I'll just be copy-pasting
# my part onto the connection doc. You may change and correct your's to your
# liking.
#
# David
#
#
# Re: Connection Project
# I see. I'm going to assume that our textbook is probably more theory-based
# compared to those.. which is still good in its own ways. Thanks for letting
# me know. I'll look into them.
#
#
# Re: Connection Project
# Haha. I think you just initiated #5, although I guess it fits into #2 as
# well, so here are my thoughts in response to your initial question.
#
# I don't think it really matters exactly what book we use as long as it does
# the job in helping us learn. I personally like to have a decent variety of
# textbooks to work off of in case if one just doesn't cut it. In this case,
# I would just use our textbook for this class mainly for doing the
# exercises, and probably another textbook to explain the materials if our's
# doesn't do it well enough (By the way, let me know of these other textbooks
# you're referring to). So more unconventional books I have knowledge of, the
# better I suppose. Even so, to be absolutely fair, our current textbook
# isn't completely out-of-the-way. As I was researching for some pdfs and
# partial texts of our current textbook, there were definitely a few online
# forums and threads that recommended using this textbook to get started on
# learning linear algebra. So definitely not a bad book.
#
#
# Connection Project
# Hey Sam,
#
# Lets get the ball rolling on the assignment. For our connection options, I
# think we can eliminate #6 and 7 since I doubt either of us would want to go
# through the trouble of interviewing community members or attending special
# community events. Some of them, like #1, is a bit open ended. So I was
# thinking of maybe choosing between #2, #3, or #5. Let me know what you
# think and/or disagree with any of these ideas.
#
# David
#
# Re: Reset Password - Apple iPhone & iPad [Reference: 170813-000127]
# Hi Casey,
#
# First Name/Last Name: David Liu
#
# Zip Code: 94546
#
# Below is a direct copy of the subscription confirmation. Thank you for your
# help!
# ___________________________________________________________________________=
# _____________
#
# [image: Apple] Subscription Confirmation
# [image: HBO NOW=E2=84=A0]
# HBO NOW=E2=84=A0
# HBO NOW=E2=84=A0 (1 month)
# Free Trial
# Dear Audrey,
# You=E2=80=99ve purchased the following subscription with a 1 month free tri=
# al:
# *Subscription* HBO NOW=E2=84=A0
# *App* HBO NOW: Stream original series, hit movies & more
# *Content Provider* HBO Digital Services, Inc.
# *Date of Purchase* Aug 11, 2017
# *Duration* 1 month
# *Trial Duration* 1 month
# *Price* $14.99
# *Payment Method* Visa .... 8668
# You won=E2=80=99t be charged for your free trial.
# Some Cancer Treatment Hospitals
# [<email.message.Message object at 0x000001FFDC3ED2B0>, <email.message.Message object at 0x000001FFDC3ED208>]
#
# Hey Bob,
#
# It's been a while. Great to hear from you. Very sorry for missing your
# call. I was busy working with a couple others when you called and we've
# only finished just now.
#
# Heard You mentioned something about helping out a student. I tried calling
# you a couple times but you didn't pick up. Give me a call if you still need
# me.
#
# David
#
# Connection Schedule - Swapping Date with Alvin
# Hey Ben,
#
# Not sure if Alvin notified you yet, but I told him that I am willing to
# switch my Sunday in July with his, and I believe he is fine with the
# switch. So unless he said otherwise, would it be fine if I switch my date
# (7/2) with his (7/23).
#
# David
#
# Re: Fw: Connection Schedule, May to Aug 2017 - Swap for 7/23
# -Alvin
#
# That would be 7/2, the first Sunday in July.
#
#
# Re: Fw: Connection Schedule, May to Aug 2017 - Swap for 7/23
# Hi Alvin,
#
# I can switch with you if you're still looking for a replacement.
#
# David
#
#
# Re: David, exciting opportunity at Counsyl!!
# Hi Genevieve,
#
# My apologies for the late reply. Thank you very much for your time and for
# letting me know about this opportunity. Unfortunately, I am currently not
# available for a position with a weekend time schedule. However, I may be in
# the near future or for any other opportunities for that matter. I would
# love to keep in touch and to hear or ask about any future openings at
# Counsyl if that is fine with you.
#
# Thanks,
#
# David
#
#
# Tel # for Medical Records
# Medical Records
# Alta Bates Campus 510-204-1440
# Summit Campus 510-869-6545
#
#
# Hey bob,
#
# Tried to return your call just now. Not sure if you got it. Currently not
# at home right now, but call or email me if you need me.
#
# David
#
# Re: Short time to work
# Hey Bob. Looks like I missed your message last night. Hope you got what you
# needed, or let me know if you still need to have some searching done.
#
# David
#
#
#
# [<email.message.Message object at 0x000001FFDC3ED198>, <email.message.Message object at 0x000001FFDC3ED6D8>]
#
# [<email.message.Message object at 0x000001FFDC3EDBA8>, <email.message.Message object at 0x000001FFDC3EDA20>]
#
# [<email.message.Message object at 0x000001FFDC3EDF60>, <email.message.Message object at 0x000001FFDC3ED668>]
#
# [<email.message.Message object at 0x000001FFDC3ED400>, <email.message.Message object at 0x000001FFDC3EDD30>]
#
# [<email.message.Message object at 0x000001FFDC3ED9E8>, <email.message.Message object at 0x000001FFDC3EDAC8>]
# Re:
# Quite a contrast between the two news. Truly sorry to hear about the first
# one. I know there isn't much I can help with the things you mentioned, but
# please let me know if there is anything you want to talk about.
#
# David
#
#
#
# Hey bob,
#
# Seems like I missed a few of your calls recently. I was out most of
# yesterday and will be out for most of today as well. Let me know the news
# via email if you can. Or I might be free later tonight.
#
# David
#
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED710>, <email.message.Message object at 0x000001FFDC3EDC50>]
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3EDBE0>, <email.message.Message object at 0x000001FFDC3ED4E0>]
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3EDC50>, <email.message.Message object at 0x000001FFDC3ED7F0>]
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3EDBE0>, <email.message.Message object at 0x000001FFDC3ED0B8>]
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED7F0>, <email.message.Message object at 0x000001FFDC3EDA58>]
# Re: File
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3EDBE0>, <email.message.Message object at 0x000001FFDC3EDDD8>]
#
# [<email.message.Message object at 0x000001FFDC3EDA58>, <email.message.Message object at 0x000001FFDC3ED978>]
#
# Hey Bob,
#
# Missed your call earlier so I thought I'd return it. Nobody picked up.
#
# In any case, got your call from a few days back. Just letting you know that
# I've enrolled in Biosci34.
#
# David
#
# Response to Your Call On Monday
# Hi Levar,
#
# I got your call on Monday regarding possible new openings and my current
# employment status. I could not get a chance to call you, so I figured that
# I will just email you instead. Sorry for the late response.
#
# Firstly, thank you for checking back up on me about my current job
# situation! I am still currently working full time at the same company from
# about a year ago and I probably won't be searching for any new employment
# opportunities at least for the next few months. I will surely contact you
# again once I get back into job searching.
#
# You mentioned something about referrals. Do you mean referrals for anybody
# I know who would be interested in job opportunities? If yes, I don't
# currently know many who are looking for laboratory positions, unless maybe
# you have other listings. However, I can still check around. Otherwise, let
# me know what you mean by that.
#
# Regards,
#
# David Liu
#
# Tel: 510-219-5580 <(510)%20219-5580>
#
#
# [<email.message.Message object at 0x000001FFDC3EDD68>, <email.message.Message object at 0x000001FFDC3EDDD8>]
# more links
# https://www.rootsforreal.com/
#
# www.forensicmag.com/article/2013/04/challenges-dna-testing-and-forensic-analysis-hair-samples
#
# http://www.legalgenealogist.com/2012/06/03/dna-and-the-locks-of-hair/
#
#
# https://www.fullgenomes.com/
#
# Re: Paper to get
#
#
# The email that had issues was the following:
# [<email.message.Message object at 0x000001FFDC3ED080>, <email.message.Message object at 0x000001FFDC3ED710>]
#
# http://www.calacademy.org:8080/sites/default/files/assets/docs/pdf/occ_pap_161_2013_swa_bib_2nd_ed_web_version.pdf
#
#
#
# The email that had issues was the following:
# http://www.calacademy.org:8080/sites/default/files/assets/docs/pdf/occ_pap_161_2013_swa_bib_2nd_ed_web_version.pdf
#
#
# [<email.message.Message object at 0x000001FFDC3ED5F8>, <email.message.Message object at 0x000001FFDC3ED5C0>]
#
# [<email.message.Message object at 0x000001FFDC3ED630>, <email.message.Message object at 0x000001FFDC3ED0B8>]
#
# [<email.message.Message object at 0x000001FFDC3ED3C8>, <email.message.Message object at 0x000001FFDC3ED4E0>]

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# Below visualizes how the data might look like

# %%
for each in extracted_emails:
    print(each)
# Out:
# this is a response
#
#
# Hi David,
#
# This is a sample email.
#
# https://www.walmart.com/ip/Apple-iPad-mini-Wi-Fi-64GB/207104625
#
# https://www.bestbuy.com/site/apple-10-2-inch-ipad-latest-model-with-wi-fi-3=
# 2gb-space-gray/5199701.p?skuId=3D5199701
#
# https://www.adorama.com/acmyla2lla.html?gclid=3DCj0KCQiAzZL-BRDnARIsAPCJs73=
# IvW8I6hSvm04SkA0uSh1H4tsa0sjbo7Q-uuhvrndPUyO2jg-Md6QaAt_5EALw_wcB&utm_sourc=
# e=3Dadl-gbase
#
# Older Model:
# https://www.walmart.com/ip/Apple-iPad-4-with-Retina-Display-32GB-Wi-Fi-4th-=
# Generation-in-Black/22288800?wmlspartner=3Dwlpa&selectedSellerId=3D9186&&ad=
# id=3D22222222227016434816&wl0=3D&wl1=3Dg&wl2=3Dc&wl3=3D343334214440&wl4=3Dp=
# la-486397163036&wl5=3D9032013&wl6=3D&wl7=3D&wl8=3D&wl9=3Dpla&wl10=3D1170193=
# 45&wl11=3Donline&wl12=3D22288800&veh=3Dsem&gclid=3DCj0KCQiAzZL-BRDnARIsAPCJ=
# s71ZBDQi_Vj6RvtNPGp55mVHFKiQ3f0UXexwDyKS6BIc_-X3kOA0wusaAmQ5EALw_wcB
#
# Hi Han,
#
#
#
# This is just a quick follow-up from yesterday. I would like to thank you
# for spending an extended period of time interviewing me, and allowing me
# to have a better understanding of what the contract position entails. I am
# excited for the possibility of working with the health strategic initiative
# team to build data pipelines and machine learning functions for health and
# wellness applications.
#
#
#
# Looking forward to hearing back about any updates on the position.
#
#
#
# Best Regards,
#
#
#
# David
#
#
# Greetings Han,
#
# I am guaranteed to be free on Friday 10/9 at 4 PM. I look forward to
# speaking with you soon!
#
# Thanks,
# David
#
#
# Hi Andy,
#
# That is great! I look forward to speaking with your lead. Should I be
# expecting an email some time later today?
#
# Thanks,
# David
#
#
# Hi Andy,
#
# This is just a follow up on our previous conversation regarding the
# contract positions. Since the positions are still in the works, would it be
# necessary for me to check in again at a later date if I am still
# interested? And if so, when do you think would be a good time for me to do
# so? I ask because it was unclear to me during our previous correspondence
# whether we were planning to further discuss the topic, or whether I should
# check in later. If there isn't much information on the planned contract
# positions at the moment, that is fine too. In any case, thank you so much
# for your time and patience regarding my inquiries about these
# opportunities, thus far.
#
# Regards,
# David
#
#
# Hi Andy,
#
# I completely understand. The contractor position sounds great and I am
# certainly open to further discuss this opportunity. What would be the next
# step?
#
# Regards,
# David
#
#
# Hi Andy,
#
# I would like to check in again on the status of the Health Strategic
# Initiatives data engineering position and whether it is still available. I
# am still very much interested in the position and I look forward to hearing
# back about any updates on the situation.
#
# Thanks,
# David
#
#
# Hi Xiaoyi,
#
# I checked in with Andy yesterday, and he responded earlier today. According
# to him, he does not know the headcount for FY2021 and told me to check in
# later as he will find out some time between now and October 1. Would you
# happen to know how long does this usually take?
#
# Thanks,
# David
#
#
# Hi Andy,
#
# Thanks for the update about the situation. I will check back around 3 weeks
# from now, or some time during the week of September 21, if you don't mind.
#
# Thanks,
# David
#
#
# Greetings Andy,
#
# We previously spoke over the phone on June 7 regarding the Health Strategic
# Initiatives data engineer position, and you suggested that I contact you
# again about it during early September of this year for a possible formal
# screening. Is the position still open at this time? If so, what would be
# the next step? Thank you very much.
#
# David
#
#
# Hi Xiaoyi,
#
# It has certainly been a while since we last spoke, so thanks for reaching
# out to me and for the reminder and tips!
#
# My apologies for the lack of news about my status recently, but I am
# currently finishing up the last week of my summer session so I have not
# been sending out many resumes for the last couple weeks. I plan on resuming
# my job apps after this week once I have more time. Project is fine. I was
# simply reworking one of my older data collection projects and applying
# machine learning techniques to better fit the job description, but there is
# still more I plan on doing with it.
#
# I will definitely be contacting you soon about apple positions, so we'll be
# in touch!
#
# Thanks,
# David
#
#
# Hi Xiaoyi,
#
# Yes, that's basically what he suggested: to talk about the methods I used
# in my project and why, any possible issues there might be, and, most
# importantly, to not take the efficiency and speed of data processing tools
# for granted. And yes, I intend to build a project in the time remaining as
# you suggested that it might be better if it is new and related to the
# position, and I will also have a good amount of machine learning resources
# to work with as I am taking it as a course this summer.
#
# I will definitely be applying for more positions at Apple in the near
# future, so thanks, and, again, we will be in touch! I will take a pause for
# maybe a month, or at least until I finish this summer, as it appears that a
# lot of data positions utilizes machine learning and I would really want to
# know what the subject is all about.
#
# David
#
#
#
#
#
#
#
#
#
# Hi Xiaoyi,
#
# We spoke for around 40 minutes, and he just wanted to look into my
# background while I had the chance to learn more about the position. There
# was actually nothing technical about it. I told him that I will graduate
# this coming December, so he told me to shoot him an email during early
# September which is when he will set up a formal interview. Here's hoping
# that the position does not fill by then.
#
# I also asked him about the interview, and he told me that it will be a 1
# hour presentation about one of my projects but gave no more details or
# whether it will be technical or not. Said that if I were to be hired for
# the position, I would be someone who would need to be mentored and grow in
# the position, so I am guessing he is not hiring me for my expertise. I
# assume that this sort of interview is pretty unusual for Apple standards?
#
# Regards,
# David
#
#
# Hi Xiaoyi,
#
# Someone named Andy Pham contacted me for the Data Engineer, Health
# Strategic Initiatives position (Role Number:200172241,
# https://jobs.apple.com/en-us/details/200172241/data-engineer-health-strateg=
# ic-initiatives?team=3DSFTWR
# ).
#
# We arranged to speak for a few minutes on a video chat for the coming
# Tuesday at 2 PM. I am guessing this is just the initial screening to see
# whether I would be a good fit before there would be an interview. Do you
# have any idea about what they might ask or what Apple does differently with
# these screenings?
#
# Thanks,
# David
#
#
#
#
# Hello Andy,
#
# Marked on calendar. Looking forward to speaking to you soon.
#
# David
#
#
# Hi Andy,
#
# I will be available anytime today or at anytime for the rest of this week.
# Next week will work as well, but only after 12 PM on Tuesdays and
# Thursdays. I look forward to speaking with you!
#
# David
#
#
# Hi Xiaoyi,
#
# Good to know! I will keep that in mind when applying for Apple jobs in the
# future.
#
# Since there isn't many job postings left that match my current skill set, I
# will probably take a hiatus on any new applications at Apple for now. Can't
# thank you enough for all your help and thank you for making yourself
# available for sending out resumes for me in the future. If your schedule or
# situation permits, I would like to do this again in the coming months,
# assuming that none of my current applications go through.
#
# Cheers,
# David
#
#
# Hi Carlos,
#
# It has been a while since we took linear algebra together at BCC. I hope
# you are doing well!
#
# I am not sure if your email was actually meant for me, but, unfortunately,
# I am in no position to hand out job opportunities as I am finishing up a
# graduates program and am looking for work positions myself; so it looks
# like we are pretty much in the same boat! Let me know if there is anything
# else I can help you with.
#
# Cheers,
#
# David Liu
#
#
# Xiaoyi,
#
# Great! Thanks again.
#
# David
#
#
# Forgot to tell you. I did not find any letters for you. I am not sure if
# somebody else is keeping them for you, but I don't think there are any
# letters that has your name on it.
#
# On Mon, May 18, 2020 at 9:38 PM David Liu <david92liu@gmail.com> wrote:
#
# > Yes. Okay. I will look for your letters.
# >
# > On Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wro=
# te:
# >
# >> Hi=EF=BC=81 David=EF=BC=9A
# >> Can you put all my letters in the mailbox today?   I'll get it tomorrow
# >> morning!  Thank  you!
# >>
# >> Yours.
# >> Yufen Lin
# >>
# >> =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone
# >
# >
#
# [<email.message.Message object at 0x000001FFDBDC2EB8>, <email.message.Message object at 0x000001FFDBDC2E10>]
# Yes. Okay. I will look for your letters.
#
# On Mon, May 18, 2020 at 7:27 PM =E6=9E=97 Fanny <lyf7272@hotmail.com> wrote=
# :
#
# > Hi=EF=BC=81 David=EF=BC=9A
# > Can you put all my letters in the mailbox today?   I'll get it tomorrow
# > morning!  Thank  you!
# >
# > Yours.
# > Yufen Lin
# >
# > =E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone
#
# Okay. I will look out for it.
#
#
# [<email.message.Message object at 0x000001FFDC3EDC88>, <email.message.Message object at 0x000001FFDC3ED898>]
# [<email.message.Message object at 0x000001FFDBDC2278>, <email.message.Message object at 0x000001FFDC3ED518>]
# Okay
#
#
# It looks like i received the letters. How do you want me to send the
# letters back?
#
#
# okay. I will look out for it
#
#
# Hi Joe,
#
# In that case, thank you very much for the information. I'll definitely see
# what I can find and get the resume updated and going.
#
# David
#
#
# Hi Joe,
#
# I was recently told about openings at a company called Veeva, and I believe
# it was your wife, Mrs. Li, who shared this information, so please give her
# my thanks. I had a chance to look through the company website and there
# were definitely some positions and roles that I found interesting. However,
# I could not find anything other than full-time/long-term positions, which I
# am not available for at this time. May I ask that she clarify exactly what
# the new positions are, or where on the website can I find them in case I am
# looking at the wrong places? Thank you very much.
#
# David
#
#
# Hi Joe,
#
# I figured that I should share this email with you so that you know which
# email I may be contacting you with, and to make sure that I added your
# email correctly.
#
# Thanks again for the talk and for the tips you shared with me last Monday.
# I very much appreciate it.
#
# Cheers,
#
# David
#
# Join Zoom Meeting
# https://csueb.zoom.us/j/554033172
#
# Meeting ID: 554 033 172
#
# One tap mobile
# +16699006833,,554033172# US (San Jose)
# +16465588656,,554033172# US (New York)
#
# Dial by your location
#         +1 669 900 6833 US (San Jose)
#         +1 646 558 8656 US (New York)
# Meeting ID: 554 033 172
# Find your local number: https://csueb.zoom.us/u/acNwdbUoa0
#
# Join by SIP
# 554033172@zoomcrc.com
#
# Join by H.323
# 162.255.37.11 (US West)
# 162.255.36.11 (US East)
# 221.122.88.195 (China)
# 115.114.131.7 (India Mumbai)
# 115.114.115.7 (India Hyderabad)
# 213.19.144.110 (EMEA)
# 103.122.166.55 (Australia)
# 209.9.211.110 (Hong Kong)
# 64.211.144.160 (Brazil)
# 69.174.57.160 (Canada)
# 207.226.132.110 (Japan)
# Meeting ID: 554 033 172
#
# User name: Yufenlin72
# Password: Lyf586091
#
# Hi Jamieelee,
#
# Thank you for getting back to me. My netid is az7762.  I was initially
# having issues with enrolling in courses because my MyCSUEB site did not
# include a student tab or student center link. I contacted Gradadmissions
# and was told that I should be able to start enrolling tomorrow, so, unless
# if there is anything else I missed, I believe I should be fine for now.
# Again, thanks for touching base with me regarding my enrollment issue, and
# I will be sure to direct any of my future correspondence with you via
# Horizon in the future.
# Greetings Again Jiming,
#
# It appears that the orientation registration had already closed. Would it
# be possible that I just show up and attend the orientation anyways?
# Otherwise, is there any other way I can register at this point?
#
# Also, I cannot seem to find an option to add courses on the myCSUEB site
# using the instructions provided in my admissions package. Do I need to
# follow additional steps to register for classes during the open enrollment
# period from Aug 15 - 19, or am I doing something wrong here?
#
# Thanks in advance, and my apologies for the last minute questions. It was a
# bit hectic waiting and gathering the information I needed to make a
# decision.
#
# Regards,
#
# David
#
#
# Greetings Dr. Jiming Wu,
#
# I received an offer for admission to the CSUEB MS Business Analytics
# program in mid July and I was told by the Graduate Admission office that
# there is no deadline to accept the offer, so I want to confirm with you
# about whether this information is accurate, and whether there are any
# information about any deadlines that I may had missed regarding the
# admission offer. I also found this information slightly confusing because
# there is an MSBA program orientation on 8/17, and I cannot register for it
# unless I accept my offer.
#
# I would like to note that the reason why I want to know about the offer
# acceptance deadline is because I am still trying to weigh my options and I
# probably will not receive all the information I can get to make my decision
# for grad school until during or after the week of August 12. Hence, it
# would be extremely helpful for me to know whether this may pose any issues
# in regards to my offer acceptance. Thank you for your time and thank you in
# advance for any information that you may provide me.
#
# Regards,
# David
#
# Hi Chris,
#
# You mentioned that August 9 will be the end of the priority registration
# period. Does this mean that I can still register even after that date, but
# minus a few priority perks, or is it absolutely the last day that I can
# still accept an offer of admission? Also, if August 9 really is the last
# date, would it still be viable for me to register this week since I
# understand that there will probably be some prerequisites or processes that
# I'll need to finish that may take some time, such as mailing in
# transcripts, registering for classes, submitting proof of immunization,
# etc...
#
# Thanks in advance,
# David
#
#
# Greetings Sophie,
#
# It has recently been brought to my attention that the time window for
# accepting my admission to the SFSU MSBA program is still open. I am
# wondering when is the actual deadline for me to make a decision. I am
# currently still weighing my options and it would be extremely helpful for
# me to know when action is needed on my part. For instance, would I still be
# allowed to make a decision by the week of August 12. Thanks.
#
# Regards,
# David Liu
#
# Greetings,
#
# It has recently been brought to my attention that the time window for
# accepting my admission to the CSUEB MSBS program is coming to a close but
# is still open. I am wondering when is the actual deadline for me to make a
# decision. I am currently still weighing my options and it would be
# extremely helpful for me to know when action is needed on my part. Thanks.
#
# Regards,
# David Liu
#
# Pretty cool you get entire books.
#
# Thanks!
#
#
# Hi Ben,
#
# yes I will be available
#
#
# [<email.message.Message object at 0x000001FFDC3ED438>, <email.message.Message object at 0x000001FFDC3ED390>]
# https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---256GB-SSD---Radeon-Pro-555X---Silver.product.100472319.html
# - ive confirmed that the one above is the one i want
#
# https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---512GB-SSD---Radeon-Pro-560X---Space-Gray.product.100472395.html
# - this one here is good too, but the other one is cheaper.
#
# [<email.message.Message object at 0x000001FFDC3ED4A8>, <email.message.Message object at 0x000001FFDC3ED320>]
# [<email.message.Message object at 0x000001FFDC3ED550>, <email.message.Message object at 0x000001FFDC3EDB00>]
# https://slickdeals.net/f/13011733-apple-macbook-pro-with-touch-bar-fptr2ll-a-15-4-laptop-computer-apple-certified-refurbished-space-gray-1599-98?attrsrc=Test%3AHideExpiredSearch%3AControl&src=SiteSearchV2Algo1
#
#
# https://www.microcenter.com/product/600944/macbook-pro-with-touch-bar-fptr2ll-a-154-laptop-computer-apple-certified-refurbished---space-gray
#
# https://www.apple.com/shop/product/G0SF2LL/A/Refurbished-133-inch-Macbook-P=
# ro-33GHz-Dual-core-Intel-Core-i7-with-Retina-Display-Space-Gray?fnode=3Ddb7=
# b1e36e34e927189e9c4c5df91d78aa961b6be9d954739f3b99b5715dafbd0c9cb1f51fb42ff=
# c44e36bafc49750a454ba7f560fb3b22d6a6e1ac7cf8ba316b41cb60ac071128a83cb14916c=
# bafb7be
#
# https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=
# 07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=
# INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=
# amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4
#
# this one.. not the one above
#
#
# https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=
# 07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=
# INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=
# amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4
#
# https://www.apple.com/shop/product/G0T21LL/A/Refurbished-133-inch-Macbook-P=
# ro-31GHz-Dual-core-Intel-Core-i5-with-Retina-Display-Silver?fnode=3D98769c7=
# 052da9a6fb988727b003fb8b2e388032d5d0fde5e4890cdc5029b8d92cd91dc6b9bc8445f66=
# 40e3f6fac54f2bc8fd0645a63fd5b983a4d4867c6e686fb089e6859185d916ac96d70b8253f=
# 311
#
# [<email.message.Message object at 0x000001FFDC3CC668>, <email.message.Message object at 0x000001FFDC3CC860>]
# [<email.message.Message object at 0x000001FFDC3CCB70>, <email.message.Message object at 0x000001FFDC3CC048>]
# [<email.message.Message object at 0x000001FFDC3CC9E8>, <email.message.Message object at 0x000001FFDC3CC978>]
# [<email.message.Message object at 0x000001FFDC3CC0B8>, <email.message.Message object at 0x000001FFDC3CCCC0>]
# [<email.message.Message object at 0x000001FFDC3CC748>, <email.message.Message object at 0x000001FFDC3CC710>]
# [<email.message.Message object at 0x000001FFDC3CC828>, <email.message.Message object at 0x000001FFDC3CCAC8>]
# [<email.message.Message object at 0x000001FFDC3CCC88>, <email.message.Message object at 0x000001FFDC3CC470>]
# [<email.message.Message object at 0x000001FFDC3CC278>, <email.message.Message object at 0x000001FFDC3CC630>]
# [<email.message.Message object at 0x000001FFDC3CC5F8>, <email.message.Message object at 0x000001FFDC3CC7F0>]
# [<email.message.Message object at 0x000001FFDC3CC160>, <email.message.Message object at 0x000001FFDC3CC3C8>]
# [<email.message.Message object at 0x000001FFDC3CC390>, <email.message.Message object at 0x000001FFDC3CC4E0>]
# [<email.message.Message object at 0x000001FFDC3CC2B0>, <email.message.Message object at 0x000001FFDC3CC4A8>]
# [<email.message.Message object at 0x000001FFDC3CC128>, <email.message.Message object at 0x000001FFDC3CC080>]
# [<email.message.Message object at 0x000001FFDC3CC208>, <email.message.Message object at 0x000001FFDC3CC8D0>]
# [<email.message.Message object at 0x000001FFDC3CC400>, <email.message.Message object at 0x000001FFDC3CCA20>]
# [<email.message.Message object at 0x000001FFDC3CC898>, <email.message.Message object at 0x000001FFDC3CC358>]
# [<email.message.Message object at 0x000001FFDC3CC780>, <email.message.Message object at 0x000001FFDC3CC438>]
# Hi Bill,
#
# Thank you for checking in with me and my apologies for the late reply. I
# have very recently been admitted to my top choice graduate program in Data
# Science and will no longer be continuing with my application. Thank you for
# spending your time to answer the questions I had early in the application
# and staying in touch with me throughout the process thus far.
#
# Regards,
#
# David Liu
#
#
#
# Scincus - get rid of 3 and dot.
# - increase size if dots slightly
# - fix border and river gaps
#
# Keyserlingii - slightly darken the yellow region.
# - do not italicize the parenthesis parts in legend
# - fix border and river gaps
# - increase size of dots slightly
# - check whether the unknown region is correct
# - fix legend font
#
# [<email.message.Message object at 0x000001FFDC3CCDA0>, <email.message.Message object at 0x000001FFDC3CCF60>]
# Greetings,
#
# I was recently admitted to the MSDS program and my application checklist
# indicated that I must send in my official Bachelor's degree transcript. The
# transcript was mistakenly sent electronically to the USF Office of Graduate
# Admission located at 2130 Fulton Street, San Francisco. This was before I
# received a letter in my application status page instructing me to send any
# electronic transcripts to the asgraduate@usfca.edu email address. Can my
# official transcript be received at its current destination or should I
# request to send a copy to asgraduate@usfca.edu as well?
#
# Thanks,
# David Liu
#
# un: david92liu@gmail.com
# pw: Ilikebagel!1
#
# https://gradapply.usfca.edu/account/login?r=https%3a%2f%2fgradapply.usfca.edu%2fapply%2fstatus
#
# [<email.message.Message object at 0x000001FFDC3CCA58>, <email.message.Message object at 0x000001FFDC3CC320>]
# [<email.message.Message object at 0x000001FFDC3CC9B0>, <email.message.Message object at 0x000001FFDC3CCD68>]
# [<email.message.Message object at 0x000001FFDC3CC588>, <email.message.Message object at 0x000001FFDC3CCA90>]
# Hi Victoria,
#
# Thank you for checking in with me and my apologies for the late reply. I
# have very recently received admissions from a couple of my top choice
# universities and will no longer be continuing with my application. However,
# I want to thank you for striving to keep me in close communications
# throughout the application and providing me with the information I need to
# weigh my options and to make an informed decision. Not many of the colleges
# I applied to actively initiated conversions with applicants.
#
# Thanks again,
#
# David Liu
#
#
#
# Was expecting something like CodeAcademy, but it looks like there's a lot
# more useful resources here than just some practices. Thanks! Will look more
# into it.
#
#
# Hi Victoria,
#
# Thank you for letting me know about the webinar. Unfortunately, I will not
# be available at that time tomorrow. Will there be any followup webinars in
# the near future?
#
# Regards,
#
# David
#
#
# Hi Maggie,
#
# Thank you for checking in with my application status. I have very recently
# received admissions from a couple of my top choice universities and will no
# longer be continuing with my application.
#
# Regards,
#
# David
#
#
# Hi Leyla,
#
# I am interested in attending the webinar. You mentioned that this will be
# the first. What date will the other ones be held and will they be the same
# as this one? Thanks.
#
# David
#
#
# [<email.message.Message object at 0x000001FFDC3CCE48>, <email.message.Message object at 0x000001FFDC3CCBA8>]
# [<email.message.Message object at 0x000001FFDC3CCE80>, <email.message.Message object at 0x000001FFDC3CC908>]
# testing testing
#
# Good to know! Will hear from you tomorrow.
#
# David
#
#
# [<email.message.Message object at 0x000001FFDC3CCEF0>, <email.message.Message object at 0x000001FFDC3CCDD8>]
# Claremont Grad. Uni.
# <https://admissions.cgu.edu/account/login?r=https%3a%2f%2fadmissions.cgu.edu%2fapply%2fcertify>
#
# UN: david92liu@gmail.com
#
# PW: Ilikebagel!1
#
# Hey Bob,
#
# Got your message. Call me back and let me know if you still need my help on
# the map.
#
# David
#
#
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
#
# Once again, thank you for speaking with me and I am enthusiastic about the
# possibility of enrolling in the program.
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
#
#
# Best Regards,
#
#
#
# David Liu
#
# Dear Professor Stephen Devlin,
#
#
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although my primary programming language is Java, I realize from the
# interview and data science programs that Python is the preferred
# programming language and I am currently taking a course, Python for Data
# Science, to improve my understanding.
#
#
# Once again, thank you for speaking with me about the program and I am
# enthusiastic about the possibility of enrolling in the program.
#
#
# Best Regards,
#
#
#
# David Liu
#
# maybe i should also thank the admissions person who set up the interview as
# well in this email.. what do you think about including it.
#
#
# Dear Professor Stephen Devlin,
#
# Thank you for taking your time to interview me last Thursday and allowing
# me to have a better understanding of the USF Data Science Program's
# curriculum roadmap, as well as the advantages that the program offers its
# students in terms of employment and learning outcome.
#
# I would like to reiterate my interest in the program's fast-paced, rigorous
# academic environment and in the hands-on learning approach through
# practicum projects. I also believe that the program's focus in not only on
# the computational aspects of data science, but also in experimental design
# and statistics, would be uniquely fitting for someone of my background.
# Although I lack a fluent understanding in certain preferred skills, such as
# in Python, I am currently actively taking online courses in order to
# improve my understanding of the subject.
#
# Once again, thanks for speaking with me about the program and I look
# forward to hearing about the final admissions decision.
#
# Regards,
#
# David Liu
#
# http://www.academia.edu/20025172/Linear_Algebra_and_Its_Applications_5th_Edition_
#
# Greetings,
#
# On January 18, I received an invitation to schedule an online interview for
# my MS Data Science program application. I set up the interview to be on
# January 24 at 1 PM and received an email that confirmed my chosen date and
# time for an online meeting with Prof. Stephen Devlin. According to the
# confirmation email, I am suppose to receive a followup email invitation
# with a calendar invite to join the meeting on Zoom on my scheduled date. I
# would like to know the status of the email as I have not yet received it.
# Thanks.
#
# Regards,
#
# David Liu
#
# Hi Patrick,
#
# I am still interested in applying for the MS Business Analytics program at
# GGU, although it might take some time to get all my materials together.
# Just to clarify, the priority deadline for applying to the fall semester is
# in August correct?
#
# Regards,
# David
#
# On Wed, Jan 16, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote=
# :
#
# >
# >
# >
# >
# > Hi David ,
# >
# >
# > We at Golden Gate University would like to remind you that we are
# > dedicated to your educational success and here to support you with many
# > options for accomplishing your academic goals.  As your Enrollment
# > Counselor, I am committed to helping you learn more about GGU and determi=
# ne
# > if our programs are a good fit for you and your goals.
# >
# >
# >
# > *Please help me understand your current educational plans by replying to
# > this email with the following scenario that best represents your
# > situation: *
# >
# > 1.    I plan to apply for the next available semester
# >
# > 2.    I am interested, but not until a later start term
# >
# > 3.    I have postponed my search at this time
# >
# > 4.    I intend to enroll at another university
# >
# > If I don't hear back from you, I will assume you are still interested in
# > Golden Gate University but not at this time. We may send you emails from
# > time to time to check in. Please get back to me when you can. I look
# > forward to working with you!
# >
# >
# >
# > Sincerely,
# >
# > Patrick Gonzales
# >
# > Golden Gate University
# >
# > 415-442-7800 GGU Hub
# >
# > GGUAdmissions@ggu.edu
# >
# > www.ggu.edu
# >
# > www.ggu.edu=E2=80=9D>GGU.edu
# >
# >
# > *WARNING: *This E-mail, and any attachments, are covered by the
# > Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=
# ail may
# > contain confidential and legally privileged information. The contents of
# > this e-mail, and any attachments, are intended solely for the use of the
# > person or entity to whom the e-mail was addressed. This email may also
# > contain information that may be protected by the attorney-client privileg=
# e,
# > work-product doctrine, or other privileges, and may be restricted from
# > disclosure by applicable Federal and State laws. If you are not the
# > intended recipient of this email *you are advised that any dissemination,
# > distribution, or use of the contents of this message is strictly prohibit=
# ed*.
# > If you received this e-mail message in error, please contact the sender b=
# y
# > reply e-mail or phone. Please also permanently delete all copies of the
# > original e-mail and any attachments.
# >
# >
#
# Dear CSUEB Graduate Admissions Office,
#
# I am applying for the MS Business Analytics program for the fall 2019
# semester, and the application asks that I send official transcripts from
# all colleges and universities attended to the CSUEB Office of Admissions.
# Does CSU East Bay accept E-transcripts, and if so, is there a specific
# email address that I can send my official transcripts to? If not, I would
# like to confirm whether the address listed as "Office of Admission, Cal
# State East Bay, 25800 Carlos Bee Blvd., Hayward, CA, 94542" is the correct
# address to send my transcript. Thanks.
#
# Regards,
# David Liu
#
# Dear Dr. Jiming Wu,
#
# In regards to the Business Analytics program's requirements, does the
# program require official standardized test scores from applicants? I can
# see that the application requires manually entering test scores but it does
# not mention needing any official copies from the testing agencies, so I
# would like to get that clarified. Thanks.
#
# Regards,
# David Liu
#
# Dear CGU Admissions Office,
#
# I am applying for the MS in Information Systems & Technology - Data Science
# & Analytics program for the fall 2019 semester, and the program asks for
# official transcripts to be sent. Does CGU accept E-transcripts, and if so,
# is there a specific email address that I can send my official transcripts
# to? If not, I would like to confirm whether the address listed as "CGU
# Office of Admissions, 150 E. 10th Street, Claremont, CA, 91711" is the
# correct address to send my official transcript to. Also, does CGU allow an
# applicant to submit transcripts and standardized test scores before
# submitting the application? Thanks.
#
# Regards,
# David Liu
#
# Definitely, it has been a while. It is great to see all the data show up on
# the map and to know that there is still development on the project in
# recent years. Hope it continues to grow, and maybe even have the pneumatic
# tubes that were discussed about back then to be installed on streets.
#
# Regards,
# David
#
#
# [<email.message.Message object at 0x000001FFDC3EDEB8>, <email.message.Message object at 0x000001FFDC3ED7B8>]
# Hi Jason,
#
# I would like to add that the date I listed on one of my applications is
# inconsistent with the one on the attachment. In my application to the
# University of Southern California (USC), I listed it as June to September
# as oppose to July to September. If this school happens to contact you and
# they mention June - September, let them know that I acknowledge the
# inconsistency and you can correct them. The application does not seem to
# provide any followup methods to edit experiences after submission. Thanks.
#
# Regards,
# David
#
#
# [<email.message.Message object at 0x000001FFDBDC2CF8>, <email.message.Message object at 0x000001FFDBDC2DA0>]
# [<email.message.Message object at 0x000001FFDBDC2F98>, <email.message.Message object at 0x000001FFDC3EDF98>]
# Hi Jason,
#
# Thank you so much for getting back to me and for making yourself available
# as a contact. Below is a brief summary of what I can recall.
#
# I was a volunteer intern for approximately two months to help build a
# traffic count database for an interactive count map project. I believe I
# started on the day listed on the application, which is 7/30/2012, and
# worked until 9/28/2012 for about 10-15 hours a week. I looked through years
# and months of traffic documents and surveys, each of which contains
# pedestrian, bicycle, and vehicle counts of a specific street intersection
# in Oakland, and I added those information onto an excel spreadsheet.
#
# Let me know if there are any more information that you might need that can
# help you in any way. Again, thank you so much for making yourself available
# for my application.
#
# Kind regards,
#
# David
#
#
#
# Hello Jason,
#
# It has been a while since we last touched base back in 2014. I hope you are
# doing well and I hope this email reaches you.
#
# I am contacting you again today because I recently started applying for
# master programs in data science. There are areas in some of my applications
# in which they asks whether the supervisors in each of my past listed
# positions can be contacted. I am letting you know that I listed my
# experience at the Bicycle and Pedestrian Program on the application, so let
# me know whether or not you are okay with me listing you as contactable. I
# believe that it is just for letting the admissions office confirm my past
# experiences. Thanks!
#
# Regards,
#
# David Liu
#
#
# Hi Patina,
#
# It has been a while since we last spoke back when I was still at Resh Lab
# doing the URAP program with you from 2013 to 2014 and also when you
# introduced me to work with your colleague, Erin, on the nematology project.
# I hope you are doing well! I hope this email reaches you.
#
# I am contacting you today because I recently started applying for master
# programs in data science. There are areas in some of my applications in
# which they asks whether the supervisors in each of my past listed positions
# can be contacted. I am letting you know that I listed my URAP experience on
# the application, so let me know whether or not you are okay with me listing
# you as contactable. I believe that it is just for letting the admissions
# office confirm my past experiences. Thanks!
#
# Regards,
#
# David Liu
#
# Hi Patrick,
#
# I would be happy to learn more about Golden Gate University and plan my
# next steps. I will be available right after 12 PM on Friday or Monday.
# Otherwise, if you are available on the weekend, anytime on Saturday or
# after 2 PM on Sunday will work for me. You can contact me at (510)
# 219-5580.
#
# Regards,
# David Liu
#
# On Wed, Jan 9, 2019 at 10:09 AM Patrick Gonzales <pgonzales@ggu.edu> wrote:
#
# >
# >
# >
# > Hi David ,
# >
# >
# > We hope you are looking forward to accomplishing your educational goals
# > with us at Golden Gate University. As your enrollment counselor, I am
# > dedicated to helping you get started on your degree with us!
# >
# >
# >
# > Please let me know when you are available to chat for 5 minutes so we can
# > plan your next steps. Kindly call to get started today.
# >
# >
# >
# > I look forward to speaking with you!
# >
# >
# > Best,
# >
# > Patrick Gonzales
# >
# > Golden Gate University
# >
# > 415-442-7800 GGU Hub
# >
# > GGUAdmissions@ggu.edu
# >
# > www.ggu.edu
# >
# >
# >
# >
# >
# >
# >
# >
# >
# > *WARNING: *This E-mail, and any attachments, are covered by the
# > Electronic Communications Privacy Act, 18 U.S.C. =C2=A72510-2521. This em=
# ail may
# > contain confidential and legally privileged information. The contents of
# > this e-mail, and any attachments, are intended solely for the use of the
# > person or entity to whom the e-mail was addressed. This email may also
# > contain information that may be protected by the attorney-client privileg=
# e,
# > work-product doctrine, or other privileges, and may be restricted from
# > disclosure by applicable Federal and State laws. If you are not the
# > intended recipient of this email *you are advised that any dissemination,
# > distribution, or use of the contents of this message is strictly prohibit=
# ed*.
# > If you received this e-mail message in error, please contact the sender b=
# y
# > reply e-mail or phone. Please also permanently delete all copies of the
# > original e-mail and any attachments.
# >
# >
#
# Dear Admissions Office,
#
# I am just in need of a clarification in regards to reporting my test scores
# for the MS in Data Science application at USF. After entering my GRE scores
# in the "Test Scores" tab in the application and sending in my GRE scores to
# USF from my testing agency, the application also asks for a test upload. I
# believe that on a previous email, I was told to upload an official student
# copy of my test scores. Am I correct to assume that I can simply submit a
# printout of my reported scores from my testing agency website, or are there
# other official methods required?
#
# David Liu
#
# Got you down as contactable. Thanks Erin!
#
# David
#
#
# [<email.message.Message object at 0x000001FFDC3C2D30>, <email.message.Message object at 0x000001FFDC3C2DD8>]
# Hi Erin,
#
# It has been a while since we last spoke back when I was still at the USDA
# facility in Albany with you and the others. I hope you are doing well! I am
# not certain whether you still communicate with this email address, so I
# hope this email reaches you.
#
# I am contacting you today because I recently started applying for masters
# programs in data science. There are areas in some of my applications in
# which they asks whether the supervisors in each of my past listed positions
# can be contacted. I am letting you know that I listed my temporary position
# at Albany as one of my previous experiences, so let me know whether or not
# you are okay with me listing you as contactable. Thanks.
#
# Regards,
#
# David Liu
#
# USF
# https://gradapply.usfca.edu/account/login
# UN: david92liu@gmail.com PW: Ilikebagel!1
#
# USC
# https://usc.liaisoncas.com/applicant-ux/#/login
# UN: dkwliu PW: Ilikebagel!1
#
# Well I keep forgetting. We can't submit anything because the scores haven't
# come in yet. But at the very least, check to see if everything else is in
# order first so that when the score comes in, I can immediately submit it.
#
# Hi Bill,
#
# I would be happy to learn more about the UC Berkeley MIDS program. I will
# be available right after 12 PM on Friday or Monday. Otherwise, if you are
# available on the weekend, anytime on Saturday or after 2 PM on Sunday will
# work for me as well. You can contact me at (510) 219-5580.
#
# Regards,
#
# David Liu
#
#
# [<email.message.Message object at 0x000001FFDC3C2B38>, <email.message.Message object at 0x000001FFDC3C2B00>]
# [<email.message.Message object at 0x000001FFDC3C27B8>, <email.message.Message object at 0x000001FFDC3C2C18>]
# [<email.message.Message object at 0x000001FFDBDC2B38>, <email.message.Message object at 0x000001FFDC3C2390>]
# He has taken various classes in computational sciences from 2015-2018 that
# covers multiple programming languages, and throughout he has consistently
# earned high marks
#
#
# [<email.message.Message object at 0x000001FFDC3C2048>, <email.message.Message object at 0x000001FFDC3C2F98>]
# David has academic experience creating applications with Java, JavaScript,
# C++, and C#. He also has a keen interest in learning PERL scripting for
# manipulating genomic data.
#
# David has academic experience creating applications with Java, JavaScript,
# C++, and C#.
#
# Hi Bob,
#
# Hope you had a great holiday! I am contacting you again about a number of
# other graduate programs that I am applying for and I just want to check
# whether you have time to send out a few more letters. Some program
# deadlines are coming up but I am definitely not in an immediate rush this
# weekend, so just let me know whenever, or if, you will be free. Thanks!
#
# David
#
# [<email.message.Message object at 0x000001FFDC3C2940>, <email.message.Message object at 0x000001FFDC3C2240>]
# Yuri,
#
# That is perfect! Thank you very much.
#
# David
#
#
#
# Greetings. I am currently attending Isaac's GRE quant session at San
# Francisco which started on 12/06 and will end on 1/10. I do not think that
# I will be able to attend class 4 (1/03) and 5 (1/10) for his session, so if
# possible, I would like to make up for those two classes at the Santa Clara
# quant session instead, which will be held on 12/11 and 12/18. Please let me
# know whether those class dates are available for make-up. If requesting for
# two make-up dates is not possible, then I am fine with just one, but I
# would prefer it to be for the fifth class on 12/18. Thanks.
#
# Regards,
#
# David Liu
#
# [<email.message.Message object at 0x000001FFDC3C2208>, <email.message.Message object at 0x000001FFDC3C2438>]
# [<email.message.Message object at 0x000001FFDC3C2F28>, <email.message.Message object at 0x000001FFDC3C2198>]
# Thanks for the responses. Yes, I took one introductory statistics and a few
# programming courses, so I believe that the financial accounting course
# should be my only prerequisite left.
#
# Also, am I correct to assume that as long as I apply by any of the first
# two application rounds that I will make it for priority consideration, or
# are there advantages to applying by either of the two dates? Thanks again.
#
# David
#
#
#
# Dear SF State Admissions,
#
# I have questions regarding the deadline for the MS Business Analytics
# program at SF state. The College of Business website linked here at
# https://cob.sfsu.edu/admissions says that there are three application
# deadlines for fall 2019. What are the differences between the three, and is
# there a priority consideration deadline? Furthermore, the application on
# Cal State Apply says that the deadline is 7/1/2019, so I am slightly
# confused as to which is the correct date.
#
# Secondly, I am planning on taking a financial accounting course to satisfy
# the MSBA program prerequisite, and I see that the MSBA website lists a few
# specific college accounting courses that I can take. Is it okay to take the
# financial accounting course elsewhere, and if so, what are the requirements
# for the course to be eligible? For instance, would the Business 1A course
# listed here http://www.berkeleycitycollege.edu/wp/business/business-courses/ be
# fine to take? Also, if the course is still ongoing after the application
# deadline, may I still list it on my application? Thank you for your time
# and thanks in advance.
#
# Regards,
#
# David Liu
#
# [<email.message.Message object at 0x000001FFDC3C2E48>, <email.message.Message object at 0x000001FFDC3C2358>]
# Jennifer,
#
# Thank you for the estimates! I wanted to make a slight change with the work
# scope on my most recent request for an estimate. Would it be possible to
# make a quick re-estimate by changing the work scope to exclude the back
# side of the building? Our plans has changed such that we only need
# scaffolds on the front, left, and right sides of the building. Thank you.
#
# David
#
#
# [<email.message.Message object at 0x000001FFDC3C2A20>, <email.message.Message object at 0x000001FFDC3C2550>]
# Hello,
#
# Would it be possible if I get a reestimate for the project if we exclude
# scaffolding on the back side of the building, and only include the front
# and and the two adjacent sides? Also, would you happen to know how long the
# entire scaffolding erecting process would take? Thanks.
#
# David Liu
#
#
# [<email.message.Message object at 0x000001FFDC3C2400>, <email.message.Message object at 0x000001FFDC3C28D0>]
# Dear Admissions Office,
#
# I have a few questions regarding uploading test scores for the MS in Data
# Science application.
#
# First, If I take a GRE test before submitting my application by December 5,
# but I know that my test scores will not arrive until after December 5, how
# can I make note of that on my application? I notice that the application
# only asks that I report a future test date if I do not have scores to
# report yet. Hence, my concern is that if I indicate a test date before my
# application submission date with no scores filled out on my application
# form, would my application be considered incomplete by the admissions
# office?
#
# Secondly, how do I send in test scores after the application is reviewed
# and submitted by me? I have not submitted my application yet, so I do not
# know how the process of uploading documents after submitting the
# application works. Will my application still be open for me to edit even
# after submission?
#
# Lastly, if my application is submitted by the December 5 priority deadline,
# but my test scores are uploaded and sent to USF afterwards, will the
# benefits of applying by the priority deadline, such as the priority
# scholarship consideration, still apply?
#
# Thank you for your time, and please let me know whether there is a more
# specific contact that I should direct my graduate application questions to.
#
# Regards,
#
# David Liu
#
# Greetings Shan,
#
# Good afternoon! I am contacting you again in regards to my previous message
# via text a week ago in which I asked whether you are willing to provide me
# with a letter of recommendation for my graduate school application. I never
# received a response, so I am not sure whether you got my text message or
# whether you still use that phone. In any case, I hope this message reaches
# you.
#
# Again, let me know whether you are willing to provide me with a letter of
# recommendation or whether you are just available as a reference. Either
# would be helpful for my applications. Looking forward to hearing from you.
#
# Have a good day,
#
# David Liu
#
# https://abc7news.com/politics/elections/local/california/alameda/
#
# Alright. I will take a look through it and see what I can change with your
# suggestions. Thanks again.
#
#
# Great! Thanks again Bob. I truly appreciate it!
#
# David
#
#
# ...
#
# Just got a notice of your email. Thank you for your interest in our post on
# craigslist! Yes, the house is still available for rent. Unfortunately, I am
# out of town at the moment and my schedule for the coming days is a bit
# uncertain. I will try to contact you once I am sure about my time schedule
# and then we can set up a time for a house tour. Would that be fine with you?
#
# Guang Da Liu
#
#
# -Ebony Hodge
#
# Just got a notice of your email. My apologies for the late reply. I am
# sorry, we are currently not accepting section 8.
#
#
# [<email.message.Message object at 0x000001FFDC3C2160>, <email.message.Message object at 0x000001FFDC3C2978>]
# Thanks for the feedback! I=E2=80=99ll take some time to look through them a=
# nd see
# if there=E2=80=99s anything I can add. May have some questions later.
#
#
# [<email.message.Message object at 0x000001FFDC3C2278>, <email.message.Message object at 0x000001FFDC3C22E8>]
# Everyone here gave me the OK. File submitted.
#
#
# Awesome. Now waiting on Carlos. I did make changes to his parts afterall.
# Hopefully he's alright with it.
#
#
# Holdup guys. In case if anyone is thinking about turning in the final paper
# attached in this email thread, don't turn it in yet. I am just about done
# making sure that everything is as easy to understand as possible. I'll be
# attaching the version from google docs on here shortly.
#
#
# Hey Sam,
#
# Sure thing. I'll put it in. And I'll post the final version here in a bit.
#
#
# Hey Carlos,
#
# Don't worry about. The one currently on google doc is more ironed out and
# Sam still need to put in his part, so we still got some time. It's due on
# Friday at 5 PM so we'll just wait till a few hours before then. Also, we
# need the survey participants' info and the one on googledocs has it.
#
#
# Hey Carlos,
#
# We are definitely modifying and adding more to the paper. In fact, I'm
# working on it right now on googledrive and I believe there's been a few
# changes since you put together your attached version. Feel free to add or
# edit some of your parts as well.
#
# David
#
#
# Hi Shawn,
#
# Because I did not do my last solution, I would like to do 6.6.38 on Monday
# or Wednesday instead. Let me know whether it is still available. My second
# and third choice would be 7.1.11 or 7.1.44 to be done on Wednesday,
# assuming that you will finish 7.1 on Monday.
#
# David Liu
#
# [<email.message.Message object at 0x000001FFDC3C2A90>, <email.message.Message object at 0x000001FFDC3C2780>]
# [<email.message.Message object at 0x000001FFDC3C2B70>, <email.message.Message object at 0x000001FFDC3C21D0>]
# [<email.message.Message object at 0x000001FFDBDC2A90>, <email.message.Message object at 0x000001FFDBDC2D68>]
# Hi Shawn,
#
# I would like to do 6.4.31 for my solution share next Wednesday. Let me know
# whether it's still available.
#
# ---------------------------------------------------------
#
# Also, the following are the questions that my team will be using for the
# extra credit survey. The subject will be on "Opinions about Protest".
#
# 1) Do you have a positive or negative perception about the way you think
# protests are conducted nowadays, and why?
#
# 2a) (*If survey taker has a negative perception) *Do you know who is Colin
# Kaepernick? (Describe to survey taker if not). Does this form of protest
# fit in your negative perception?
#
# 2b) *(If survey taker has a positive perception) *Do you know about the
# recent Berkeley protests? (Describe to survey taker if not). Does this form
# of protest fit in your positive perception?
#
# 3) As far as you know, what do you think needs to be changed about how
# protests are conducted nowadays?
#
# Let me hear your objections.
#
#
# Thanks,
# David Liu
#
# Hi Shan,
#
# As I had mentioned a couple months prior, as a part of my plan to make time
# to pursue my educational and career goals, I need to make revisions to my
# weekly working schedule. So from this point forth, I will be available to
# work each week on-call on the following days: Tuesday, Thursday, Friday,
# and conditionally on Saturday.
#
# Regards,
#
# David Liu
#
# Looks like everything=E2=80=99s covered. I will also be free if I=E2=80=99m n=
# eeded for any reason.=20
#
# David
#
# Sent from my iPhone
#
# >
# keyboard and mouse
#
# https://www.amazon.com/dp/B00NLZUM36/?tag=pcpapi-20
#
# motherboard
# https://www.newegg.com/Product/Product.aspx?Item=N82E16813130935&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=
#
#
# RAM
# https://www.newegg.com/Product/Product.aspx?Item=N82E16820232419&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=
#
# Submitted.
#
#
# Hey Ratthanan,
#
# The writeup looks good! I will go ahead and send it in in maybe about half
# an hour. But until then, let me know if you still want anything changed.
#
# David
#
#
# Hey Ratthanan,
#
# Just shared a doc with you. You can ignore this email if you got it. If
# not, let me know.
#
# David
#
# Woops. Didn't check my email yesterday. Also got home a bit late. Let me kno=
# w if you still need me, in which case I'll just call you later today.
#
# Sent from my iPhone
#
# >
# Hey Jihyun,
#
# Finally got to write up a response. Go ahead and look it over and see if
# you'd like to add anymore comments for your part, and I'll probably do the
# same. Otherwise, I think we got a pretty good piece for submission.
#
# David
#
# Hey Bob,
#
# Just a bit of clarification for the last 6 emails I sent you in the last 20
# minutes or so.
#
# The emails that says "PDF versions" and "TIF versions" on the subject line
# are probably the ones you want to look at.
#
# The ones that says "Word versions" are the original files in which I used
# to create the PDFs and TIFs. You may look at those only if you're planning
# on making some adjustments or corrections.
#
# cheers,
#
# David
#
# [<email.message.Message object at 0x000001FFDC3CCF28>, <email.message.Message object at 0x000001FFDC3ED6A0>]
# [<email.message.Message object at 0x000001FFDC3ED2E8>, <email.message.Message object at 0x000001FFDC3EDEF0>]
# [<email.message.Message object at 0x000001FFDC3ED358>, <email.message.Message object at 0x000001FFDC3ED0F0>]
# [<email.message.Message object at 0x000001FFDC3ED828>, <email.message.Message object at 0x000001FFDC3EDE48>]
# [<email.message.Message object at 0x000001FFDC3ED780>, <email.message.Message object at 0x000001FFDC3ED048>]
# [<email.message.Message object at 0x000001FFDC3ED128>, <email.message.Message object at 0x000001FFDC3ED908>]
# [<email.message.Message object at 0x000001FFDC3ED278>, <email.message.Message object at 0x000001FFDC3ED9B0>]
# Also, let me know whether you agree that this article is considered a math
# article.
#
#
# Hey Alex,
#
# Lets get the ball rolling. I've decided to go with a question involving
# "news story with (interesting, confusing, problematic) use of math". If you
# have another question in mind, feel free to share it. We can later decide
# which question would be the easiest to work off of. Otherwise, feel free to
# reply to my email with your response to my prompt.
#
#
# Initiator: David Liu
# Responder: Alex Alba
# Date: 9/6/2017
# Topic: News story with (interesting, confusing, problematic) use of math:
# plastic-contaminated water
# Source: Magness, Josh. Billions are drinking water contaminated with
# plastic - and US has it the worst, study finds. September 6, 2017
# http://www.sacbee.com/latest-news/article171475582.html
#
# So I found this article about plastic contamination in the world's water
# supply. In the study in which the article is based on, 159 tap water
# samples in total were tested from five different continents. The overall
# result is that 83% of the samples were contaminated with plastic. The water
# with the lowest contamination rate was collected from Europe, which had a
# 72% contamination, whereas the United States had the highest contamination
# at 94%. I did not read the original manuscript, but, without knowing the
# methods used in the experiment, I would take the results from this study
# with a grain of salt. The overall contamination rate is way too high to be
# believable and to have not done something to us already.
#
# Hi Bob,
#
# All is well. So I will refer to this doc instead of the old one then. I
# will look through it as soon as I can.
#
# Thanks,
#
# David
#
#
# Hey bob,
#
# Great to hear from you. Can't help at the moment. Will be home at probably a=
# round 6-7. Will call you. Otherwise you can call me if you still need help w=
# ith the scans.
#
# David=20
#
# Sent from my iPhone
#
# >
# Almost forgot. Checking in to let you know the assignment was submitted.
#
#
# Also. Let me know if/when you decide to submit it.
#
#
# Hey Sam,
#
# Lets put the connection document together. I was thinking that you can put
# all the parts you want to include in a word doc first since you initiated
# the question on Monday. Then you can send the word doc to me and I'll add
# my parts to it.
#
# Content-wise, I think the short exchange we had over emails on Monday would
# do just fine as our connection. At least I know I'll just be copy-pasting
# my part onto the connection doc. You may change and correct your's to your
# liking.
#
# David
#
#
# I see. I'm going to assume that our textbook is probably more theory-based
# compared to those.. which is still good in its own ways. Thanks for letting
# me know. I'll look into them.
#
#
# Haha. I think you just initiated #5, although I guess it fits into #2 as
# well, so here are my thoughts in response to your initial question.
#
# I don't think it really matters exactly what book we use as long as it does
# the job in helping us learn. I personally like to have a decent variety of
# textbooks to work off of in case if one just doesn't cut it. In this case,
# I would just use our textbook for this class mainly for doing the
# exercises, and probably another textbook to explain the materials if our's
# doesn't do it well enough (By the way, let me know of these other textbooks
# you're referring to). So more unconventional books I have knowledge of, the
# better I suppose. Even so, to be absolutely fair, our current textbook
# isn't completely out-of-the-way. As I was researching for some pdfs and
# partial texts of our current textbook, there were definitely a few online
# forums and threads that recommended using this textbook to get started on
# learning linear algebra. So definitely not a bad book.
#
#
# Hey Sam,
#
# Lets get the ball rolling on the assignment. For our connection options, I
# think we can eliminate #6 and 7 since I doubt either of us would want to go
# through the trouble of interviewing community members or attending special
# community events. Some of them, like #1, is a bit open ended. So I was
# thinking of maybe choosing between #2, #3, or #5. Let me know what you
# think and/or disagree with any of these ideas.
#
# David
#
# Hi Casey,
#
# First Name/Last Name: David Liu
#
# Zip Code: 94546
#
# Below is a direct copy of the subscription confirmation. Thank you for your
# help!
# ___________________________________________________________________________=
# _____________
#
# [image: Apple] Subscription Confirmation
# [image: HBO NOW=E2=84=A0]
# HBO NOW=E2=84=A0
# HBO NOW=E2=84=A0 (1 month)
# Free Trial
# Dear Audrey,
# You=E2=80=99ve purchased the following subscription with a 1 month free tri=
# al:
# *Subscription* HBO NOW=E2=84=A0
# *App* HBO NOW: Stream original series, hit movies & more
# *Content Provider* HBO Digital Services, Inc.
# *Date of Purchase* Aug 11, 2017
# *Duration* 1 month
# *Trial Duration* 1 month
# *Price* $14.99
# *Payment Method* Visa .... 8668
# You won=E2=80=99t be charged for your free trial.
# [<email.message.Message object at 0x000001FFDC3ED2B0>, <email.message.Message object at 0x000001FFDC3ED208>]
# Hey Bob,
#
# It's been a while. Great to hear from you. Very sorry for missing your
# call. I was busy working with a couple others when you called and we've
# only finished just now.
#
# Heard You mentioned something about helping out a student. I tried calling
# you a couple times but you didn't pick up. Give me a call if you still need
# me.
#
# David
#
# Hey Ben,
#
# Not sure if Alvin notified you yet, but I told him that I am willing to
# switch my Sunday in July with his, and I believe he is fine with the
# switch. So unless he said otherwise, would it be fine if I switch my date
# (7/2) with his (7/23).
#
# David
#
# -Alvin
#
# That would be 7/2, the first Sunday in July.
#
#
# Hi Alvin,
#
# I can switch with you if you're still looking for a replacement.
#
# David
#
#
# Hi Genevieve,
#
# My apologies for the late reply. Thank you very much for your time and for
# letting me know about this opportunity. Unfortunately, I am currently not
# available for a position with a weekend time schedule. However, I may be in
# the near future or for any other opportunities for that matter. I would
# love to keep in touch and to hear or ask about any future openings at
# Counsyl if that is fine with you.
#
# Thanks,
#
# David
#
#
# Medical Records
# Alta Bates Campus 510-204-1440
# Summit Campus 510-869-6545
#
# Hey bob,
#
# Tried to return your call just now. Not sure if you got it. Currently not
# at home right now, but call or email me if you need me.
#
# David
#
# Hey Bob. Looks like I missed your message last night. Hope you got what you
# needed, or let me know if you still need to have some searching done.
#
# David
#
#
# [<email.message.Message object at 0x000001FFDC3ED198>, <email.message.Message object at 0x000001FFDC3ED6D8>]
# [<email.message.Message object at 0x000001FFDC3EDBA8>, <email.message.Message object at 0x000001FFDC3EDA20>]
# [<email.message.Message object at 0x000001FFDC3EDF60>, <email.message.Message object at 0x000001FFDC3ED668>]
# [<email.message.Message object at 0x000001FFDC3ED400>, <email.message.Message object at 0x000001FFDC3EDD30>]
# [<email.message.Message object at 0x000001FFDC3ED9E8>, <email.message.Message object at 0x000001FFDC3EDAC8>]
# Quite a contrast between the two news. Truly sorry to hear about the first
# one. I know there isn't much I can help with the things you mentioned, but
# please let me know if there is anything you want to talk about.
#
# David
#
#
# Hey bob,
#
# Seems like I missed a few of your calls recently. I was out most of
# yesterday and will be out for most of today as well. Let me know the news
# via email if you can. Or I might be free later tonight.
#
# David
#
# [<email.message.Message object at 0x000001FFDC3EDA58>, <email.message.Message object at 0x000001FFDC3ED978>]
# Hey Bob,
#
# Missed your call earlier so I thought I'd return it. Nobody picked up.
#
# In any case, got your call from a few days back. Just letting you know that
# I've enrolled in Biosci34.
#
# David
#
# Hi Levar,
#
# I got your call on Monday regarding possible new openings and my current
# employment status. I could not get a chance to call you, so I figured that
# I will just email you instead. Sorry for the late response.
#
# Firstly, thank you for checking back up on me about my current job
# situation! I am still currently working full time at the same company from
# about a year ago and I probably won't be searching for any new employment
# opportunities at least for the next few months. I will surely contact you
# again once I get back into job searching.
#
# You mentioned something about referrals. Do you mean referrals for anybody
# I know who would be interested in job opportunities? If yes, I don't
# currently know many who are looking for laboratory positions, unless maybe
# you have other listings. However, I can still check around. Otherwise, let
# me know what you mean by that.
#
# Regards,
#
# David Liu
#
# Tel: 510-219-5580 <(510)%20219-5580>
#
# [<email.message.Message object at 0x000001FFDC3EDD68>, <email.message.Message object at 0x000001FFDC3EDDD8>]
# https://www.rootsforreal.com/
#
# www.forensicmag.com/article/2013/04/challenges-dna-testing-and-forensic-analysis-hair-samples
#
# http://www.legalgenealogist.com/2012/06/03/dna-and-the-locks-of-hair/
#
# https://www.fullgenomes.com/
#
# http://www.calacademy.org:8080/sites/default/files/assets/docs/pdf/occ_pap_161_2013_swa_bib_2nd_ed_web_version.pdf
#
# [<email.message.Message object at 0x000001FFDC3ED5F8>, <email.message.Message object at 0x000001FFDC3ED5C0>]
# [<email.message.Message object at 0x000001FFDC3ED630>, <email.message.Message object at 0x000001FFDC3ED0B8>]
# [<email.message.Message object at 0x000001FFDC3ED3C8>, <email.message.Message object at 0x000001FFDC3ED4E0>]

# %%
for each in extracted_emails:
    try:
        print(each.split())
    except:
        print("Could not be split")
# Out:
# ['this', 'is', 'a', 'response']
# ['Hi', 'David,', 'This', 'is', 'a', 'sample', 'email.']
# ['https://www.walmart.com/ip/Apple-iPad-mini-Wi-Fi-64GB/207104625', 'https://www.bestbuy.com/site/apple-10-2-inch-ipad-latest-model-with-wi-fi-3=', '2gb-space-gray/5199701.p?skuId=3D5199701', 'https://www.adorama.com/acmyla2lla.html?gclid=3DCj0KCQiAzZL-BRDnARIsAPCJs73=', 'IvW8I6hSvm04SkA0uSh1H4tsa0sjbo7Q-uuhvrndPUyO2jg-Md6QaAt_5EALw_wcB&utm_sourc=', 'e=3Dadl-gbase', 'Older', 'Model:', 'https://www.walmart.com/ip/Apple-iPad-4-with-Retina-Display-32GB-Wi-Fi-4th-=', 'Generation-in-Black/22288800?wmlspartner=3Dwlpa&selectedSellerId=3D9186&&ad=', 'id=3D22222222227016434816&wl0=3D&wl1=3Dg&wl2=3Dc&wl3=3D343334214440&wl4=3Dp=', 'la-486397163036&wl5=3D9032013&wl6=3D&wl7=3D&wl8=3D&wl9=3Dpla&wl10=3D1170193=', '45&wl11=3Donline&wl12=3D22288800&veh=3Dsem&gclid=3DCj0KCQiAzZL-BRDnARIsAPCJ=', 's71ZBDQi_Vj6RvtNPGp55mVHFKiQ3f0UXexwDyKS6BIc_-X3kOA0wusaAmQ5EALw_wcB']
# ['Hi', 'Han,', 'This', 'is', 'just', 'a', 'quick', 'follow-up', 'from', 'yesterday.', 'I', 'would', 'like', 'to', 'thank', 'you', 'for', 'spending', 'an', 'extended', 'period', 'of', 'time', 'interviewing', 'me,', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'what', 'the', 'contract', 'position', 'entails.', 'I', 'am', 'excited', 'for', 'the', 'possibility', 'of', 'working', 'with', 'the', 'health', 'strategic', 'initiative', 'team', 'to', 'build', 'data', 'pipelines', 'and', 'machine', 'learning', 'functions', 'for', 'health', 'and', 'wellness', 'applications.', 'Looking', 'forward', 'to', 'hearing', 'back', 'about', 'any', 'updates', 'on', 'the', 'position.', 'Best', 'Regards,', 'David']
# ['Greetings', 'Han,', 'I', 'am', 'guaranteed', 'to', 'be', 'free', 'on', 'Friday', '10/9', 'at', '4', 'PM.', 'I', 'look', 'forward', 'to', 'speaking', 'with', 'you', 'soon!', 'Thanks,', 'David']
# ['Hi', 'Andy,', 'That', 'is', 'great!', 'I', 'look', 'forward', 'to', 'speaking', 'with', 'your', 'lead.', 'Should', 'I', 'be', 'expecting', 'an', 'email', 'some', 'time', 'later', 'today?', 'Thanks,', 'David']
# ['Hi', 'Andy,', 'This', 'is', 'just', 'a', 'follow', 'up', 'on', 'our', 'previous', 'conversation', 'regarding', 'the', 'contract', 'positions.', 'Since', 'the', 'positions', 'are', 'still', 'in', 'the', 'works,', 'would', 'it', 'be', 'necessary', 'for', 'me', 'to', 'check', 'in', 'again', 'at', 'a', 'later', 'date', 'if', 'I', 'am', 'still', 'interested?', 'And', 'if', 'so,', 'when', 'do', 'you', 'think', 'would', 'be', 'a', 'good', 'time', 'for', 'me', 'to', 'do', 'so?', 'I', 'ask', 'because', 'it', 'was', 'unclear', 'to', 'me', 'during', 'our', 'previous', 'correspondence', 'whether', 'we', 'were', 'planning', 'to', 'further', 'discuss', 'the', 'topic,', 'or', 'whether', 'I', 'should', 'check', 'in', 'later.', 'If', 'there', "isn't", 'much', 'information', 'on', 'the', 'planned', 'contract', 'positions', 'at', 'the', 'moment,', 'that', 'is', 'fine', 'too.', 'In', 'any', 'case,', 'thank', 'you', 'so', 'much', 'for', 'your', 'time', 'and', 'patience', 'regarding', 'my', 'inquiries', 'about', 'these', 'opportunities,', 'thus', 'far.', 'Regards,', 'David']
# ['Hi', 'Andy,', 'I', 'completely', 'understand.', 'The', 'contractor', 'position', 'sounds', 'great', 'and', 'I', 'am', 'certainly', 'open', 'to', 'further', 'discuss', 'this', 'opportunity.', 'What', 'would', 'be', 'the', 'next', 'step?', 'Regards,', 'David']
# ['Hi', 'Andy,', 'I', 'would', 'like', 'to', 'check', 'in', 'again', 'on', 'the', 'status', 'of', 'the', 'Health', 'Strategic', 'Initiatives', 'data', 'engineering', 'position', 'and', 'whether', 'it', 'is', 'still', 'available.', 'I', 'am', 'still', 'very', 'much', 'interested', 'in', 'the', 'position', 'and', 'I', 'look', 'forward', 'to', 'hearing', 'back', 'about', 'any', 'updates', 'on', 'the', 'situation.', 'Thanks,', 'David']
# ['Hi', 'Xiaoyi,', 'I', 'checked', 'in', 'with', 'Andy', 'yesterday,', 'and', 'he', 'responded', 'earlier', 'today.', 'According', 'to', 'him,', 'he', 'does', 'not', 'know', 'the', 'headcount', 'for', 'FY2021', 'and', 'told', 'me', 'to', 'check', 'in', 'later', 'as', 'he', 'will', 'find', 'out', 'some', 'time', 'between', 'now', 'and', 'October', '1.', 'Would', 'you', 'happen', 'to', 'know', 'how', 'long', 'does', 'this', 'usually', 'take?', 'Thanks,', 'David']
# ['Hi', 'Andy,', 'Thanks', 'for', 'the', 'update', 'about', 'the', 'situation.', 'I', 'will', 'check', 'back', 'around', '3', 'weeks', 'from', 'now,', 'or', 'some', 'time', 'during', 'the', 'week', 'of', 'September', '21,', 'if', 'you', "don't", 'mind.', 'Thanks,', 'David']
# ['Greetings', 'Andy,', 'We', 'previously', 'spoke', 'over', 'the', 'phone', 'on', 'June', '7', 'regarding', 'the', 'Health', 'Strategic', 'Initiatives', 'data', 'engineer', 'position,', 'and', 'you', 'suggested', 'that', 'I', 'contact', 'you', 'again', 'about', 'it', 'during', 'early', 'September', 'of', 'this', 'year', 'for', 'a', 'possible', 'formal', 'screening.', 'Is', 'the', 'position', 'still', 'open', 'at', 'this', 'time?', 'If', 'so,', 'what', 'would', 'be', 'the', 'next', 'step?', 'Thank', 'you', 'very', 'much.', 'David']
# ['Hi', 'Xiaoyi,', 'It', 'has', 'certainly', 'been', 'a', 'while', 'since', 'we', 'last', 'spoke,', 'so', 'thanks', 'for', 'reaching', 'out', 'to', 'me', 'and', 'for', 'the', 'reminder', 'and', 'tips!', 'My', 'apologies', 'for', 'the', 'lack', 'of', 'news', 'about', 'my', 'status', 'recently,', 'but', 'I', 'am', 'currently', 'finishing', 'up', 'the', 'last', 'week', 'of', 'my', 'summer', 'session', 'so', 'I', 'have', 'not', 'been', 'sending', 'out', 'many', 'resumes', 'for', 'the', 'last', 'couple', 'weeks.', 'I', 'plan', 'on', 'resuming', 'my', 'job', 'apps', 'after', 'this', 'week', 'once', 'I', 'have', 'more', 'time.', 'Project', 'is', 'fine.', 'I', 'was', 'simply', 'reworking', 'one', 'of', 'my', 'older', 'data', 'collection', 'projects', 'and', 'applying', 'machine', 'learning', 'techniques', 'to', 'better', 'fit', 'the', 'job', 'description,', 'but', 'there', 'is', 'still', 'more', 'I', 'plan', 'on', 'doing', 'with', 'it.', 'I', 'will', 'definitely', 'be', 'contacting', 'you', 'soon', 'about', 'apple', 'positions,', 'so', "we'll", 'be', 'in', 'touch!', 'Thanks,', 'David']
# ['Hi', 'Xiaoyi,', 'Yes,', "that's", 'basically', 'what', 'he', 'suggested:', 'to', 'talk', 'about', 'the', 'methods', 'I', 'used', 'in', 'my', 'project', 'and', 'why,', 'any', 'possible', 'issues', 'there', 'might', 'be,', 'and,', 'most', 'importantly,', 'to', 'not', 'take', 'the', 'efficiency', 'and', 'speed', 'of', 'data', 'processing', 'tools', 'for', 'granted.', 'And', 'yes,', 'I', 'intend', 'to', 'build', 'a', 'project', 'in', 'the', 'time', 'remaining', 'as', 'you', 'suggested', 'that', 'it', 'might', 'be', 'better', 'if', 'it', 'is', 'new', 'and', 'related', 'to', 'the', 'position,', 'and', 'I', 'will', 'also', 'have', 'a', 'good', 'amount', 'of', 'machine', 'learning', 'resources', 'to', 'work', 'with', 'as', 'I', 'am', 'taking', 'it', 'as', 'a', 'course', 'this', 'summer.', 'I', 'will', 'definitely', 'be', 'applying', 'for', 'more', 'positions', 'at', 'Apple', 'in', 'the', 'near', 'future,', 'so', 'thanks,', 'and,', 'again,', 'we', 'will', 'be', 'in', 'touch!', 'I', 'will', 'take', 'a', 'pause', 'for', 'maybe', 'a', 'month,', 'or', 'at', 'least', 'until', 'I', 'finish', 'this', 'summer,', 'as', 'it', 'appears', 'that', 'a', 'lot', 'of', 'data', 'positions', 'utilizes', 'machine', 'learning', 'and', 'I', 'would', 'really', 'want', 'to', 'know', 'what', 'the', 'subject', 'is', 'all', 'about.', 'David']
# ['Hi', 'Xiaoyi,', 'We', 'spoke', 'for', 'around', '40', 'minutes,', 'and', 'he', 'just', 'wanted', 'to', 'look', 'into', 'my', 'background', 'while', 'I', 'had', 'the', 'chance', 'to', 'learn', 'more', 'about', 'the', 'position.', 'There', 'was', 'actually', 'nothing', 'technical', 'about', 'it.', 'I', 'told', 'him', 'that', 'I', 'will', 'graduate', 'this', 'coming', 'December,', 'so', 'he', 'told', 'me', 'to', 'shoot', 'him', 'an', 'email', 'during', 'early', 'September', 'which', 'is', 'when', 'he', 'will', 'set', 'up', 'a', 'formal', 'interview.', "Here's", 'hoping', 'that', 'the', 'position', 'does', 'not', 'fill', 'by', 'then.', 'I', 'also', 'asked', 'him', 'about', 'the', 'interview,', 'and', 'he', 'told', 'me', 'that', 'it', 'will', 'be', 'a', '1', 'hour', 'presentation', 'about', 'one', 'of', 'my', 'projects', 'but', 'gave', 'no', 'more', 'details', 'or', 'whether', 'it', 'will', 'be', 'technical', 'or', 'not.', 'Said', 'that', 'if', 'I', 'were', 'to', 'be', 'hired', 'for', 'the', 'position,', 'I', 'would', 'be', 'someone', 'who', 'would', 'need', 'to', 'be', 'mentored', 'and', 'grow', 'in', 'the', 'position,', 'so', 'I', 'am', 'guessing', 'he', 'is', 'not', 'hiring', 'me', 'for', 'my', 'expertise.', 'I', 'assume', 'that', 'this', 'sort', 'of', 'interview', 'is', 'pretty', 'unusual', 'for', 'Apple', 'standards?', 'Regards,', 'David']
# ['Hi', 'Xiaoyi,', 'Someone', 'named', 'Andy', 'Pham', 'contacted', 'me', 'for', 'the', 'Data', 'Engineer,', 'Health', 'Strategic', 'Initiatives', 'position', '(Role', 'Number:200172241,', 'https://jobs.apple.com/en-us/details/200172241/data-engineer-health-strateg=', 'ic-initiatives?team=3DSFTWR', ').', 'We', 'arranged', 'to', 'speak', 'for', 'a', 'few', 'minutes', 'on', 'a', 'video', 'chat', 'for', 'the', 'coming', 'Tuesday', 'at', '2', 'PM.', 'I', 'am', 'guessing', 'this', 'is', 'just', 'the', 'initial', 'screening', 'to', 'see', 'whether', 'I', 'would', 'be', 'a', 'good', 'fit', 'before', 'there', 'would', 'be', 'an', 'interview.', 'Do', 'you', 'have', 'any', 'idea', 'about', 'what', 'they', 'might', 'ask', 'or', 'what', 'Apple', 'does', 'differently', 'with', 'these', 'screenings?', 'Thanks,', 'David']
# ['Hello', 'Andy,', 'Marked', 'on', 'calendar.', 'Looking', 'forward', 'to', 'speaking', 'to', 'you', 'soon.', 'David']
# ['Hi', 'Andy,', 'I', 'will', 'be', 'available', 'anytime', 'today', 'or', 'at', 'anytime', 'for', 'the', 'rest', 'of', 'this', 'week.', 'Next', 'week', 'will', 'work', 'as', 'well,', 'but', 'only', 'after', '12', 'PM', 'on', 'Tuesdays', 'and', 'Thursdays.', 'I', 'look', 'forward', 'to', 'speaking', 'with', 'you!', 'David']
# ['Hi', 'Xiaoyi,', 'Good', 'to', 'know!', 'I', 'will', 'keep', 'that', 'in', 'mind', 'when', 'applying', 'for', 'Apple', 'jobs', 'in', 'the', 'future.', 'Since', 'there', "isn't", 'many', 'job', 'postings', 'left', 'that', 'match', 'my', 'current', 'skill', 'set,', 'I', 'will', 'probably', 'take', 'a', 'hiatus', 'on', 'any', 'new', 'applications', 'at', 'Apple', 'for', 'now.', "Can't", 'thank', 'you', 'enough', 'for', 'all', 'your', 'help', 'and', 'thank', 'you', 'for', 'making', 'yourself', 'available', 'for', 'sending', 'out', 'resumes', 'for', 'me', 'in', 'the', 'future.', 'If', 'your', 'schedule', 'or', 'situation', 'permits,', 'I', 'would', 'like', 'to', 'do', 'this', 'again', 'in', 'the', 'coming', 'months,', 'assuming', 'that', 'none', 'of', 'my', 'current', 'applications', 'go', 'through.', 'Cheers,', 'David']
# ['Hi', 'Carlos,', 'It', 'has', 'been', 'a', 'while', 'since', 'we', 'took', 'linear', 'algebra', 'together', 'at', 'BCC.', 'I', 'hope', 'you', 'are', 'doing', 'well!', 'I', 'am', 'not', 'sure', 'if', 'your', 'email', 'was', 'actually', 'meant', 'for', 'me,', 'but,', 'unfortunately,', 'I', 'am', 'in', 'no', 'position', 'to', 'hand', 'out', 'job', 'opportunities', 'as', 'I', 'am', 'finishing', 'up', 'a', 'graduates', 'program', 'and', 'am', 'looking', 'for', 'work', 'positions', 'myself;', 'so', 'it', 'looks', 'like', 'we', 'are', 'pretty', 'much', 'in', 'the', 'same', 'boat!', 'Let', 'me', 'know', 'if', 'there', 'is', 'anything', 'else', 'I', 'can', 'help', 'you', 'with.', 'Cheers,', 'David', 'Liu']
# ['Xiaoyi,', 'Great!', 'Thanks', 'again.', 'David']
# ['Forgot', 'to', 'tell', 'you.', 'I', 'did', 'not', 'find', 'any', 'letters', 'for', 'you.', 'I', 'am', 'not', 'sure', 'if', 'somebody', 'else', 'is', 'keeping', 'them', 'for', 'you,', 'but', 'I', "don't", 'think', 'there', 'are', 'any', 'letters', 'that', 'has', 'your', 'name', 'on', 'it.', 'On', 'Mon,', 'May', '18,', '2020', 'at', '9:38', 'PM', 'David', 'Liu', '<david92liu@gmail.com>', 'wrote:', '>', 'Yes.', 'Okay.', 'I', 'will', 'look', 'for', 'your', 'letters.', '>', '>', 'On', 'Mon,', 'May', '18,', '2020', 'at', '7:27', 'PM', '=E6=9E=97', 'Fanny', '<lyf7272@hotmail.com>', 'wro=', 'te:', '>', '>>', 'Hi=EF=BC=81', 'David=EF=BC=9A', '>>', 'Can', 'you', 'put', 'all', 'my', 'letters', 'in', 'the', 'mailbox', 'today?', "I'll", 'get', 'it', 'tomorrow', '>>', 'morning!', 'Thank', 'you!', '>>', '>>', 'Yours.', '>>', 'Yufen', 'Lin', '>>', '>>', '=E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone', '>', '>']
# Could not be split
# ['Yes.', 'Okay.', 'I', 'will', 'look', 'for', 'your', 'letters.', 'On', 'Mon,', 'May', '18,', '2020', 'at', '7:27', 'PM', '=E6=9E=97', 'Fanny', '<lyf7272@hotmail.com>', 'wrote=', ':', '>', 'Hi=EF=BC=81', 'David=EF=BC=9A', '>', 'Can', 'you', 'put', 'all', 'my', 'letters', 'in', 'the', 'mailbox', 'today?', "I'll", 'get', 'it', 'tomorrow', '>', 'morning!', 'Thank', 'you!', '>', '>', 'Yours.', '>', 'Yufen', 'Lin', '>', '>', '=E5=8F=91=E8=87=AA=E6=88=91=E7=9A=84iPhone']
# ['Okay.', 'I', 'will', 'look', 'out', 'for', 'it.']
# Could not be split
# Could not be split
# ['Okay']
# ['It', 'looks', 'like', 'i', 'received', 'the', 'letters.', 'How', 'do', 'you', 'want', 'me', 'to', 'send', 'the', 'letters', 'back?']
# ['okay.', 'I', 'will', 'look', 'out', 'for', 'it']
# ['Hi', 'Joe,', 'In', 'that', 'case,', 'thank', 'you', 'very', 'much', 'for', 'the', 'information.', "I'll", 'definitely', 'see', 'what', 'I', 'can', 'find', 'and', 'get', 'the', 'resume', 'updated', 'and', 'going.', 'David']
# ['Hi', 'Joe,', 'I', 'was', 'recently', 'told', 'about', 'openings', 'at', 'a', 'company', 'called', 'Veeva,', 'and', 'I', 'believe', 'it', 'was', 'your', 'wife,', 'Mrs.', 'Li,', 'who', 'shared', 'this', 'information,', 'so', 'please', 'give', 'her', 'my', 'thanks.', 'I', 'had', 'a', 'chance', 'to', 'look', 'through', 'the', 'company', 'website', 'and', 'there', 'were', 'definitely', 'some', 'positions', 'and', 'roles', 'that', 'I', 'found', 'interesting.', 'However,', 'I', 'could', 'not', 'find', 'anything', 'other', 'than', 'full-time/long-term', 'positions,', 'which', 'I', 'am', 'not', 'available', 'for', 'at', 'this', 'time.', 'May', 'I', 'ask', 'that', 'she', 'clarify', 'exactly', 'what', 'the', 'new', 'positions', 'are,', 'or', 'where', 'on', 'the', 'website', 'can', 'I', 'find', 'them', 'in', 'case', 'I', 'am', 'looking', 'at', 'the', 'wrong', 'places?', 'Thank', 'you', 'very', 'much.', 'David']
# ['Hi', 'Joe,', 'I', 'figured', 'that', 'I', 'should', 'share', 'this', 'email', 'with', 'you', 'so', 'that', 'you', 'know', 'which', 'email', 'I', 'may', 'be', 'contacting', 'you', 'with,', 'and', 'to', 'make', 'sure', 'that', 'I', 'added', 'your', 'email', 'correctly.', 'Thanks', 'again', 'for', 'the', 'talk', 'and', 'for', 'the', 'tips', 'you', 'shared', 'with', 'me', 'last', 'Monday.', 'I', 'very', 'much', 'appreciate', 'it.', 'Cheers,', 'David']
# ['Join', 'Zoom', 'Meeting', 'https://csueb.zoom.us/j/554033172', 'Meeting', 'ID:', '554', '033', '172', 'One', 'tap', 'mobile', '+16699006833,,554033172#', 'US', '(San', 'Jose)', '+16465588656,,554033172#', 'US', '(New', 'York)', 'Dial', 'by', 'your', 'location', '+1', '669', '900', '6833', 'US', '(San', 'Jose)', '+1', '646', '558', '8656', 'US', '(New', 'York)', 'Meeting', 'ID:', '554', '033', '172', 'Find', 'your', 'local', 'number:', 'https://csueb.zoom.us/u/acNwdbUoa0', 'Join', 'by', 'SIP', '554033172@zoomcrc.com', 'Join', 'by', 'H.323', '162.255.37.11', '(US', 'West)', '162.255.36.11', '(US', 'East)', '221.122.88.195', '(China)', '115.114.131.7', '(India', 'Mumbai)', '115.114.115.7', '(India', 'Hyderabad)', '213.19.144.110', '(EMEA)', '103.122.166.55', '(Australia)', '209.9.211.110', '(Hong', 'Kong)', '64.211.144.160', '(Brazil)', '69.174.57.160', '(Canada)', '207.226.132.110', '(Japan)', 'Meeting', 'ID:', '554', '033', '172']
# ['User', 'name:', 'Yufenlin72', 'Password:', 'Lyf586091']
# ['Hi', 'Jamieelee,', 'Thank', 'you', 'for', 'getting', 'back', 'to', 'me.', 'My', 'netid', 'is', 'az7762.', 'I', 'was', 'initially', 'having', 'issues', 'with', 'enrolling', 'in', 'courses', 'because', 'my', 'MyCSUEB', 'site', 'did', 'not', 'include', 'a', 'student', 'tab', 'or', 'student', 'center', 'link.', 'I', 'contacted', 'Gradadmissions', 'and', 'was', 'told', 'that', 'I', 'should', 'be', 'able', 'to', 'start', 'enrolling', 'tomorrow,', 'so,', 'unless', 'if', 'there', 'is', 'anything', 'else', 'I', 'missed,', 'I', 'believe', 'I', 'should', 'be', 'fine', 'for', 'now.', 'Again,', 'thanks', 'for', 'touching', 'base', 'with', 'me', 'regarding', 'my', 'enrollment', 'issue,', 'and', 'I', 'will', 'be', 'sure', 'to', 'direct', 'any', 'of', 'my', 'future', 'correspondence', 'with', 'you', 'via', 'Horizon', 'in', 'the', 'future.']
# ['Greetings', 'Again', 'Jiming,', 'It', 'appears', 'that', 'the', 'orientation', 'registration', 'had', 'already', 'closed.', 'Would', 'it', 'be', 'possible', 'that', 'I', 'just', 'show', 'up', 'and', 'attend', 'the', 'orientation', 'anyways?', 'Otherwise,', 'is', 'there', 'any', 'other', 'way', 'I', 'can', 'register', 'at', 'this', 'point?', 'Also,', 'I', 'cannot', 'seem', 'to', 'find', 'an', 'option', 'to', 'add', 'courses', 'on', 'the', 'myCSUEB', 'site', 'using', 'the', 'instructions', 'provided', 'in', 'my', 'admissions', 'package.', 'Do', 'I', 'need', 'to', 'follow', 'additional', 'steps', 'to', 'register', 'for', 'classes', 'during', 'the', 'open', 'enrollment', 'period', 'from', 'Aug', '15', '-', '19,', 'or', 'am', 'I', 'doing', 'something', 'wrong', 'here?', 'Thanks', 'in', 'advance,', 'and', 'my', 'apologies', 'for', 'the', 'last', 'minute', 'questions.', 'It', 'was', 'a', 'bit', 'hectic', 'waiting', 'and', 'gathering', 'the', 'information', 'I', 'needed', 'to', 'make', 'a', 'decision.', 'Regards,', 'David']
# ['Greetings', 'Dr.', 'Jiming', 'Wu,', 'I', 'received', 'an', 'offer', 'for', 'admission', 'to', 'the', 'CSUEB', 'MS', 'Business', 'Analytics', 'program', 'in', 'mid', 'July', 'and', 'I', 'was', 'told', 'by', 'the', 'Graduate', 'Admission', 'office', 'that', 'there', 'is', 'no', 'deadline', 'to', 'accept', 'the', 'offer,', 'so', 'I', 'want', 'to', 'confirm', 'with', 'you', 'about', 'whether', 'this', 'information', 'is', 'accurate,', 'and', 'whether', 'there', 'are', 'any', 'information', 'about', 'any', 'deadlines', 'that', 'I', 'may', 'had', 'missed', 'regarding', 'the', 'admission', 'offer.', 'I', 'also', 'found', 'this', 'information', 'slightly', 'confusing', 'because', 'there', 'is', 'an', 'MSBA', 'program', 'orientation', 'on', '8/17,', 'and', 'I', 'cannot', 'register', 'for', 'it', 'unless', 'I', 'accept', 'my', 'offer.', 'I', 'would', 'like', 'to', 'note', 'that', 'the', 'reason', 'why', 'I', 'want', 'to', 'know', 'about', 'the', 'offer', 'acceptance', 'deadline', 'is', 'because', 'I', 'am', 'still', 'trying', 'to', 'weigh', 'my', 'options', 'and', 'I', 'probably', 'will', 'not', 'receive', 'all', 'the', 'information', 'I', 'can', 'get', 'to', 'make', 'my', 'decision', 'for', 'grad', 'school', 'until', 'during', 'or', 'after', 'the', 'week', 'of', 'August', '12.', 'Hence,', 'it', 'would', 'be', 'extremely', 'helpful', 'for', 'me', 'to', 'know', 'whether', 'this', 'may', 'pose', 'any', 'issues', 'in', 'regards', 'to', 'my', 'offer', 'acceptance.', 'Thank', 'you', 'for', 'your', 'time', 'and', 'thank', 'you', 'in', 'advance', 'for', 'any', 'information', 'that', 'you', 'may', 'provide', 'me.', 'Regards,', 'David']
# ['Hi', 'Chris,', 'You', 'mentioned', 'that', 'August', '9', 'will', 'be', 'the', 'end', 'of', 'the', 'priority', 'registration', 'period.', 'Does', 'this', 'mean', 'that', 'I', 'can', 'still', 'register', 'even', 'after', 'that', 'date,', 'but', 'minus', 'a', 'few', 'priority', 'perks,', 'or', 'is', 'it', 'absolutely', 'the', 'last', 'day', 'that', 'I', 'can', 'still', 'accept', 'an', 'offer', 'of', 'admission?', 'Also,', 'if', 'August', '9', 'really', 'is', 'the', 'last', 'date,', 'would', 'it', 'still', 'be', 'viable', 'for', 'me', 'to', 'register', 'this', 'week', 'since', 'I', 'understand', 'that', 'there', 'will', 'probably', 'be', 'some', 'prerequisites', 'or', 'processes', 'that', "I'll", 'need', 'to', 'finish', 'that', 'may', 'take', 'some', 'time,', 'such', 'as', 'mailing', 'in', 'transcripts,', 'registering', 'for', 'classes,', 'submitting', 'proof', 'of', 'immunization,', 'etc...', 'Thanks', 'in', 'advance,', 'David']
# ['Greetings', 'Sophie,', 'It', 'has', 'recently', 'been', 'brought', 'to', 'my', 'attention', 'that', 'the', 'time', 'window', 'for', 'accepting', 'my', 'admission', 'to', 'the', 'SFSU', 'MSBA', 'program', 'is', 'still', 'open.', 'I', 'am', 'wondering', 'when', 'is', 'the', 'actual', 'deadline', 'for', 'me', 'to', 'make', 'a', 'decision.', 'I', 'am', 'currently', 'still', 'weighing', 'my', 'options', 'and', 'it', 'would', 'be', 'extremely', 'helpful', 'for', 'me', 'to', 'know', 'when', 'action', 'is', 'needed', 'on', 'my', 'part.', 'For', 'instance,', 'would', 'I', 'still', 'be', 'allowed', 'to', 'make', 'a', 'decision', 'by', 'the', 'week', 'of', 'August', '12.', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Greetings,', 'It', 'has', 'recently', 'been', 'brought', 'to', 'my', 'attention', 'that', 'the', 'time', 'window', 'for', 'accepting', 'my', 'admission', 'to', 'the', 'CSUEB', 'MSBS', 'program', 'is', 'coming', 'to', 'a', 'close', 'but', 'is', 'still', 'open.', 'I', 'am', 'wondering', 'when', 'is', 'the', 'actual', 'deadline', 'for', 'me', 'to', 'make', 'a', 'decision.', 'I', 'am', 'currently', 'still', 'weighing', 'my', 'options', 'and', 'it', 'would', 'be', 'extremely', 'helpful', 'for', 'me', 'to', 'know', 'when', 'action', 'is', 'needed', 'on', 'my', 'part.', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Pretty', 'cool', 'you', 'get', 'entire', 'books.', 'Thanks!']
# ['Hi', 'Ben,', 'yes', 'I', 'will', 'be', 'available']
# Could not be split
# ['https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---256GB-SSD---Radeon-Pro-555X---Silver.product.100472319.html', '-', 'ive', 'confirmed', 'that', 'the', 'one', 'above', 'is', 'the', 'one', 'i', 'want', 'https://www.costco.com/Apple-MacBook-Pro-15.4%22-with-Touch-Bar---Intel-Core-i7---16GB-Memory---512GB-SSD---Radeon-Pro-560X---Space-Gray.product.100472395.html', '-', 'this', 'one', 'here', 'is', 'good', 'too,', 'but', 'the', 'other', 'one', 'is', 'cheaper.']
# Could not be split
# Could not be split
# ['https://slickdeals.net/f/13011733-apple-macbook-pro-with-touch-bar-fptr2ll-a-15-4-laptop-computer-apple-certified-refurbished-space-gray-1599-98?attrsrc=Test%3AHideExpiredSearch%3AControl&src=SiteSearchV2Algo1']
# ['https://www.microcenter.com/product/600944/macbook-pro-with-touch-bar-fptr2ll-a-154-laptop-computer-apple-certified-refurbished---space-gray']
# ['https://www.apple.com/shop/product/G0SF2LL/A/Refurbished-133-inch-Macbook-P=', 'ro-33GHz-Dual-core-Intel-Core-i7-with-Retina-Display-Space-Gray?fnode=3Ddb7=', 'b1e36e34e927189e9c4c5df91d78aa961b6be9d954739f3b99b5715dafbd0c9cb1f51fb42ff=', 'c44e36bafc49750a454ba7f560fb3b22d6a6e1ac7cf8ba316b41cb60ac071128a83cb14916c=', 'bafb7be']
# ['https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=', '07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=', 'INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=', 'amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4', 'this', 'one..', 'not', 'the', 'one', 'above']
# ['https://www.amazon.com/Apple-i7-7700HQ-Quad-Core-Bluetooth-Refurbished/dp/B=', '07JZXYWW4/135-5647305-5070602?ascsubtag=3Db47f47067e6511e9b8b71a5de5c8a3b20=', 'INT&SubscriptionId=3D07PVPGV9KPJSRT8N9GG2&tag=3Dslickdeals&linkCode=3Dxm2&c=', 'amp=3D2025&creative=3D165953&creativeASIN=3DB07JZXYWW4']
# ['https://www.apple.com/shop/product/G0T21LL/A/Refurbished-133-inch-Macbook-P=', 'ro-31GHz-Dual-core-Intel-Core-i5-with-Retina-Display-Silver?fnode=3D98769c7=', '052da9a6fb988727b003fb8b2e388032d5d0fde5e4890cdc5029b8d92cd91dc6b9bc8445f66=', '40e3f6fac54f2bc8fd0645a63fd5b983a4d4867c6e686fb089e6859185d916ac96d70b8253f=', '311']
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# ['Hi', 'Bill,', 'Thank', 'you', 'for', 'checking', 'in', 'with', 'me', 'and', 'my', 'apologies', 'for', 'the', 'late', 'reply.', 'I', 'have', 'very', 'recently', 'been', 'admitted', 'to', 'my', 'top', 'choice', 'graduate', 'program', 'in', 'Data', 'Science', 'and', 'will', 'no', 'longer', 'be', 'continuing', 'with', 'my', 'application.', 'Thank', 'you', 'for', 'spending', 'your', 'time', 'to', 'answer', 'the', 'questions', 'I', 'had', 'early', 'in', 'the', 'application', 'and', 'staying', 'in', 'touch', 'with', 'me', 'throughout', 'the', 'process', 'thus', 'far.', 'Regards,', 'David', 'Liu']
# ['Scincus', '-', 'get', 'rid', 'of', '3', 'and', 'dot.', '-', 'increase', 'size', 'if', 'dots', 'slightly', '-', 'fix', 'border', 'and', 'river', 'gaps', 'Keyserlingii', '-', 'slightly', 'darken', 'the', 'yellow', 'region.', '-', 'do', 'not', 'italicize', 'the', 'parenthesis', 'parts', 'in', 'legend', '-', 'fix', 'border', 'and', 'river', 'gaps', '-', 'increase', 'size', 'of', 'dots', 'slightly', '-', 'check', 'whether', 'the', 'unknown', 'region', 'is', 'correct', '-', 'fix', 'legend', 'font']
# Could not be split
# ['Greetings,', 'I', 'was', 'recently', 'admitted', 'to', 'the', 'MSDS', 'program', 'and', 'my', 'application', 'checklist', 'indicated', 'that', 'I', 'must', 'send', 'in', 'my', 'official', "Bachelor's", 'degree', 'transcript.', 'The', 'transcript', 'was', 'mistakenly', 'sent', 'electronically', 'to', 'the', 'USF', 'Office', 'of', 'Graduate', 'Admission', 'located', 'at', '2130', 'Fulton', 'Street,', 'San', 'Francisco.', 'This', 'was', 'before', 'I', 'received', 'a', 'letter', 'in', 'my', 'application', 'status', 'page', 'instructing', 'me', 'to', 'send', 'any', 'electronic', 'transcripts', 'to', 'the', 'asgraduate@usfca.edu', 'email', 'address.', 'Can', 'my', 'official', 'transcript', 'be', 'received', 'at', 'its', 'current', 'destination', 'or', 'should', 'I', 'request', 'to', 'send', 'a', 'copy', 'to', 'asgraduate@usfca.edu', 'as', 'well?', 'Thanks,', 'David', 'Liu']
# ['un:', 'david92liu@gmail.com', 'pw:', 'Ilikebagel!1', 'https://gradapply.usfca.edu/account/login?r=https%3a%2f%2fgradapply.usfca.edu%2fapply%2fstatus']
# Could not be split
# Could not be split
# Could not be split
# ['Hi', 'Victoria,', 'Thank', 'you', 'for', 'checking', 'in', 'with', 'me', 'and', 'my', 'apologies', 'for', 'the', 'late', 'reply.', 'I', 'have', 'very', 'recently', 'received', 'admissions', 'from', 'a', 'couple', 'of', 'my', 'top', 'choice', 'universities', 'and', 'will', 'no', 'longer', 'be', 'continuing', 'with', 'my', 'application.', 'However,', 'I', 'want', 'to', 'thank', 'you', 'for', 'striving', 'to', 'keep', 'me', 'in', 'close', 'communications', 'throughout', 'the', 'application', 'and', 'providing', 'me', 'with', 'the', 'information', 'I', 'need', 'to', 'weigh', 'my', 'options', 'and', 'to', 'make', 'an', 'informed', 'decision.', 'Not', 'many', 'of', 'the', 'colleges', 'I', 'applied', 'to', 'actively', 'initiated', 'conversions', 'with', 'applicants.', 'Thanks', 'again,', 'David', 'Liu']
# ['Was', 'expecting', 'something', 'like', 'CodeAcademy,', 'but', 'it', 'looks', 'like', "there's", 'a', 'lot', 'more', 'useful', 'resources', 'here', 'than', 'just', 'some', 'practices.', 'Thanks!', 'Will', 'look', 'more', 'into', 'it.']
# ['Hi', 'Victoria,', 'Thank', 'you', 'for', 'letting', 'me', 'know', 'about', 'the', 'webinar.', 'Unfortunately,', 'I', 'will', 'not', 'be', 'available', 'at', 'that', 'time', 'tomorrow.', 'Will', 'there', 'be', 'any', 'followup', 'webinars', 'in', 'the', 'near', 'future?', 'Regards,', 'David']
# ['Hi', 'Maggie,', 'Thank', 'you', 'for', 'checking', 'in', 'with', 'my', 'application', 'status.', 'I', 'have', 'very', 'recently', 'received', 'admissions', 'from', 'a', 'couple', 'of', 'my', 'top', 'choice', 'universities', 'and', 'will', 'no', 'longer', 'be', 'continuing', 'with', 'my', 'application.', 'Regards,', 'David']
# ['Hi', 'Leyla,', 'I', 'am', 'interested', 'in', 'attending', 'the', 'webinar.', 'You', 'mentioned', 'that', 'this', 'will', 'be', 'the', 'first.', 'What', 'date', 'will', 'the', 'other', 'ones', 'be', 'held', 'and', 'will', 'they', 'be', 'the', 'same', 'as', 'this', 'one?', 'Thanks.', 'David']
# Could not be split
# Could not be split
# ['testing', 'testing']
# ['Good', 'to', 'know!', 'Will', 'hear', 'from', 'you', 'tomorrow.', 'David']
# Could not be split
# ['Claremont', 'Grad.', 'Uni.', '<https://admissions.cgu.edu/account/login?r=https%3a%2f%2fadmissions.cgu.edu%2fapply%2fcertify>', 'UN:', 'david92liu@gmail.com', 'PW:', 'Ilikebagel!1']
# ['Hey', 'Bob,', 'Got', 'your', 'message.', 'Call', 'me', 'back', 'and', 'let', 'me', 'know', 'if', 'you', 'still', 'need', 'my', 'help', 'on', 'the', 'map.', 'David']
# ['Dear', 'Professor', 'Stephen', 'Devlin,', 'Thank', 'you', 'for', 'taking', 'your', 'time', 'to', 'interview', 'me', 'last', 'Thursday', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'the', 'USF', 'Data', 'Science', "Program's", 'curriculum', 'roadmap,', 'as', 'well', 'as', 'the', 'advantages', 'that', 'the', 'program', 'offers', 'its', 'students', 'in', 'terms', 'of', 'employment', 'and', 'learning', 'outcome.', 'I', 'would', 'like', 'to', 'reiterate', 'my', 'interest', 'in', 'the', "program's", 'fast-paced,', 'rigorous', 'academic', 'environment', 'and', 'in', 'the', 'hands-on', 'learning', 'approach', 'through', 'practicum', 'projects.', 'I', 'also', 'believe', 'that', 'the', "program's", 'focus', 'in', 'not', 'only', 'on', 'the', 'computational', 'aspects', 'of', 'data', 'science,', 'but', 'also', 'in', 'experimental', 'design', 'and', 'statistics,', 'would', 'be', 'uniquely', 'fitting', 'for', 'someone', 'of', 'my', 'background.', 'Although', 'my', 'primary', 'programming', 'language', 'is', 'Java,', 'I', 'realize', 'from', 'the', 'interview', 'and', 'data', 'science', 'programs', 'that', 'Python', 'is', 'the', 'preferred', 'programming', 'language', 'and', 'I', 'am', 'currently', 'taking', 'a', 'course,', 'Python', 'for', 'Data', 'Science,', 'to', 'improve', 'my', 'understanding.', 'Once', 'again,', 'thank', 'you', 'for', 'speaking', 'with', 'me', 'and', 'I', 'am', 'enthusiastic', 'about', 'the', 'possibility', 'of', 'enrolling', 'in', 'the', 'program.', 'Best', 'Regards,', 'David', 'Liu']
# ['Dear', 'Professor', 'Stephen', 'Devlin,', 'Thank', 'you', 'for', 'taking', 'your', 'time', 'to', 'interview', 'me', 'last', 'Thursday', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'the', 'USF', 'Data', 'Science', "Program's", 'curriculum', 'roadmap,', 'as', 'well', 'as', 'the', 'advantages', 'that', 'the', 'program', 'offers', 'its', 'students', 'in', 'terms', 'of', 'employment', 'and', 'learning', 'outcome.', 'I', 'would', 'like', 'to', 'reiterate', 'my', 'interest', 'in', 'the', "program's", 'fast-paced,', 'rigorous', 'academic', 'environment', 'and', 'in', 'the', 'hands-on', 'learning', 'approach', 'through', 'practicum', 'projects.', 'I', 'also', 'believe', 'that', 'the', "program's", 'focus', 'in', 'not', 'only', 'on', 'the', 'computational', 'aspects', 'of', 'data', 'science,', 'but', 'also', 'in', 'experimental', 'design', 'and', 'statistics,', 'would', 'be', 'uniquely', 'fitting', 'for', 'someone', 'of', 'my', 'background.', 'Although', 'my', 'primary', 'programming', 'language', 'is', 'Java,', 'I', 'realize', 'from', 'the', 'interview', 'and', 'data', 'science', 'programs', 'that', 'Python', 'is', 'the', 'preferred', 'programming', 'language', 'and', 'I', 'am', 'currently', 'taking', 'a', 'course,', 'Python', 'for', 'Data', 'Science,', 'to', 'improve', 'my', 'understanding.', 'Once', 'again,', 'thank', 'you', 'for', 'speaking', 'with', 'me', 'about', 'the', 'program', 'and', 'I', 'am', 'enthusiastic', 'about', 'the', 'possibility', 'of', 'enrolling', 'in', 'the', 'program.', 'Best', 'Regards,', 'David', 'Liu']
# ['Dear', 'Professor', 'Stephen', 'Devlin,', 'Thank', 'you', 'for', 'taking', 'your', 'time', 'to', 'interview', 'me', 'last', 'Thursday', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'the', 'USF', 'Data', 'Science', "Program's", 'curriculum', 'roadmap,', 'as', 'well', 'as', 'the', 'advantages', 'that', 'the', 'program', 'offers', 'its', 'students', 'in', 'terms', 'of', 'employment', 'and', 'learning', 'outcome.', 'I', 'would', 'like', 'to', 'reiterate', 'my', 'interest', 'in', 'the', "program's", 'fast-paced,', 'rigorous', 'academic', 'environment', 'and', 'in', 'the', 'hands-on', 'learning', 'approach', 'through', 'practicum', 'projects.', 'I', 'also', 'believe', 'that', 'the', "program's", 'focus', 'in', 'not', 'only', 'on', 'the', 'computational', 'aspects', 'of', 'data', 'science,', 'but', 'also', 'in', 'experimental', 'design', 'and', 'statistics,', 'would', 'be', 'uniquely', 'fitting', 'for', 'someone', 'of', 'my', 'background.', 'Although', 'my', 'primary', 'programming', 'language', 'is', 'Java,', 'I', 'realize', 'from', 'the', 'interview', 'and', 'data', 'science', 'programs', 'that', 'Python', 'is', 'the', 'preferred', 'programming', 'language', 'and', 'I', 'am', 'currently', 'taking', 'a', 'course,', 'Python', 'for', 'Data', 'Science,', 'to', 'improve', 'my', 'understanding.', 'Once', 'again,', 'thank', 'you', 'for', 'speaking', 'with', 'me', 'about', 'the', 'program', 'and', 'I', 'am', 'enthusiastic', 'about', 'the', 'possibility', 'of', 'enrolling', 'in', 'the', 'program.', 'Best', 'Regards,', 'David', 'Liu']
# ['Dear', 'Professor', 'Stephen', 'Devlin,', 'Thank', 'you', 'for', 'taking', 'your', 'time', 'to', 'interview', 'me', 'last', 'Thursday', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'the', 'USF', 'Data', 'Science', "Program's", 'curriculum', 'roadmap,', 'as', 'well', 'as', 'the', 'advantages', 'that', 'the', 'program', 'offers', 'its', 'students', 'in', 'terms', 'of', 'employment', 'and', 'learning', 'outcome.', 'I', 'would', 'like', 'to', 'reiterate', 'my', 'interest', 'in', 'the', "program's", 'fast-paced,', 'rigorous', 'academic', 'environment', 'and', 'in', 'the', 'hands-on', 'learning', 'approach', 'through', 'practicum', 'projects.', 'I', 'also', 'believe', 'that', 'the', "program's", 'focus', 'in', 'not', 'only', 'on', 'the', 'computational', 'aspects', 'of', 'data', 'science,', 'but', 'also', 'in', 'experimental', 'design', 'and', 'statistics,', 'would', 'be', 'uniquely', 'fitting', 'for', 'someone', 'of', 'my', 'background.', 'Although', 'my', 'primary', 'programming', 'language', 'is', 'Java,', 'I', 'realize', 'from', 'the', 'interview', 'and', 'data', 'science', 'programs', 'that', 'Python', 'is', 'the', 'preferred', 'programming', 'language', 'and', 'I', 'am', 'currently', 'taking', 'a', 'course,', 'Python', 'for', 'Data', 'Science,', 'to', 'improve', 'my', 'understanding.', 'Once', 'again,', 'thank', 'you', 'for', 'speaking', 'with', 'me', 'about', 'the', 'program', 'and', 'I', 'am', 'enthusiastic', 'about', 'the', 'possibility', 'of', 'enrolling', 'in', 'the', 'program.', 'Best', 'Regards,', 'David', 'Liu']
# ['maybe', 'i', 'should', 'also', 'thank', 'the', 'admissions', 'person', 'who', 'set', 'up', 'the', 'interview', 'as', 'well', 'in', 'this', 'email..', 'what', 'do', 'you', 'think', 'about', 'including', 'it.']
# ['Dear', 'Professor', 'Stephen', 'Devlin,', 'Thank', 'you', 'for', 'taking', 'your', 'time', 'to', 'interview', 'me', 'last', 'Thursday', 'and', 'allowing', 'me', 'to', 'have', 'a', 'better', 'understanding', 'of', 'the', 'USF', 'Data', 'Science', "Program's", 'curriculum', 'roadmap,', 'as', 'well', 'as', 'the', 'advantages', 'that', 'the', 'program', 'offers', 'its', 'students', 'in', 'terms', 'of', 'employment', 'and', 'learning', 'outcome.', 'I', 'would', 'like', 'to', 'reiterate', 'my', 'interest', 'in', 'the', "program's", 'fast-paced,', 'rigorous', 'academic', 'environment', 'and', 'in', 'the', 'hands-on', 'learning', 'approach', 'through', 'practicum', 'projects.', 'I', 'also', 'believe', 'that', 'the', "program's", 'focus', 'in', 'not', 'only', 'on', 'the', 'computational', 'aspects', 'of', 'data', 'science,', 'but', 'also', 'in', 'experimental', 'design', 'and', 'statistics,', 'would', 'be', 'uniquely', 'fitting', 'for', 'someone', 'of', 'my', 'background.', 'Although', 'I', 'lack', 'a', 'fluent', 'understanding', 'in', 'certain', 'preferred', 'skills,', 'such', 'as', 'in', 'Python,', 'I', 'am', 'currently', 'actively', 'taking', 'online', 'courses', 'in', 'order', 'to', 'improve', 'my', 'understanding', 'of', 'the', 'subject.', 'Once', 'again,', 'thanks', 'for', 'speaking', 'with', 'me', 'about', 'the', 'program', 'and', 'I', 'look', 'forward', 'to', 'hearing', 'about', 'the', 'final', 'admissions', 'decision.', 'Regards,', 'David', 'Liu']
# ['http://www.academia.edu/20025172/Linear_Algebra_and_Its_Applications_5th_Edition_']
# ['Greetings,', 'On', 'January', '18,', 'I', 'received', 'an', 'invitation', 'to', 'schedule', 'an', 'online', 'interview', 'for', 'my', 'MS', 'Data', 'Science', 'program', 'application.', 'I', 'set', 'up', 'the', 'interview', 'to', 'be', 'on', 'January', '24', 'at', '1', 'PM', 'and', 'received', 'an', 'email', 'that', 'confirmed', 'my', 'chosen', 'date', 'and', 'time', 'for', 'an', 'online', 'meeting', 'with', 'Prof.', 'Stephen', 'Devlin.', 'According', 'to', 'the', 'confirmation', 'email,', 'I', 'am', 'suppose', 'to', 'receive', 'a', 'followup', 'email', 'invitation', 'with', 'a', 'calendar', 'invite', 'to', 'join', 'the', 'meeting', 'on', 'Zoom', 'on', 'my', 'scheduled', 'date.', 'I', 'would', 'like', 'to', 'know', 'the', 'status', 'of', 'the', 'email', 'as', 'I', 'have', 'not', 'yet', 'received', 'it.', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Hi', 'Patrick,', 'I', 'am', 'still', 'interested', 'in', 'applying', 'for', 'the', 'MS', 'Business', 'Analytics', 'program', 'at', 'GGU,', 'although', 'it', 'might', 'take', 'some', 'time', 'to', 'get', 'all', 'my', 'materials', 'together.', 'Just', 'to', 'clarify,', 'the', 'priority', 'deadline', 'for', 'applying', 'to', 'the', 'fall', 'semester', 'is', 'in', 'August', 'correct?', 'Regards,', 'David', 'On', 'Wed,', 'Jan', '16,', '2019', 'at', '10:09', 'AM', 'Patrick', 'Gonzales', '<pgonzales@ggu.edu>', 'wrote=', ':', '>', '>', '>', '>', '>', 'Hi', 'David', ',', '>', '>', '>', 'We', 'at', 'Golden', 'Gate', 'University', 'would', 'like', 'to', 'remind', 'you', 'that', 'we', 'are', '>', 'dedicated', 'to', 'your', 'educational', 'success', 'and', 'here', 'to', 'support', 'you', 'with', 'many', '>', 'options', 'for', 'accomplishing', 'your', 'academic', 'goals.', 'As', 'your', 'Enrollment', '>', 'Counselor,', 'I', 'am', 'committed', 'to', 'helping', 'you', 'learn', 'more', 'about', 'GGU', 'and', 'determi=', 'ne', '>', 'if', 'our', 'programs', 'are', 'a', 'good', 'fit', 'for', 'you', 'and', 'your', 'goals.', '>', '>', '>', '>', '*Please', 'help', 'me', 'understand', 'your', 'current', 'educational', 'plans', 'by', 'replying', 'to', '>', 'this', 'email', 'with', 'the', 'following', 'scenario', 'that', 'best', 'represents', 'your', '>', 'situation:', '*', '>', '>', '1.', 'I', 'plan', 'to', 'apply', 'for', 'the', 'next', 'available', 'semester', '>', '>', '2.', 'I', 'am', 'interested,', 'but', 'not', 'until', 'a', 'later', 'start', 'term', '>', '>', '3.', 'I', 'have', 'postponed', 'my', 'search', 'at', 'this', 'time', '>', '>', '4.', 'I', 'intend', 'to', 'enroll', 'at', 'another', 'university', '>', '>', 'If', 'I', "don't", 'hear', 'back', 'from', 'you,', 'I', 'will', 'assume', 'you', 'are', 'still', 'interested', 'in', '>', 'Golden', 'Gate', 'University', 'but', 'not', 'at', 'this', 'time.', 'We', 'may', 'send', 'you', 'emails', 'from', '>', 'time', 'to', 'time', 'to', 'check', 'in.', 'Please', 'get', 'back', 'to', 'me', 'when', 'you', 'can.', 'I', 'look', '>', 'forward', 'to', 'working', 'with', 'you!', '>', '>', '>', '>', 'Sincerely,', '>', '>', 'Patrick', 'Gonzales', '>', '>', 'Golden', 'Gate', 'University', '>', '>', '415-442-7800', 'GGU', 'Hub', '>', '>', 'GGUAdmissions@ggu.edu', '>', '>', 'www.ggu.edu', '>', '>', 'www.ggu.edu=E2=80=9D>GGU.edu', '>', '>', '>', '*WARNING:', '*This', 'E-mail,', 'and', 'any', 'attachments,', 'are', 'covered', 'by', 'the', '>', 'Electronic', 'Communications', 'Privacy', 'Act,', '18', 'U.S.C.', '=C2=A72510-2521.', 'This', 'em=', 'ail', 'may', '>', 'contain', 'confidential', 'and', 'legally', 'privileged', 'information.', 'The', 'contents', 'of', '>', 'this', 'e-mail,', 'and', 'any', 'attachments,', 'are', 'intended', 'solely', 'for', 'the', 'use', 'of', 'the', '>', 'person', 'or', 'entity', 'to', 'whom', 'the', 'e-mail', 'was', 'addressed.', 'This', 'email', 'may', 'also', '>', 'contain', 'information', 'that', 'may', 'be', 'protected', 'by', 'the', 'attorney-client', 'privileg=', 'e,', '>', 'work-product', 'doctrine,', 'or', 'other', 'privileges,', 'and', 'may', 'be', 'restricted', 'from', '>', 'disclosure', 'by', 'applicable', 'Federal', 'and', 'State', 'laws.', 'If', 'you', 'are', 'not', 'the', '>', 'intended', 'recipient', 'of', 'this', 'email', '*you', 'are', 'advised', 'that', 'any', 'dissemination,', '>', 'distribution,', 'or', 'use', 'of', 'the', 'contents', 'of', 'this', 'message', 'is', 'strictly', 'prohibit=', 'ed*.', '>', 'If', 'you', 'received', 'this', 'e-mail', 'message', 'in', 'error,', 'please', 'contact', 'the', 'sender', 'b=', 'y', '>', 'reply', 'e-mail', 'or', 'phone.', 'Please', 'also', 'permanently', 'delete', 'all', 'copies', 'of', 'the', '>', 'original', 'e-mail', 'and', 'any', 'attachments.', '>', '>']
# ['Dear', 'CSUEB', 'Graduate', 'Admissions', 'Office,', 'I', 'am', 'applying', 'for', 'the', 'MS', 'Business', 'Analytics', 'program', 'for', 'the', 'fall', '2019', 'semester,', 'and', 'the', 'application', 'asks', 'that', 'I', 'send', 'official', 'transcripts', 'from', 'all', 'colleges', 'and', 'universities', 'attended', 'to', 'the', 'CSUEB', 'Office', 'of', 'Admissions.', 'Does', 'CSU', 'East', 'Bay', 'accept', 'E-transcripts,', 'and', 'if', 'so,', 'is', 'there', 'a', 'specific', 'email', 'address', 'that', 'I', 'can', 'send', 'my', 'official', 'transcripts', 'to?', 'If', 'not,', 'I', 'would', 'like', 'to', 'confirm', 'whether', 'the', 'address', 'listed', 'as', '"Office', 'of', 'Admission,', 'Cal', 'State', 'East', 'Bay,', '25800', 'Carlos', 'Bee', 'Blvd.,', 'Hayward,', 'CA,', '94542"', 'is', 'the', 'correct', 'address', 'to', 'send', 'my', 'transcript.', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Dear', 'Dr.', 'Jiming', 'Wu,', 'In', 'regards', 'to', 'the', 'Business', 'Analytics', "program's", 'requirements,', 'does', 'the', 'program', 'require', 'official', 'standardized', 'test', 'scores', 'from', 'applicants?', 'I', 'can', 'see', 'that', 'the', 'application', 'requires', 'manually', 'entering', 'test', 'scores', 'but', 'it', 'does', 'not', 'mention', 'needing', 'any', 'official', 'copies', 'from', 'the', 'testing', 'agencies,', 'so', 'I', 'would', 'like', 'to', 'get', 'that', 'clarified.', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Dear', 'CGU', 'Admissions', 'Office,', 'I', 'am', 'applying', 'for', 'the', 'MS', 'in', 'Information', 'Systems', '&', 'Technology', '-', 'Data', 'Science', '&', 'Analytics', 'program', 'for', 'the', 'fall', '2019', 'semester,', 'and', 'the', 'program', 'asks', 'for', 'official', 'transcripts', 'to', 'be', 'sent.', 'Does', 'CGU', 'accept', 'E-transcripts,', 'and', 'if', 'so,', 'is', 'there', 'a', 'specific', 'email', 'address', 'that', 'I', 'can', 'send', 'my', 'official', 'transcripts', 'to?', 'If', 'not,', 'I', 'would', 'like', 'to', 'confirm', 'whether', 'the', 'address', 'listed', 'as', '"CGU', 'Office', 'of', 'Admissions,', '150', 'E.', '10th', 'Street,', 'Claremont,', 'CA,', '91711"', 'is', 'the', 'correct', 'address', 'to', 'send', 'my', 'official', 'transcript', 'to.', 'Also,', 'does', 'CGU', 'allow', 'an', 'applicant', 'to', 'submit', 'transcripts', 'and', 'standardized', 'test', 'scores', 'before', 'submitting', 'the', 'application?', 'Thanks.', 'Regards,', 'David', 'Liu']
# ['Definitely,', 'it', 'has', 'been', 'a', 'while.', 'It', 'is', 'great', 'to', 'see', 'all', 'the', 'data', 'show', 'up', 'on', 'the', 'map', 'and', 'to', 'know', 'that', 'there', 'is', 'still', 'development', 'on', 'the', 'project', 'in', 'recent', 'years.', 'Hope', 'it', 'continues', 'to', 'grow,', 'and', 'maybe', 'even', 'have', 'the', 'pneumatic', 'tubes', 'that', 'were', 'discussed', 'about', 'back', 'then', 'to', 'be', 'installed', 'on', 'streets.', 'Regards,', 'David']
# Could not be split
# ['Hi', 'Jason,', 'I', 'would', 'like', 'to', 'add', 'that', 'the', 'date', 'I', 'listed', 'on', 'one', 'of', 'my', 'applications', 'is', 'inconsistent', 'with', 'the', 'one', 'on', 'the', 'attachment.', 'In', 'my', 'application', 'to', 'the', 'University', 'of', 'Southern', 'California', '(USC),', 'I', 'listed', 'it', 'as', 'June', 'to', 'September', 'as', 'oppose', 'to', 'July', 'to', 'September.', 'If', 'this', 'school', 'happens', 'to', 'contact', 'you', 'and', 'they', 'mention', 'June', '-', 'September,', 'let', 'them', 'know', 'that', 'I', 'acknowledge', 'the', 'inconsistency', 'and', 'you', 'can', 'correct', 'them.', 'The', 'application', 'does', 'not', 'seem', 'to', 'provide', 'any', 'followup', 'methods', 'to', 'edit', 'experiences', 'after', 'submission.', 'Thanks.', 'Regards,', 'David']
# Could not be split
# Could not be split
# ['Hi', 'Jason,', 'Thank', 'you', 'so', 'much', 'for', 'getting', 'back', 'to', 'me', 'and', 'for', 'making', 'yourself', 'available', 'as', 'a', 'contact.', 'Below', 'is', 'a', 'brief', 'summary', 'of', 'what', 'I', 'can', 'recall.', 'I', 'was', 'a', 'volunteer', 'intern', 'for', 'approximately', 'two', 'months', 'to', 'help', 'build', 'a', 'traffic', 'count', 'database', 'for', 'an', 'interactive', 'count', 'map', 'project.', 'I', 'believe', 'I', 'started', 'on', 'the', 'day', 'listed', 'on', 'the', 'application,', 'which', 'is', '7/30/2012,', 'and', 'worked', 'until', '9/28/2012', 'for', 'about', '10-15', 'hours', 'a', 'week.', 'I', 'looked', 'through', 'years', 'and', 'months', 'of', 'traffic', 'documents', 'and', 'surveys,', 'each', 'of', 'which', 'contains', 'pedestrian,', 'bicycle,', 'and', 'vehicle', 'counts', 'of', 'a', 'specific', 'street', 'intersection', 'in', 'Oakland,', 'and', 'I', 'added', 'those', 'information', 'onto', 'an', 'excel', 'spreadsheet.', 'Let', 'me', 'know', 'if', 'there', 'are', 'any', 'more', 'information', 'that', 'you', 'might', 'need', 'that', 'can', 'help', 'you', 'in', 'any', 'way.', 'Again,', 'thank', 'you', 'so', 'much', 'for', 'making', 'yourself', 'available', 'for', 'my', 'application.', 'Kind', 'regards,', 'David']
# ...
# ['Hi', 'Shan,', 'As', 'I', 'had', 'mentioned', 'a', 'couple', 'months', 'prior,', 'as', 'a', 'part', 'of', 'my', 'plan', 'to', 'make', 'time', 'to', 'pursue', 'my', 'educational', 'and', 'career', 'goals,', 'I', 'need', 'to', 'make', 'revisions', 'to', 'my', 'weekly', 'working', 'schedule.', 'So', 'from', 'this', 'point', 'forth,', 'I', 'will', 'be', 'available', 'to', 'work', 'each', 'week', 'on-call', 'on', 'the', 'following', 'days:', 'Tuesday,', 'Thursday,', 'Friday,', 'and', 'conditionally', 'on', 'Saturday.', 'Regards,', 'David', 'Liu']
# ['Looks', 'like', 'everything=E2=80=99s', 'covered.', 'I', 'will', 'also', 'be', 'free', 'if', 'I=E2=80=99m', 'n=', 'eeded', 'for', 'any', 'reason.=20', 'David', 'Sent', 'from', 'my', 'iPhone', '>']
# ['keyboard', 'and', 'mouse', 'https://www.amazon.com/dp/B00NLZUM36/?tag=pcpapi-20']
# ['motherboard', 'https://www.newegg.com/Product/Product.aspx?Item=N82E16813130935&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=', 'RAM', 'https://www.newegg.com/Product/Product.aspx?Item=N82E16820232419&ignorebbr=1&nm_mc=AFC-C8Junction&cm_mmc=AFC-C8Junction-PCPartPicker,%20LLC-_-na-_-na-_-na&cm_sp=&AID=10446076&PID=3938566&SID=']
# ['Submitted.']
# ['Hey', 'Ratthanan,', 'The', 'writeup', 'looks', 'good!', 'I', 'will', 'go', 'ahead', 'and', 'send', 'it', 'in', 'in', 'maybe', 'about', 'half', 'an', 'hour.', 'But', 'until', 'then,', 'let', 'me', 'know', 'if', 'you', 'still', 'want', 'anything', 'changed.', 'David']
# ['Hey', 'Ratthanan,', 'Just', 'shared', 'a', 'doc', 'with', 'you.', 'You', 'can', 'ignore', 'this', 'email', 'if', 'you', 'got', 'it.', 'If', 'not,', 'let', 'me', 'know.', 'David']
# ['Woops.', "Didn't", 'check', 'my', 'email', 'yesterday.', 'Also', 'got', 'home', 'a', 'bit', 'late.', 'Let', 'me', 'kno=', 'w', 'if', 'you', 'still', 'need', 'me,', 'in', 'which', 'case', "I'll", 'just', 'call', 'you', 'later', 'today.', 'Sent', 'from', 'my', 'iPhone', '>']
# ['Hey', 'Jihyun,', 'Finally', 'got', 'to', 'write', 'up', 'a', 'response.', 'Go', 'ahead', 'and', 'look', 'it', 'over', 'and', 'see', 'if', "you'd", 'like', 'to', 'add', 'anymore', 'comments', 'for', 'your', 'part,', 'and', "I'll", 'probably', 'do', 'the', 'same.', 'Otherwise,', 'I', 'think', 'we', 'got', 'a', 'pretty', 'good', 'piece', 'for', 'submission.', 'David']
# ['Hey', 'Bob,', 'Just', 'a', 'bit', 'of', 'clarification', 'for', 'the', 'last', '6', 'emails', 'I', 'sent', 'you', 'in', 'the', 'last', '20', 'minutes', 'or', 'so.', 'The', 'emails', 'that', 'says', '"PDF', 'versions"', 'and', '"TIF', 'versions"', 'on', 'the', 'subject', 'line', 'are', 'probably', 'the', 'ones', 'you', 'want', 'to', 'look', 'at.', 'The', 'ones', 'that', 'says', '"Word', 'versions"', 'are', 'the', 'original', 'files', 'in', 'which', 'I', 'used', 'to', 'create', 'the', 'PDFs', 'and', 'TIFs.', 'You', 'may', 'look', 'at', 'those', 'only', 'if', "you're", 'planning', 'on', 'making', 'some', 'adjustments', 'or', 'corrections.', 'cheers,', 'David']
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# ['Also,', 'let', 'me', 'know', 'whether', 'you', 'agree', 'that', 'this', 'article', 'is', 'considered', 'a', 'math', 'article.']
# ['Hey', 'Alex,', 'Lets', 'get', 'the', 'ball', 'rolling.', "I've", 'decided', 'to', 'go', 'with', 'a', 'question', 'involving', '"news', 'story', 'with', '(interesting,', 'confusing,', 'problematic)', 'use', 'of', 'math".', 'If', 'you', 'have', 'another', 'question', 'in', 'mind,', 'feel', 'free', 'to', 'share', 'it.', 'We', 'can', 'later', 'decide', 'which', 'question', 'would', 'be', 'the', 'easiest', 'to', 'work', 'off', 'of.', 'Otherwise,', 'feel', 'free', 'to', 'reply', 'to', 'my', 'email', 'with', 'your', 'response', 'to', 'my', 'prompt.', 'Initiator:', 'David', 'Liu', 'Responder:', 'Alex', 'Alba', 'Date:', '9/6/2017', 'Topic:', 'News', 'story', 'with', '(interesting,', 'confusing,', 'problematic)', 'use', 'of', 'math:', 'plastic-contaminated', 'water', 'Source:', 'Magness,', 'Josh.', 'Billions', 'are', 'drinking', 'water', 'contaminated', 'with', 'plastic', '-', 'and', 'US', 'has', 'it', 'the', 'worst,', 'study', 'finds.', 'September', '6,', '2017', 'http://www.sacbee.com/latest-news/article171475582.html', 'So', 'I', 'found', 'this', 'article', 'about', 'plastic', 'contamination', 'in', 'the', "world's", 'water', 'supply.', 'In', 'the', 'study', 'in', 'which', 'the', 'article', 'is', 'based', 'on,', '159', 'tap', 'water', 'samples', 'in', 'total', 'were', 'tested', 'from', 'five', 'different', 'continents.', 'The', 'overall', 'result', 'is', 'that', '83%', 'of', 'the', 'samples', 'were', 'contaminated', 'with', 'plastic.', 'The', 'water', 'with', 'the', 'lowest', 'contamination', 'rate', 'was', 'collected', 'from', 'Europe,', 'which', 'had', 'a', '72%', 'contamination,', 'whereas', 'the', 'United', 'States', 'had', 'the', 'highest', 'contamination', 'at', '94%.', 'I', 'did', 'not', 'read', 'the', 'original', 'manuscript,', 'but,', 'without', 'knowing', 'the', 'methods', 'used', 'in', 'the', 'experiment,', 'I', 'would', 'take', 'the', 'results', 'from', 'this', 'study', 'with', 'a', 'grain', 'of', 'salt.', 'The', 'overall', 'contamination', 'rate', 'is', 'way', 'too', 'high', 'to', 'be', 'believable', 'and', 'to', 'have', 'not', 'done', 'something', 'to', 'us', 'already.']
# ['Hi', 'Bob,', 'All', 'is', 'well.', 'So', 'I', 'will', 'refer', 'to', 'this', 'doc', 'instead', 'of', 'the', 'old', 'one', 'then.', 'I', 'will', 'look', 'through', 'it', 'as', 'soon', 'as', 'I', 'can.', 'Thanks,', 'David']
# ['Hey', 'bob,', 'Great', 'to', 'hear', 'from', 'you.', "Can't", 'help', 'at', 'the', 'moment.', 'Will', 'be', 'home', 'at', 'probably', 'a=', 'round', '6-7.', 'Will', 'call', 'you.', 'Otherwise', 'you', 'can', 'call', 'me', 'if', 'you', 'still', 'need', 'help', 'w=', 'ith', 'the', 'scans.', 'David=20', 'Sent', 'from', 'my', 'iPhone', '>']
# ['Almost', 'forgot.', 'Checking', 'in', 'to', 'let', 'you', 'know', 'the', 'assignment', 'was', 'submitted.']
# ['Also.', 'Let', 'me', 'know', 'if/when', 'you', 'decide', 'to', 'submit', 'it.']
# ['Hey', 'Sam,', 'Lets', 'put', 'the', 'connection', 'document', 'together.', 'I', 'was', 'thinking', 'that', 'you', 'can', 'put', 'all', 'the', 'parts', 'you', 'want', 'to', 'include', 'in', 'a', 'word', 'doc', 'first', 'since', 'you', 'initiated', 'the', 'question', 'on', 'Monday.', 'Then', 'you', 'can', 'send', 'the', 'word', 'doc', 'to', 'me', 'and', "I'll", 'add', 'my', 'parts', 'to', 'it.', 'Content-wise,', 'I', 'think', 'the', 'short', 'exchange', 'we', 'had', 'over', 'emails', 'on', 'Monday', 'would', 'do', 'just', 'fine', 'as', 'our', 'connection.', 'At', 'least', 'I', 'know', "I'll", 'just', 'be', 'copy-pasting', 'my', 'part', 'onto', 'the', 'connection', 'doc.', 'You', 'may', 'change', 'and', 'correct', "your's", 'to', 'your', 'liking.', 'David']
# ['I', 'see.', "I'm", 'going', 'to', 'assume', 'that', 'our', 'textbook', 'is', 'probably', 'more', 'theory-based', 'compared', 'to', 'those..', 'which', 'is', 'still', 'good', 'in', 'its', 'own', 'ways.', 'Thanks', 'for', 'letting', 'me', 'know.', "I'll", 'look', 'into', 'them.']
# ['Haha.', 'I', 'think', 'you', 'just', 'initiated', '#5,', 'although', 'I', 'guess', 'it', 'fits', 'into', '#2', 'as', 'well,', 'so', 'here', 'are', 'my', 'thoughts', 'in', 'response', 'to', 'your', 'initial', 'question.', 'I', "don't", 'think', 'it', 'really', 'matters', 'exactly', 'what', 'book', 'we', 'use', 'as', 'long', 'as', 'it', 'does', 'the', 'job', 'in', 'helping', 'us', 'learn.', 'I', 'personally', 'like', 'to', 'have', 'a', 'decent', 'variety', 'of', 'textbooks', 'to', 'work', 'off', 'of', 'in', 'case', 'if', 'one', 'just', "doesn't", 'cut', 'it.', 'In', 'this', 'case,', 'I', 'would', 'just', 'use', 'our', 'textbook', 'for', 'this', 'class', 'mainly', 'for', 'doing', 'the', 'exercises,', 'and', 'probably', 'another', 'textbook', 'to', 'explain', 'the', 'materials', 'if', "our's", "doesn't", 'do', 'it', 'well', 'enough', '(By', 'the', 'way,', 'let', 'me', 'know', 'of', 'these', 'other', 'textbooks', "you're", 'referring', 'to).', 'So', 'more', 'unconventional', 'books', 'I', 'have', 'knowledge', 'of,', 'the', 'better', 'I', 'suppose.', 'Even', 'so,', 'to', 'be', 'absolutely', 'fair,', 'our', 'current', 'textbook', "isn't", 'completely', 'out-of-the-way.', 'As', 'I', 'was', 'researching', 'for', 'some', 'pdfs', 'and', 'partial', 'texts', 'of', 'our', 'current', 'textbook,', 'there', 'were', 'definitely', 'a', 'few', 'online', 'forums', 'and', 'threads', 'that', 'recommended', 'using', 'this', 'textbook', 'to', 'get', 'started', 'on', 'learning', 'linear', 'algebra.', 'So', 'definitely', 'not', 'a', 'bad', 'book.']
# ['Hey', 'Sam,', 'Lets', 'get', 'the', 'ball', 'rolling', 'on', 'the', 'assignment.', 'For', 'our', 'connection', 'options,', 'I', 'think', 'we', 'can', 'eliminate', '#6', 'and', '7', 'since', 'I', 'doubt', 'either', 'of', 'us', 'would', 'want', 'to', 'go', 'through', 'the', 'trouble', 'of', 'interviewing', 'community', 'members', 'or', 'attending', 'special', 'community', 'events.', 'Some', 'of', 'them,', 'like', '#1,', 'is', 'a', 'bit', 'open', 'ended.', 'So', 'I', 'was', 'thinking', 'of', 'maybe', 'choosing', 'between', '#2,', '#3,', 'or', '#5.', 'Let', 'me', 'know', 'what', 'you', 'think', 'and/or', 'disagree', 'with', 'any', 'of', 'these', 'ideas.', 'David']
# ['Hi', 'Casey,', 'First', 'Name/Last', 'Name:', 'David', 'Liu', 'Zip', 'Code:', '94546', 'Below', 'is', 'a', 'direct', 'copy', 'of', 'the', 'subscription', 'confirmation.', 'Thank', 'you', 'for', 'your', 'help!', '___________________________________________________________________________=', '_____________', '[image:', 'Apple]', 'Subscription', 'Confirmation', '[image:', 'HBO', 'NOW=E2=84=A0]', 'HBO', 'NOW=E2=84=A0', 'HBO', 'NOW=E2=84=A0', '(1', 'month)', 'Free', 'Trial', 'Dear', 'Audrey,', 'You=E2=80=99ve', 'purchased', 'the', 'following', 'subscription', 'with', 'a', '1', 'month', 'free', 'tri=', 'al:', '*Subscription*', 'HBO', 'NOW=E2=84=A0', '*App*', 'HBO', 'NOW:', 'Stream', 'original', 'series,', 'hit', 'movies', '&', 'more', '*Content', 'Provider*', 'HBO', 'Digital', 'Services,', 'Inc.', '*Date', 'of', 'Purchase*', 'Aug', '11,', '2017', '*Duration*', '1', 'month', '*Trial', 'Duration*', '1', 'month', '*Price*', '$14.99', '*Payment', 'Method*', 'Visa', '....', '8668', 'You', 'won=E2=80=99t', 'be', 'charged', 'for', 'your', 'free', 'trial.']
# Could not be split
# ['Hey', 'Bob,', "It's", 'been', 'a', 'while.', 'Great', 'to', 'hear', 'from', 'you.', 'Very', 'sorry', 'for', 'missing', 'your', 'call.', 'I', 'was', 'busy', 'working', 'with', 'a', 'couple', 'others', 'when', 'you', 'called', 'and', "we've", 'only', 'finished', 'just', 'now.', 'Heard', 'You', 'mentioned', 'something', 'about', 'helping', 'out', 'a', 'student.', 'I', 'tried', 'calling', 'you', 'a', 'couple', 'times', 'but', 'you', "didn't", 'pick', 'up.', 'Give', 'me', 'a', 'call', 'if', 'you', 'still', 'need', 'me.', 'David']
# ['Hey', 'Ben,', 'Not', 'sure', 'if', 'Alvin', 'notified', 'you', 'yet,', 'but', 'I', 'told', 'him', 'that', 'I', 'am', 'willing', 'to', 'switch', 'my', 'Sunday', 'in', 'July', 'with', 'his,', 'and', 'I', 'believe', 'he', 'is', 'fine', 'with', 'the', 'switch.', 'So', 'unless', 'he', 'said', 'otherwise,', 'would', 'it', 'be', 'fine', 'if', 'I', 'switch', 'my', 'date', '(7/2)', 'with', 'his', '(7/23).', 'David']
# ['-Alvin', 'That', 'would', 'be', '7/2,', 'the', 'first', 'Sunday', 'in', 'July.']
# ['Hi', 'Alvin,', 'I', 'can', 'switch', 'with', 'you', 'if', "you're", 'still', 'looking', 'for', 'a', 'replacement.', 'David']
# ['Hi', 'Genevieve,', 'My', 'apologies', 'for', 'the', 'late', 'reply.', 'Thank', 'you', 'very', 'much', 'for', 'your', 'time', 'and', 'for', 'letting', 'me', 'know', 'about', 'this', 'opportunity.', 'Unfortunately,', 'I', 'am', 'currently', 'not', 'available', 'for', 'a', 'position', 'with', 'a', 'weekend', 'time', 'schedule.', 'However,', 'I', 'may', 'be', 'in', 'the', 'near', 'future', 'or', 'for', 'any', 'other', 'opportunities', 'for', 'that', 'matter.', 'I', 'would', 'love', 'to', 'keep', 'in', 'touch', 'and', 'to', 'hear', 'or', 'ask', 'about', 'any', 'future', 'openings', 'at', 'Counsyl', 'if', 'that', 'is', 'fine', 'with', 'you.', 'Thanks,', 'David']
# ['Medical', 'Records', 'Alta', 'Bates', 'Campus', '510-204-1440', 'Summit', 'Campus', '510-869-6545']
# ['Hey', 'bob,', 'Tried', 'to', 'return', 'your', 'call', 'just', 'now.', 'Not', 'sure', 'if', 'you', 'got', 'it.', 'Currently', 'not', 'at', 'home', 'right', 'now,', 'but', 'call', 'or', 'email', 'me', 'if', 'you', 'need', 'me.', 'David']
# ['Hey', 'Bob.', 'Looks', 'like', 'I', 'missed', 'your', 'message', 'last', 'night.', 'Hope', 'you', 'got', 'what', 'you', 'needed,', 'or', 'let', 'me', 'know', 'if', 'you', 'still', 'need', 'to', 'have', 'some', 'searching', 'done.', 'David']
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# Could not be split
# ['Quite', 'a', 'contrast', 'between', 'the', 'two', 'news.', 'Truly', 'sorry', 'to', 'hear', 'about', 'the', 'first', 'one.', 'I', 'know', 'there', "isn't", 'much', 'I', 'can', 'help', 'with', 'the', 'things', 'you', 'mentioned,', 'but', 'please', 'let', 'me', 'know', 'if', 'there', 'is', 'anything', 'you', 'want', 'to', 'talk', 'about.', 'David']
# ['Hey', 'bob,', 'Seems', 'like', 'I', 'missed', 'a', 'few', 'of', 'your', 'calls', 'recently.', 'I', 'was', 'out', 'most', 'of', 'yesterday', 'and', 'will', 'be', 'out', 'for', 'most', 'of', 'today', 'as', 'well.', 'Let', 'me', 'know', 'the', 'news', 'via', 'email', 'if', 'you', 'can.', 'Or', 'I', 'might', 'be', 'free', 'later', 'tonight.', 'David']
# Could not be split
# ['Hey', 'Bob,', 'Missed', 'your', 'call', 'earlier', 'so', 'I', 'thought', "I'd", 'return', 'it.', 'Nobody', 'picked', 'up.', 'In', 'any', 'case,', 'got', 'your', 'call', 'from', 'a', 'few', 'days', 'back.', 'Just', 'letting', 'you', 'know', 'that', "I've", 'enrolled', 'in', 'Biosci34.', 'David']
# ['Hi', 'Levar,', 'I', 'got', 'your', 'call', 'on', 'Monday', 'regarding', 'possible', 'new', 'openings', 'and', 'my', 'current', 'employment', 'status.', 'I', 'could', 'not', 'get', 'a', 'chance', 'to', 'call', 'you,', 'so', 'I', 'figured', 'that', 'I', 'will', 'just', 'email', 'you', 'instead.', 'Sorry', 'for', 'the', 'late', 'response.', 'Firstly,', 'thank', 'you', 'for', 'checking', 'back', 'up', 'on', 'me', 'about', 'my', 'current', 'job', 'situation!', 'I', 'am', 'still', 'currently', 'working', 'full', 'time', 'at', 'the', 'same', 'company', 'from', 'about', 'a', 'year', 'ago', 'and', 'I', 'probably', "won't", 'be', 'searching', 'for', 'any', 'new', 'employment', 'opportunities', 'at', 'least', 'for', 'the', 'next', 'few', 'months.', 'I', 'will', 'surely', 'contact', 'you', 'again', 'once', 'I', 'get', 'back', 'into', 'job', 'searching.', 'You', 'mentioned', 'something', 'about', 'referrals.', 'Do', 'you', 'mean', 'referrals', 'for', 'anybody', 'I', 'know', 'who', 'would', 'be', 'interested', 'in', 'job', 'opportunities?', 'If', 'yes,', 'I', "don't", 'currently', 'know', 'many', 'who', 'are', 'looking', 'for', 'laboratory', 'positions,', 'unless', 'maybe', 'you', 'have', 'other', 'listings.', 'However,', 'I', 'can', 'still', 'check', 'around.', 'Otherwise,', 'let', 'me', 'know', 'what', 'you', 'mean', 'by', 'that.', 'Regards,', 'David', 'Liu', 'Tel:', '510-219-5580', '<(510)%20219-5580>']
# Could not be split
# ['https://www.rootsforreal.com/', 'www.forensicmag.com/article/2013/04/challenges-dna-testing-and-forensic-analysis-hair-samples', 'http://www.legalgenealogist.com/2012/06/03/dna-and-the-locks-of-hair/']
# ['https://www.fullgenomes.com/']
# ['http://www.calacademy.org:8080/sites/default/files/assets/docs/pdf/occ_pap_161_2013_swa_bib_2nd_ed_web_version.pdf']
# Could not be split
# Could not be split
# Could not be split
